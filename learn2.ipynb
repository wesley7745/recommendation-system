# %% [markdown]
# # 學習資源推薦系統專案---恆逸網站爬蟲

# %% [markdown]
# # 1.爬取數據分析與商業智慧 Data Analysis & Business Intelligence課程

# %% [markdown]
# 程式碼說明:
#
# 1. **讀取並解析文件內容**：
#     - 打開並讀取指定文件的內容，將其存儲在`file_content`變量中。
#
# 2. **使用正則表達式查找目標節點**：
#     - 使用正則表達式在文件內容中查找"數據分析與商業智慧 Data Analysis & Business Intelligence"及其子節點。
#
# 3. **解析匹配的子節點並生成課程網址**：
#     - 提取並解析匹配的子節點為JSON格式，生成每個課程的URL列表。
#
# 4. **定義爬取課程詳細信息的函數**：
#     - 從給定的URL爬取課程詳細信息，包括標題、課程時長、課程費用、適合對象和課程大綱。
#
# 5. **爬取所有課程並保存到Excel文件**：
#     - 遍歷所有URL，爬取課程詳細信息，將所有課程信息保存到Excel文件`courses_details4.xlsx`中。

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到 "數據分析與商業智慧 Data Analysis & Business Intelligence" 的節點及其 children 節點
search_pattern = re.compile(r'{"id":"\{J\}23","typeName":"JobCategory","pkid":23,"text":"數據分析與商業智慧 Data Analysis & Business Intelligence","children":(\[.*?\])', re.DOTALL)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print("未找到 '數據分析與商業智慧 Data Analysis & Business Intelligence' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details4.xlsx', index=False)
    print("Data saved to courses_details4.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     ChatGPT與Excel整合實戰
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望學習如何使用Excel進行基本的數據處理的初學者對ChatGPT和Excel整合感興趣的個人與專業人士希望提高Excel數據處理技能，並將ChatGPT整合到他們的工作中希望了解如何使用ChatGPT和Excel提高工作效率
# DocumentBOX Outline: ChatGPT簡介和基本原理ChatGPT x Excel公式的應用ChatGPT x Excel函數的應用ChatGPT x Excel功能的應用ChatGPT x Excel巨集的應用
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Python中文自然語言NLP深度學習專家課程
#
#
# Course duration: 28小時
# Course cost: NT$ 24,000
# Target audience: 高階軟體開發工程師大數據相關研發人員或資料科學家統計/數值分析研究人員中文自然語言處理專家大型語言模型微調專家大型語言模型 RAG 架構專家
# DocumentBOX Outline: 1.AI下一世代：ChatGPT的崛起● 自然語言處理、自然語言理解和自然語言生成2.文字資料採集● 深入Python爬蟲Crawler框架和MongoDB非結構化資料庫建構● 收集巨量資料集，並進行文字資料清洗3.機器學習快速上手● 決策樹（Decision Tree）、隨機森林（Random Forest）和梯度下降（Gradient Descent）4.機率生成模型與分類模型● 貝氏分類（Bayesian Classification）在中文語意的應用場景5.關聯字詞模型訓練● 中文斷詞、斷句和詞彙Tokenization，實作Word2Vec、Doc2Vec、Ckip和Transformers6.文章分類模型訓練● 詞袋模型（Bag of Words）、TF-IDF詞頻分類法、Naive Bayes分類器和XGBoost分類器7.情感分析模型訓練● Fine-tuning HuggingFace上的模型於中文長短句的正負面機率● 使用Google Play Store留言，實作Keras/Tensorflow RNN情感程度模型訓練8.暱稱/姓名預測性別男女模型● 訓練中、英文姓名男女分類判別● 建立文字檔案以查找分群的標籤9.自然語言處理個案研究● 中文姓名預測API，以Python Flask為例● 自然語言文章分類在廣告標籤投放的應用● Facebook/Instagram留言探針時刻監測品牌危機● 留言情感分析在品牌策略操作上的處理● PTT新聞摘要與關聯10.如何微調ChatGPT模型，讓它認識你的產業知識?● 通用人工智慧 (Artificial General Intelligence)● 大型語言模型(LLM)需要準備的資料集指引，套用自己的資料集● 從ChatGPT 4前往Llama 2實作遷移式學習● 微調(Fine-tuning) OpenAI 模型，提供問答助手11.延伸大語言模型 (LLM) 擴增(RAG) 知識● 結合知識檢索的 OpenAI 生成技術● 提示詞工程(Prompt Engineering) 使用 LangChain 與 LlamaIndex● 事實查核避免 AI 幻想 (Fact-checking of ChatGPT and LLMs)● 部署地端大型語言模型 (GGUF)
# Title of the webpage:
#
#     Python與資料處理實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 具有簡單代數統計能力，並具有程式基礎的工程師，資料分析師，數據分析師
# DocumentBOX Outline: Python的環境安裝與IDE設定Python與物件導向Python與IPython NotebookPython與地圖的處理Python與地理位置的編碼Python與Excel的連結使用Scipy處理資料Python與Wiki的資料存取Python與背景狀態的更新Python與圖的處理Python與資料分析Python的ORM與SQL Server的連結Python與Apache Spark的結合
# Title of the webpage:
#
#     使用Spring Framework 5開發企業級應用程式
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要了解如何以Spring Framework開發企業Web應用程式的開發人員
# DocumentBOX Outline: 簡介Spring Framework 5Spring 元件與IoC容器Spring BootDependency InjectionSpring AOP(Aspect Oriented Programming)Spring整合資料庫交易控管Spring Data JPASpring整合MongoDBSpring與訊息(Message)整合Spring Web MVCSpring SecuritySpring Batch
# Title of the webpage:
#
#     Angular搭配Java EE開發現代化的Web應用程式
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 網頁前端工程師、後端工程師
# DocumentBOX Outline: Angular 7簡介Java EE 8簡介CDI(Context and Dependency Injection)EJB LiteJPA(Java Persistence API)Microservice與MicroProfileJSON-PJSON-BJAX-RS開發Restful Web ServiceMVC Pattern前端MVC框架與後台MVC框架比較TypeScript基礎Angular CLIAngular基礎Angular Data BindingAngular表單Angular呼叫Restful Web ServiceSecurity
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     爬蟲與社群聆聽視覺化分析實務課程-使用Python
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: 已經有Python或其他程式語言基礎或有獨立開發或管理過小型軟體專案者，對於爬蟲初次接觸，或無撰寫過爬蟲經驗者，課程將深入淺出引導關鍵程式，從無到有學習爬蟲腳本、非結構化(NoSQL)資料庫，成為大數據分析社群分析的領先者。
# DocumentBOX Outline: 社群網路- Social Network爬蟲技術，採集、清洗、儲存、運算Python, MongoDB, PHP, Apache環境準備與安裝Python Scrapy爬蟲實作PHP爬蟲實作社群發文、留言分析社群Dashboard-視覺化呈現爬蟲應用-輿情分析、即時、非即時品牌災難應變-以啤酒代言人專案為例
# Title of the webpage:
#
#     BigData入門-Hadoop與Spark介紹
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想要了解Big Data架構的系統管理人員2.想要了解Hadoop/Spark開發架構的程式開發人員3.想要了解Hadoop/Spark架構的資料分析人員
# DocumentBOX Outline: 1.BigData架構介紹●Hadoop生態系2.Hadoop架構介紹●HDFS●MapReduce(MR v2)開發框架●Spark開發框架3.Spark程式開發●Spark core語法介紹-RDD●DataFrame/DataSet●Spark SQL4.Hadoop資料分析●探索式分析●Hive(HQL)5.Hadoop機器學習●Spark MLlib
# Title of the webpage:
#
#     Python資料分析工具-使用Matplotlib、Numpy、Pandas
#
#
# Course duration: 21小時
# Course cost: NT$ 18,000
# Target audience: 想要了解資料分析的程式開發人員想要了解如何使用Python進行資料分析的資料分析人員
# DocumentBOX Outline: 探索式資料分析概論Numpy介紹Matplotlib基礎Matplotlib進階Pandas基礎-SeriesPandas基礎-DataFramePandas進階Pandas時間序列
# Title of the webpage:
#
#     ChatGPT與Excel整合實戰
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望學習如何使用Excel進行基本的數據處理的初學者對ChatGPT和Excel整合感興趣的個人與專業人士希望提高Excel數據處理技能，並將ChatGPT整合到他們的工作中希望了解如何使用ChatGPT和Excel提高工作效率
# DocumentBOX Outline: ChatGPT簡介和基本原理ChatGPT x Excel公式的應用ChatGPT x Excel函數的應用ChatGPT x Excel功能的應用ChatGPT x Excel巨集的應用
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# DocumentBOX Outline: 介紹什麼是Microsoft Power Platform(Introduction to Microsoft Power Platform)如何使用Microsoft Dataverse資料中心來進行資料庫的設計(Work with Microsoft Dataverse)如何使用Power Apps的model-driven apps來建立資料中心的後台資料中心處理的應用系統(Make model-driven apps with Power Apps)如何使用Power Apps的畫布應用工具來設計並開發客製化前端的使用者介面(Make canvas apps with Power Apps)如何使用Power Apps的入口網站開發工具來開發企業所需的應用系統入口網站(Make portals with Power Apps)介紹什麼是Microsoft Power automation (Introduction to automation)如何使用Power Automate的設計工具來設計開發雲端的自動化服務(Build cloud flows with Power Automate)如何使用Power Automate的桌面設計工具來設計整合地端桌面服務的自動化流程(Build desktop flows with Power Automate)如何設計在Model-Driven Apps的商務處理流程(Build business process flows)如何使用Power Virtual Agents來設計開發自訂的聊天機器人(Build chatbots with Power Virtual Agents)如何使用Power BI來設計開發資料的分析(Analyze data with Power BI)如何利用所有的工具來設計建立整體的應用系統(Putting it all together)
# Title of the webpage:
#
#     Python機器學習-使用Scikit-Learn
#
#
# Course duration: 21小時
# Course cost: NT$ 18,000
# Target audience: 想成為資料工程師/科學家的資訊相關人員
# DocumentBOX Outline: 1.機器學習介紹2.監督式學習2-1迴歸分析(Regression)2-2邏輯迴歸分類(Logistic Regression Classification)2-3貝氏分類(Bayesian Classification)2-4決策樹(Decision Tree)2-5支援向量機(Support Vector Machine)2-6最近鄰居分類(K-nearest Neighbors)
# 3.非監督式學習
# 3-1分群(Clustering)3-2異常偵測(Anomaly Detection)3-3主成分分析(Principal-Component Analysis)4.整體學習(Ensemble Learning)5.神經網路(Neural Network)6.特徵工程(Feature Engineering)
# Title of the webpage:
#
#     Microsoft Power BI資料分析
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要學習微軟大數據分析解決方案的整個架構規劃想要了解Power BI Desktop及Power BI服務如何結合運作熟悉SQL Server報表的建立者想要取得Microsoft Certified：Power BI Data Analyst Associate專業認證的人員
# DocumentBOX Outline: Microsoft 資料分析入門在Power BI中進行資料擷取、清理、轉換及載入作業在Power BI中設計資料模型在Power BI中使用DAX建立資料計算在Power BI建立視覺化報告在Power BI進行進階分析部署及維護Power BI的資產資料列層級安全性
# Title of the webpage:
#
#     PowerPoint 2022設計專業多媒體簡報
#
#
# Course duration: 14小時
# Course cost: NT$ 9,000
# Target audience: 有PowerPoint使用基礎
# DocumentBOX Outline: 1.設計簡報背景1.1 設定簡報單色或漸層背景1.2 圖片背景1.3 圖樣背景2.設計效果標題文字2.1 依版面配置直接輸入文字2.2 建立美工文字2.3 文字藝術師效果2.4 自訂文字效果2.5 漸層文字與圖片文字2.6 建立段落文字塊2.7 段落文字設定2.8 編號與項目符號3.圖案與圖片素材應用3.1 插入圖片與圖片效果3.2 Google搜尋透明背景圖3.3將螢幕擷取畫面新增至投影片3.4插入圖案3.5 圖案組合運算3.6 插入圖示3.7 圖示圖案加上效果3.8 圖示進階應用3.9繪製圖案與效果應用4.加強SmartArt圖形與圖表視覺效果4.1 建立SmartArt圖形物件4.2 美化SmartArt圖形物件4.3 調整SmartArt內容4.4 SmartArt圖案編輯應用4.5表格美化應用4.6圖表美化應用5.設計母片與佈景主題5.1新增投影片頁面5.2套用設計佈景主題5.3 修改佈景主題內容5.4 自訂佈景主題（母片）6.動畫效果與影片設定6.1 文字加動畫6.2 動畫順序與動畫啟動安排6.3 圖案加動畫與動畫類型6.4 圖片加動畫與複製動畫6.5 SmartArt加上動畫6.6圖表上套用動畫6.7 自訂動畫效果6.8複製動畫與安排順序6.9 安排動畫時間差6.10 善用旋轉強調動畫6.11 路徑動畫效果6.12加入3D模型與動畫進階影片、音效編輯7.1加入與編輯音訊7.2 插入視訊與編輯影片檔7.3 使用螢幕錄製8.轉場與頁面連結8.1 轉場設定8.2 投影片頁面連結8.3 轉化轉場應用8.4 投影片章節與縮放8.5 簡報輸出成自動播放影片
# Title of the webpage:
#
#     Python與機器學習深度學習-使用Keras與TensorFlow
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想做Data Scientist者需要學習Machine Learning /深度學習者
# DocumentBOX Outline: Anaconda與Python下tensorflow與sklearn的設定與組態開發環境整理與調校機器學習與深度學習概論機器學習與深度學習需要的資料處理與視覺化多變數線性迴歸監督式學習Logistic RegressionSupport Vector MachineDecision TreeRandom ForestKNNNaive Bayes非監督式學習KMeanPCA(Principal Component Analysis)Tensorflow與Keras離散分類問題的建模模型效能評估資料集合的處理Model Selection模型選取hyper parameter後設參數調校Keras與Neural Network數種MNIST預測IMDB與Reuter資料處理Keras與CNN(Convolutioal Neural Network)建模TensorBoard的使用彈性補充RNN深度學習與NVidia的Cuda的組態與設定
# Title of the webpage:
#
#     Microsoft Power Platform開發人員
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 想要成為Microsoft Power Platform的開發者想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展程式開發人員想要更詳細了解Power Platform各項工具的核心架構與設計內容，進而可以具備更深入的客製化設計能力的系統程式設計師想要取得Microsoft Certified：Power Platform Developer Associate專業認證的人員
# DocumentBOX Outline: 與Microsoft Dataverse雲端資料庫平台一起工作建立由Power Apps所提供的模型驅式動應用服務系統(Create a model-driven app in Power Apps)建立由Power Apps所提供的畫布應用程式(Create a canvas app in Power Apps)如何掌握畫布應用程式中的高級技巧和數據選項的使用(Master advance techniques and data options in canvas app)如何應用Power Automate中的自動化業務流程的處理(Automate a business process using Power Automate)Power Platform的開發簡介(Introduction to developing with Power Platform)如何擴展Power Platform通用數據服務(Extending the Power Platform Common Data Service)如何擴展Power Platform用戶體驗模型驅動式的應用程式與服務(Extending the Power Platform user experience Model Driven apps)如何使用Power Apps組件框架來建立所需要的組件(Create components with Power Apps Component Framework)如何擴充Power Apps的網站入口環境(Extend Power Apps Portals)如何將Power Platform與Common Data Service進行整合(Integrate with Power Platform and Common Data Service)
# Title of the webpage:
#
#     Python中文自然語言NLP深度學習專家課程
#
#
# Course duration: 28小時
# Course cost: NT$ 24,000
# Target audience: 高階軟體開發工程師大數據相關研發人員或資料科學家統計/數值分析研究人員中文自然語言處理專家大型語言模型微調專家大型語言模型 RAG 架構專家
# DocumentBOX Outline: 1.AI下一世代：ChatGPT的崛起● 自然語言處理、自然語言理解和自然語言生成2.文字資料採集● 深入Python爬蟲Crawler框架和MongoDB非結構化資料庫建構● 收集巨量資料集，並進行文字資料清洗3.機器學習快速上手● 決策樹（Decision Tree）、隨機森林（Random Forest）和梯度下降（Gradient Descent）4.機率生成模型與分類模型● 貝氏分類（Bayesian Classification）在中文語意的應用場景5.關聯字詞模型訓練● 中文斷詞、斷句和詞彙Tokenization，實作Word2Vec、Doc2Vec、Ckip和Transformers6.文章分類模型訓練● 詞袋模型（Bag of Words）、TF-IDF詞頻分類法、Naive Bayes分類器和XGBoost分類器7.情感分析模型訓練● Fine-tuning HuggingFace上的模型於中文長短句的正負面機率● 使用Google Play Store留言，實作Keras/Tensorflow RNN情感程度模型訓練8.暱稱/姓名預測性別男女模型● 訓練中、英文姓名男女分類判別● 建立文字檔案以查找分群的標籤9.自然語言處理個案研究● 中文姓名預測API，以Python Flask為例● 自然語言文章分類在廣告標籤投放的應用● Facebook/Instagram留言探針時刻監測品牌危機● 留言情感分析在品牌策略操作上的處理● PTT新聞摘要與關聯10.如何微調ChatGPT模型，讓它認識你的產業知識?● 通用人工智慧 (Artificial General Intelligence)● 大型語言模型(LLM)需要準備的資料集指引，套用自己的資料集● 從ChatGPT 4前往Llama 2實作遷移式學習● 微調(Fine-tuning) OpenAI 模型，提供問答助手11.延伸大語言模型 (LLM) 擴增(RAG) 知識● 結合知識檢索的 OpenAI 生成技術● 提示詞工程(Prompt Engineering) 使用 LangChain 與 LlamaIndex● 事實查核避免 AI 幻想 (Fact-checking of ChatGPT and LLMs)● 部署地端大型語言模型 (GGUF)
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     使用者介面視覺構成解析與優化
#
#
# Course duration: 14小時
# Course cost: NT$ 9,000
# Target audience: 程式設計師、App程式設計師、系統開發、網站企劃、行銷企劃本課程適合無任何設計軟體基礎者
# DocumentBOX Outline: 1.系統與介面設計畫面的版面設計1-1 關於介面設計1-2 畫面的合理版面1-3 畫面的版面分類2.配色優化一點通2-1 色彩在介面中的作用2-2 色彩基礎與屬性2-3 色彩基本概念2-4 配色工具輕鬆上手3.Photoshop必備影像快速處理撇步3-1 影像快速調整3-1-1 曲線調整亮度3-1-2 色相飽和度調色3-2 影像尺寸簡單處理3-2-1 最理想的影像格式3-2-2 直接更改尺寸與儲存最佳化影像3-2-3裁切影像3-3 裁切準確尺寸影像3-3-1 設定尺寸後裁切3-3-2 依目標尺寸多張裁切3-4 自動批次處理大量影像3-4-1 錄製動作與更改尺寸批次處理3-4-2 影像調整批次處理3-4-3 裁切批次處理4.Photoshop搭配畫面之影像精準切割法4-1 影像同尺寸等分切割4-2 不規則影像切割4-3 多種尺寸Icon切割4-4 搭配畫面之影像切割實作4-4-1 固定寬度介面影像圖框4-4-2 變動寬度介面影像圖框5.Photoshop輕鬆搞定畫面材質效果與按鈕素材5-1 形狀繪圖工具5-1-1 矩型工具5-1-2 圓角矩型工具5-1-3 橢圓工具5-1-4 多邊型工具5-1-5 直線工具5-1-6 自訂形狀工具5-2 輕鬆為圖案加上效果5-3 自製按鈕素材5-3-1 繪製按鈕與圖案5-3-2 加入按鈕文字5-4 快速打造畫面材質效果5-4-1繪製區塊圖框5-4-2 繪製介面區塊
# Title of the webpage:
#
#     Microsoft Power Automate RPA開發人員
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 想要成為Microsoft Power Automate RPA的開發者想要完整的了解Power Automate在桌面自動化處理的設計師想要取得Microsoft Certified：Power Automate RPA Developer專業認證的人員
# DocumentBOX Outline: 總覽Power Platform RPAPower Automate Cloud FlowsPower Automate Desktop Flows從Cloud Flows來使用Desktop Flows自訂連結器部署與管理自動化作業
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     Oracle 資料庫之適用於資料倉儲分析的SQL
#
#
# Course duration: 18小時
# Course cost: NT$ 49,000
# Target audience: 欲了解Oracle SQL資料分析函數與語法的資料庫管理者欲使用Oracle SQL資料分析函數與語法的程式設計人員欲了解Oracle SQL資料分析函數與語法的資料倉儲資料庫管理者
# DocumentBOX Outline: 課程簡介使用SQL指令對資料進行分群與彙總階層式查詢使用正規表示式使用SQL指令分析資料進行Pivot/Unpivot操作使用SQL指令進行樣式比對使用SQL指定對資料進行Model操作
# Data saved to courses_details4.xlsx

# %% [markdown]
# 結果說明:
#
# 1. 會把爬蟲取到的資料儲存成excel檔，並分別使用預設標題。

# %% [markdown]
# # 2. 更換search_pattern就可以爬取不同的系列課程資訊

# %% [markdown]
# ### 爬取資訊安全 Security 系列課程

# %% [markdown]
# search_pattern = re.compile(r'{"id":"\{J\}23","typeName":"JobCategory","pkid":23,"text":"數據分析與商業智慧 Data Analysis & Business Intelligence","children":(\[.*?\])', re.DOTALL)
# ________________________________________________________________________________________________________________
# search_pattern = re.compile(r'{"id":"\{J\}24","typeName":"JobCategory","pkid":24,"text":"資訊安全 Security","children":(\[.*?\])', re.DOTALL)

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到 "資訊安全 Security" 的節點及其 children 節點
search_pattern = re.compile(r'{"id":"\{J\}24","typeName":"JobCategory","pkid":24,"text":"資訊安全 Security","children":(\[.*?\])', re.DOTALL)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print("未找到 '資訊安全 Security' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details5.xlsx', index=False)
    print("Data saved to courses_details5.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CISA國際電腦稽核師認證研習班
#
#
# Course duration: 35小時
# Course cost: NT$ 40,000
# Target audience: 稽核人員、資訊人員及對資訊系統稽核或控制有興趣者
# DocumentBOX Outline: 資訊系統稽核流程 (Information System Auditing Process)資訊科技治理與管理 (Governance and Management of IT)資訊系統的取得、開發與建置 (Information Systems Acquisition, Development and Implementation)資訊系統的營運及企業靈活性 (Information Systems Operations and Business Resilience)資訊資產的保護 (Protection of Information Assets)
# Title of the webpage:
#
#     CISM國際資訊安全經理人認證專班
#
#
# Course duration: 35小時
# Course cost: NT$ 40,000
# Target audience: 資訊長/資安長、資訊人員、稽核人員及對資安管理或資訊系統稽核/控制有興趣者
# DocumentBOX Outline: 資訊安全治理 (Information Security Governance)資訊安全風險管理 (Information Security Risk Management)資訊安全計劃 (Information Security Program)事故管理 (Incident Management)
# Title of the webpage:
#
#     CompTIA Security＋國際網路資安認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者初階系統/網路工程師
# DocumentBOX Outline: Summarize Fundamental Security Concepts(總論基本安全概念)Compare Threat Types(比較威脅類型)Explain Cryptographic Solutions(解釋加密解決方案)Implement Identity and Access Management(實施身份和存取管理)Secure Enterprise Network Architecture(安全的企業網路架構)Secure Cloud Network Architecture(安全的雲端網路架構)Explain Resiliency and Site Security Concepts(解釋彈性與網站安全的概念)Explain Vulnerability Management(解釋漏洞管理)Evaluate Network Security Capabilities(評估網路安全能力)Assess Endpoint Security Capabilities(評估端點安全能力)Enhance Application Security Capabilities(增強應用程式的安全能力)Explain Incident Response and Monitoring Concepts(解釋事件回應與監控概念)Analyze Indicators of Malicious Activity(分析惡意活動指標)Summarize Security Governance Concepts(歸納安全治理概念)Explain Risk Management Processes(解釋風險管理流程)Summarize Data Protection and Compliance Concepts(總論資料保護與合規性概念)
# Title of the webpage:
#
#     EC-Council CCT 網路安全認證技師課程
#
#
# Course duration: 40小時
# Course cost: NT$ 39,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者初階系統/網路工程師
# DocumentBOX Outline: Information Security Threats and Vulnerabilities (資訊安全威脅與弱點)Information Security Attacks (資訊安全攻擊)Network Security Fundamentals (網路安全基礎)Identification, Authentication, and Authorization (識別、鑑別與授權)Network Security Controls–Administrative Controls (網路安全控制措施-管理控制措施)Network Security Controls–Physical Controls (網路安全控制措施-實體控制措施)Network Security Controls–Technical Controls (網路安全控制措施-技術控制措施)Network Security Assessment Techniques and Tools (網路安全評估技術與工具)Application Security (應用程式安全)Virtualization and Cloud Computing (虛擬化與雲端運算)Wireless Network Security (無線網路安全)Mobile Device Security (行動裝置安全)IoT and OT Security (物聯網與工控安全)Cryptography (密碼學)Data Security (資料安全)Network Troubleshooting (網路故障排除)Network Traffic Monitoring (網路流量監控)Network Logs Monitoring and Analysis (網路日誌監控與分析)Incident Response (事故應變)Computer Forensics (電腦鑑識)Business Continuity and Disaster Recovery (持續營運與災難復原)Risk Management (風險管理)
# Title of the webpage:
#
#     EC-Council CSCU安全電腦使用者認證課程
#
#
# Course duration: 16小時
# Course cost: NT$ 16,000
# Target audience: 個人用戶和家庭使用者商業和組織用戶學生和學術界人士任何對安全使用電腦、行動裝置、物聯網系統有興趣的人員
# DocumentBOX Outline: 資料安全介紹作業系統的安全性惡意軟體和防毒軟體網際網路安全社交網站的安全性保護電子郵件通訊行動裝置的安全性雲端安全性網路連接的安全性資料備份和災難復原保護物聯網設備和遊戲主機遠距工作的安全性
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     ISO/IEC 27001：2022資訊安全管理系統核心概念與條文要點解析訓練課程
#
#
# Course duration: 16小時
# Course cost: NT$ 21,000
# Target audience: 資訊安全人員欲從事ISO27001顧問人員公司內部導入ISMS系統的人員IT人員稽核部門人員
# DocumentBOX Outline: 資訊安全管理系統詮釋管理責任詮釋內部資訊安全稽核詮釋資訊安全管理審核詮釋資訊安全管理系統改善詮釋資訊安全控制措施詮釋
# Title of the webpage:
#
#     SSCP-資安專業人員認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 40,000
# Target audience: 對資訊安全工作有興趣者欲取得SSCP®認證資格者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 第一章 Introducing Security and Aligning Asset Management to Risk Management介紹安全及符合風險管理之資產管理第二章 Understanding Risk Management Options and the Use of Access Controls to Protect Assets認識管理風險之選項並使用存取控制保護資產第三章 Cryptography密碼學第四章 Securing Software, Data and Endpoints 保護軟體、資料與端點第五章 Network and Communications Security 網路與通訊安全第六章 Cloud and Wireless Security 雲端與無線安全第七章 Incident Detection and Response 事故偵測與應變第八章 Maturing Risk Management 強化風險管理
# Title of the webpage:
#
#     Veritas NetBackup資料保護專業人員認證課程
#
#
# Course duration: 35小時
# Course cost: NT$ 75,000
# Target audience: 適合負責設計、配置、操作、監控或支持NetBackup的技術專業人員
# DocumentBOX Outline: 介紹Veritas NetBackup以NetBackup Web UI介面執行工作進行 NetBackup憑證管理設定NetBackup基本及進階磁碟儲存設定NetBackup備份政策及工作排程設定檔案系統的備份及還原設定NetBackup媒體伺服器精簡刪除儲存池設定雲端儲存最佳化檔案系統備份管理及保護VMware虛擬環境復原VMware虛擬環境建立備份複本及異地抄寫保護NetBackup Catalog減輕勒索軟體的影響使用NetBackup報表升級及更新NetBackup版本收集事件記錄及診斷用資訊
# Title of the webpage:
#
#     掌握ChatGPT進行道德駭客攻擊和滲透測試
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 想要學習活用ChatGPT進行網路攻防演練的資安從業人員具備基本滲透測試技術能力的資安從業人員與網路工程師
# DocumentBOX Outline: 道德駭客基礎知識了解ChatGPT的優點和局限性在滲透測試平台中整合ChatGPT使用ChatGPT進行偵察和掃描使用ChatGPT執行密碼破解和暴力攻擊使用ChatGPT執行SQL注入和XSS使用ChatGPT進行進階漏洞利用開發相關實作演練
# Title of the webpage:
#
#     掌握ChatGPT進行道德駭客攻擊和滲透測試
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 想要學習活用ChatGPT進行網路攻防演練的資安從業人員具備基本滲透測試技術能力的資安從業人員與網路工程師
# DocumentBOX Outline: 道德駭客基礎知識了解ChatGPT的優點和局限性在滲透測試平台中整合ChatGPT使用ChatGPT進行偵察和掃描使用ChatGPT執行密碼破解和暴力攻擊使用ChatGPT執行SQL注入和XSS使用ChatGPT進行進階漏洞利用開發相關實作演練
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     資訊安全分析實務-方法、流程與工具
#
#
# Course duration: 35小時
# Course cost: NT$ 28,000
# Target audience: 想要學習資安實用操作技巧的IT人員對系統的資安有興趣管理，希望能加強實作技巧的IT人員
# DocumentBOX Outline: 評估系統的資訊安全評估流程與相關工具列舉與入侵系統的參考步驟駭客的矛盾對決探索與測試常見服務檢測：電子郵件伺服器常見服務檢測：網站伺服器常見服務檢測：搭配伺服器加密需求TLS跡證保存與警報系統備份與復原標準化建立系統與弱掃零檢出相關實作演練
# Title of the webpage:
#
#     網路鑑識及惡意程式分析
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 對資安事件調查領域工作有興趣者欲充實本身資安鑑識技術能力的人員
# DocumentBOX Outline: 惡意程式事件之現場蒐證處理方式網路封包蒐證及分析Windows 惡意程式主機端分析的主要重點資料資料搜尋、TimeLine及 Log分析惡意程式記憶體分析暨案例處理惡意程式反組譯分析
# Title of the webpage:
#
#     CSSLP-資安軟體開發專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 50,000
# Target audience: 參與系統或軟體開發之相關人員軟體專案經理、系統架構師、系統分析師程式設計師、軟體測試人員稽核人員
# DocumentBOX Outline: 本課程涵蓋CSSLP® CBK® SDLC八大領域。課程內容不涉及特定開發技術，而是著重在如何進行安全程式開發的流程與方法。Domain 1 安全軟體概念L1.1 定義軟體開發的核心安全目標L1.2 描述資訊安全三要素並解釋資訊機密性、完整性和可用性的主要機制L1.3 描述資訊安全與資料隱私之間的關係L1.4 辨識影響軟體安全的監管考量L1.5 解釋安全方法如何透過存取控制減輕弱點L1.6 描述軟體安全中多層保護的目的和功能L1.7 描述安全文化和實踐如何影響資料隱私和安全Domain 2 安全軟體生命週期管理L2.1 探討軟體開發的預測性和適應性方法中的安全性L2.2 描述將軟體安全實踐納入軟體開發生命週期過程中L2.3 辨識DevOps和DevSecOpsL2.4 認識安全性組態標準和基準L2.5 描述以安全為重點的組態管理過程L2.6 確定軟體弱點和漏洞的安全標準L2.7 解釋OWASP的軟體保證成熟模型和建立安全性成熟模型L2.8 在DevSecOps管道中定義軟體安全里程碑和檢查點L2.9 解釋系統安全計畫L2.10 辨識與安全相關的文件L2.11 辨識軟體開發中的指標L2.12 詳細說明軟體停用政策和流程L2.13 解釋DevSecOps中的安全性報告機制L2.14 描述風險評估和風險管理L2.15 審查安全運作流程的實施L2.16 辨識容器生命週期中的安全考慮Domain 3 安全軟體需求L3.1 描述需求管理以及軟體安全需求的來源L3.2 辨識功能性和非功能性需求L3.3 解釋SCRUM/SCRUM相似方法中以安全為重的故事的影響L3.4 描述軟體安全需求的來源L3.5 分析安全政策及其支援元素作為內部安全需求的來源L3.6 解釋遵循要求，並辨識法律、法規和行業標準作為外部安全需求的來源L3.7 討論安全標準和架構L3.8 描述資料治理和所有權L3.9 描述資料分類以及安全標籤和標記L3.10 辨識結構化和非結構化的資料類型L3.11 描述資料生命週期L3.12 辨識旨在減輕隱私風險的隱私法律和法規L3.13 討論資料匿名化並列舉各種匿名化方法L3.14 在隱私情境中解釋使用者同意、資料保留和資料處理L3.15 辨識跨境資料轉移的影響以及個人資料轉移的限制L3.16 描述使用者和軟體資料存取規定L3.17 描述誤用和濫用案例以及它們與已知攻擊模式的相關性L3.18 描述安全需求追蹤矩陣L3.19 辨識第三方供應商的安全性需求Domain 4 安全軟體架構和設計L4.1 描述架構和相關的安全設計模式L4.2 辨識介面設計的安全性標準L4.3 比較並區分各種身分驗證和授權機制L4.4 描述憑證管理L4.5 辨識網路安全中使用的原則和工具L4.6 描述維護資料庫安全性的方法L4.7 辨識威脅建模的過程、工具和方法L4.8 指出可攻擊面積評估和管理的過程L4.9 討論威脅情報和網絡威脅資訊的來源L4.10 描述架構風險評估的過程L4.11 辨識非功能性安全性特性和限制L4.12 辨識安全操作架構的考量Domain 5 安全軟體建置L5.1辨識安全編碼標準的特點L5.2 描述在受控應用程式中建置安全性的不同方法L5.3 辨識軟體中的常見缺陷以及相應的緩解策略L5.4 解釋常見的安全開發實踐L5.5 辨識在傳輸中和儲存中的資料保護方法L5.6 辨識列在最常見弱點清單和資料庫中的軟體弱點L5.7 描述軟體保證工具的功能和方法L5.8 描述按類型和功能對控制的分類L5.9 辨識防止常見網路應用程式弱點的控制措施L5.10 描述制定包括軟體風險考量的安全策略的過程L5.11 辨識使用第三方和開源組件和庫時相關的風險L5.12 描述各種整合類別及其對軟體安全性的相關性L5.13 描述建構自動化過程L5.14 解釋軟體保證中使用的技術Domain 6 安全軟體測試L6.1 辨識常見的安全測試技術L6.2 描述測試環境L6.3 辨識組織的軟體安全標準和指南L6.4 解釋群眾外包安全性和獎金計劃的好處L6.5 辨識安全測試的指南L6.6 辨識各種安全性測試案例L6.7 認識建立誤用和濫用案例的重要性L6.8 描述文件驗證和驗證L6.9 解釋OWASP的應用程式安全驗證標準的結構和目標L6.10 描述未記錄的功能和原始碼L6.11 解釋測試結果的安全性影響L6.12 區分測試結果的類型L6.13 描述追蹤安全性缺陷的過程L6.14 解釋風險評分系統和常見弱點評分系統L6.15 解釋測試數據的生成以及使用生產數據的後果L6.16 描述驗證和驗證測試的過程Domain 7 安全軟體部署、運營、維護L7.1在ISO 31000系列的背景下描述操作風險分析L7.2 描述安全配置管理(SecCM)L7.3 辨識安全持續整合和持續交付管道的元素L7.4 解釋應用程式安全工具鏈L7.5 辨識識別應用程式弱點的步驟L7.6 比較和區分常見的存儲和管理安全資料的方法L7.7 描述安全的安裝過程和方法L7.8 釋安全的軟體啟動機制L7.9 辨識運營授權(ATO)過程中的步驟和方法L7.10 解釋如何執行資訊安全持續監控L7.11 描述涉及事件應對計劃的階段L7.12 將修補管理過程與整體軟體安全實踐相關聯L7.13 描述用於弱點管理的方法和工具L7.14 描述控制如何在執行階段以控制措施保護應用程式L7.15 比較和區分業務持續性和災害復原計劃如何支援作業的連續性L7.16 解釋並區分服務水準協議（SLA）、服務水準目標（SLO）和服務水準指標（SLI），以實現供應商的持續性Domain 8 安全軟體供應鏈L8.1 描述軟體供應鏈L8.2 審查軟體供應鏈風險管理的過程L8.3 解釋與第三方軟體相關的安全風險L8.4 將風險與點對點應用程式和文件共享相關聯L8.5 解釋程式碼儲存庫和環境安全L8.6 表達具有密碼學雜湊和數位簽章的元件L8.7 辨識軟體取得中的安全需求和原則L8.8 詳細說明軟體取得的關鍵考慮因素L8.9 解釋軟體取得的合約要求
# Title of the webpage:
#
#     駭客殺手–CEH認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 65,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對駭客攻防技術有興趣者
# DocumentBOX Outline: Introduction to Ethical Hacking (介紹何謂道德入侵)Footprinting and Reconnaissance (蒐集蛛絲馬跡與網路勘查)Scanning Networks (網路服務與弱點掃描)Enumeration (列舉系統資訊)Vulnerability Analysis (弱點分析)System Hacking (入侵電腦系統)Malware Threats (惡意程式威脅)Sniffers (網路監聽與攻擊)Social Engineering (社交工程)Denial-of-Service (阻斷服務攻擊與傀儡網路)Session Hijacking (連線劫持)Evading IDS, Firewalls and Honeypots (規避入侵偵測/防火牆與誘捕系統)Hacking Webservers (入侵網站)Hacking Web Application (入侵網站程式)SQL Injection (資料隱碼攻擊)Hacking Wireless Network (入侵無線網路)Hacking Mobile Platforms (入侵行動平台)IoT and OT Hacking(入侵物聯網與工控)Cloud Computing (雲端運算)Cryptography (密碼學)
# Title of the webpage:
#
#     EC-Council CHFI資安鑑識調查專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: CHFI 課程專為所有參與資訊系統安全、計算機取證和危機事件處理的IT專業人員而設計。包含：警察和相關執法人員國防安全相關人員電子商務安全專業人士法律專業人士銀行、保險和其他專業人士政府機構 IT 資訊經理數位取證服務提供商
# DocumentBOX Outline: Computer Forensics in Today’s World (電腦鑑識總論)Computer Forensics Investigation Process (電腦鑑識程序)Understanding Hard Disks and File Systems (硬碟與檔案系統)Data Acquisition and Duplication (資料獲取與複製)Defeating Anti-Forensics Techniques (破解反鑑識技巧)Windows Forensics (Windows作業系統鑑識)Linux and Mac Forensics (Linux, Mac作業系統鑑識)Network Forensics (網路鑑識)Malware Forensics (惡意程式鑑識)Investigating Web Attacks (網站及網路服務攻擊鑑識)Dark Web Forensics (暗網調查)Cloud Forensics (雲端鑑識)Email and Social Media Forensics (電子郵件與社群媒體鑑識)Mobile Forensics (行動裝置鑑識)IoT Forensics (IoT鑑識)
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     ISO 27001資訊安全管理系統風險評鑑課程
#
#
# Course duration: 16小時
# Course cost: NT$ 21,000
# Target audience: 資訊安全人員欲從事ISO27001顧問人員公司內部導入ISMS系統的人員IT人員稽核部門人員
# DocumentBOX Outline: 何謂風險風險管理之目的流程導向之ISO 27001風險評估控制影響資訊安全管理系統風險之要素風險分析方法風險評估與執行在流程導向之資安系統中導入風險管理實務演練
# Title of the webpage:
#
#     資安事件損害控制暨資料復原實務
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 對資安領域工作有興趣者網商或電商經營者（有個資及交易紀錄）政府單位或八大關鍵基礎設施之資訊人員
# DocumentBOX Outline: 資安法對於資安緊急事件之要求個資法暨 165 網商詐騙通報對於個資外洩之要求資安事件應建立事前偵測才能把損害有效控制災損控制暨系統回復重點事前的防禦措施決定復原及災損的控制能力資料外洩之災損控制及回復實體故障/人員因素之災損控制及回復DDOS攻擊/主機遭駭之災損控制及回復實務綜合演練
# Title of the webpage:
#
#     資通安全法令遵循實務
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 法務人員、IT人員、資安人員、稽核人員
# DocumentBOX Outline: 資通安全現況資通安全事故案例研析資通安全法律規範 – 刑法妨害電腦使用罪章資通安全法律規範 – 個人資料保護法資通安全法律規範 – 資通安全管理法資通安全技術面應用資通安全管理面設計資通安全法令遵循執行策略與方法
# Title of the webpage:
#
#     藍隊資安事故處理-EC-Council ECIH認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 資安危機處理員、單位風險評估管理員、滲透測試人員、系統弱點評估人員、資安鑑識人員、系統管理員、系統工程師、防火牆管理員、IT主管或其他IT相關人員
# DocumentBOX Outline: Introduction to Incident Handling and Response (資安事件危機處理與回應簡介)Incident Handling and Response Process (資安事件危機處理的程序)Forensic Readiness and First Response (數位鑑識與第一時間反應準則)Handling and Responding to Malware Incidents (惡意程式所造成的危機事件應對與處理原則)Handling and Responding to Email Security Incidents (電子郵件所造成的危機事件應對與處理原則)Handling and Responding to Network Security Incidents (網路攻擊所造成的危機事件應對與處理原則)Handling and Responding to Web Application Security Incidents (網站及網路應用程式所造成的危機事件應對與處理原則)Handling and Responding to Cloud Security Incidents (雲端應用所造成的危機事件應對與處理原則)Handling and Responding to Insider Threats (內部威脅所造成的危機事件應對與處理原則)Handling and Responding to Endpoint Security Incidents(端點安全所造成的危機事件應對與處理原則)
# Title of the webpage:
#
#     CEH大師雙認證實戰考試總複習班
#
#
# Course duration: 14小時
# Course cost: NT$ 40,000
# Target audience: 已經取得CEH認證或者已經完成CEH課程且對取得CEH Practical認證有興趣者
# DocumentBOX Outline: 網路暨弱點掃描網路服務標誌擷取與列舉網路流量分析系統攻擊手法分析網站攻擊手法分析
# Title of the webpage:
#
#     CISSP-資安系統專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 安全開發人員、網路系統工程師、資安分析人員、資安系統工程師、資訊部門主管、資訊長、資安顧問、欲取得CISSP®資格者、欲從事資訊安全管理/顧問工作者
# DocumentBOX Outline: Domain 1: Security and Risk Management 安全與風險管理1.1 理解、遵守並促進專業倫理1.2 理解並應用安全概念1.3 評估、應用並維持安全治理
# 原則1.4 全面理解與資訊安全相關的法律、法規和合規問題1.5 理解調查類型的要求1.6 制定、文件化並實施安全政策、標準、程序和指南1.7 識別、分析、評估、優先排序並實施營運連續性 (BC) 要求1.8 貢獻並執行人員安全政策和程序1.9 理解並應用風險管理概念1.10 理解並應用威脅建模概念和方法1.11 應用供應鏈風險管理 (SCRM) 概念1.12 建立和維護安全意識、教育和培訓計畫Domain 2: Asset Security 資產安全2.1 確定並分類資訊和資產2.2 建立資訊和資產處理需求2.3 安全提供資源2.4 管理資料生命週期2.5 確保適當的資產保留2.6 確定資料安全控制和合規需求Domain 3: Security Architecture and Engineering 安全架構與工程3.1 研究、實施和管理使用安全設計原則的工程流程3.2 理解安全模型的基本概念3.3 根據系統安全要求選擇控制3.4 了解資訊系統的安全功能3.5 評估和減輕安全架構、設計和解決方案元素的漏洞3.6 選擇和確定加密解決方案3.7 了解加密攻擊的方法3.8 將安全原則應用於場地和設施設計3.9 設計場地和設施安全控制3.10 管理資訊系統的生命週期Domain 4: Communication and Network Security 通訊與網路安全4.1 在網路架構中應用安全設計原則4.2 保護網路元件安全4.3 根據設計實施安全通訊
# 通道Domain 5: Identity and Access Management (IAM) 識別與存取管理5.1 控制對資產的實體和邏輯存取5.2 設計身份識別和驗證策略5.3 使用第三方服務實現聯邦式身份5.4 實施和管理授權機制5.5 管理身份和存取提供生命週期5.6 實施身份驗證系統Domain 6: Security Assessmentand Testing 安全評估測試6.1 設計並驗證評估、測試和稽核策略6.2 進行安全控制測試6.3 收集安全流程資料6.4 分析測試輸出並產生報告6.5 進行或促進安全稽核Domain 7: Security Operations 安全作業7.1 理解並遵守調查程序7.2 執行日誌記錄和監控活動7.3 進行組態管理7.4 應用基礎安全作業概念7.5 應用資源保護7.6 進行事故管理7.7 操作和維護偵測和預防措施7.8 實施和支援修補和漏洞管理7.9 了解並參與變更管理流程7.10 實施復原策略7.11 實施災害復原流程7.12 測試災害復原計畫7.13 參與營運持續性規劃和演練7.14 實施和管理實體安全7.15 解決人員安全和安全擔憂Domain 8: Software Development Security 軟體開發安全8.1 了解並在軟體開發生命週期中整合安全性8.2 識別並應用軟體開發生態系統中的安全控制8.3 評估軟體安全性的有效性8.4 評估所獲得軟體的安全影響8.5 定義並應用安全程式撰寫準則和標準
# Title of the webpage:
#
#     CompTIA CySA＋網路資安分析師國際認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 48,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者想要成為安全營運中心的威脅情報分析師、應用程式安全分析師、合規分析師、安全事件回應處理專員的相關管理人員
# DocumentBOX Outline: Explaining the Importance of Security Controls(解釋安全控制的重要性)Utilizing Threat Data and Intelligence(如何利用威脅數據與情報)Analyzing Security Monitoring Data(如何分析安全監控的數據)Collecting and Querying Security Monitoring Data(如何收集與查看安全監控的數據)Utilizing Digital Forensics and Indicator Analysis Techniques(如何利用數位取證與指標分析的技術)Applying Incident Response Procedures(如何進行事件回應程序)Applying Risk Mitigation and Security Frameworks(如何進行風險緩解與安全框架)Performing Vulnerability Management(如何執行漏洞管理)Applying Security Solutions for Infrastructure Management(如何進行有關網路基礎架構的安全解決方案)Understanding Data Privacy and Protection(了解數據的隱私性與安全保護)Applying Security Solutions for Software Assurance(如何進行軟體保證的安全解決方案)Applying Security Solutions for Cloud and Automation(如何進行雲端自動化的安全解決方案)
# Title of the webpage:
#
#     EC-Council EDRP資安災害復原專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 網路設備管理員、防火牆管理員、系統管理員、應用程式開發人員、資訊安全人員
# DocumentBOX Outline: Introduction to Disaster Recovery and Business Continuity(災難復原計畫與營運持續計畫介紹)Business Continuity Management(營運持續計畫)Risk Assessment(風險評估)Business Impact Analysis (BIA)(商業衝擊分析)Business Continuity Planning (BCP) (商業持續營運計劃書)Data Backup(資料備份)Data Recovery(資料復原)Virtualization-Based Disaster Recovery(虛擬環境災害復原)System Recovery(系統復原)Centralized and Decentralized System Recovery(集中式與分散式之系統復原的選擇)Disaster Recovery Planning Process(災難復原計畫程序)BCP Testing, Maintenance, and Training(商業持續營運計劃書之測試，維運及訓練)
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     ISO 27001：2022資訊安全管理系統主導稽核員訓練課程
#
#
# Course duration: 40小時
# Course cost: NT$ 53,000
# Target audience: 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人2.風險管理相關經理人3.公司治理、政策制定經理人4.欲從事ISO 27001諮詢、顧問之人員5.內部稽核員、電腦稽核員
# DocumentBOX Outline: 1.資訊安全管理系統要求 (ISO/IEC 27001)2.資訊安全管理系統要求 (ISO/IEC 27001)、管理系統稽核指引(ISO 19011)、驗證稽核要求 (ISO 17021)3.管理系統稽核指引 (ISO 19011)-稽核過程演練-稽核準備與計畫4.管理系統稽核指引 (ISO 19011)-稽核過程演練-稽核起始會議、執行現場稽核活動、稽核員角色與稽核技巧演練5.管理系統稽核指引(ISO 19011)-稽核過程演練-稽核結束會議、稽核發現追蹤與認證
# Title of the webpage:
#
#     智慧型手機APP資安分析
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 想學習App iOS、Android鑑識知識、手機APP開發人員、資安分析人員、欲充實本身資安鑑識技術能力的人員
# DocumentBOX Outline: 智慧型手機APP的安全問題及目前國際間的分析作法iOS平台 APP分析基本環境架設iOS平台 APP程式反組譯及相關靜態分析Android 平台APP分析基本環境架設Android 平台APP程式反組譯及相關靜態分析Android平台 APP 虛擬平台及Sandbox分析智慧型手機APP網路封包Man-in-the-middle解密分析
# Title of the webpage:
#
#     藍隊資安SOC監控-EC-Council CSA認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: SOC分析師(第一級和第二級)網路和安全管理員網路和安全工程師網路防禦分析師，網路防禦技術人員網路安全運營商以及處理網路安全操作的相關安全專業人員網路安全分析師任何想成為SOC分析師的人
# DocumentBOX Outline: 安全運營和管理(Security Operations and Management)了解網路威脅，IoC和攻擊方法(Understanding Cyber Threats,IoCs, and Attack Methodology)事件、事件和日誌記錄(Incidents, Events, and Logging)危機事件偵測與安全訊息及事件管理的(SIEM) (Incident Detection with Security Information and Event Management(SIEM))利用威脅情資增強事件檢測能力(Enhanced Incident Detection with Threat Intelligence)危機處理程序及應對方法(Incident Response)
# Title of the webpage:
#
#     CISSP資安系統專家認證課程-假日進修班
#
#
# Course duration: 40小時
# Course cost: NT$ 32,000
# Target audience: 安全開發人員、網路系統工程師、資安分析人員、資安系統工程師、資訊部門主管、資訊長、資安顧問、欲取得CISSP®資格者、欲從事資訊安全管理/顧問工作者
# DocumentBOX Outline: Domain 1: Security and Risk Management 安全與風險管理1.1 理解、遵守並促進專業倫理1.2 理解並應用安全概念1.3 評估、應用並維持安全治理
# 原則1.4 全面理解與資訊安全相關的法律、法規和合規問題1.5 理解調查類型的要求1.6 制定、文件化並實施安全政策、標準、程序和指南1.7 識別、分析、評估、優先排序並實施營運連續性 (BC) 要求1.8 貢獻並執行人員安全政策和程序1.9 理解並應用風險管理概念1.10 理解並應用威脅建模概念和方法1.11 應用供應鏈風險管理 (SCRM) 概念1.12 建立和維護安全意識、教育和培訓計畫Domain 2: Asset Security 資產安全2.1 確定並分類資訊和資產2.2 建立資訊和資產處理需求2.3 安全提供資源2.4 管理資料生命週期2.5 確保適當的資產保留2.6 確定資料安全控制和合規需求Domain 3: Security Architecture and Engineering 安全架構與工程3.1 研究、實施和管理使用安全設計原則的工程流程3.2 理解安全模型的基本概念3.3 根據系統安全要求選擇控制3.4 了解資訊系統的安全功能3.5 評估和減輕安全架構、設計和解決方案元素的漏洞3.6 選擇和確定加密解決方案3.7 了解加密攻擊的方法3.8 將安全原則應用於場地和設施設計3.9 設計場地和設施安全控制3.10 管理資訊系統的生命週期Domain 4: Communication and Network Security 通訊與網路安全4.1 在網路架構中應用安全設計原則4.2 保護網路元件安全4.3 根據設計實施安全通訊
# 通道Domain 5: Identity and Access Management (IAM) 識別與存取管理5.1 控制對資產的實體和邏輯存取5.2 設計身份識別和驗證策略5.3 使用第三方服務實現聯邦式身份5.4 實施和管理授權機制5.5 管理身份和存取提供生命週期5.6 實施身份驗證系統Domain 6: Security Assessmentand Testing 安全評估測試6.1 設計並驗證評估、測試和稽核策略6.2 進行安全控制測試6.3 收集安全流程資料6.4 分析測試輸出並產生報告6.5 進行或促進安全稽核Domain 7: Security Operations 安全作業7.1 理解並遵守調查程序7.2 執行日誌記錄和監控活動7.3 進行組態管理7.4 應用基礎安全作業概念7.5 應用資源保護7.6 進行事故管理7.7 操作和維護偵測和預防措施7.8 實施和支援修補和漏洞管理7.9 了解並參與變更管理流程7.10 實施復原策略7.11 實施災害復原流程7.12 測試災害復原計畫7.13 參與營運持續性規劃和演練7.14 實施和管理實體安全7.15 解決人員安全和安全擔憂Domain 8: Software Development Security 軟體開發安全8.1 了解並在軟體開發生命週期中整合安全性8.2 識別並應用軟體開發生態系統中的安全控制8.3 評估軟體安全性的有效性8.4 評估所獲得軟體的安全影響8.5 定義並應用安全程式撰寫準則和標準
# Title of the webpage:
#
#     EC-Council Web 應用程式安全課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 對網路安全有興趣者對應用程式安全性有興趣，希望能加強資安實作技巧的IT人員有志成為安全分析師、滲透測試人員、道德駭客或安全顧問等專業人員
# DocumentBOX Outline: Web應用程式：駭客與安全介紹初學級挑戰：SQL資料隱碼攻擊(SQL Injection)初學級挑戰：安全性錯誤配置(Security Misconfiguration)初學級挑戰：跨網站腳本攻擊(Cross Site Scripting)初學級挑戰：網路應用程式漏洞掃描和枚舉 (Scanning and Enumeration)中級挑戰：SQL資料隱碼攻擊(SQL Injection)中級挑戰：安全性錯誤配置(Security Misconfiguration)中級挑戰：無效的存取控管(Broken Access Control)精通級挑戰：無效的存取控管(Broken Access Control)精通級挑戰：安全性錯誤配置(Security Misconfiguration)精通級挑戰：伺服器層級認證與授權存取(Server Level Access)專家級挑戰：伺服器層級認證與授權存取(Server Level Access)專家級挑戰：安全性錯誤配置(Security Misconfiguration)
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     藍隊資安威脅分析-EC-Council CTIA認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對威脅情資分析有興趣者
# DocumentBOX Outline: Introduction to Threat Intelligence(何謂威脅情資)Cyber Threats and Attack Frameworks(網路威脅與攻擊框架)Requirements, Planning, Direction, and Review(要求、規劃、指導與檢討)Data Collection and Processing(資料收集與處理)Data Analysis(資料分析)Intelligence Reporting and Dissemination(情資通報與傳遞)Threat Hunting and Detection(威脅獵殺與偵測)Threat Intelligence in SOC Operations, Incident Response, and Risk Management(SOC作業、事故應變與風險管理中的威脅情資)
# Title of the webpage:
#
#     CISSP資安系統專家認證課程總複習班
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 已經取得CISSP課程40小時訓練證明，報考CISSP資格者
# DocumentBOX Outline: 第一天CISSP CBK 重點複習1.1 Domain 1: Security and Risk Management1.2 Domain 2: Asset Security1.3 Domain 3: Security Architecture and Engineering1.4 Domain 4: Communication and Network Security1.5 Domain 5: Identity and Access Management (IAM)第二天CISSP CBK 重點複習2.1 Domain 6: Security Assessment and Testing2.2 Domain 7: Security Operations2.3 Domain 8: Software Development Security2.4 考題重點講解2.5 經驗分享●　準備考試注意事項●　臨場考試注意事項●　考上後申請流程●　證照維持規定
# Title of the webpage:
#
#     EC-Council CPENT滲透測試專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 網路設備管理員、防火牆管理員、資訊安全測試人員、系統安全分析師
# DocumentBOX Outline: Introduction to Penetration Testing (滲透測試介紹)Penetration Testing Scoping and Engagement (滲透測試範疇與締約)Open-Source Intelligence(OSINT) (開放情報蒐集)Social Engineering Penetration Testing (社交工程滲透測試)Network Penetration Testing -External(外網滲透測試)Network Penetration Testing -Internal(內網滲透測試)Network Penetration Testing -Perimeter Devices(網路周邊裝置滲透測試)Web Application Penetration Testing (網站程式滲透測試方法)Wireless Network Penetration Testing (無線網路滲透測試方法)IoT Penetration Testing (物聯網滲透測試)OT/SCADA Penetration Testing (工控滲透測試)Cloud Penetration Testing (雲端滲透測試方法)Binary Analysis and Exploitation (二進制程式分析與攻擊)Reports Writing and Post Test Action(撰寫報告與測試後續動作)
# Title of the webpage:
#
#     FCP-NS認證 - FortiClient EMS Administrator認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 相關參與FortiClient EMS管理、配置和操作的 IT 和安全專業人員，以用於保護其組織的端點設備欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: FortiClient 和 FortiClient EMS 的簡介安裝和授權許可FortiClient EMS 的配置和管理FortiClient 的部署使用 FortiClient EMS 進行 FortiClient 的配置FortiClient Endpoint ProfilesZTNAZTNA 配置FortiClient Cloud診斷和故障排除
# Title of the webpage:
#
#     資訊安全基礎課程
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 人人皆需要資訊安全的知識，本課程特別適合企業內所有工作人員，每人皆應具備資訊安全的基礎觀念
# DocumentBOX Outline: 回顧近年重大個人資安時事檢視不良的上網習慣有線／無線連網的安全性個人／公用電腦安全健身操行動裝置黑魔法防禦術選擇使用安全的應用程式社群軟體安全注意事項有備無患-如何正確進行資料備份
# Title of the webpage:
#
#     網路安全封包分析認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: 具備TCP/IP網路技術概念者企業網路之管理人員欲從事網路安全之相關人員對網路安全有興趣者
# DocumentBOX Outline: 網路封包分析的基本知識與常用技巧常見網路服務FTP、Telnet、SSH、SMTP、POP3、IMAP封包行為分析常見HTTP、HTTPS之正常與異常封包行為分析網路芳鄰(CIFS/SMB/NAS)之正常與異常封包行為分析ODBC、MS-SQL、MySQL、PostgreSQL、Oracle資料庫之封包行為分析惡意程式(Malware)、跳板主機與駭客攻擊封包行為分析網路異常與駭客攻擊的案例分析
# Title of the webpage:
#
#     藍隊資安威脅分析-EC-Council CTIA認證課程-假日進修班
#
#
# Course duration: 24小時
# Course cost: NT$ 25,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對威脅情資分析有興趣者
# DocumentBOX Outline: Introduction to Threat Intelligence(何謂威脅情資)Cyber Threats and Attack Frameworks(網路威脅與攻擊框架)Requirements, Planning, Direction, and Review(要求、規劃、指導與檢討)Data Collection and Processing(資料收集與處理)Data Analysis(資料分析)Intelligence Reporting and Dissemination(情資通報與傳遞)Threat Hunting and Detection(威脅獵殺與偵測)Threat Intelligence in SOC Operations, Incident Response, and Risk Management(SOC作業、事故應變與風險管理中的威脅情資)
# Title of the webpage:
#
#     EC-Council CCSE雲端資安工程師認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 雲端技術工程師、或對雲端安全技術有興趣者
# DocumentBOX Outline: Introduction to Cloud Security (介紹雲端運算安全)Platform and Infrastructure Security in Cloud (雲端運算中的平台與基礎設施安全)Application Security in Cloud (雲端運算中的應用程式安全)Data Security in Cloud (雲端運算中的資料安全)Security Operations in Cloud (雲端運算中的安全作業)Penetration Testing in Cloud (雲端運算中的滲透測試)Incident Response in Cloud (雲端運算中的事故應變)Forensic Investigation in Cloud (雲端運算中的鑑識調查)Business Continuity and Disaster Recovery in Cloud (雲端運算中的持續營運與災難回復)Governance, Risk Management, and Compliance in Cloud (雲端運算中的治理、風險管理與遵循)Standards, Policies, and Legal Issues in Cloud (雲端運算中的標準、政策與法律議題)
# Title of the webpage:
#
#     EC-Council CSCU安全電腦使用者認證課程
#
#
# Course duration: 16小時
# Course cost: NT$ 16,000
# Target audience: 個人用戶和家庭使用者商業和組織用戶學生和學術界人士任何對安全使用電腦、行動裝置、物聯網系統有興趣的人員
# DocumentBOX Outline: 資料安全介紹作業系統的安全性惡意軟體和防毒軟體網際網路安全社交網站的安全性保護電子郵件通訊行動裝置的安全性雲端安全性網路連接的安全性資料備份和災難復原保護物聯網設備和遊戲主機遠距工作的安全性
# Title of the webpage:
#
#     FCP-NS認證 - 資安鐵三角FortiSwitch認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或參與Fortinet資安鐵三角–FortiSwitch管理、配置和監控，以為終端設備提供安全網路存取的網路安全專業人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 交換器託管模式(Managed Switch)交換器基礎功能第2層設計第2層安全性進階功能監控交換器獨立模式(Standalone Switch)故障排除
# Title of the webpage:
#
#     ISO/IEC 27701：2019隱私資訊管理系統主導稽核員轉證訓練課程
#
#
# Course duration: 14小時
# Course cost: NT$ 21,000
# Target audience: 稽核人員法務/法令遵循人員個人資訊管理專責人員資訊安全管理專責人員有志從事ISO 27701輔導顧問之人員
# DocumentBOX Outline: 認識個人資訊管理系統國際個人資訊法規要求趨勢ISO 27000 資安管理系列架構概論ISO 27701:2019 條款與附錄個人資料盤點與風險管理ISO 27701:2019與BS10012:2017差異說明驗證申請與條件實作演練稽核證據稽核角色扮演稽核報告 / 陳述稽核發現
# Title of the webpage:
#
#     網路安全封包分析進階實作
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: NSPA Class C 認證人員企業網路之管理人員欲從事網路安全之相關人員對網路安全有興趣者
# DocumentBOX Outline: 1、網路安全封包分析-常見木馬程式實例包括有：網路資安基本檢測方式、判斷網路異常通訊方式、正常網路封包的分析(實作)、惡意程式攻擊實作與封包分析(AgentTesla, HawkEye, QuasarRAT, NjRAT, NanoCore, AveMaria, Lucifer等等)、封包分析技巧的學習評量與討論(實作題5題、木馬程式部分)2、網路安全封包分析-常見加密勒索實例包括有:加密勒索的運作與偵測、加密勒索的案例研析、加密勒索攻擊實作與封包分析(Loocipher, WannaCry, Sodinokibi, Dharma, Nemty, GlobleImposter)的分析、封包分析技巧的學習評量與討論(實作題5題, 加密勒索部分)3、網路安全封包分析-常見IDS/IPS與手機封包實例包括有: APT組織的探討與案例、駭客攻擊的策略與戰術、多重複合式攻擊的案例、IDS/IPS偵測規則與Wireshark的規則轉換、封包分析技巧的學習評量與討論(實作題18題)
# Title of the webpage:
#
#     FCP-NS認證 - 資安鐵三角Secure Wireless LAN認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或參與Fortinet資安鐵三角–FortiAP (整合與雲端無線解決方案)的管理、配置和監控的網路和安全專業人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: Managed FortiAP無線網路安全無線網路存取FortiAP配置檔 (FortiAP Profiles)Rogue Aps (非法APs) 和FortiPresence進階選項和監控故障排除
# Title of the webpage:
#
#     CompTIA PenTest＋滲透測試和漏洞管理國際認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 48,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者想要成為安全營運中心的威脅情報分析師、應用程式安全分析師、合規分析師、安全事件回應處理專員的相關管理人員
# DocumentBOX Outline: Planning and Scoping Penetration Tests(如何規劃滲透測試的範圍)Conducting Passive Reconnaissance(如何進行被動式偵查)Performing Non-Technical Tests(如何執行非技術性的測試)Conducting Active Reconnaissance(如何進行主動式偵查)Analyzing Vulnerabilities(如何進行漏洞分析)Penetrating Networks(什麼是網路滲透)Exploiting Host-Based Vulnerabilities(如何利用主機式的漏洞)Testing Applications(應用程式的測試)Completing Post-Exploit Tasks(完成漏洞利用後的任務)Analyzing and Reporting Pen Test Results(如何分析並報告滲透測試的結果)
# Title of the webpage:
#
#     EC-Council CCISO資安長課程
#
#
# Course duration: 40小時
# Course cost: NT$ 99,000
# Target audience: 有志於成為專業資安經理人或資安長資訊安全之規劃、設計與管理者對資訊安全管理與知識有興趣者
# DocumentBOX Outline: Domain 1：Governance治理Drivers that Influence Governance 治理驅動力Corporate Governance Activities 公司治理活動Information Security Governance Activities 資安治理活動Governance and Ethical Decision Making 治理與道德決策Domain 2：Security Management Controls and Auditing Management資安管理控制措施與稽核管理Risk Management 風險管理Risk Treatment 風險處置Risk Management Frameworks 風險管理框架Audit Management 稽核管理Risk Communication and Organizational Reporting 溝通風險與通報Domain 3：Security Program Management and Operations 安全計畫管理與作業Information Security Portfolio Management 資安組合管理Information Security Program Management 資安計畫管理Information Security Project Management 資安專案管理Security Operations 安全作業Domain 4：Information Security Core Competencies資安核心職能Access Control 存取控制Physical Security 實體安全Network and Communications Security 網通安全Threat and Vulnerability Management 威脅與弱點管理System and Application Security 系統安全Encryption Concepts and Technology 加密與相關技術Domain 5：Strategic Planning, Financial Management, and Vendor Management 策略性規劃及財務與供應商管理Strategic Planning 策略性規劃Financial Management 財務管理Vendor Risk Management 供應商風險管理
# Title of the webpage:
#
#     FCP-NS認證 - FortiAuthenticator Administrator認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 負責FortiAuthenticator日常管理的任何人欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置使用者管理和高可用性管理和驗證使用者使用者身份驗證故障排除雙因子身份驗證(2FA)Fortinet單一登入(FSSO) 流程和方法Fortinet單一登入(FSSO) 部署和故障排除入口網站服務(Portal Services)PKI和設定FortiAuthenticator為CA憑證管理802.1X驗證OAuth和SAMLFIDO2身份驗證
# Title of the webpage:
#
#     FCP-NS認證 - FortiAnalyzer Administrator認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 簡介和初始配置系統管理容錯式磁碟陣列(RAID) 和 高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     EC-Council CASE Java應用程式安全工程師認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 2年以上Java實務開發經驗有志成為Java應用程式安全工程師/安全分析師/安全測試專業人員工作範圍涉及開發、測試、管理或保護應用程式安全之專業人員
# DocumentBOX Outline: 應用程式的安全、威脅與攻擊應用程式安全需求收集安全應用程式設計與架構輸入驗證安全編碼實務鑑別與授權加密技術安全編碼實務Session管理錯誤處理安全編碼實務靜態與動態應用程式安全測試(SAST & DAST)安全部署與維護
# Title of the webpage:
#
#     FCP-PCS認證 - FortiWeb Administrator認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 參與FortiWeb管理和支援的網路&安全專業人員欲取得FCP-PCS專業認證資格者欲重認證FCF, FCA, FCP-PCS者
# DocumentBOX Outline: 介紹基本設定合規性身份驗證和存取控制網路應用程式安全服務阻斷(DoS)和竄改(Defacement)攻擊機器學習和機器人檢測(Bot Detection)SSL/TLS應用程式交付API保護和機器人緩解措施(Bot Mitigation)其他配置故障排除
# Title of the webpage:
#
#     FCP-PCS認證 -AWS Cloud Security Administrator認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 任何負責在AWS上部署或管理 Fortinet 解決方案的人都應該參加本課程欲取得FCP-PCS專業認證資格者欲重認證FCF, FCA, FCP-PCS者
# DocumentBOX Outline: 公有雲簡介AWS元件用於AWS的Fortinet產品和部署用於AWS 的高可用性用於AWS 的負載平衡器
# Title of the webpage:
#
#     Security Engineering on AWS
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 安全工程師安全架構師安全分析人員安全稽核人員
# DocumentBOX Outline: AWS上的入口點Web應用程式環境的安全注意事項保護Amazon VPC內的網路通訊安全應用程式安全性與事件回應資料安全性與事件回應混合環境的安全注意事項AWS監控和日誌收集在AWS上處理日誌保護Amazon VPC以外的威脅AWS上的帳戶管理無伺服器環境的安全注意事項在AWS上自動執行安全性和事件回應威脅檢測和敏感資料監控
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate Enterprise Firewall認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 欲學習FortiGate高階專業知識者本課程假定您具備高階網路知識，以及FortiGate、FortiManager 和 FortiAnalyzer 的豐富使用經驗欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 網路安全架構簡介硬體加速安全織網 (Security Fabric)高可用性(HA)集中管理OSPFBGPFortiGuard 和 Security Profiles入侵防禦系統(IPS)IPsec VPNAuto-Discovery VPN (ADVPN)
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate SD-WAN認證課程
#
#
# Course duration: 28小時
# Course cost: NT$ 63,000
# Target audience: 想了解或負責Fortinet SD-WAN部署和網路日常維運的任何人欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 介紹集中管理成員、Zones和Performance SLA路由、連線會話SD-WAN 優先等級規則 (SD-WAN Rules)進階IPsec流量塑型
# Title of the webpage:
#
#     FCSS-SO認證 - FortiSIEM Advanced Analytics認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 參與企業或服務提供商(MSSP)部署中的FortiSIEM和FortiSOAR設備的管理、配置和監控的安全專業人員欲取得FCSS-SO高階專業認證資格者欲重認證FCF, FCA, FCP-SO, FCSS-SO者
# DocumentBOX Outline: 多租戶FortiSIEM Collectors和FortiSOAR 連接器Collectors的運作Windows和Linux Agents規則單子模式規則多子模式規則基線(Baseline)基線規則FortiSIEM UEBA巢狀式查詢和查找表告警事故自動清除條件緩解告警事故(Remediation)
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate Network Security Support Engineer認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 使用FortiGate設備對企業安全基礎設施進行診斷、故障排除和支援之網路安全專業人員本課程假定您具備高階網路知識以及FortiGate的豐富使用經驗欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 故障排除概念系統資源連線會話、流量和網路安全織網防火牆身份驗證FSSOSecurity Profiles高可用性IPsecIPsec—IKEv2BGPOSPF
# Title of the webpage:
#
#     FCSS-OS認證 - OT Security認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 使用 Fortinet 設備設計、實施和管理 OT 基礎設施之網路安全專業人員欲取得FCSS-OS高階專業認證資格者欲重認證FCF, FCA, FCSS-OS者
# DocumentBOX Outline: 介紹資產管理存取控制分段防護日誌記錄和監控風險評估
# Title of the webpage:
#
#     Fortinet FortiSIEM Parser課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 負責FortiSIEM日常管理的人想了解如何建立客製化解譯器的人
# DocumentBOX Outline: 介紹正規表示式事件格式識別器解析Switch Case結構客製化CMDB 事件類型Choose-When結構鍵/值對(Key Value Pair)日誌的處理值列表(Value List)日誌的處理進階功能
# Title of the webpage:
#
#     EC-Council CASE .NET應用程式安全工程師認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 2年以上.NET實務開發經驗有志成為.NET應用程式資安工程師/資安分析師/資安測試專業人員工作範圍涉及開發、測試、管理或保護應用程式安全之專業人員
# DocumentBOX Outline: 應用程式的安全、威脅與攻擊應用程式安全需求收集安全應用程式設計與架構輸入驗證安全編碼實務鑑別與授權加密技術安全編碼實務Session管理錯誤處理安全編碼實務靜態與動態應用程式安全測試(SAST & DAST)安全部署與維護
# Title of the webpage:
#
#     Mobile App Security資訊安全程式實作演練-通訊與資料儲存的安全
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 1.已完成Android或iOS行動裝置應用系統課程者，或具備基本App觀念與關聯式資料庫、網路存取的學員。2.Android方面需對Activity生命週期與Java語法有基礎認識3.iOS方面需了解基本的Objective-C/swift，對MVC架構有基本理解
# DocumentBOX Outline: iOS的keychain swift實作iOS的sqlite加密sqlcipher說明iOS的sqlite加密sqlcipher應用Android的keyguard實作Android的sqlcipher實作與說明Android的sqlcipher建置OWASP mobile重點說明與其餘補充網路傳輸與加解密基礎導論
# Data saved to courses_details5.xlsx

# %% [markdown]
# # 3.再改成一開始只要打好課程代碼和系列課程名稱就可以指定爬取

# %% [markdown]
# ### 設定目標系列課程的ID和名稱
# 1. course_id = 29
# 2. course_name = "雲端技術 Cloud - Google Cloud"

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 設定目標系列課程的ID和名稱
course_id = 29
course_name = "雲端技術 Cloud - Google Cloud"

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到目標系列課程的節點及其 children 節點
search_pattern = re.compile(
    rf'{{"id":"\{{J\}}{course_id}","typeName":"JobCategory","pkid":{course_id},"text":"{course_name}","children":(\[.*?\])',
    re.DOTALL
)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print(f"未找到 '{course_name}' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details_7.xlsx', index=False)
    print("Data saved to courses_details_7.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_7.xlsx

# %% [markdown]
# # 4.爬取所有課程

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 設定目標系列課程的ID和名稱
courses = [
    (1, "網路系統工程 System Engineer"),
    (15, "網路通訊 System Communication"),
    (16, "雲端技術 Cloud - Microsoft Azure"),
    (17, "雲端技術 Cloud - Amazon Web Services (AWS)"),
    (18, "虛擬化技術"),
    (19, "程式設計 Programer"),
    (20, "前端工程師系列 Front-End Engineer"),
    (21, "智慧型手機應用程式 Mobile App"),
    (22, "資料庫管理 Database"),
    (23, "數據分析與商業智慧 Data Analysis & Business Intelligence"),
    (24, "資訊安全 Security"),
    (25, "管理類別 Management"),
    (26, "主導稽核員 Leading auditors"),
    (27, "多媒體設計 Multimedia Design"),
    (28, "區塊鏈"),
    (29, "雲端技術 Cloud - Google Cloud")
]

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

all_course_urls = []

for course_id, course_name in courses:
    # 使用正則表達式找到目標系列課程的節點及其 children 節點
    search_pattern = re.compile(
        rf'{{"id":"\{{J\}}{course_id}","typeName":"JobCategory","pkid":{course_id},"text":"{course_name}","children":(\[.*?\])',
        re.DOTALL
    )
    match = search_pattern.search(file_content)

    if match:
        # 提取匹配的 children 節點
        start_index = match.start(1)
        bracket_count = 1
        end_index = start_index + 1

        # 查找匹配的結束括號以提取完整的 children 節點
        while bracket_count > 0 and end_index < len(file_content):
            if file_content[end_index] == '[':
                bracket_count += 1
            elif file_content[end_index] == ']':
                bracket_count -= 1
            end_index += 1
        
        children_json = file_content[start_index:end_index]
        
        try:
            # 解析為 JSON 格式
            children_courses = json.loads(children_json)
            
            # 生成課程網址
            base_url = "https://www.uuu.com.tw/Course/Show/"
            urls = []
            for course in children_courses:
                course_id = course['id'].replace("{C}", "")
                friendly_url = course['attributes']['FriendlyUrl']
                full_url = f"{base_url}{course_id}/{friendly_url}"
                urls.append(full_url)
            
            all_course_urls.extend(urls)
        except json.JSONDecodeError as e:
            print(f"JSON 解碼錯誤: {e}")
    else:
        print(f"未找到 '{course_name}' 的相關內容。")

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details_all.xlsx', index=False)
    print("Data saved to courses_details_all.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(all_course_urls)
# Out:
# 未找到 '雲端技術 Cloud - Amazon Web Services (AWS)' 的相關內容。
# Title of the webpage:
#
#     CCNA認證-建置與管理Cisco解決方案
#
#
# Course duration: 70小時
# Course cost: NT$ 66,000
# Target audience: 1.對通訊產業有高度興趣，欲從事相關工作者2.從事網路維運相關工作者3.想要取得CCNA認證者
# DocumentBOX Outline: 1.建立網路與區域網路的基礎概念2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協定介紹）3.認識封包的基本構造4.網路設備的設定與IOS的管理5.建置企業交換器虛擬區域網路(VLAN)環境6.交換器擴展樹協定（STP與RSTP）運作原理與最佳化7.乙太通道網路EtherChannel的運作概念與設定8.路由運作基礎與設定9.廣域網路WAN與虛擬私人網路VPN相關運作技術與設定介紹10.網路設備安全性強化措施，ACL相關技術的實作與設定11.Layer 3 Redundancy的相關技術介紹與HSRP的實作12.淺談智能網路（SDN、SD-Access、SD-WAN、Cisco DNA Center）的發展與變革13.常用網管協定的設定與自動化，例如：SNMP、Syslog、NTP、CDP/LLDP14.網路服務效能（QoS）簡介15.無線區域網路（WLAN）運作原理與基本設定16.認識網路安全威脅與相關的防範因應措施
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路建置專家
#
#
# Course duration: 98小時
# Course cost: NT$ 129,000
# Target audience: 企業網路架構管理與規劃人員企業網路解決方案規劃與支援人員對大型企業網路運作技術有興趣深入瞭解者
# DocumentBOX Outline: ENCOR—思科企業網路核心技術建置與維運ENARSI—建置思科高級企業等級路由與服務
# Title of the webpage:
#
#     CCNP Security認證-思科網路安全核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 負責企業網路安全維護管理者需要企業網路安全相關知識與技術者對於企業網路安全機制有興趣瞭解者
# DocumentBOX Outline: 了解資訊安全概念了常見的TCP/IP攻擊、網路應用攻擊、端點攻擊與網路安全技術部署思科ASA防火牆與思科Firepower下一代防火牆部署電子郵件與網站內容安全性部署Cisco Umbrella了解VPN技術和密碼學推出思科站點之間VPN安全解決方案與點對點的Cisco IOS VTI在Cisco ASA和Cisco Firepower NGFW上部署點對點IPsec VPN與遠端存取的SSL VPN了解思科安全網路訪問解決方案了解與配置802.1X驗證了解端點安全技術並部署Cisco端點AMP介紹並部署網路基礎架構保護措施
# Title of the webpage:
#
#     CompTIA Network＋國際網路認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 想要跨至資訊網路工程領域的學習工作者想要取得網路基礎技術認證的工程師想要完成網路安全技術認證的工程師相要進一步學習不同的網路系統技術（包括Microsoft、Linux、CISCO）需要具備的網路基礎知識的網路工程師。
# DocumentBOX Outline: Comparing OSI Model Network Functions（比較 OSI 模型的網路功能）Deploying Ethernet Cabling（部署乙太網路的線路）Deploying Ethernet Switching（部署乙太網路的交換器）Troubleshooting Ethernet Networks（乙太網路的疑難排除）Explaining IPv4 Addressing（了解IPv4的定址模式）Supporting IPv4 and IPv6 Networks（如何同時支援IPv4與IPv6的網路）Configuring and Troubleshooting Routers（網路路由器的設定與疑難排除）Explaining Network Topologies and Types（了解網路的拓樸架構與類型）Explaining Transport Layer Protocols（了解傳輸層的協定）Explaining Network Services（了解什麼是網路服務）Explaining Network Applications（了解什麼是網路應用程式）Ensuring Network Availability（確保網路的可用性）Explaining Common Security Concepts（了解通用安全的概念）Supporting and Troubleshooting Secure Networks（安全網路的支援與疑難排除）Deploying and Troubleshooting Wireless Networks（無線網路的部署與疑難排除）Comparing WAN Links and Remote Access Methods（比較廣域網路連線與網路遠端存取連線的方法）Explaining Organizational and Physical Security Concepts（了解組織與實體安全的概念）Explaining Disaster Recovery and High Availability Concepts（了解災難重建與高可用性的概念）Applying Network Hardening Techniques（應用網路的強化技術）Summarizing Cloud and Datacenter Architecture（總論雲端與資料中心的架構）
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     Red Hat JBoss應用伺服器的系統管理
#
#
# Course duration: 35小時
# Course cost: NT$ 56,000
# Target audience: 想要在公司導入JBoss系統的系統管理人員欲學習JBoss EAP 7伺服器的安裝與管理的系統管理人員欲了解JBoss EAP 7伺服器在部署與維運時搭配的管理重點者
# DocumentBOX Outline: 安裝與設定JBoss EAP 7伺服器在Standalone與Domain模式上配置一個Domain部署Java應用程式在JBoss EAP 7伺服器上組態與JBoss EAP 7伺服器的DataSource連結工作組態Java Message Service與HornetQ組態與JBoss EAP 7伺服器的日誌相關設定部署應用程式的安全性與批次處理在JBoss EAP 7伺服器上認識JBoss EAP 7伺服器的Cluster環境
# Title of the webpage:
#
#     Red Hat OpenShift I：Containers和Kubernetes
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 想深入了解Container與Kubernetes如何組成微服務運作的軟體架構人員工作需求需要設計微服務的應用程式開發人員協助企業評估Container應用需求的架構工程人員
# DocumentBOX Outline: 了解Container、Docker和Red Hat OpenShift的Container架構建立Container化服務管理Container和Container的映像檔案管理客製Container映像檔在Red Hat OpenShift上部署搭配Container的應用程序部署多Container的應用程序
# Title of the webpage:
#
#     Red Hat Linux認證工程師培訓班
#
#
# Course duration: 98小時
# Course cost: NT$ 72,000
# Target audience: 1.Linux入門者、具備網路基本架構概念者2.想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124： Red Hat紅帽系統管理 I (35小時)RH134： Red Hat紅帽系統管理 II (35小時)RH294： Red Hat紅帽系統管理 III-Linux自動化(28小時)
# Title of the webpage:
#
#     Red Hat紅帽RHCSA 認證課程
#
#
# Course duration: 70小時
# Course cost: NT$ 50,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124：Red Hat紅帽系統管理 I (35小時)RH134：Red Hat紅帽系統管理 II (35小時)
# Title of the webpage:
#
#     Red Hat紅帽系統管理 I
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RHEL介紹Linux指令模式的使用在指令模式下進行檔案的管理如何取系統說明文件Linux的帳號管理檔案存取權限的管理Linux系統下的行程管理Linux系統下的服務管理OpenSSH的使用Linux系統的Log管理Linux系統下的網路管理Linux系統下的壓縮工具及檔案傳輸工具RHEL 9下的套件管理( DNF )Linux系統下的檔案系統管理
# Title of the webpage:
#
#     配置Aruba行動網路第一級
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 1.對無線通訊產業有高度興趣，欲從事相關工作者2.部署中小企業等級無線網路解決方案的網路IT專業人員
# DocumentBOX Outline: 介紹無線區域網路802.11與射頻(RF)基礎知識介紹以行動為優先的Aruba OS 8.X網路架構，包含行動控制台種類與運作模式設置Aruba行動主控台(Mobility Master)與行動控制台(Mobility Controller)，了解群組與子群組的分層設定，並介紹使用不同的配置方法將行動控制台加入到行動主控台使用行動主控台的GUI配置安全的無線區域網路，並解釋AP群組架構(AP Group)與其配置檔(AP Group Profile)介紹AP的配置佈建(AP Provisioning)，包含AP與行動控制台間的通訊、AP開機過程、與Control Plane保護機制(CPSec)介紹無線區域網路的資安概念，包含各種不同的WPA/WPA2 802.1X認證與MAC認證方法、對稱與不對稱加密金鑰、與使用WIPS來發現惡意的無線基地台(Rogue AP)介紹Aruba整合式防火牆策略與角色，包含以身份為基礎的Aruba防火牆、使用別名(alias)來設定防火牆策略與規則、與如何指派角色給用戶(Role Derivation)介紹Aruba自動管理射頻(RF)功能，包含Airmatch/ARM功能是如何校準網路來選擇最佳的頻道與設定功率、與Client Match功能是如何引導用戶連接更好的AP使用Captive portal搭配Clearpass認證伺服器來建置Aruba訪客造訪(Guest Access)的資安解決方案，與創建guest provisioning account介紹無線區域網路的監控與故障排除，包含使用Airwave與行動主控台儀表板功能來監控與診斷client/WLAN/AP相關疑難問題、與使用APPrf過濾功能來分析流量
# Title of the webpage:
#
#     網路基礎架構與網路服務
#
#
# Course duration: 42小時
# Course cost: NT$ 16,000
# Target audience: 想進入資訊領域，卻完全沒有資訊背景或經驗者想成為網路工程師、系統工程師，基礎不穩固或無基礎者跨領域學習工作者
# DocumentBOX Outline: 了解主/從(Client/Server)、雲端(Cloud Computing)架構微軟Hypervisor虛擬機器使用及操作ISO/OSI 7 Layer獨家精闢詳解細說乙太網路設備運作原理(訊號增益器、橋接器、交換器、路由器與閘道器)IPv4/IPv6位址、子網段切割、CIDR、Supernetting獨家教材詳解與教學廣域網路(WAN)介紹深入淺出TCP/IP網路重要概念路由(Routing)及網路位址轉譯(NAT)原理詳解及實作IT人員必備的基本網路服務的運作原理(DHCP、DNS、Web、FTP)資訊安全與防毒系統的整體概念
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 1.負責中大型企業網路運作與管理者2.需要中大型企業網路優化調校相關知識與技術者3.對於中大型企業網路運作機制有興趣瞭解者
# DocumentBOX Outline: 檢查思科企業網路架構與思科交換路徑建置園區域網路高可用性網路連接探索、建置及優化企業路由通訊協定（包含OSPF、EIGRP、BGP）介紹網路虛擬化協定與虛擬私人網路和介面探索無線原理、無線漫遊和定位服務與無線AP操作無線部署與無線客戶端身份驗證選項檢查與建置無線客戶端連接故障排除群播（Multicast）路由協定介紹介紹、建置QoS與其他網路服務使用網路分析工具了解企業網路安全架構建置基礎架構安全與安全訪問控制使用思科DNA中心探索自動化和保證，並且在Cisco DNA Center和vManage中導入API檢查思科SD-Access解決方案了解思科SD-WAN解決方案的工作原理介紹網路可開發性協議與Python程式設計基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CDCP資訊機房專業人員國際認證班
#
#
# Course duration: 14小時
# Course cost: NT$ 60,000
# Target audience: 資訊機房(Data Center)相關IT/設施人員資訊機房負責營運人員/管理層學習如何建置符合企業需求資訊機房(Data Center)的人員想取得CDCP國際認證者
# DocumentBOX Outline: 1.資料中心，重要性和停機的原因2.資料中心標準和最佳實踐3.資料中心的地點，建設和建設•   選擇合適的場所和建築物以及如何避免陷阱•   有效資料中心的各種組件和支持設施的設置4.高架地板/輕鋼架•   統一、集中和滾動載荷定義•   適用標準•   高架地板準則•   信號參考網格、機架接地•   殘疾法和法規•   輕鋼架的使用和要求5.照明•   標準•   照明類型和位置•   應急照明，應急電源(EPS)6.電力基礎設施•   從發電到機架的電力基礎設施佈局•   ATS和STS系統•   冗餘級別和技術•   三相和單相使用•   房中的配電選項•   電源線和母線槽•   連接和接地•   共模噪聲和隔離變壓器•   配電板，尺寸和IP保護等級•   電能質量準則•   有功功率和視在功率•   如何確定和計算資料中心的負載•   發電機•   靜態和動態UPS系統，選擇標準，操作模式和能效選項•   電池類型，正確的選擇和測試•   熱成像•   可再生能源係數 (REF，Renewable Energy Factor)7.電磁場•   電場和磁場的定義和測量單位•   電磁場的來源•   電磁場對人體健康和設備的影響•   (H)EMP•   標準•   EMF遮蔽解決方案8.機架•   機架標準、特性和選擇標準•   安全注意事項•   配電盤/槽選項9.冷卻基礎設施•   溫度和濕度建議•   冷卻測量單位和轉換率•   顯熱和潛熱定義•   舒適型與精密冷卻之間的差異•   不同的空調技術概述•   高架地板與非高架地板散熱•   空調單元的放置和限制•   補充冷卻選項•   冷通道/熱通道密閉•   液浸冷卻•   冷卻概念：季節性熱能儲存 (STER, Seasonal Thermal Energy Storage)10.供水•   供水和應用領域的重要性•   備用供水技術11.設計可擴展的網路基礎架構•   結構化佈線系統的重要性•   規劃注意事項•   銅和光纜技術和標準•   ANSI/ TIA-942佈線層次結構和建議•   測試與驗證•   網路冗餘•   建築物之間的連接•   網路監控系統要求12.防火•   滅火標準•   檢測系統•   各種全浸式滅火技術和系統、其優缺點•   手提式滅火器•   標牌與安全•   法規要求和最佳做法13.物理保全和人身安全•   物理保全考慮•   人身安全注意事項14.輔助系統•   資料中心監控要求•   EMS、BMS和DCIM•   漏水檢測系統•   警報通知
# Title of the webpage:
#
#     Designing and Implementing Storage on AWS
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端儲存工程師解決方案架構師雲端維運工程師DevOps工程師
# DocumentBOX Outline: 第一天：Module 1：雲端儲存介紹Module 2：設計物件儲存解決方案Module 3：使用Amazon S3建置物件儲存解決方案Module 4：設計區塊儲存解決方案第二天：Module 5：使用Amazon EBS建置區塊儲存解決方案Module 6：檔案儲存與Amazon EFSModule 7：使用Amazon FSx建置雲端檔案儲存第三天：Module 8：混合與邊緣的雲端儲存Module 9：搬移資料至AWSModule 10：AWS的備份與災難復原Module 11：對AWS儲存進行監控、自動化與最佳化
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Microsoft 365 Fundamentals認證班
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 由於本課程是許多將要銷售Microsoft 365服務的銷售員或專員的基本認證課程，所以只要是從事相關工作的人員都是要學習本課程的對象從事Microsoft 365相關服務銷售、代理、整合應用服務的銷售員、服務解說員想要認識、評估或使用Microsoft 365的操作人員、資訊工作者欲進一步熟悉Microsoft 365所提供軟體即應用服務的架構，與需要進行管理與維護的Microsoft 365管理員有志取得完整Microsoft 365 Certified：Fundamentals認證者
# DocumentBOX Outline: 展示Microsoft 365生產力和團隊合作的基本知識(Demonstrate fundamental knowledge of Microsoft 365 productivity and teamwork)展示Microsoft 365商務管理功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 business management capabilities)展示Microsoft 365授權、服務和支援的基礎知識(Demonstrate fundamental knowledge of Microsoft 365 licensing, service and support)展示Microsoft 365安全性與合規性功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 security and compliance capabilities)
# Title of the webpage:
#
#     Microsoft Azure基礎知識
#
#
# Course duration: 14小時
# Course cost: NT$ 12,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified Azure Fundamentals認證者
# DocumentBOX Outline: 描述雲端概念•      說明雲端運算•      說明使用雲端服務的優點•      描述雲端服務類型描述Azure架構與服務•      描述Azure的核心架構元件•      說明Azure計算和網路服務•      描述Azure儲存體服務•      說明Azure身分識別、存取和安全性描述Azure管理與治理•      說明在Azure中成本管理•      說明Azure中與治理及合規性相關的功能與工具•      說明管理和部署Azure資源的功能和工具•      說明Azure中的監視工具微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft安全性、合規性和身份基礎知識
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified：Security, Compliance, and Identity Fundamentals認證者
# DocumentBOX Outline: 安全性、合規性和身份的基本概念Microsoft身份和存取管理解決方案的觀念及功能Microsoft安全解決方案Microsoft合規性管理的功能微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Red Hat紅帽系統管理II
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習Linux系統管理的IT人員
# DocumentBOX Outline: Linux系統下文字模式的進階使用及shell scriptLinux系統下的排程管理Linux系統下的效能調校SELinux系統的管理Linux系統下的硬碟管理及儲存空間的使用Linux Volume Manage的管理及使用NFS Client的使用Linux系統的開機流程RHEL 9的網路存取控制安裝RHEL 9虛擬化技術 / 容器技術
# Title of the webpage:
#
#     VMware Aria Automation安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: System administrators and system integrators responsible for designing, implementing, and managing VMware Aria Automation
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.VMware Aria Automation Overview and Architecture• Describe the purpose and functionality of VMware Aria Automation• Identify the key services offered by VMware Aria Automation• Describe the VMware Aria Automation architecture• Describe the use of VMware Workspace ONE Access™• Describe the relationship between Kubernetes clusters, container, and VMware Aria Automation services3.Installing VMware Aria Automation• List the different VMware Aria Automation deployment types• Describe the purpose of Easy Installer• Describe the VMware Aria Automation installation process4.Authentication and Authorization• Identify the steps to integrating Workspace ONE® Access with Active Directory• Describe the features of Workspace ONE Access• Describe the user roles available in VMware Aria Automation• Identify the key tasks performed by each user role• Define custom roles• Configure branding and multitenancy5.Basic Initial Configuration• Create a basic configuration with a cloud account, cloud zone, project, flavor mapping, and image mapping6.VMware Aria Automation Templates• Configure and deploy a basic VMware Aria Automation template• Create a VMware Aria Automation template that can run on any cloud• Use cloudConfig and cloudbase-init to run commands, create users, and install software• Use YAML for inputs, variables, and conditional deployments7.Tags• Configure tags• Describe functions of tags• Manage tags
# 8.Storage Configuration• Configure storage profiles• Use tags and storage profiles9.Integrating NSX With VMware Aria Automation• List the capabilities and use cases of VMware NSX®• Describe the NSX architecture and components• Integrate NSX with VMware Aria Automation• List the supported network profiles in VMware Aria Automation• Use the NSX components to design a multitier application with VMware Aria Automation Templates• Identify the network and security options available in design canvas• Create and manage on-demand networks and security groups• Configure NSX Day 2 actions10.Integrating with Public Clouds• Configure and use VMware Cloud Foundation™ accounts• Integrate VMware Cloud Director™ account• Configure and use an AWS cloud account• Configure and use an Azure cloud account• Configure and use a Google Cloud Platform cloud account• Integrate VMware Cloud on AWS cloud account11.Using VMware Aria Automation Consumption• Release a VMware Aria Automation template• Define content source and content sharing• Define VMware Aria Automation policy enforcement• Use custom forms for catalog items12.VMware Aria Automation Extensibility• Describe VMware Aria Automation extensibility• Use event topics• Create a subscription• Call a VMware Aria Automation Orchestrator workflow• Create ABX actions13.Using Kubernetes Clusters• Introduction to Kubernetes• Connect to an existing Kubernetes Cluster• Create a VMware Aria Automation template with Kubernetes components14.Using VMware Aria Automation Config for Configuration Management• Describe VMware Aria Automation Config• Use VMware Aria Automation Config for software deployment• Use VMware Aria Automation Config for configuration management• Use VMware Aria Automation Config with event-driven orchestration15.VMware Aria Automation Troubleshooting and Integration• Demonstrate how to monitor deployment history• Demonstrate basic troubleshooting• Execute CLI commands• Explain how to collect logs• Describe integration with VMware Aria Operations for Logs• Describe integration with VMware Aria Operations
# Title of the webpage:
#
#     VMware Kubernetes Fundamentals and Cluster Operations
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Anyone who is preparing to build and run Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction•  Introductions and objectives2.Containers•  What and Why containers•  Building images•  Running containers•  Registry and image management3.Kubernetes Overview•  Kubernetes project•  Plugin interfaces•  Building Kubernetes•  Kubectl CLI4.Beyond Kubernetes Basics•  Kubernetes objects•  YAML•  Pods, replicas, and deployments•  Services•  Deployment management•  Rolling updates•  Controlling deployments•  Pod and container configurations5.Kubernetes Networking•  Networking within a pod•  Pod-to-Pod Networking•  Services to Pods•  ClusterIP, NodePort, and LoadBalancer•  Ingress controllers•  Service Discovery via DNS6.Stateful Applications in Kubernetes•  Stateless versus Stateful•  Volumes•  Persistent volumes claims•  StorageClasses•  StatefulSets7.Additional Kubernetes Considerations•  Dynamic configuration•  ConfigMaps•  Secrets•  Jobs, CronJobs8.Security•  Network policy•  Applying a NetworkPolicy•  SecurityContext•  runAsUser/Group•  Service accounts•  Role-based access control9.Logging and Monitoring•  Logging for various objects•  Sidecar logging•  Node logging•  Audit logging•  Monitoring architecture•  Monitoring solutions•  Octant•  VMware vRealize®Operations Manager™10.Cluster Operations•  Onboarding new applications•  Backups•  Upgrading•  Drain and cordon commands•  Impact of an upgrade to running applications•  Troubleshooting commands•  VMware Tanzu™ portfolio overview
# Title of the webpage:
#
#     VMware NSX安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: Experienced security administrators or network administrators
# DocumentBOX Outline: 1.Course Introduction2.VMware Virtual Cloud Network and VMware NSX3.Preparing the NSX Infrastructure4.NSX Logical Switching5.NSX Logical Routing6.NSX Bridging7.NSX Firewalls8.NSX Advanced Threat Prevention9.NSX Services10.NSX User and Role Management11.NSX Federation
# Title of the webpage:
#
#     VMware Tanzu Kubernetes Grid安裝及設定管理課程
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Platform operators who are responsible for deploying and managing Tanzu Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction2.Introducing VMware Tanzu Kubernetes Grid3.VMware Tanzu Kubernetes Grid CLI and API4.Authentication5.Load Balancers6.VMware Tanzu Kubernetes Grid on vSphere7.VMware Tanzu Kubernetes Grid on Public Clouds8.Tanzu Kubernetes Workload Clusters9.Tanzu Kubernetes Grid Packages10.Configuring and Managing Tanzu Kubernetes Grid Operation and Analytics Packages11.Configuring and Managing Tanzu Kubernetes Grid Networking Packages12.Tanzu Kubernetes Grid Day 2 Operations13.Troubleshooting Tanzu Kubernetes Grid
# Title of the webpage:
#
#     VMware vSphere安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 69,900
# Target audience: 系統管理員系統工程師
# DocumentBOX Outline: 1.Course Introduction2.vSphere and Virtualization Overview3.Installing and Configuring ESXi4.Deploying and Configuring vCenter5.Configuring and Managing Virtual Networks6.Configuring vSphere Storage7.Deploying Virtual Machines8.Managing Virtual Machines9.Deploying and Configuring vSphere Clusters10.Managing the vSphere Lifecycle
# Title of the webpage:
#
#     Windows Server 2016的安裝、儲存及運算
#
#
# Course duration: 42小時
# Course cost: NT$ 28,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望提升企業資訊服務高可用性與負載平衡的管理者與規劃人員
# DocumentBOX Outline: Nano、Server Core伺服器準備、安裝、升級與遷移的策略設定本地儲存裝置企業儲存解決方案儲存空間與重複資料刪除安裝設定Hyper-V與虛擬機器部署管理Windows與Hyper-V容器(Container)高可用性與災難恢復的概論施作與管理容錯移轉叢集建置Hyper-V虛擬機器的容錯移轉叢集配置網路負載平衡(NLB)建立、管理與部署映像檔案(Image)管理、監控和維護虛擬機器的安裝
# Title of the webpage:
#
#     配置Aruba行動網路第二級
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 1.負責中大型企業無線網路維運、管理與部署相關工作者2.對中大型企業無線網路技術有高度興趣者
# DocumentBOX Outline: 回顧配置Aruba行動網路第一級的課程主題，包含各種AP專業用語、圖形界面的分層架構、與WLAN轉發模式介紹行動主控台的備援機制(Mobility Master Redundancy)，包含VRRP的安裝設定、與MM資料庫的同步介紹行動主控台(MM)與行動控制台(MC)的操作，包含行動控制台的各種部署方式、與安裝設定許可證(license)的進階功能介紹Multizone功能，包含Multizone AP功能流程、Primary與Data zone、與Multizone故障排除介紹MC叢集(Cluster)功能，包含cluster leader選舉過程、MC叢集角色、無中斷式叢集的故障切換(hitless cluster failover)、與叢集內部AP和用戶的負載平衡介紹Aruba行動漫遊(Roaming)功能，包含標準的802.11漫遊、單台與多台行動控制台間的漫遊、與叢集式的行動漫遊(Cluster Mobility)介紹角色的指派(Role Derivation)功能，包含使用VSA來解釋角色的指派、描述用戶規則(user rule)與認證預設角色(authentication default role)、解釋如何做故障排除、與以角色為基礎的ACL介紹Aruba遠端存取(Remote Access)的各種解決方案(RAP/VIA/IAP-VPN/branch controller)，包含RAP的認證、安裝、設定、備援選項及故障排除、與VIA的設定、下載、安裝及故障排除介紹Aruba語音最佳化功能，包含檢視語音QoS、解釋WMM、描述UCC Heuristic與SDN API運行模式、語音連線的監控與故障排除介紹Aruba網狀無線網路(Mesh)功能，包含mesh技術、與mesh cluster設定介紹Aruba裝置的管理，包含管理帳戶與其密碼的重置、設定Guest Provisioning account、使用RADIUS或TACACS認證、與如何取消console access介紹行動控制台的操作，包含如何升級新的影像檔、AP image preload、cluster in service的升級、設定檔的自動回滾(Auto roll back)功能、與可載入的服務模組(LSM)介紹Aruba AirGroup功能，包含AirGroup解決方案的設定及其限制、與ClearPass的整合、AirGroup伺服器與用戶的監控介紹自動分段(Dynamic Segmentation)功能，包含以端口為基礎的通道功能(PBT)與以用戶為基礎的通道功能(UBT)、描述交換機與行動控制台的互動、與如何排除tunnel連線的故障介紹Aruba AirWave管理平台，包含描述AirWave功能、使用群組與檔案夾、設定裝置憑證(device credential)、與如何添加新裝置介紹使用AirWave平台來識別與監控網路健康問題，包含解釋診斷頁面的指示、使用網路健康圖形來識別網路問題、使用效能圖形來幫助網路規劃、與使用Clarity功能引導管理員尋找問題的根源介紹使用AirWave平台來排除用戶與AP裝置的疑難問題，包含解釋如何搜尋用戶與排除相關問題、調查用戶SNR、與如何在AirWave內監控MC叢集介紹使用AirWave平台的VisualRF、報告與警示功能，包含解釋不同的VisualRF顯示選項、描述VisualRF應用程式的監控、設定triggers以創建alerts、與生成22種各式各樣的報告
# Title of the webpage:
#
#     區域網路規劃與架設導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對通訊網路產業有高度興趣，想從事相關工作者有志從事網路規劃的IT人員欲自我提升能力的網路系統工程師
# DocumentBOX Outline: 網路規劃的基本觀念網路規劃的方法論規劃企業區域網路應有的考量VLAN的規劃概要IP位址的規劃概要線路備援的規劃概要網路管理的規劃案例研討
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     管理Exchange Server 2016及2019
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 對微軟郵件訊息平台有興趣者對Exchange Server 2016/2019管理有濃厚興趣，欲成為Exchange Server管理者本身為Exchange Server 2003/2007/2010管理者，欲晉升為Exchange Server 2016/2019管理者
# DocumentBOX Outline: 部署Exchange Server 2019，和在Server Core上安裝Exchange Server 2019管理Exchange Server信箱伺服器建立和管理各種收件者物件，和配置地址清單的策略使用EMS管理收件者物件和Exchange伺服器規劃用戶端連線、部署和配置用戶端存取服務管理Exchange Server伺服器的高可用性實作Exchange Server伺服器角色的災難復原設定及管理訊息傳輸架構設定防毒、垃圾郵件以及防惡意程式保護Exchange Server的監視和疑難排解保護和維護Exchange Server的管理稽核規劃及管理Exchange Online的部署
# Title of the webpage:
#
#     ACA-Campus Access認證－Aruba園區存取網路基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 網路現場技術人員、部署技術人員、第1級NOC人員、或具有Aruba產品實作經驗的初級網路工程師具有1年以上的網路經驗為佳，並且瞭解各家廠商通用的基本網路協定想要取得(Aruba Certified Associate - Campus Access)國際認證者
# DocumentBOX Outline: Networking Fundamentals－解釋OSI模型與封包封裝、TCPIP堆疊、討論不同種類的實體介質、與比較單播、群播與廣播AOS-CX Switching Fundamentals－介紹交換機的初始設定、如何配置VLAN與tagging、如何使用LLDP與ICMP做為網路發現與診斷、如何配置Link aggregation以增進效能Basic IP Setup－討論inter-VLAN routing、解釋DHCP relay、討論Static IP routing、解釋如何配置單一區域的OSPFNetwork Redundancy－討論Spanning Tree、解釋VRRP與VSXVSF－介紹VSF、解釋如何配置VSF、描述Auto-VSF、解釋VSF MADIntroduction to Aruba Solutions－介紹Aruba交換機與WLAN的產品組合、介紹Aruba Central與ClearPassCentral for Device Mangement－介紹Device Onboarding、描述如何創建Central Groups、描述UI設定模式、描述template設定解釋如何實施模式、描述Aruba Central licensingDevice Profiles and AP Onboarding－描述Device Profiling的使用、描述LLDP與MAC profiling、解釋如何連接AP到Aruba Central、解釋如何實施AP的初始設定WLAN Fundamentals－描述802.11與射頻(RF)基礎知識、解釋SNR、描述漫遊標準與QoS需求、描述射頻的規劃、解釋如何配置WLANImplementing Secure WLANs－介紹AAA、描述802.1X認證、解釋如何配置安全的WLAN、討論角色(roles)與訪問規則Implementing Guest Access－解釋如何配置captive portal認證、描述如何設定guest WLANWLAN Security－介紹無線網路的資安、解釋憑證(certificates)、描述雲端認證Monitoring and Maintenance－解釋如何使用Aruba Central的監控能力、描述如何識別LED狀態、解釋如何實施firmware的升級、描述如何啟動設備的SNMP、描述AI Insights、描述警報與報告、解釋UXITroubleshooting－描述如何實施密碼復原與重置出廠設定步驟、解釋Central connectivity的故障排除、描述如何啟動頻譜的分析(spectrum analysis)、探索Central排除故障的工具
# Title of the webpage:
#
#     AWS Cloud Practitioner Essentials
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 銷售法律行銷商業分析師專案經理高層主管AWS Academy學員其他 IT 相關專業人員
# DocumentBOX Outline: 雲端概念AWS服務安全性架構定價與支援
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科高級企業等級路由與服務
#
#
# Course duration: 42小時
# Course cost: NT$ 68,000
# Target audience: 1.企業路由基礎架構管理與規劃人員2.企業路由解決方案規劃與支援人員3.對大型企業網路運作技術有興趣者
# DocumentBOX Outline: EIGRP建置、優化與疑難排解OSPF建置、優化與疑難排解BGP建置、優化與疑難排解路由重新發佈（Redistribution）設定與疑難排解建置路徑控制探討及探討L3 MPLS VPN架構與路由設定簡化的虛擬路由與轉送（VRF-Lite）建置動態多點虛擬私人網路（DMVPN）建置與疑難排解DHCP介紹IPv6的第一站安全性保全思科路由器疑難排解安全架構與服務針對DNA Center Assurance 進行疑難排解
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     Microsoft 365管理者認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 本課程適用於有志成為Microsoft 365系統管理員角色的IT人員
# DocumentBOX Outline: 部署與設定您的Microsoft 365租用戶環境管理您的Microsoft 365租用戶環境部署與地端AD目錄服務的識別驗證同步服務作業探索Microsoft 365的安全指標管理您在Microsoft 365 Defender中的安全服務如何使用Microsoft 365 Defender來部署威脅保護探索在Microsoft 365的資料治理部署在Microsoft 365中的合規性管理在Microsoft 365中的合規性
# Title of the webpage:
#
#     Microsoft Azure管理員認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure的使用經驗欲進一步熟悉Azure基礎結構建置、管理與維護的Azure管理員有志取得Microsoft Certified：Azure Administrator Associate認證者
# DocumentBOX Outline: 身份識別•     Azure Active Directory(Microsoft Entra ID)、Users and Groups治理與合規•     Subscriptions and Accounts、Azure Policy、Role-based Access ControlAzure管理•     Azure Resource Manager、Azure Portal and Cloud Shell、Azure PowerShell and CLI、ARM Templates虛擬網路•     Virtual Networks、IP Addressing、Network Security Groups、Azure Firewall、Azure DNS網路間連接•     Vnet Peering、VPN Gateway Connections、ExpressRoute and Virtual WAN網路流量管理•     Network Routing and Endpoints、Azure Load Balancer、Azure Application GatewayAzure儲存體帳戶•     Storage Accounts、Blob Storage、Storage Security、Azure Files and File Sync、Managing StorageAzure虛擬機器•     Virtual Machine Planning、Creating Virtual Machines、Virtual Machine Availability、Virtual Machine Extensions管理PaaS運算選項•     Azure App Service Plans、Azure App Service、Container Services、Azure Kubernetes Service、Azure Container Instance資料保護•     File and Folder Backups、Virtual Machine Backups監視•     Azure Monitor、Azure Alerts、Log Analytics、Network Watcher
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     Microsoft安全營運分析師
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，且已具備Azure與Microsoft 365使用經驗欲進一步熟悉Azure安全營運與Microsoft 365安全營運的分析師有志取得Microsoft Certified：Security Operations Analyst Associate認證者
# DocumentBOX Outline: 使用Microsoft 365 Defender緩解威脅使用Microsoft Defender for Endpoint緩解威脅使用Microsoft Defender for Cloud緩解威脅使用Kusto Query Language(KQL)為Microsoft Sentinel建立查詢設定您的Microsoft Sentinel環境將logs連接到Microsoft Sentinel使用Microsoft Sentinel建立檢測並執行調查在Microsoft Sentinel中執行威脅搜尋微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     RHCA認證-Red Hat OpenShift開發II：容器化應用
#
#
# Course duration: 28小時
# Course cost: NT$ 56,000
# Target audience: 企業應用開發人員站點可靠性工程師
# DocumentBOX Outline: 管理和觸發應用建置版本自定義現有Source-to-image基礎鏡像建立OpenShift模板建立健康檢查，監控和提高應用可靠性建立和部署Jenkins流水線，以實現持續集成和持續部署為OpenShift建立和部署雲原生應用
# Title of the webpage:
#
#     VMware NSX疑難排除與操作課程
#
#
# Course duration: 35小時
# Course cost: NT$ 84,400
# Target audience: • Experienced system administrators and network administrators• Network and security professionals who work with enterprise networks
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.NSX Operations and Tools• Explain and validate the native troubleshooting tools for NSX• Configure syslog, IPFIX, and log collections for the NSX environment• Integrate NSX with VMware Aria Operations for Logs and VMware Aria Operations for Networks• Validate and review the API methods available to configure the NSX environment3.Troubleshooting the NSX Management Cluster• Describe the NSX Management cluster architecture, components, and communication channels• Identify the workflows involved in configuring the NSX Management cluster• Validate and troubleshoot the NSX Management cluster formation4.Troubleshooting Infrastructure Preparation• Describe the data plane architecture, components, and communication channels• Explain and troubleshoot VMware ESXi transport node preparation issues• Explain and troubleshoot NSX Edge deployment issues5.Troubleshooting Logical Switching• Describe the architecture of logical switching• List the modules and processes involved in configuring logical switching• Explain the importance of VDS in transport nodes• Review the architecture and workflows involved in attaching workloads to segments• Identify and troubleshoot common logical switching issues6.Troubleshooting Logical Routing• Review the architecture of logical routing• Explain the workflows involved in the configuration of Tier-0 and Tier-1 gateways• Explain the high availability modes and validate logical router placements• Identify and troubleshoot common logical routing issues using both BGP and OSPF7.Troubleshooting Security• Review the architecture of the Distributed Firewall• Explain the workflows involved in configuring the Distributed Firewall• Review the architecture of the Gateway Firewall• Explain the workflows involved in configuring the Gateway Firewall• Identify and troubleshoot common Distributed firewall and Gateway Firewall issues• Review the architecture and workflows involved in configuring Distributed IDS/IPS• Identify and troubleshoot common Distributed IDS/IPS problems8.Troubleshooting Services• Review the NSX Advanced Load Balancer architecture and components• Identify and troubleshoot common NSX Advanced Load Balancer issues• Review the IPsec and L2 VPN architecture and components• Identify and troubleshoot common IPsec and L2 VPN issues9.Datapath Walkthrough• Verify and validate the path of the packet on the NSX datapath• Identify and perform packet captures at various points in the datapath• Use NSX CLI and native hypervisor commands to retrieve configurations involved in the NSX datapath
# Title of the webpage:
#
#     VMware vSphere新增功能
#
#
# Course duration: 14小時
# Course cost: NT$ 30,600
# Target audience: System architects, system administrators, IT managers, VMware partners, and individuals responsible for implementing and managing vSphere architectures who want to deploy vSphere 8.0 into their existing vSphere environment.
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.Artificial Intelligence and Machine Learning• Describe how device groups support AI and ML in vSphere 8.0• Describe how device virtualization extensions support AI and ML in vSphere 8.03.vSphere Distributed Services Engine• Describe the benefits of Distributed Services Engine• Explain how Distributed Services Engine works• Recognize use cases for Distributed Services Engine• Install ESXi on a host equipped with a DPU• View DPU information in the vSphere Client• Add an ESXi host equipped with a DPU to a cluster• Use vSphere Lifecycle Manager to update an ESXi host that contains a DPU• Create a vSphere distributed switch for network offloads• Add a host with a DPU to the vSphere distributed switch• Configure a VM to use uniform passthrough mode4.vSphere and vCenter Management• Describe improvements to the communication between vCenter and ESXi hosts• Describe enhancements to the vCenter recovery process5.ESXi Enhancements• Describe the function of the central configuration store in ESXi• Explain how ConfigStore affects interaction with ESXi configuration files• Recognize the supported system storage partition configuration on ESXi 8.0• Identify devices supported for system storage on ESXi 8.0• Configure an RDMA host local device on ESXi 8.06.vSphere Storage• Describe the VMware vSAN¬ Express Storage Architecture• Recognize the benefits of using vSAN Express Storage Architecture• Describe the benefits of using NVMe• Recognize the support for NVMe devices in vSphere 8.07.Guest OS and Workloads• Review the enhancements of the latest virtual hardware versions• Describe the features introduced with virtual hardware version 20• Identify the snapshot modes of NVDIMM devices8.Resource Management• View energy and carbon emission metrics in VMware vRealize® Operations Manager™• Describe the vSphere Memory Monitoring and Remediation (vMMR) functionality• Describe how vMMR enhances the performance of DRS9.Security and Compliance• Describe how to manage vTPM secrets when cloning a VM• Manage OVF templates for VMs configured with vTPM• Deploy an OVF template with vTPM• Describe the enhancements to trusted binary enforcement in ESXi• Describe ESXi 8.0 enhanced security features10.vSphere Lifecycle Manager• Describe the enhancements to life cycle management of standalone ESXi hosts• Manage the configuration profiles of ESXi hosts in a cluster• Use Auto Deploy to boot a host with the desired image and configuration specifications• Upgrade multiple ESXi hosts in a cluster in parallel• Stage an ESXi host image before remediation11.Auto Deploy• Manage custom host certificates using Auto Deploy12.vSphere with Tanzu• Describe the features of Vmware Tanzu® Kubernetes Grid™ 2.013.Announcing vSphere+• Describe the functionality and benefits of vSphere+
# Title of the webpage:
#
#     企業IT服務伺服器架設與選擇方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對IT產業有興趣、想從事伺服器管理相關工作者想學習認識企業建構伺服器有哪些不同的異質平台(如：Windows、Linux、Mac等)可供選擇者
# DocumentBOX Outline: 企業常見IT伺服器平台介紹企業常見IT伺服器應用介紹File伺服器介紹Proxy/NAT/Firewall介紹DNS伺服器介紹Web伺服器介紹Mail伺服器介紹集中驗證伺服器介紹授權伺服器軟體vs.免費伺服器軟體Hands on Lab
# Title of the webpage:
#
#     ACP-Campus Access認證－建置Aruba園區存取網路
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 第2/3級NOC人員、網路分析師、或具有2-5年Aruba產品組合經驗的網路工程師為佳想要取得(Aruba Certified Professional - Campus Access)國際認證者
# DocumentBOX Outline: Introduction to Aruba Solutions－介紹Aruba ESP架構、Aruba產品組合、自動化與REST APIBuilding Wired Infrastructure－介紹VSX、OSPF、虛擬化路由與轉發、以策略為基礎的路由、Aruba Central Template GroupsWireless Infrastructure with Aruba Gateways－介紹AOS 10與Central Groups、Aruba Gateways的部署、Gateway的初始設定、Gateway ClusterTunneled WLAN Architecture－介紹Tunneled Mode WLAN、Client MonitoringSecure Enterprise WLAN－介紹802.1X認證、防火牆Roles與Role Derivation、CoA支持Guest and Captive Portal－介紹訪客的訪問、訪客認證過程、訪客WLAN配置、MAC快取Wireless Authentication for IoT－介紹MPSK、MPSK認證過程、本地MPSK設定Mixed Mode Architecture－介紹Aruba混合模式WLAN、與其設定Gateway Cluster Deployments－介紹Cluster部署選項、Cluster設定、Cluster監控、Secondary GatewayWired Port Access－介紹Wired認證、802.1X設定、MAC認證、RADIUS Attributes與Roles、動態分段、Wired Captive PortalVXLAN and GBP－介紹分散式Overlay與VXLAN、VXLAN GBPSecurity and Availability Features－介紹IDS/IPS、Authentication Survivability、Central Survivability、管理用戶認證Traffic Optimization and QOS－介紹WLAN優化、AirGroup、服務品質、UCC、LLDP MEDMonitoring－介紹Central警告、Device Insights、用戶體驗Insights
# Title of the webpage:
#
#     AWS Cloud Financial Management for Builders
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 解決方案架構師開發者成本優化管理者系統管理者
# DocumentBOX Outline: 雲端服務財務管理導論：管理簡介、四個支柱、資源標記定價與成本：定價基礎、AWS免費方案、批量折扣、儲蓄計劃、預留實例AWS的帳單、報告、監控、發票、預算運算資源的成本構建：Amazon EC2規格調整、購買選項、Amazon CloudWatch監控和自動化、Amazon EC2競價型實例、自動化基礎架構、無伺服器解決方案網路資源的成本構建：資料傳輸費用、不同服務的資料成本、如何分攤網路成本儲存資源的成本構建：Amazon EBS、Amazon S3、Amazon EFS的成本、定價和最佳實踐資料庫資源的成本構建：Amazon RDS、Amazon Aurora、Amazon DynamoDB、Amazon ElastiCache、Amazon Redshift的成本、定價和最佳實踐成本治理：設置AWS組織、AWS Systems Manager
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科SD-WAN解決方案
#
#
# Course duration: 35小時
# Course cost: NT$ 79,000
# Target audience: 企業路由基礎架構管理與規劃人員企業路由解決方案規劃與支援人員對大型企業網路運作技術有興趣者
# DocumentBOX Outline: 檢查 Cisco SD WAN 架構檢查 Cisco SD-WAN 部署選項部署廣域網路邊緣設備設備設定管理探索冗餘、高可用性和可擴展性啟用服務端和傳輸端路由了解Cisco SD-WAN策略配置基礎知識定義高階控制策略定義高階資料策略建置應用程式體驗品質（Application Quality of Experience）建置應用程式感知路由（Application-Aware Routing）檢查直接Internet訪問和雲部署選項探索思科SD-WAN安全性設計和遷移到Cisco SD-WAN執行Cisco SD-WAN網路管理和故障排除檢查Cisco SD-WAN群播支持
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     Microsoft Azure安全性技術
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事Azure系統與網路管理之管理人員或系統工程師欲進一步了解Azure安全性技術者有志取得Microsoft Certified：Azure Security Engineer Associate認證者
# DocumentBOX Outline: 管理身分識別和存取•     Azure Active Directory(Microsoft Entra ID)•     Azure身分保護•     企業治理•     設定Azure AD特權身份管理•     混合身分識別實行平台防護•     周邊網路的安全性•     網路安全性•     主機安全性•     容器安全性保全資料與應用程式•     Azure金鑰保存庫•     應用程式安全性•     儲存體安全性•     SQL資料庫安全性管理安全操作•     Azure監視•     Microsoft Defender for Cloud•     Microsoft Sentine微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft身份和存取管理員
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，並已具備Azure的管理技能欲進一步了解在安全架構中規劃與解決方案的專業人員有志取得Microsoft Certified：Identity and Access Administrator Associate認證者
# DocumentBOX Outline: 實施身份管理解決方案實施身份驗證和存取解決方案實施應用程式的存取管理規劃和實施身份治理的策略微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Red Hat OpenShift管理III：在企業中擴展Kubernetes部署
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 專為想要在其數據中心部署和管理大型Red Hat OpenShift Container Platform環境的系統管理人員而設計
# DocumentBOX Outline: 身份驗證和身份管理備份、還原和遷移OADP(OpenShift API for Data Protection) 的應用程式叢集分區Pod 調度OpenShift GitOpsOpenShift 監控OpenShift 日誌記錄
# Title of the webpage:
#
#     VMware vSphere設計規劃課程
#
#
# Course duration: 21小時
# Course cost: NT$ 50,700
# Target audience: Experienced system integrators and consultants responsible for designing and deploying vSphere environments
# DocumentBOX Outline: Course Introduction•          Introductions and course logistics•      Course objectivesInfrastructure Assessment•      Follow a proven process to design a virtualization solution•          Define customer business objectives•          Gather and analyze business and application requirements•      Document design requirements, constraints, assumptions, and risks•      Use a systematic method to evaluate and document design decisions•      Create a conceptual designCore Management Infrastructure•          Determine the number of VMware vCenter® Server ApplianceTM instances to include in a design•      Choose the appropriate single sign-on identity source•      Choose the time synchronization method•          Choose methods to collect log files and ESXi core dumps•          Design a vCenter Server deployment topology that is appropriate for the size and requirements of the data centerVirtual Data Center Infrastructure•      Calculate total compute capacity requirements for a virtual data center•          Create a virtual data center cluster design that meets business and workload requirements•      Evaluate in the virtual data center the use of several management services, such as VMware vSphere® High Availability and VMware vSphere® Distributed Resource Scheduler™•      Evaluate the use of resource pools in the virtual data center designCompute Infrastructure•      Create a compute infrastructure design that includes the appropriate ESXi boot, installation, and configuration options•      Choose the ESXi host hardware for the compute infrastructureStorage Infrastructure•      Calculate storage capacity and performance requirements for a design•          Evaluate the use of different storage platforms and storage management solutions•      Design a storage platform infrastructure and storage management architecture that meets the needs of the vSphere environmentNetwork Infrastructure•      Evaluate the use of different network component and network management solutions•      Design a network component architecture that includes information about network segmentation and virtual switch types•      Design a network management architecture that meets the needs of the vSphere environmentVirtual Machine Design•      Make virtual machine design decisions, including decisions about resources•      Design virtual machines that meet the needs of the applications in the vSphere environment and follow VMware best practicesInfrastructure Security•      Make security design decisions for various layers in the vSphere environment•      Design a security strategy that meets the needs of the vSphere environment and follows VMware best practicesInfrastructure Manageability•          Make lifecycle management, scalability, and capacity planning design decisions that adhere to business requirements•      Design lifecycle management, scalability, and capacity planning strategies that meet the needs of the vSphere environment and follow VMware best practicesInfrastructure Recoverability•      Make infrastructure recoverability design decisions that adhere to business requirements•          Design an infrastructure recoverability strategy that meets the needs of the vSphere environment and follows VMware best practices
# Title of the webpage:
#
#     Windows Server 2016的身分識別
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望經由AD目錄服務整合憑證、版權管理及防護機敏資料的管理人員已具備Windows Server 2008/2012 AD網路管理經驗者
# DocumentBOX Outline: 安裝與設定網域控制器(DC)管理AD DS系統與物件進階AD DS基礎結構管理施作與管理AD DS站台與複寫群組原則部署與除錯運用群組原則管理用戶設定強化AD DS的安全性部署與設定AD憑證服務(AD CS)配置與管理憑證實施與管理AD同盟服務(AD FS)實施與管理AD版權管理服務(AD RMS)部署AD DS與Microsoft Azure AD的同步監視、管理、與復原AD DS
# Title of the webpage:
#
#     企業資料的備份與救援簡易解決方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: IT人員，管理伺服器與資料安全領域相關工作者想了解企業與個人資料保全相關技術者
# DocumentBOX Outline: 設計企業資料保全政策資料安全風險評估選擇備份媒體、方法與技術排程備份與檢視備份資料救援與系統快照磁碟陣列儲存網路異地備援備份反運作：數位資源的抹除大量的實務練習
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     製作適用於Microsoft 365的Microsoft Copilot的有效提示
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 學習者應熟悉Microsoft 365應用程式，例如Word、Excel和PowerPoint。本課程適用於使用Microsoft 365的Microsoft Copilot的所有類型使用者
# DocumentBOX Outline: 適用於Microsoft 365的Copilot簡介探索使用適用於Microsoft 365的Copilot的可能性優化和擴充適用於Microsoft 365的Copilot使用Microsoft Copilot for Microsoft 365進行總結使用Microsoft Copilot for Microsoft 365建立和起草文案使用Microsoft Copilot for Microsoft 365編輯和轉換內容使用Microsoft Copilot for Microsoft 365提出問題並分析內容
# Title of the webpage:
#
#     Azure管理員及解決方案架構專家雙認證班
#
#
# Course duration: 63小時
# Course cost: NT$ 55,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure使用經驗欲進一步熟悉Azure基礎結構建置、管理、維護及解決方案架構設計的IT管理員
# DocumentBOX Outline: AZ104：Microsoft Azure管理員認證班(35小時)•　 身份識別•　 治理與合規•　 Azure管理•　 虛擬網路•　 網路間連接•　 網路流量管理•　 Azure儲存體帳戶•　 Azure虛擬機器•　 管理PaaS運算(Web App、ACI及AKS)•　 資料保護•　 監視AZ305：設計Microsoft Azure基礎結構解決方案(28小時)•　 設計治理與計算解決方案•　 設計儲存體和資料整合解決方案•　 設計應用程式架構•　 存取和監視解決方案•　 設計網路、持續性和移轉解決方案微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# ...
# Title of the webpage:
#
#     前端必學的網頁開發基礎技能
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 對網頁開發有興趣的所有人員
# DocumentBOX Outline: HTML 文件結構HTML 常用與語意標籤圖片、表格與超連結標籤表單的建立影音多媒體標籤CSS 基本語法CSS 選取方式介紹色彩與文字設定寬度與高度屬性CSS 外框模型背景與漸層屬性定位方式與版面設定媒體查詢Flex 彈性排版效果響應式網頁設計變形與動畫效果JavaScript語法簡介以JavaScript設定簡易互動效果
# Title of the webpage:
#
#     前端網頁與UI設計師轉職就業養成班
#
#
# Course duration: 306小時
# Course cost: NT$ 72,000
# Target audience: 不需要相關科系背景或經歷，只要是對從事平面設計、網頁設計、App設計、網路數位行銷、網頁互動、數位內容產業有興趣者都可以參加
# DocumentBOX Outline: - Photoshop視覺影像與前端設計應用 30小時課程將帶您進入Photoshop的神奇世界，學習如何製作令人驚豔的視覺效果，包括圖片編輯、多媒體應用設計，讓您學會用電腦製作出您腦中的無限創意設計。- Illustrator專業向量繪圖與動畫素材設計 24小時您將掌握Illustrator並專注於網頁素材和動畫設計，這是一個非常重要的關鍵技能，對於網站和應用程序的成功至關重要。- Photoshop與Illustrator專業App UI介面視覺設計 24小時課程涵蓋App UI介面的視覺設計，教您如何設計流暢的用戶界面，並將您的視覺設計技能應用於使用者體驗設計當中。- Figma專業UI設計實作 18小時透過對Figma的深入研究，您將學會如何使用這個領先的UI設計工具，並在實際專案中應用您的技術。- Adobe Animate CC 製作HTML5動畫與互動效果 24小時課程將幫助您掌握Adobe Animate CC，以製作出生動的HTML5動畫和互動效果，使您的網頁更具吸引力。- HTML與CSS網頁編輯製作 30小時HTML決定網頁的架構而CSS決定網頁的視覺設計，可以說CSS就是網頁的化妝師，此課程引導不黯程式撰寫的您精耕HTML與CSS相關語法，加強專業的網頁設計實力，也方便後續與JavaScript/jQuery之間的設計應用。- WordPress快速上手網站實作 18小時WordPress是一個快速建立功能強大網站的重要工具。我們將教您如何使用WordPress，製作出專屬於您的網站，以展現您的設計創意。- 響應式網頁設計 24小時隨著行動裝置多樣化，響應式網頁設計是當今的網頁主要趨勢之一，您將學到如何設計可以在不同裝置上完美呈現網頁。- 前端互動式網頁程式設計-UI與元件設計 30小時由最基礎的語法開始，逐步的引導學員瞭解JavaScript的基礎，能讓完全沒有程式基礎的設計人員快速瞭解JavaScript的運作原理，課程將引導您深入瞭解前端互動式網頁程式設計，包括UI和元件設計，為您的網頁增添互動性。- JavaScript與jQuery網頁互動實作 36小時jQuery提供了許多強大功能函式庫，能夠一次解決網頁設計上常見的重大困難。透過範例中的步驟，您將掌握JavaScript和jQuery，提供網頁的互動能力，優化使用者經驗。- 個人作品集設計實務整合與數位影音履歷 48小時整合上述所學，打造完整個人作品集和數位影音履歷，讓後續轉職找工作有重要的作品呈現。這門課程涵蓋了以下內容：1. 個人作品集設計實務整合：精心設計和整合個人作品集，以展示您的設計技能和創意，包括您的平面設計、網頁設計、動畫和其他相關領域的作品。2. 數位影音履歷設計：這個部分涵蓋了如何設計和製作一個引人入勝的數位影音履歷，透過影片、動畫和其他元素來強調個人技能和經驗。製作令人印象深刻的履歷。進階課程需求，提供更優惠的價格，讓您在網頁設計師的職涯上更得心應手！【前端課程系列】- Sass與SCSS快速上手(原價12,000元)- 網頁統計圖表Chart.js快速上手(原價12,000元)養成班顧客於結業後一年內報名上述前端課程系列，可以原價5折優惠上課。
# Title of the webpage:
#
#     Photoshop視覺影像與前端設計應用
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: Photoshop初學者、欲學習Photoshop多媒體設計應用者
# DocumentBOX Outline: 基本操作環境與數位影像概念1-1  工作區域概覽1-2  檢視工具1-3  尺標、參考線1-4  影像檔案管理1-5  影像尺寸與版面尺寸1-6  裁切影像1-7  儲存檔案與影像檔案格式圖層與Photoshop影像編輯入門2-1 認識圖層2-2 圖層浮動視窗基本操作2-3 圖層管理2-4 選取與移動圖層2-5 變形指令2-6 各式變形2-7 數值變形2-8 翻轉變形由選取範圍開始玩耍影像合成3-1 固定形狀選取畫面工具3-2 特定形狀選取畫面工具3-3 選取範圍與影像編輯3-4 選取與填色3-5 漸層填色3-6 漸層顏色編輯3-7 油漆桶填色快速影像修正撇步4-1 影像調整工具組4-2 影像處理工具組4-3 影像亮度快速調整4-4 快速影像顏色加強術4-5 修復工具組4-6 內容感知填色4-7 仿製印章修圖向量形狀工具與路徑編輯應用5-1 向量形狀工具繪圖5-2 向量形狀工具繪製路徑應用5-3 路徑編輯工具5-4 使用筆型工具5-5 筆型工具描圖去背5-6 繪製形狀格式向量繪圖進階圖層編輯與濾鏡6-1 圖層對齊與均分6-2 使用圖層樣式6-3 圖層樣式設定6-4 建立圖層遮色片6-5 圖層混色模式6-6 濾鏡效果與設定文字編輯與設計應用7-1 建立文字7-2 段落文字7-3 圖層樣式文字應用7-4 效果文字應用影像處理與設計應用8-1 影像去背處理8-2 影像白邊框風格8-3 繪製剪影表現風格8-4 立可拍風格8-5 影像產品去背與陰影8-6 產品側面陰影前端網頁設計實作9-1 網頁按鈕與圖文框設計9-2 形象網站主視覺設計9-3 活動網站主視覺設計9-4 商品網站主視覺設計9-5 網頁內容設計
# Title of the webpage:
#
#     輕鬆玩出網頁影音新威力
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 1.有興趣學習影音處理製作者2.有需要製作網頁影音作品者
# DocumentBOX Outline: 開始數位影音創作1.1操作環境1.2匯入影片素材與儲存1.3素材取得幻燈片秀、自動模式輕鬆完成影片2.1 幻燈片秀編輯器2.2 自動模式2.3 Magic Movie精靈應用數位影音創作功能3.1 置換天空與動態人物特效3.2 關鍵畫格與動畫3.3 進階編輯模式製作動畫效果3.4 遮罩設計師製作動畫效果3.5 炫粒製作效果3.6 文字效果快速編排影片與效果神奇魔術工具快速編排影片5.1 素材分類管理與裁切圖片5.2 Magic Movie快速編排影片5.3 平移與縮放效果5.4 Magic Cut 快速剪輯影片遮罩與創意主題設計應用6.1 製作連續多張圖片放大影片片段6.2 組合成完整多張圖片放大影片6.3 完成遮色片文字動畫6.4 加入創意主題內容開場動畫與影片剪輯應用7.1製作遮色片開場動畫7.2剪輯主要影片內容與說明文字教學步驟影片進階編輯8.1善用轉場製作開場動畫8.2材料清單文字動畫8.3 主要影片編輯8.4加入圖框與影片效果運用影片調整與特效9.1 製作片頭文字專案9.2 製作主影片與調整影片9.3 應用疊加>炫粒9.4 加入文字動畫堆疊效果影片編輯應用10.1片頭影片與動畫10.2編輯主要影片10.3安排堆疊效果多角度拍攝影片編輯11.1開場動畫11.2編輯主要影片11.3加入影片文字與字幕動作類影片進階編輯12.1整合3D動畫素材12.2圖片平移縮放製作開場動畫12.3運動動作類影片整合編輯進階編輯個人數位影音介紹13.1加入素材13.2介紹影片去背合成13.3加入旁白與字幕13.4背景音樂與片尾
# Title of the webpage:
#
#     響應式網頁設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 需有HTML與CSS基礎，欲學習響應式網頁設計的設計師
# DocumentBOX Outline: 從動手瀏覽觀察網頁開始1-1    甚麼是響應式網頁1-2    建置響應式網頁1.3     安裝VS code 延伸模組開始使用Bootstrap2.1     新增Bootstrap空白頁面2.2     Bootstrap柵格系統2.3     Bootstrap 一般內容與通用類別+2.3.1     文字顏色與背景色2.3.2     文字屬性2.3.3     標題與顯示標題2.3.4     文字行高2.3.5     邊界與內距屬性設定2.3.6     對齊圖片2.3.7     響應式表格(Table)2.3.8     圓角(rounded)與邊框(Borders)2.3.9     響應式圖片與圖片區(Figures)2.3.10     BootStrtap ICON圖標2.4         其他更多的版面區塊編排2.4.1     自動佈局的欄 / 等寬2.4.2     巢狀排列2.4.3     使用邊界水平對齊區塊2.4.4     多個區塊水平對齊2.4.5     欄的推移2.4.6     間隙Gutters2.4.7     Flex對齊Bootstrap元件素材3.1     一般物件3.1.1     按鈕 (Buttons)3.1.2     麵包屑 (Breadcrumb)3.1.3     廣告大屏幕 (Jumbotron)3.2     區塊內容物件3.2.1     多項圖文編排(Media Object)3.2.2     標籤切換內容(Tab)3.2.3     折疊切換內容 (Accordion)3.3     Bootstrap響應式導覽列3.3.1     基本型收合導覽列3.3.2     收合導覽列元件3.4     Card卡片3.4.1     預設卡片類型3.4.2    卡片組合3.4.3     水平卡片3.4.4     網格卡片3.4.5     card圖文框排列版面3.5     Carousel輪播3.5.1     carousel-caption3.5.2     更改carousel CSS3.5.3     控制高度與自訂切換按鈕Bootstrap頁面編排應用4.1     先讓頁面捲動起來4.2    側邊導覽列捲動頁面4.3     頁面編排與效果4.4     頁面動態效果
# Title of the webpage:
#
#     Illustrator專業向量繪圖與動畫素材設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 對於向量插圖、網頁與動畫素材設計有興趣者
# DocumentBOX Outline: 操作環境介紹與檔案管理1-1 操作環境1-2 工具箱1-3 檔案管理與輔助操作基礎繪圖與物件選取變形2-1 基礎繪圖工具2-2 線條繪圖工具2-3 橡皮擦、美工刀與剪刀工具2-4 物件選取與管理2-5 變形工具與變形指令2-6 封套變形指令物件造型與進階變形3-1 形狀模式3-2 路徑管理運算3-3 路徑管理運算繪製圖案應用3-4 即時上色3-5 使用影像描圖與即時上色繪圖3-6 點陣圖剪裁遮色片3-7 漸層填色3-8 形狀運算與漸層填色3-9 網格漸層填色不規則繪圖與描圖4-1 鉛筆工具組徒手繪圖4-2 繪製路徑工具組4-3 路徑編輯工具4-4 鋼筆繪製曲線路徑文字處理5-1 文字字元屬性5-2 建立外框字5-3 路徑文字5-4 文字造型設計應用5-5 段落文字特殊繪圖效果6-1 物件漸變6-2 筆畫效果6-3 Illustrator 效果6-4 3D 效果6-5 Photoshop 濾鏡7 繪圖應用7-1 對齊排列構圖7-2 路徑管理員設計動畫元件7-3 可愛動物動畫元件繪製8 漸層填色與特殊效果功能繪製素材8-1 漸層文字8-2 漸層星光8-3 漸層繪圖造型文字8-4 3D 效果繪圖應用
# Title of the webpage:
#
#     前端互動式網頁程式設計-UI與元件設計
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 網站開發人員、網頁設計人員
# DocumentBOX Outline: 網頁設計:HTML, CSS, JavaScript簡介JavaScript基礎語法深入瞭解JavaScript資料與變數宣告基礎運算子操作數值資料處理進階文字處理邏輯與判斷式迴圈處理與應用DOM文件物件模型操作利用JSON處理複雜資料深入瞭解Function函式架構日期物件與時間處理事件處理常式彈出式互動視窗 Modal window廣告定時呈現與關閉效果Timeout popup window放大鏡檢視圖片Zoom in image頁籤切換介面Tabs手風琴收合效果Accordion圖片輪撥效果Carousel
# Title of the webpage:
#
#     JavaScript與jQuery網頁互動實作
#
#
# Course duration: 36小時
# Course cost: NT$ 18,000
# Target audience: 希望提升網頁互動能力，或縮短開發時程者適合網頁設計師或網站程式開發人員
# DocumentBOX Outline: CSS樣式基礎知識與設定JavaScript基礎知識與語法jQuery基礎知識jQuery動態效果，與動畫設定jQuery選取器，包含階層、內容、屬性、表單等各式選取方式jQuery樣式套用，可取得物件樣式屬性與動態設定樣式jQuery綁定事件，如滑鼠、鍵盤、系統等jQuery控制DOM物件jQuery操控AJAXjQuery UI的介紹與安裝設定輕易完成分頁標籤(Tabs)手風琴選單(Accordion)的製作可移動與縮放對話盒(Dialog)的設計藉由刻度滑桿(Slider)的介面輸入數值便利的日期選擇器(Datepicker)
# Title of the webpage:
#
#     HTML與CSS網頁編輯製作
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 欲學習專業網站建置基礎與編輯應用者
# DocumentBOX Outline: 安裝與使用程式碼編輯器Visual Studio CodeHTML與網頁內容架構CSS基礎與網頁編排CSS與版面DIV編排CSS版面編排應用輕鬆搞懂HTML5與CSS3
# Title of the webpage:
#
#     WordPress快速上手網站實作
#
#
# Course duration: 18小時
# Course cost: NT$ 9,000
# Target audience: 需有HTML與CSS基礎
# DocumentBOX Outline: 在本機安裝 WordPress 網站1.1 使用 XAMPP 在本機安裝 WordPress 網站1.2  安裝Wordpress開始使用WordPress編輯頁面2.1 網站後臺管理介面2.2 新增文章2.3 新增頁面2.4 設定導覽列與首頁WordPress 佈景主題安裝與編輯3.1  安裝新的wordpress3.2  安裝佈景主題3.3  安裝 Elementor 免費版3.4  Elementor編輯頁面一頁式網站佈景主題實作4.1  安裝Wordpress與佈景主題4.2  更改與設定頁首4.3  編輯頁面4.4 設定EMAIL收發信形象網站佈景主題實作5.1  安裝Astra佈景主題5.2  調整網站設定5.3  修改頁面商品網站佈景主題實作6.1  安裝佈景主題Blocksy6.2  新增文章與頁面6.3  修改模板網站6.4  修改商品與文章6.5  修改頁尾6.6  設定購物相關功能6.7  設定會員帳號功能6.8  製作優惠劵附錄 / 網站上傳至 WEB 伺服器（網站空間）7.1  申請免費個人網站空間7.2  安裝網站空間端的wordpress7.3  匯出本機網站程式
# Title of the webpage:
#
#     區塊鏈與智慧合約實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想了解區塊鏈與智慧合約的工程師與專案經理2.想了解智慧合約的實作者
# DocumentBOX Outline: 1.BlockChain歷史與簡介●加解密演算法●Hash Tree/Merkle Tree雜湊樹●非對稱加解密2.BlockChain生態系簡介3.智慧合約與Solidity簡介●Solidity與Solidity相關檔案●Pragma、註解與Mport●合約本體●state變數、struct與修飾子●事件、列舉與函數●資料型態●參照型態●陣列與對應4.Solidity語法●函數與修飾子●View、常數與Pure Function●Address Function●Fallback Function●例外處理、事件和Summary5.Ethereum●EVM(Ethereum Virtual Machine)●Ethereum(Smart Contract)●Truffle框架的設定與使用6.合約的偵錯7.合約的升級
# Title of the webpage:
#
#     區塊鏈與DApp去中心化應用程式Full Stack全棧開發實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要開發區塊鏈應用程式的工程師想學習Ethereum區塊鏈實作的工程師想要了解區塊鏈的軟體架構師
# DocumentBOX Outline: 1.Ethereum網路架構●Blockchain的基本架構●Blockchain的演化●Ether、GAS和EVM2.使用wallet錢包和區塊鏈網路溝通●網頁錢包的安裝●連線與使用3.web3.js●帳戶列表和餘額API使用●交易與合約API呼叫●交易物件傳送●事件與日誌●過濾監控API4.Truffle Framework與Solidity智慧合約5.智慧合約設計樣式6.前端分散式應用程式的考量7.ERC20自訂代幣8.Truffle與React/Redux●建立前端應用程式專案●部署合約●使用React進行前端開發Truffle與VUETruffle與drizzleNFT (Non fungible token)
# Title of the webpage:
#
#     IIB Council區塊鏈專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 商業技術主管政府技術幕僚全端工程師(Full Stack Developer)
# DocumentBOX Outline: 掌握區塊鏈技術的理論和技術基礎了解去中心化(decentralization)的概念，其影響以及與區塊鏈技術的關係了解區塊鏈開發和實現的基本技術原則了解比特幣和其他加密貨幣背後的區塊鏈技術運作機制透過實際範例了解加密技術如何用於數據保護了解智能合約(smart contracts)的理論基礎，以及如何使用Solidity和相關開發框架，在以太坊(Ethereum)區塊鏈上開發去中心化的應用程式(DAapp)研究替代區塊鏈解決方案，包括超級帳本(Hyperledger)、Corda等了解各行各業中區塊鏈應用的使用案例探索區塊鏈實現和商業化策略了解當前業務架構中區塊鏈整合的最佳實務確定可能的區塊鏈實現對法律方面的影響預測應用策略採行可能帶來的風險和失敗，並學習採用有效的變更管理和專案管理方法加以避免探索區塊鏈技術的新研究課題和未來應用範圍
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_all.xlsx

# %% [markdown]
# ## 5. 透過關鍵字查找相關課程

# %% [markdown]
# ### 使用方式:
# ### 更換 keyword = "Cloud"，最後會存成 "courses_details_Cloud.xlsx"

# %%
# 爬取所有課程並保存到一個列表中
def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並返回包含課程詳細信息的列表。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    return courses_data

# 使用生成的課程網址爬取課程詳細信息
all_courses_data = scrape_courses(all_course_urls)

# 根據關鍵字過濾課程並保存到Excel文件
def save_courses_to_excel(courses_data, keyword):
    """
    根據關鍵字過濾課程並保存到Excel文件中。
    """
    filtered_courses = [course for course in courses_data if keyword.lower() in course['Title'].lower()]
    df = pd.DataFrame(filtered_courses)
    df.to_excel(f'courses_details_{keyword}.xlsx', index=False)
    print(f"Data saved to courses_details_{keyword}.xlsx")

# 示例關鍵字查找
keyword = "Cloud"
save_courses_to_excel(all_courses_data, keyword)
# Out:
# Title of the webpage:
#
#     CCNA認證-建置與管理Cisco解決方案
#
#
# Course duration: 70小時
# Course cost: NT$ 66,000
# Target audience: 1.對通訊產業有高度興趣，欲從事相關工作者2.從事網路維運相關工作者3.想要取得CCNA認證者
# DocumentBOX Outline: 1.建立網路與區域網路的基礎概念2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協定介紹）3.認識封包的基本構造4.網路設備的設定與IOS的管理5.建置企業交換器虛擬區域網路(VLAN)環境6.交換器擴展樹協定（STP與RSTP）運作原理與最佳化7.乙太通道網路EtherChannel的運作概念與設定8.路由運作基礎與設定9.廣域網路WAN與虛擬私人網路VPN相關運作技術與設定介紹10.網路設備安全性強化措施，ACL相關技術的實作與設定11.Layer 3 Redundancy的相關技術介紹與HSRP的實作12.淺談智能網路（SDN、SD-Access、SD-WAN、Cisco DNA Center）的發展與變革13.常用網管協定的設定與自動化，例如：SNMP、Syslog、NTP、CDP/LLDP14.網路服務效能（QoS）簡介15.無線區域網路（WLAN）運作原理與基本設定16.認識網路安全威脅與相關的防範因應措施
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路建置專家
#
#
# Course duration: 98小時
# Course cost: NT$ 129,000
# Target audience: 企業網路架構管理與規劃人員企業網路解決方案規劃與支援人員對大型企業網路運作技術有興趣深入瞭解者
# DocumentBOX Outline: ENCOR—思科企業網路核心技術建置與維運ENARSI—建置思科高級企業等級路由與服務
# Title of the webpage:
#
#     CCNP Security認證-思科網路安全核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 負責企業網路安全維護管理者需要企業網路安全相關知識與技術者對於企業網路安全機制有興趣瞭解者
# DocumentBOX Outline: 了解資訊安全概念了常見的TCP/IP攻擊、網路應用攻擊、端點攻擊與網路安全技術部署思科ASA防火牆與思科Firepower下一代防火牆部署電子郵件與網站內容安全性部署Cisco Umbrella了解VPN技術和密碼學推出思科站點之間VPN安全解決方案與點對點的Cisco IOS VTI在Cisco ASA和Cisco Firepower NGFW上部署點對點IPsec VPN與遠端存取的SSL VPN了解思科安全網路訪問解決方案了解與配置802.1X驗證了解端點安全技術並部署Cisco端點AMP介紹並部署網路基礎架構保護措施
# Title of the webpage:
#
#     CompTIA Network＋國際網路認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 想要跨至資訊網路工程領域的學習工作者想要取得網路基礎技術認證的工程師想要完成網路安全技術認證的工程師相要進一步學習不同的網路系統技術（包括Microsoft、Linux、CISCO）需要具備的網路基礎知識的網路工程師。
# DocumentBOX Outline: Comparing OSI Model Network Functions（比較 OSI 模型的網路功能）Deploying Ethernet Cabling（部署乙太網路的線路）Deploying Ethernet Switching（部署乙太網路的交換器）Troubleshooting Ethernet Networks（乙太網路的疑難排除）Explaining IPv4 Addressing（了解IPv4的定址模式）Supporting IPv4 and IPv6 Networks（如何同時支援IPv4與IPv6的網路）Configuring and Troubleshooting Routers（網路路由器的設定與疑難排除）Explaining Network Topologies and Types（了解網路的拓樸架構與類型）Explaining Transport Layer Protocols（了解傳輸層的協定）Explaining Network Services（了解什麼是網路服務）Explaining Network Applications（了解什麼是網路應用程式）Ensuring Network Availability（確保網路的可用性）Explaining Common Security Concepts（了解通用安全的概念）Supporting and Troubleshooting Secure Networks（安全網路的支援與疑難排除）Deploying and Troubleshooting Wireless Networks（無線網路的部署與疑難排除）Comparing WAN Links and Remote Access Methods（比較廣域網路連線與網路遠端存取連線的方法）Explaining Organizational and Physical Security Concepts（了解組織與實體安全的概念）Explaining Disaster Recovery and High Availability Concepts（了解災難重建與高可用性的概念）Applying Network Hardening Techniques（應用網路的強化技術）Summarizing Cloud and Datacenter Architecture（總論雲端與資料中心的架構）
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     Red Hat JBoss應用伺服器的系統管理
#
#
# Course duration: 35小時
# Course cost: NT$ 56,000
# Target audience: 想要在公司導入JBoss系統的系統管理人員欲學習JBoss EAP 7伺服器的安裝與管理的系統管理人員欲了解JBoss EAP 7伺服器在部署與維運時搭配的管理重點者
# DocumentBOX Outline: 安裝與設定JBoss EAP 7伺服器在Standalone與Domain模式上配置一個Domain部署Java應用程式在JBoss EAP 7伺服器上組態與JBoss EAP 7伺服器的DataSource連結工作組態Java Message Service與HornetQ組態與JBoss EAP 7伺服器的日誌相關設定部署應用程式的安全性與批次處理在JBoss EAP 7伺服器上認識JBoss EAP 7伺服器的Cluster環境
# Title of the webpage:
#
#     Red Hat OpenShift I：Containers和Kubernetes
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 想深入了解Container與Kubernetes如何組成微服務運作的軟體架構人員工作需求需要設計微服務的應用程式開發人員協助企業評估Container應用需求的架構工程人員
# DocumentBOX Outline: 了解Container、Docker和Red Hat OpenShift的Container架構建立Container化服務管理Container和Container的映像檔案管理客製Container映像檔在Red Hat OpenShift上部署搭配Container的應用程序部署多Container的應用程序
# Title of the webpage:
#
#     Red Hat Linux認證工程師培訓班
#
#
# Course duration: 98小時
# Course cost: NT$ 72,000
# Target audience: 1.Linux入門者、具備網路基本架構概念者2.想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124： Red Hat紅帽系統管理 I (35小時)RH134： Red Hat紅帽系統管理 II (35小時)RH294： Red Hat紅帽系統管理 III-Linux自動化(28小時)
# Title of the webpage:
#
#     Red Hat紅帽RHCSA 認證課程
#
#
# Course duration: 70小時
# Course cost: NT$ 50,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124：Red Hat紅帽系統管理 I (35小時)RH134：Red Hat紅帽系統管理 II (35小時)
# Title of the webpage:
#
#     Red Hat紅帽系統管理 I
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RHEL介紹Linux指令模式的使用在指令模式下進行檔案的管理如何取系統說明文件Linux的帳號管理檔案存取權限的管理Linux系統下的行程管理Linux系統下的服務管理OpenSSH的使用Linux系統的Log管理Linux系統下的網路管理Linux系統下的壓縮工具及檔案傳輸工具RHEL 9下的套件管理( DNF )Linux系統下的檔案系統管理
# Title of the webpage:
#
#     配置Aruba行動網路第一級
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 1.對無線通訊產業有高度興趣，欲從事相關工作者2.部署中小企業等級無線網路解決方案的網路IT專業人員
# DocumentBOX Outline: 介紹無線區域網路802.11與射頻(RF)基礎知識介紹以行動為優先的Aruba OS 8.X網路架構，包含行動控制台種類與運作模式設置Aruba行動主控台(Mobility Master)與行動控制台(Mobility Controller)，了解群組與子群組的分層設定，並介紹使用不同的配置方法將行動控制台加入到行動主控台使用行動主控台的GUI配置安全的無線區域網路，並解釋AP群組架構(AP Group)與其配置檔(AP Group Profile)介紹AP的配置佈建(AP Provisioning)，包含AP與行動控制台間的通訊、AP開機過程、與Control Plane保護機制(CPSec)介紹無線區域網路的資安概念，包含各種不同的WPA/WPA2 802.1X認證與MAC認證方法、對稱與不對稱加密金鑰、與使用WIPS來發現惡意的無線基地台(Rogue AP)介紹Aruba整合式防火牆策略與角色，包含以身份為基礎的Aruba防火牆、使用別名(alias)來設定防火牆策略與規則、與如何指派角色給用戶(Role Derivation)介紹Aruba自動管理射頻(RF)功能，包含Airmatch/ARM功能是如何校準網路來選擇最佳的頻道與設定功率、與Client Match功能是如何引導用戶連接更好的AP使用Captive portal搭配Clearpass認證伺服器來建置Aruba訪客造訪(Guest Access)的資安解決方案，與創建guest provisioning account介紹無線區域網路的監控與故障排除，包含使用Airwave與行動主控台儀表板功能來監控與診斷client/WLAN/AP相關疑難問題、與使用APPrf過濾功能來分析流量
# Title of the webpage:
#
#     網路基礎架構與網路服務
#
#
# Course duration: 42小時
# Course cost: NT$ 16,000
# Target audience: 想進入資訊領域，卻完全沒有資訊背景或經驗者想成為網路工程師、系統工程師，基礎不穩固或無基礎者跨領域學習工作者
# DocumentBOX Outline: 了解主/從(Client/Server)、雲端(Cloud Computing)架構微軟Hypervisor虛擬機器使用及操作ISO/OSI 7 Layer獨家精闢詳解細說乙太網路設備運作原理(訊號增益器、橋接器、交換器、路由器與閘道器)IPv4/IPv6位址、子網段切割、CIDR、Supernetting獨家教材詳解與教學廣域網路(WAN)介紹深入淺出TCP/IP網路重要概念路由(Routing)及網路位址轉譯(NAT)原理詳解及實作IT人員必備的基本網路服務的運作原理(DHCP、DNS、Web、FTP)資訊安全與防毒系統的整體概念
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 1.負責中大型企業網路運作與管理者2.需要中大型企業網路優化調校相關知識與技術者3.對於中大型企業網路運作機制有興趣瞭解者
# DocumentBOX Outline: 檢查思科企業網路架構與思科交換路徑建置園區域網路高可用性網路連接探索、建置及優化企業路由通訊協定（包含OSPF、EIGRP、BGP）介紹網路虛擬化協定與虛擬私人網路和介面探索無線原理、無線漫遊和定位服務與無線AP操作無線部署與無線客戶端身份驗證選項檢查與建置無線客戶端連接故障排除群播（Multicast）路由協定介紹介紹、建置QoS與其他網路服務使用網路分析工具了解企業網路安全架構建置基礎架構安全與安全訪問控制使用思科DNA中心探索自動化和保證，並且在Cisco DNA Center和vManage中導入API檢查思科SD-Access解決方案了解思科SD-WAN解決方案的工作原理介紹網路可開發性協議與Python程式設計基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CDCP資訊機房專業人員國際認證班
#
#
# Course duration: 14小時
# Course cost: NT$ 60,000
# Target audience: 資訊機房(Data Center)相關IT/設施人員資訊機房負責營運人員/管理層學習如何建置符合企業需求資訊機房(Data Center)的人員想取得CDCP國際認證者
# DocumentBOX Outline: 1.資料中心，重要性和停機的原因2.資料中心標準和最佳實踐3.資料中心的地點，建設和建設•   選擇合適的場所和建築物以及如何避免陷阱•   有效資料中心的各種組件和支持設施的設置4.高架地板/輕鋼架•   統一、集中和滾動載荷定義•   適用標準•   高架地板準則•   信號參考網格、機架接地•   殘疾法和法規•   輕鋼架的使用和要求5.照明•   標準•   照明類型和位置•   應急照明，應急電源(EPS)6.電力基礎設施•   從發電到機架的電力基礎設施佈局•   ATS和STS系統•   冗餘級別和技術•   三相和單相使用•   房中的配電選項•   電源線和母線槽•   連接和接地•   共模噪聲和隔離變壓器•   配電板，尺寸和IP保護等級•   電能質量準則•   有功功率和視在功率•   如何確定和計算資料中心的負載•   發電機•   靜態和動態UPS系統，選擇標準，操作模式和能效選項•   電池類型，正確的選擇和測試•   熱成像•   可再生能源係數 (REF，Renewable Energy Factor)7.電磁場•   電場和磁場的定義和測量單位•   電磁場的來源•   電磁場對人體健康和設備的影響•   (H)EMP•   標準•   EMF遮蔽解決方案8.機架•   機架標準、特性和選擇標準•   安全注意事項•   配電盤/槽選項9.冷卻基礎設施•   溫度和濕度建議•   冷卻測量單位和轉換率•   顯熱和潛熱定義•   舒適型與精密冷卻之間的差異•   不同的空調技術概述•   高架地板與非高架地板散熱•   空調單元的放置和限制•   補充冷卻選項•   冷通道/熱通道密閉•   液浸冷卻•   冷卻概念：季節性熱能儲存 (STER, Seasonal Thermal Energy Storage)10.供水•   供水和應用領域的重要性•   備用供水技術11.設計可擴展的網路基礎架構•   結構化佈線系統的重要性•   規劃注意事項•   銅和光纜技術和標準•   ANSI/ TIA-942佈線層次結構和建議•   測試與驗證•   網路冗餘•   建築物之間的連接•   網路監控系統要求12.防火•   滅火標準•   檢測系統•   各種全浸式滅火技術和系統、其優缺點•   手提式滅火器•   標牌與安全•   法規要求和最佳做法13.物理保全和人身安全•   物理保全考慮•   人身安全注意事項14.輔助系統•   資料中心監控要求•   EMS、BMS和DCIM•   漏水檢測系統•   警報通知
# Title of the webpage:
#
#     Designing and Implementing Storage on AWS
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端儲存工程師解決方案架構師雲端維運工程師DevOps工程師
# DocumentBOX Outline: 第一天：Module 1：雲端儲存介紹Module 2：設計物件儲存解決方案Module 3：使用Amazon S3建置物件儲存解決方案Module 4：設計區塊儲存解決方案第二天：Module 5：使用Amazon EBS建置區塊儲存解決方案Module 6：檔案儲存與Amazon EFSModule 7：使用Amazon FSx建置雲端檔案儲存第三天：Module 8：混合與邊緣的雲端儲存Module 9：搬移資料至AWSModule 10：AWS的備份與災難復原Module 11：對AWS儲存進行監控、自動化與最佳化
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Microsoft 365 Fundamentals認證班
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 由於本課程是許多將要銷售Microsoft 365服務的銷售員或專員的基本認證課程，所以只要是從事相關工作的人員都是要學習本課程的對象從事Microsoft 365相關服務銷售、代理、整合應用服務的銷售員、服務解說員想要認識、評估或使用Microsoft 365的操作人員、資訊工作者欲進一步熟悉Microsoft 365所提供軟體即應用服務的架構，與需要進行管理與維護的Microsoft 365管理員有志取得完整Microsoft 365 Certified：Fundamentals認證者
# DocumentBOX Outline: 展示Microsoft 365生產力和團隊合作的基本知識(Demonstrate fundamental knowledge of Microsoft 365 productivity and teamwork)展示Microsoft 365商務管理功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 business management capabilities)展示Microsoft 365授權、服務和支援的基礎知識(Demonstrate fundamental knowledge of Microsoft 365 licensing, service and support)展示Microsoft 365安全性與合規性功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 security and compliance capabilities)
# Title of the webpage:
#
#     Microsoft Azure基礎知識
#
#
# Course duration: 14小時
# Course cost: NT$ 12,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified Azure Fundamentals認證者
# DocumentBOX Outline: 描述雲端概念•      說明雲端運算•      說明使用雲端服務的優點•      描述雲端服務類型描述Azure架構與服務•      描述Azure的核心架構元件•      說明Azure計算和網路服務•      描述Azure儲存體服務•      說明Azure身分識別、存取和安全性描述Azure管理與治理•      說明在Azure中成本管理•      說明Azure中與治理及合規性相關的功能與工具•      說明管理和部署Azure資源的功能和工具•      說明Azure中的監視工具微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft安全性、合規性和身份基礎知識
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified：Security, Compliance, and Identity Fundamentals認證者
# DocumentBOX Outline: 安全性、合規性和身份的基本概念Microsoft身份和存取管理解決方案的觀念及功能Microsoft安全解決方案Microsoft合規性管理的功能微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Red Hat紅帽系統管理II
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習Linux系統管理的IT人員
# DocumentBOX Outline: Linux系統下文字模式的進階使用及shell scriptLinux系統下的排程管理Linux系統下的效能調校SELinux系統的管理Linux系統下的硬碟管理及儲存空間的使用Linux Volume Manage的管理及使用NFS Client的使用Linux系統的開機流程RHEL 9的網路存取控制安裝RHEL 9虛擬化技術 / 容器技術
# Title of the webpage:
#
#     VMware Aria Automation安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: System administrators and system integrators responsible for designing, implementing, and managing VMware Aria Automation
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.VMware Aria Automation Overview and Architecture• Describe the purpose and functionality of VMware Aria Automation• Identify the key services offered by VMware Aria Automation• Describe the VMware Aria Automation architecture• Describe the use of VMware Workspace ONE Access™• Describe the relationship between Kubernetes clusters, container, and VMware Aria Automation services3.Installing VMware Aria Automation• List the different VMware Aria Automation deployment types• Describe the purpose of Easy Installer• Describe the VMware Aria Automation installation process4.Authentication and Authorization• Identify the steps to integrating Workspace ONE® Access with Active Directory• Describe the features of Workspace ONE Access• Describe the user roles available in VMware Aria Automation• Identify the key tasks performed by each user role• Define custom roles• Configure branding and multitenancy5.Basic Initial Configuration• Create a basic configuration with a cloud account, cloud zone, project, flavor mapping, and image mapping6.VMware Aria Automation Templates• Configure and deploy a basic VMware Aria Automation template• Create a VMware Aria Automation template that can run on any cloud• Use cloudConfig and cloudbase-init to run commands, create users, and install software• Use YAML for inputs, variables, and conditional deployments7.Tags• Configure tags• Describe functions of tags• Manage tags
# 8.Storage Configuration• Configure storage profiles• Use tags and storage profiles9.Integrating NSX With VMware Aria Automation• List the capabilities and use cases of VMware NSX®• Describe the NSX architecture and components• Integrate NSX with VMware Aria Automation• List the supported network profiles in VMware Aria Automation• Use the NSX components to design a multitier application with VMware Aria Automation Templates• Identify the network and security options available in design canvas• Create and manage on-demand networks and security groups• Configure NSX Day 2 actions10.Integrating with Public Clouds• Configure and use VMware Cloud Foundation™ accounts• Integrate VMware Cloud Director™ account• Configure and use an AWS cloud account• Configure and use an Azure cloud account• Configure and use a Google Cloud Platform cloud account• Integrate VMware Cloud on AWS cloud account11.Using VMware Aria Automation Consumption• Release a VMware Aria Automation template• Define content source and content sharing• Define VMware Aria Automation policy enforcement• Use custom forms for catalog items12.VMware Aria Automation Extensibility• Describe VMware Aria Automation extensibility• Use event topics• Create a subscription• Call a VMware Aria Automation Orchestrator workflow• Create ABX actions13.Using Kubernetes Clusters• Introduction to Kubernetes• Connect to an existing Kubernetes Cluster• Create a VMware Aria Automation template with Kubernetes components14.Using VMware Aria Automation Config for Configuration Management• Describe VMware Aria Automation Config• Use VMware Aria Automation Config for software deployment• Use VMware Aria Automation Config for configuration management• Use VMware Aria Automation Config with event-driven orchestration15.VMware Aria Automation Troubleshooting and Integration• Demonstrate how to monitor deployment history• Demonstrate basic troubleshooting• Execute CLI commands• Explain how to collect logs• Describe integration with VMware Aria Operations for Logs• Describe integration with VMware Aria Operations
# Title of the webpage:
#
#     VMware Kubernetes Fundamentals and Cluster Operations
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Anyone who is preparing to build and run Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction•  Introductions and objectives2.Containers•  What and Why containers•  Building images•  Running containers•  Registry and image management3.Kubernetes Overview•  Kubernetes project•  Plugin interfaces•  Building Kubernetes•  Kubectl CLI4.Beyond Kubernetes Basics•  Kubernetes objects•  YAML•  Pods, replicas, and deployments•  Services•  Deployment management•  Rolling updates•  Controlling deployments•  Pod and container configurations5.Kubernetes Networking•  Networking within a pod•  Pod-to-Pod Networking•  Services to Pods•  ClusterIP, NodePort, and LoadBalancer•  Ingress controllers•  Service Discovery via DNS6.Stateful Applications in Kubernetes•  Stateless versus Stateful•  Volumes•  Persistent volumes claims•  StorageClasses•  StatefulSets7.Additional Kubernetes Considerations•  Dynamic configuration•  ConfigMaps•  Secrets•  Jobs, CronJobs8.Security•  Network policy•  Applying a NetworkPolicy•  SecurityContext•  runAsUser/Group•  Service accounts•  Role-based access control9.Logging and Monitoring•  Logging for various objects•  Sidecar logging•  Node logging•  Audit logging•  Monitoring architecture•  Monitoring solutions•  Octant•  VMware vRealize®Operations Manager™10.Cluster Operations•  Onboarding new applications•  Backups•  Upgrading•  Drain and cordon commands•  Impact of an upgrade to running applications•  Troubleshooting commands•  VMware Tanzu™ portfolio overview
# Title of the webpage:
#
#     VMware NSX安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: Experienced security administrators or network administrators
# DocumentBOX Outline: 1.Course Introduction2.VMware Virtual Cloud Network and VMware NSX3.Preparing the NSX Infrastructure4.NSX Logical Switching5.NSX Logical Routing6.NSX Bridging7.NSX Firewalls8.NSX Advanced Threat Prevention9.NSX Services10.NSX User and Role Management11.NSX Federation
# Title of the webpage:
#
#     VMware Tanzu Kubernetes Grid安裝及設定管理課程
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Platform operators who are responsible for deploying and managing Tanzu Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction2.Introducing VMware Tanzu Kubernetes Grid3.VMware Tanzu Kubernetes Grid CLI and API4.Authentication5.Load Balancers6.VMware Tanzu Kubernetes Grid on vSphere7.VMware Tanzu Kubernetes Grid on Public Clouds8.Tanzu Kubernetes Workload Clusters9.Tanzu Kubernetes Grid Packages10.Configuring and Managing Tanzu Kubernetes Grid Operation and Analytics Packages11.Configuring and Managing Tanzu Kubernetes Grid Networking Packages12.Tanzu Kubernetes Grid Day 2 Operations13.Troubleshooting Tanzu Kubernetes Grid
# Title of the webpage:
#
#     VMware vSphere安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 69,900
# Target audience: 系統管理員系統工程師
# DocumentBOX Outline: 1.Course Introduction2.vSphere and Virtualization Overview3.Installing and Configuring ESXi4.Deploying and Configuring vCenter5.Configuring and Managing Virtual Networks6.Configuring vSphere Storage7.Deploying Virtual Machines8.Managing Virtual Machines9.Deploying and Configuring vSphere Clusters10.Managing the vSphere Lifecycle
# Title of the webpage:
#
#     Windows Server 2016的安裝、儲存及運算
#
#
# Course duration: 42小時
# Course cost: NT$ 28,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望提升企業資訊服務高可用性與負載平衡的管理者與規劃人員
# DocumentBOX Outline: Nano、Server Core伺服器準備、安裝、升級與遷移的策略設定本地儲存裝置企業儲存解決方案儲存空間與重複資料刪除安裝設定Hyper-V與虛擬機器部署管理Windows與Hyper-V容器(Container)高可用性與災難恢復的概論施作與管理容錯移轉叢集建置Hyper-V虛擬機器的容錯移轉叢集配置網路負載平衡(NLB)建立、管理與部署映像檔案(Image)管理、監控和維護虛擬機器的安裝
# Title of the webpage:
#
#     配置Aruba行動網路第二級
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 1.負責中大型企業無線網路維運、管理與部署相關工作者2.對中大型企業無線網路技術有高度興趣者
# DocumentBOX Outline: 回顧配置Aruba行動網路第一級的課程主題，包含各種AP專業用語、圖形界面的分層架構、與WLAN轉發模式介紹行動主控台的備援機制(Mobility Master Redundancy)，包含VRRP的安裝設定、與MM資料庫的同步介紹行動主控台(MM)與行動控制台(MC)的操作，包含行動控制台的各種部署方式、與安裝設定許可證(license)的進階功能介紹Multizone功能，包含Multizone AP功能流程、Primary與Data zone、與Multizone故障排除介紹MC叢集(Cluster)功能，包含cluster leader選舉過程、MC叢集角色、無中斷式叢集的故障切換(hitless cluster failover)、與叢集內部AP和用戶的負載平衡介紹Aruba行動漫遊(Roaming)功能，包含標準的802.11漫遊、單台與多台行動控制台間的漫遊、與叢集式的行動漫遊(Cluster Mobility)介紹角色的指派(Role Derivation)功能，包含使用VSA來解釋角色的指派、描述用戶規則(user rule)與認證預設角色(authentication default role)、解釋如何做故障排除、與以角色為基礎的ACL介紹Aruba遠端存取(Remote Access)的各種解決方案(RAP/VIA/IAP-VPN/branch controller)，包含RAP的認證、安裝、設定、備援選項及故障排除、與VIA的設定、下載、安裝及故障排除介紹Aruba語音最佳化功能，包含檢視語音QoS、解釋WMM、描述UCC Heuristic與SDN API運行模式、語音連線的監控與故障排除介紹Aruba網狀無線網路(Mesh)功能，包含mesh技術、與mesh cluster設定介紹Aruba裝置的管理，包含管理帳戶與其密碼的重置、設定Guest Provisioning account、使用RADIUS或TACACS認證、與如何取消console access介紹行動控制台的操作，包含如何升級新的影像檔、AP image preload、cluster in service的升級、設定檔的自動回滾(Auto roll back)功能、與可載入的服務模組(LSM)介紹Aruba AirGroup功能，包含AirGroup解決方案的設定及其限制、與ClearPass的整合、AirGroup伺服器與用戶的監控介紹自動分段(Dynamic Segmentation)功能，包含以端口為基礎的通道功能(PBT)與以用戶為基礎的通道功能(UBT)、描述交換機與行動控制台的互動、與如何排除tunnel連線的故障介紹Aruba AirWave管理平台，包含描述AirWave功能、使用群組與檔案夾、設定裝置憑證(device credential)、與如何添加新裝置介紹使用AirWave平台來識別與監控網路健康問題，包含解釋診斷頁面的指示、使用網路健康圖形來識別網路問題、使用效能圖形來幫助網路規劃、與使用Clarity功能引導管理員尋找問題的根源介紹使用AirWave平台來排除用戶與AP裝置的疑難問題，包含解釋如何搜尋用戶與排除相關問題、調查用戶SNR、與如何在AirWave內監控MC叢集介紹使用AirWave平台的VisualRF、報告與警示功能，包含解釋不同的VisualRF顯示選項、描述VisualRF應用程式的監控、設定triggers以創建alerts、與生成22種各式各樣的報告
# Title of the webpage:
#
#     區域網路規劃與架設導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對通訊網路產業有高度興趣，想從事相關工作者有志從事網路規劃的IT人員欲自我提升能力的網路系統工程師
# DocumentBOX Outline: 網路規劃的基本觀念網路規劃的方法論規劃企業區域網路應有的考量VLAN的規劃概要IP位址的規劃概要線路備援的規劃概要網路管理的規劃案例研討
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     管理Exchange Server 2016及2019
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 對微軟郵件訊息平台有興趣者對Exchange Server 2016/2019管理有濃厚興趣，欲成為Exchange Server管理者本身為Exchange Server 2003/2007/2010管理者，欲晉升為Exchange Server 2016/2019管理者
# DocumentBOX Outline: 部署Exchange Server 2019，和在Server Core上安裝Exchange Server 2019管理Exchange Server信箱伺服器建立和管理各種收件者物件，和配置地址清單的策略使用EMS管理收件者物件和Exchange伺服器規劃用戶端連線、部署和配置用戶端存取服務管理Exchange Server伺服器的高可用性實作Exchange Server伺服器角色的災難復原設定及管理訊息傳輸架構設定防毒、垃圾郵件以及防惡意程式保護Exchange Server的監視和疑難排解保護和維護Exchange Server的管理稽核規劃及管理Exchange Online的部署
# Title of the webpage:
#
#     ACA-Campus Access認證－Aruba園區存取網路基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 網路現場技術人員、部署技術人員、第1級NOC人員、或具有Aruba產品實作經驗的初級網路工程師具有1年以上的網路經驗為佳，並且瞭解各家廠商通用的基本網路協定想要取得(Aruba Certified Associate - Campus Access)國際認證者
# DocumentBOX Outline: Networking Fundamentals－解釋OSI模型與封包封裝、TCPIP堆疊、討論不同種類的實體介質、與比較單播、群播與廣播AOS-CX Switching Fundamentals－介紹交換機的初始設定、如何配置VLAN與tagging、如何使用LLDP與ICMP做為網路發現與診斷、如何配置Link aggregation以增進效能Basic IP Setup－討論inter-VLAN routing、解釋DHCP relay、討論Static IP routing、解釋如何配置單一區域的OSPFNetwork Redundancy－討論Spanning Tree、解釋VRRP與VSXVSF－介紹VSF、解釋如何配置VSF、描述Auto-VSF、解釋VSF MADIntroduction to Aruba Solutions－介紹Aruba交換機與WLAN的產品組合、介紹Aruba Central與ClearPassCentral for Device Mangement－介紹Device Onboarding、描述如何創建Central Groups、描述UI設定模式、描述template設定解釋如何實施模式、描述Aruba Central licensingDevice Profiles and AP Onboarding－描述Device Profiling的使用、描述LLDP與MAC profiling、解釋如何連接AP到Aruba Central、解釋如何實施AP的初始設定WLAN Fundamentals－描述802.11與射頻(RF)基礎知識、解釋SNR、描述漫遊標準與QoS需求、描述射頻的規劃、解釋如何配置WLANImplementing Secure WLANs－介紹AAA、描述802.1X認證、解釋如何配置安全的WLAN、討論角色(roles)與訪問規則Implementing Guest Access－解釋如何配置captive portal認證、描述如何設定guest WLANWLAN Security－介紹無線網路的資安、解釋憑證(certificates)、描述雲端認證Monitoring and Maintenance－解釋如何使用Aruba Central的監控能力、描述如何識別LED狀態、解釋如何實施firmware的升級、描述如何啟動設備的SNMP、描述AI Insights、描述警報與報告、解釋UXITroubleshooting－描述如何實施密碼復原與重置出廠設定步驟、解釋Central connectivity的故障排除、描述如何啟動頻譜的分析(spectrum analysis)、探索Central排除故障的工具
# Title of the webpage:
#
#     AWS Cloud Practitioner Essentials
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 銷售法律行銷商業分析師專案經理高層主管AWS Academy學員其他 IT 相關專業人員
# DocumentBOX Outline: 雲端概念AWS服務安全性架構定價與支援
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科高級企業等級路由與服務
#
#
# Course duration: 42小時
# Course cost: NT$ 68,000
# Target audience: 1.企業路由基礎架構管理與規劃人員2.企業路由解決方案規劃與支援人員3.對大型企業網路運作技術有興趣者
# DocumentBOX Outline: EIGRP建置、優化與疑難排解OSPF建置、優化與疑難排解BGP建置、優化與疑難排解路由重新發佈（Redistribution）設定與疑難排解建置路徑控制探討及探討L3 MPLS VPN架構與路由設定簡化的虛擬路由與轉送（VRF-Lite）建置動態多點虛擬私人網路（DMVPN）建置與疑難排解DHCP介紹IPv6的第一站安全性保全思科路由器疑難排解安全架構與服務針對DNA Center Assurance 進行疑難排解
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     Microsoft 365管理者認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 本課程適用於有志成為Microsoft 365系統管理員角色的IT人員
# DocumentBOX Outline: 部署與設定您的Microsoft 365租用戶環境管理您的Microsoft 365租用戶環境部署與地端AD目錄服務的識別驗證同步服務作業探索Microsoft 365的安全指標管理您在Microsoft 365 Defender中的安全服務如何使用Microsoft 365 Defender來部署威脅保護探索在Microsoft 365的資料治理部署在Microsoft 365中的合規性管理在Microsoft 365中的合規性
# Title of the webpage:
#
#     Microsoft Azure管理員認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure的使用經驗欲進一步熟悉Azure基礎結構建置、管理與維護的Azure管理員有志取得Microsoft Certified：Azure Administrator Associate認證者
# DocumentBOX Outline: 身份識別•     Azure Active Directory(Microsoft Entra ID)、Users and Groups治理與合規•     Subscriptions and Accounts、Azure Policy、Role-based Access ControlAzure管理•     Azure Resource Manager、Azure Portal and Cloud Shell、Azure PowerShell and CLI、ARM Templates虛擬網路•     Virtual Networks、IP Addressing、Network Security Groups、Azure Firewall、Azure DNS網路間連接•     Vnet Peering、VPN Gateway Connections、ExpressRoute and Virtual WAN網路流量管理•     Network Routing and Endpoints、Azure Load Balancer、Azure Application GatewayAzure儲存體帳戶•     Storage Accounts、Blob Storage、Storage Security、Azure Files and File Sync、Managing StorageAzure虛擬機器•     Virtual Machine Planning、Creating Virtual Machines、Virtual Machine Availability、Virtual Machine Extensions管理PaaS運算選項•     Azure App Service Plans、Azure App Service、Container Services、Azure Kubernetes Service、Azure Container Instance資料保護•     File and Folder Backups、Virtual Machine Backups監視•     Azure Monitor、Azure Alerts、Log Analytics、Network Watcher
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     Microsoft安全營運分析師
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，且已具備Azure與Microsoft 365使用經驗欲進一步熟悉Azure安全營運與Microsoft 365安全營運的分析師有志取得Microsoft Certified：Security Operations Analyst Associate認證者
# DocumentBOX Outline: 使用Microsoft 365 Defender緩解威脅使用Microsoft Defender for Endpoint緩解威脅使用Microsoft Defender for Cloud緩解威脅使用Kusto Query Language(KQL)為Microsoft Sentinel建立查詢設定您的Microsoft Sentinel環境將logs連接到Microsoft Sentinel使用Microsoft Sentinel建立檢測並執行調查在Microsoft Sentinel中執行威脅搜尋微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     RHCA認證-Red Hat OpenShift開發II：容器化應用
#
#
# Course duration: 28小時
# Course cost: NT$ 56,000
# Target audience: 企業應用開發人員站點可靠性工程師
# DocumentBOX Outline: 管理和觸發應用建置版本自定義現有Source-to-image基礎鏡像建立OpenShift模板建立健康檢查，監控和提高應用可靠性建立和部署Jenkins流水線，以實現持續集成和持續部署為OpenShift建立和部署雲原生應用
# Title of the webpage:
#
#     VMware NSX疑難排除與操作課程
#
#
# Course duration: 35小時
# Course cost: NT$ 84,400
# Target audience: • Experienced system administrators and network administrators• Network and security professionals who work with enterprise networks
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.NSX Operations and Tools• Explain and validate the native troubleshooting tools for NSX• Configure syslog, IPFIX, and log collections for the NSX environment• Integrate NSX with VMware Aria Operations for Logs and VMware Aria Operations for Networks• Validate and review the API methods available to configure the NSX environment3.Troubleshooting the NSX Management Cluster• Describe the NSX Management cluster architecture, components, and communication channels• Identify the workflows involved in configuring the NSX Management cluster• Validate and troubleshoot the NSX Management cluster formation4.Troubleshooting Infrastructure Preparation• Describe the data plane architecture, components, and communication channels• Explain and troubleshoot VMware ESXi transport node preparation issues• Explain and troubleshoot NSX Edge deployment issues5.Troubleshooting Logical Switching• Describe the architecture of logical switching• List the modules and processes involved in configuring logical switching• Explain the importance of VDS in transport nodes• Review the architecture and workflows involved in attaching workloads to segments• Identify and troubleshoot common logical switching issues6.Troubleshooting Logical Routing• Review the architecture of logical routing• Explain the workflows involved in the configuration of Tier-0 and Tier-1 gateways• Explain the high availability modes and validate logical router placements• Identify and troubleshoot common logical routing issues using both BGP and OSPF7.Troubleshooting Security• Review the architecture of the Distributed Firewall• Explain the workflows involved in configuring the Distributed Firewall• Review the architecture of the Gateway Firewall• Explain the workflows involved in configuring the Gateway Firewall• Identify and troubleshoot common Distributed firewall and Gateway Firewall issues• Review the architecture and workflows involved in configuring Distributed IDS/IPS• Identify and troubleshoot common Distributed IDS/IPS problems8.Troubleshooting Services• Review the NSX Advanced Load Balancer architecture and components• Identify and troubleshoot common NSX Advanced Load Balancer issues• Review the IPsec and L2 VPN architecture and components• Identify and troubleshoot common IPsec and L2 VPN issues9.Datapath Walkthrough• Verify and validate the path of the packet on the NSX datapath• Identify and perform packet captures at various points in the datapath• Use NSX CLI and native hypervisor commands to retrieve configurations involved in the NSX datapath
# Title of the webpage:
#
#     VMware vSphere新增功能
#
#
# Course duration: 14小時
# Course cost: NT$ 30,600
# Target audience: System architects, system administrators, IT managers, VMware partners, and individuals responsible for implementing and managing vSphere architectures who want to deploy vSphere 8.0 into their existing vSphere environment.
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.Artificial Intelligence and Machine Learning• Describe how device groups support AI and ML in vSphere 8.0• Describe how device virtualization extensions support AI and ML in vSphere 8.03.vSphere Distributed Services Engine• Describe the benefits of Distributed Services Engine• Explain how Distributed Services Engine works• Recognize use cases for Distributed Services Engine• Install ESXi on a host equipped with a DPU• View DPU information in the vSphere Client• Add an ESXi host equipped with a DPU to a cluster• Use vSphere Lifecycle Manager to update an ESXi host that contains a DPU• Create a vSphere distributed switch for network offloads• Add a host with a DPU to the vSphere distributed switch• Configure a VM to use uniform passthrough mode4.vSphere and vCenter Management• Describe improvements to the communication between vCenter and ESXi hosts• Describe enhancements to the vCenter recovery process5.ESXi Enhancements• Describe the function of the central configuration store in ESXi• Explain how ConfigStore affects interaction with ESXi configuration files• Recognize the supported system storage partition configuration on ESXi 8.0• Identify devices supported for system storage on ESXi 8.0• Configure an RDMA host local device on ESXi 8.06.vSphere Storage• Describe the VMware vSAN¬ Express Storage Architecture• Recognize the benefits of using vSAN Express Storage Architecture• Describe the benefits of using NVMe• Recognize the support for NVMe devices in vSphere 8.07.Guest OS and Workloads• Review the enhancements of the latest virtual hardware versions• Describe the features introduced with virtual hardware version 20• Identify the snapshot modes of NVDIMM devices8.Resource Management• View energy and carbon emission metrics in VMware vRealize® Operations Manager™• Describe the vSphere Memory Monitoring and Remediation (vMMR) functionality• Describe how vMMR enhances the performance of DRS9.Security and Compliance• Describe how to manage vTPM secrets when cloning a VM• Manage OVF templates for VMs configured with vTPM• Deploy an OVF template with vTPM• Describe the enhancements to trusted binary enforcement in ESXi• Describe ESXi 8.0 enhanced security features10.vSphere Lifecycle Manager• Describe the enhancements to life cycle management of standalone ESXi hosts• Manage the configuration profiles of ESXi hosts in a cluster• Use Auto Deploy to boot a host with the desired image and configuration specifications• Upgrade multiple ESXi hosts in a cluster in parallel• Stage an ESXi host image before remediation11.Auto Deploy• Manage custom host certificates using Auto Deploy12.vSphere with Tanzu• Describe the features of Vmware Tanzu® Kubernetes Grid™ 2.013.Announcing vSphere+• Describe the functionality and benefits of vSphere+
# Title of the webpage:
#
#     企業IT服務伺服器架設與選擇方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對IT產業有興趣、想從事伺服器管理相關工作者想學習認識企業建構伺服器有哪些不同的異質平台(如：Windows、Linux、Mac等)可供選擇者
# DocumentBOX Outline: 企業常見IT伺服器平台介紹企業常見IT伺服器應用介紹File伺服器介紹Proxy/NAT/Firewall介紹DNS伺服器介紹Web伺服器介紹Mail伺服器介紹集中驗證伺服器介紹授權伺服器軟體vs.免費伺服器軟體Hands on Lab
# Title of the webpage:
#
#     ACP-Campus Access認證－建置Aruba園區存取網路
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 第2/3級NOC人員、網路分析師、或具有2-5年Aruba產品組合經驗的網路工程師為佳想要取得(Aruba Certified Professional - Campus Access)國際認證者
# DocumentBOX Outline: Introduction to Aruba Solutions－介紹Aruba ESP架構、Aruba產品組合、自動化與REST APIBuilding Wired Infrastructure－介紹VSX、OSPF、虛擬化路由與轉發、以策略為基礎的路由、Aruba Central Template GroupsWireless Infrastructure with Aruba Gateways－介紹AOS 10與Central Groups、Aruba Gateways的部署、Gateway的初始設定、Gateway ClusterTunneled WLAN Architecture－介紹Tunneled Mode WLAN、Client MonitoringSecure Enterprise WLAN－介紹802.1X認證、防火牆Roles與Role Derivation、CoA支持Guest and Captive Portal－介紹訪客的訪問、訪客認證過程、訪客WLAN配置、MAC快取Wireless Authentication for IoT－介紹MPSK、MPSK認證過程、本地MPSK設定Mixed Mode Architecture－介紹Aruba混合模式WLAN、與其設定Gateway Cluster Deployments－介紹Cluster部署選項、Cluster設定、Cluster監控、Secondary GatewayWired Port Access－介紹Wired認證、802.1X設定、MAC認證、RADIUS Attributes與Roles、動態分段、Wired Captive PortalVXLAN and GBP－介紹分散式Overlay與VXLAN、VXLAN GBPSecurity and Availability Features－介紹IDS/IPS、Authentication Survivability、Central Survivability、管理用戶認證Traffic Optimization and QOS－介紹WLAN優化、AirGroup、服務品質、UCC、LLDP MEDMonitoring－介紹Central警告、Device Insights、用戶體驗Insights
# Title of the webpage:
#
#     AWS Cloud Financial Management for Builders
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 解決方案架構師開發者成本優化管理者系統管理者
# DocumentBOX Outline: 雲端服務財務管理導論：管理簡介、四個支柱、資源標記定價與成本：定價基礎、AWS免費方案、批量折扣、儲蓄計劃、預留實例AWS的帳單、報告、監控、發票、預算運算資源的成本構建：Amazon EC2規格調整、購買選項、Amazon CloudWatch監控和自動化、Amazon EC2競價型實例、自動化基礎架構、無伺服器解決方案網路資源的成本構建：資料傳輸費用、不同服務的資料成本、如何分攤網路成本儲存資源的成本構建：Amazon EBS、Amazon S3、Amazon EFS的成本、定價和最佳實踐資料庫資源的成本構建：Amazon RDS、Amazon Aurora、Amazon DynamoDB、Amazon ElastiCache、Amazon Redshift的成本、定價和最佳實踐成本治理：設置AWS組織、AWS Systems Manager
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科SD-WAN解決方案
#
#
# Course duration: 35小時
# Course cost: NT$ 79,000
# Target audience: 企業路由基礎架構管理與規劃人員企業路由解決方案規劃與支援人員對大型企業網路運作技術有興趣者
# DocumentBOX Outline: 檢查 Cisco SD WAN 架構檢查 Cisco SD-WAN 部署選項部署廣域網路邊緣設備設備設定管理探索冗餘、高可用性和可擴展性啟用服務端和傳輸端路由了解Cisco SD-WAN策略配置基礎知識定義高階控制策略定義高階資料策略建置應用程式體驗品質（Application Quality of Experience）建置應用程式感知路由（Application-Aware Routing）檢查直接Internet訪問和雲部署選項探索思科SD-WAN安全性設計和遷移到Cisco SD-WAN執行Cisco SD-WAN網路管理和故障排除檢查Cisco SD-WAN群播支持
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     Microsoft Azure安全性技術
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事Azure系統與網路管理之管理人員或系統工程師欲進一步了解Azure安全性技術者有志取得Microsoft Certified：Azure Security Engineer Associate認證者
# DocumentBOX Outline: 管理身分識別和存取•     Azure Active Directory(Microsoft Entra ID)•     Azure身分保護•     企業治理•     設定Azure AD特權身份管理•     混合身分識別實行平台防護•     周邊網路的安全性•     網路安全性•     主機安全性•     容器安全性保全資料與應用程式•     Azure金鑰保存庫•     應用程式安全性•     儲存體安全性•     SQL資料庫安全性管理安全操作•     Azure監視•     Microsoft Defender for Cloud•     Microsoft Sentine微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft身份和存取管理員
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，並已具備Azure的管理技能欲進一步了解在安全架構中規劃與解決方案的專業人員有志取得Microsoft Certified：Identity and Access Administrator Associate認證者
# DocumentBOX Outline: 實施身份管理解決方案實施身份驗證和存取解決方案實施應用程式的存取管理規劃和實施身份治理的策略微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Red Hat OpenShift管理III：在企業中擴展Kubernetes部署
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 專為想要在其數據中心部署和管理大型Red Hat OpenShift Container Platform環境的系統管理人員而設計
# DocumentBOX Outline: 身份驗證和身份管理備份、還原和遷移OADP(OpenShift API for Data Protection) 的應用程式叢集分區Pod 調度OpenShift GitOpsOpenShift 監控OpenShift 日誌記錄
# Title of the webpage:
#
#     VMware vSphere設計規劃課程
#
#
# Course duration: 21小時
# Course cost: NT$ 50,700
# Target audience: Experienced system integrators and consultants responsible for designing and deploying vSphere environments
# DocumentBOX Outline: Course Introduction•          Introductions and course logistics•      Course objectivesInfrastructure Assessment•      Follow a proven process to design a virtualization solution•          Define customer business objectives•          Gather and analyze business and application requirements•      Document design requirements, constraints, assumptions, and risks•      Use a systematic method to evaluate and document design decisions•      Create a conceptual designCore Management Infrastructure•          Determine the number of VMware vCenter® Server ApplianceTM instances to include in a design•      Choose the appropriate single sign-on identity source•      Choose the time synchronization method•          Choose methods to collect log files and ESXi core dumps•          Design a vCenter Server deployment topology that is appropriate for the size and requirements of the data centerVirtual Data Center Infrastructure•      Calculate total compute capacity requirements for a virtual data center•          Create a virtual data center cluster design that meets business and workload requirements•      Evaluate in the virtual data center the use of several management services, such as VMware vSphere® High Availability and VMware vSphere® Distributed Resource Scheduler™•      Evaluate the use of resource pools in the virtual data center designCompute Infrastructure•      Create a compute infrastructure design that includes the appropriate ESXi boot, installation, and configuration options•      Choose the ESXi host hardware for the compute infrastructureStorage Infrastructure•      Calculate storage capacity and performance requirements for a design•          Evaluate the use of different storage platforms and storage management solutions•      Design a storage platform infrastructure and storage management architecture that meets the needs of the vSphere environmentNetwork Infrastructure•      Evaluate the use of different network component and network management solutions•      Design a network component architecture that includes information about network segmentation and virtual switch types•      Design a network management architecture that meets the needs of the vSphere environmentVirtual Machine Design•      Make virtual machine design decisions, including decisions about resources•      Design virtual machines that meet the needs of the applications in the vSphere environment and follow VMware best practicesInfrastructure Security•      Make security design decisions for various layers in the vSphere environment•      Design a security strategy that meets the needs of the vSphere environment and follows VMware best practicesInfrastructure Manageability•          Make lifecycle management, scalability, and capacity planning design decisions that adhere to business requirements•      Design lifecycle management, scalability, and capacity planning strategies that meet the needs of the vSphere environment and follow VMware best practicesInfrastructure Recoverability•      Make infrastructure recoverability design decisions that adhere to business requirements•          Design an infrastructure recoverability strategy that meets the needs of the vSphere environment and follows VMware best practices
# Title of the webpage:
#
#     Windows Server 2016的身分識別
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望經由AD目錄服務整合憑證、版權管理及防護機敏資料的管理人員已具備Windows Server 2008/2012 AD網路管理經驗者
# DocumentBOX Outline: 安裝與設定網域控制器(DC)管理AD DS系統與物件進階AD DS基礎結構管理施作與管理AD DS站台與複寫群組原則部署與除錯運用群組原則管理用戶設定強化AD DS的安全性部署與設定AD憑證服務(AD CS)配置與管理憑證實施與管理AD同盟服務(AD FS)實施與管理AD版權管理服務(AD RMS)部署AD DS與Microsoft Azure AD的同步監視、管理、與復原AD DS
# Title of the webpage:
#
#     企業資料的備份與救援簡易解決方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: IT人員，管理伺服器與資料安全領域相關工作者想了解企業與個人資料保全相關技術者
# DocumentBOX Outline: 設計企業資料保全政策資料安全風險評估選擇備份媒體、方法與技術排程備份與檢視備份資料救援與系統快照磁碟陣列儲存網路異地備援備份反運作：數位資源的抹除大量的實務練習
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     製作適用於Microsoft 365的Microsoft Copilot的有效提示
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 學習者應熟悉Microsoft 365應用程式，例如Word、Excel和PowerPoint。本課程適用於使用Microsoft 365的Microsoft Copilot的所有類型使用者
# DocumentBOX Outline: 適用於Microsoft 365的Copilot簡介探索使用適用於Microsoft 365的Copilot的可能性優化和擴充適用於Microsoft 365的Copilot使用Microsoft Copilot for Microsoft 365進行總結使用Microsoft Copilot for Microsoft 365建立和起草文案使用Microsoft Copilot for Microsoft 365編輯和轉換內容使用Microsoft Copilot for Microsoft 365提出問題並分析內容
# Title of the webpage:
#
#     Azure管理員及解決方案架構專家雙認證班
#
#
# Course duration: 63小時
# Course cost: NT$ 55,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure使用經驗欲進一步熟悉Azure基礎結構建置、管理、維護及解決方案架構設計的IT管理員
# DocumentBOX Outline: AZ104：Microsoft Azure管理員認證班(35小時)•　 身份識別•　 治理與合規•　 Azure管理•　 虛擬網路•　 網路間連接•　 網路流量管理•　 Azure儲存體帳戶•　 Azure虛擬機器•　 管理PaaS運算(Web App、ACI及AKS)•　 資料保護•　 監視AZ305：設計Microsoft Azure基礎結構解決方案(28小時)•　 設計治理與計算解決方案•　 設計儲存體和資料整合解決方案•　 設計應用程式架構•　 存取和監視解決方案•　 設計網路、持續性和移轉解決方案微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# ...
# Title of the webpage:
#
#     前端必學的網頁開發基礎技能
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 對網頁開發有興趣的所有人員
# DocumentBOX Outline: HTML 文件結構HTML 常用與語意標籤圖片、表格與超連結標籤表單的建立影音多媒體標籤CSS 基本語法CSS 選取方式介紹色彩與文字設定寬度與高度屬性CSS 外框模型背景與漸層屬性定位方式與版面設定媒體查詢Flex 彈性排版效果響應式網頁設計變形與動畫效果JavaScript語法簡介以JavaScript設定簡易互動效果
# Title of the webpage:
#
#     前端網頁與UI設計師轉職就業養成班
#
#
# Course duration: 306小時
# Course cost: NT$ 72,000
# Target audience: 不需要相關科系背景或經歷，只要是對從事平面設計、網頁設計、App設計、網路數位行銷、網頁互動、數位內容產業有興趣者都可以參加
# DocumentBOX Outline: - Photoshop視覺影像與前端設計應用 30小時課程將帶您進入Photoshop的神奇世界，學習如何製作令人驚豔的視覺效果，包括圖片編輯、多媒體應用設計，讓您學會用電腦製作出您腦中的無限創意設計。- Illustrator專業向量繪圖與動畫素材設計 24小時您將掌握Illustrator並專注於網頁素材和動畫設計，這是一個非常重要的關鍵技能，對於網站和應用程序的成功至關重要。- Photoshop與Illustrator專業App UI介面視覺設計 24小時課程涵蓋App UI介面的視覺設計，教您如何設計流暢的用戶界面，並將您的視覺設計技能應用於使用者體驗設計當中。- Figma專業UI設計實作 18小時透過對Figma的深入研究，您將學會如何使用這個領先的UI設計工具，並在實際專案中應用您的技術。- Adobe Animate CC 製作HTML5動畫與互動效果 24小時課程將幫助您掌握Adobe Animate CC，以製作出生動的HTML5動畫和互動效果，使您的網頁更具吸引力。- HTML與CSS網頁編輯製作 30小時HTML決定網頁的架構而CSS決定網頁的視覺設計，可以說CSS就是網頁的化妝師，此課程引導不黯程式撰寫的您精耕HTML與CSS相關語法，加強專業的網頁設計實力，也方便後續與JavaScript/jQuery之間的設計應用。- WordPress快速上手網站實作 18小時WordPress是一個快速建立功能強大網站的重要工具。我們將教您如何使用WordPress，製作出專屬於您的網站，以展現您的設計創意。- 響應式網頁設計 24小時隨著行動裝置多樣化，響應式網頁設計是當今的網頁主要趨勢之一，您將學到如何設計可以在不同裝置上完美呈現網頁。- 前端互動式網頁程式設計-UI與元件設計 30小時由最基礎的語法開始，逐步的引導學員瞭解JavaScript的基礎，能讓完全沒有程式基礎的設計人員快速瞭解JavaScript的運作原理，課程將引導您深入瞭解前端互動式網頁程式設計，包括UI和元件設計，為您的網頁增添互動性。- JavaScript與jQuery網頁互動實作 36小時jQuery提供了許多強大功能函式庫，能夠一次解決網頁設計上常見的重大困難。透過範例中的步驟，您將掌握JavaScript和jQuery，提供網頁的互動能力，優化使用者經驗。- 個人作品集設計實務整合與數位影音履歷 48小時整合上述所學，打造完整個人作品集和數位影音履歷，讓後續轉職找工作有重要的作品呈現。這門課程涵蓋了以下內容：1. 個人作品集設計實務整合：精心設計和整合個人作品集，以展示您的設計技能和創意，包括您的平面設計、網頁設計、動畫和其他相關領域的作品。2. 數位影音履歷設計：這個部分涵蓋了如何設計和製作一個引人入勝的數位影音履歷，透過影片、動畫和其他元素來強調個人技能和經驗。製作令人印象深刻的履歷。進階課程需求，提供更優惠的價格，讓您在網頁設計師的職涯上更得心應手！【前端課程系列】- Sass與SCSS快速上手(原價12,000元)- 網頁統計圖表Chart.js快速上手(原價12,000元)養成班顧客於結業後一年內報名上述前端課程系列，可以原價5折優惠上課。
# Title of the webpage:
#
#     Photoshop視覺影像與前端設計應用
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: Photoshop初學者、欲學習Photoshop多媒體設計應用者
# DocumentBOX Outline: 基本操作環境與數位影像概念1-1  工作區域概覽1-2  檢視工具1-3  尺標、參考線1-4  影像檔案管理1-5  影像尺寸與版面尺寸1-6  裁切影像1-7  儲存檔案與影像檔案格式圖層與Photoshop影像編輯入門2-1 認識圖層2-2 圖層浮動視窗基本操作2-3 圖層管理2-4 選取與移動圖層2-5 變形指令2-6 各式變形2-7 數值變形2-8 翻轉變形由選取範圍開始玩耍影像合成3-1 固定形狀選取畫面工具3-2 特定形狀選取畫面工具3-3 選取範圍與影像編輯3-4 選取與填色3-5 漸層填色3-6 漸層顏色編輯3-7 油漆桶填色快速影像修正撇步4-1 影像調整工具組4-2 影像處理工具組4-3 影像亮度快速調整4-4 快速影像顏色加強術4-5 修復工具組4-6 內容感知填色4-7 仿製印章修圖向量形狀工具與路徑編輯應用5-1 向量形狀工具繪圖5-2 向量形狀工具繪製路徑應用5-3 路徑編輯工具5-4 使用筆型工具5-5 筆型工具描圖去背5-6 繪製形狀格式向量繪圖進階圖層編輯與濾鏡6-1 圖層對齊與均分6-2 使用圖層樣式6-3 圖層樣式設定6-4 建立圖層遮色片6-5 圖層混色模式6-6 濾鏡效果與設定文字編輯與設計應用7-1 建立文字7-2 段落文字7-3 圖層樣式文字應用7-4 效果文字應用影像處理與設計應用8-1 影像去背處理8-2 影像白邊框風格8-3 繪製剪影表現風格8-4 立可拍風格8-5 影像產品去背與陰影8-6 產品側面陰影前端網頁設計實作9-1 網頁按鈕與圖文框設計9-2 形象網站主視覺設計9-3 活動網站主視覺設計9-4 商品網站主視覺設計9-5 網頁內容設計
# Title of the webpage:
#
#     輕鬆玩出網頁影音新威力
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 1.有興趣學習影音處理製作者2.有需要製作網頁影音作品者
# DocumentBOX Outline: 開始數位影音創作1.1操作環境1.2匯入影片素材與儲存1.3素材取得幻燈片秀、自動模式輕鬆完成影片2.1 幻燈片秀編輯器2.2 自動模式2.3 Magic Movie精靈應用數位影音創作功能3.1 置換天空與動態人物特效3.2 關鍵畫格與動畫3.3 進階編輯模式製作動畫效果3.4 遮罩設計師製作動畫效果3.5 炫粒製作效果3.6 文字效果快速編排影片與效果神奇魔術工具快速編排影片5.1 素材分類管理與裁切圖片5.2 Magic Movie快速編排影片5.3 平移與縮放效果5.4 Magic Cut 快速剪輯影片遮罩與創意主題設計應用6.1 製作連續多張圖片放大影片片段6.2 組合成完整多張圖片放大影片6.3 完成遮色片文字動畫6.4 加入創意主題內容開場動畫與影片剪輯應用7.1製作遮色片開場動畫7.2剪輯主要影片內容與說明文字教學步驟影片進階編輯8.1善用轉場製作開場動畫8.2材料清單文字動畫8.3 主要影片編輯8.4加入圖框與影片效果運用影片調整與特效9.1 製作片頭文字專案9.2 製作主影片與調整影片9.3 應用疊加>炫粒9.4 加入文字動畫堆疊效果影片編輯應用10.1片頭影片與動畫10.2編輯主要影片10.3安排堆疊效果多角度拍攝影片編輯11.1開場動畫11.2編輯主要影片11.3加入影片文字與字幕動作類影片進階編輯12.1整合3D動畫素材12.2圖片平移縮放製作開場動畫12.3運動動作類影片整合編輯進階編輯個人數位影音介紹13.1加入素材13.2介紹影片去背合成13.3加入旁白與字幕13.4背景音樂與片尾
# Title of the webpage:
#
#     響應式網頁設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 需有HTML與CSS基礎，欲學習響應式網頁設計的設計師
# DocumentBOX Outline: 從動手瀏覽觀察網頁開始1-1    甚麼是響應式網頁1-2    建置響應式網頁1.3     安裝VS code 延伸模組開始使用Bootstrap2.1     新增Bootstrap空白頁面2.2     Bootstrap柵格系統2.3     Bootstrap 一般內容與通用類別+2.3.1     文字顏色與背景色2.3.2     文字屬性2.3.3     標題與顯示標題2.3.4     文字行高2.3.5     邊界與內距屬性設定2.3.6     對齊圖片2.3.7     響應式表格(Table)2.3.8     圓角(rounded)與邊框(Borders)2.3.9     響應式圖片與圖片區(Figures)2.3.10     BootStrtap ICON圖標2.4         其他更多的版面區塊編排2.4.1     自動佈局的欄 / 等寬2.4.2     巢狀排列2.4.3     使用邊界水平對齊區塊2.4.4     多個區塊水平對齊2.4.5     欄的推移2.4.6     間隙Gutters2.4.7     Flex對齊Bootstrap元件素材3.1     一般物件3.1.1     按鈕 (Buttons)3.1.2     麵包屑 (Breadcrumb)3.1.3     廣告大屏幕 (Jumbotron)3.2     區塊內容物件3.2.1     多項圖文編排(Media Object)3.2.2     標籤切換內容(Tab)3.2.3     折疊切換內容 (Accordion)3.3     Bootstrap響應式導覽列3.3.1     基本型收合導覽列3.3.2     收合導覽列元件3.4     Card卡片3.4.1     預設卡片類型3.4.2    卡片組合3.4.3     水平卡片3.4.4     網格卡片3.4.5     card圖文框排列版面3.5     Carousel輪播3.5.1     carousel-caption3.5.2     更改carousel CSS3.5.3     控制高度與自訂切換按鈕Bootstrap頁面編排應用4.1     先讓頁面捲動起來4.2    側邊導覽列捲動頁面4.3     頁面編排與效果4.4     頁面動態效果
# Title of the webpage:
#
#     Illustrator專業向量繪圖與動畫素材設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 對於向量插圖、網頁與動畫素材設計有興趣者
# DocumentBOX Outline: 操作環境介紹與檔案管理1-1 操作環境1-2 工具箱1-3 檔案管理與輔助操作基礎繪圖與物件選取變形2-1 基礎繪圖工具2-2 線條繪圖工具2-3 橡皮擦、美工刀與剪刀工具2-4 物件選取與管理2-5 變形工具與變形指令2-6 封套變形指令物件造型與進階變形3-1 形狀模式3-2 路徑管理運算3-3 路徑管理運算繪製圖案應用3-4 即時上色3-5 使用影像描圖與即時上色繪圖3-6 點陣圖剪裁遮色片3-7 漸層填色3-8 形狀運算與漸層填色3-9 網格漸層填色不規則繪圖與描圖4-1 鉛筆工具組徒手繪圖4-2 繪製路徑工具組4-3 路徑編輯工具4-4 鋼筆繪製曲線路徑文字處理5-1 文字字元屬性5-2 建立外框字5-3 路徑文字5-4 文字造型設計應用5-5 段落文字特殊繪圖效果6-1 物件漸變6-2 筆畫效果6-3 Illustrator 效果6-4 3D 效果6-5 Photoshop 濾鏡7 繪圖應用7-1 對齊排列構圖7-2 路徑管理員設計動畫元件7-3 可愛動物動畫元件繪製8 漸層填色與特殊效果功能繪製素材8-1 漸層文字8-2 漸層星光8-3 漸層繪圖造型文字8-4 3D 效果繪圖應用
# Title of the webpage:
#
#     前端互動式網頁程式設計-UI與元件設計
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 網站開發人員、網頁設計人員
# DocumentBOX Outline: 網頁設計:HTML, CSS, JavaScript簡介JavaScript基礎語法深入瞭解JavaScript資料與變數宣告基礎運算子操作數值資料處理進階文字處理邏輯與判斷式迴圈處理與應用DOM文件物件模型操作利用JSON處理複雜資料深入瞭解Function函式架構日期物件與時間處理事件處理常式彈出式互動視窗 Modal window廣告定時呈現與關閉效果Timeout popup window放大鏡檢視圖片Zoom in image頁籤切換介面Tabs手風琴收合效果Accordion圖片輪撥效果Carousel
# Title of the webpage:
#
#     JavaScript與jQuery網頁互動實作
#
#
# Course duration: 36小時
# Course cost: NT$ 18,000
# Target audience: 希望提升網頁互動能力，或縮短開發時程者適合網頁設計師或網站程式開發人員
# DocumentBOX Outline: CSS樣式基礎知識與設定JavaScript基礎知識與語法jQuery基礎知識jQuery動態效果，與動畫設定jQuery選取器，包含階層、內容、屬性、表單等各式選取方式jQuery樣式套用，可取得物件樣式屬性與動態設定樣式jQuery綁定事件，如滑鼠、鍵盤、系統等jQuery控制DOM物件jQuery操控AJAXjQuery UI的介紹與安裝設定輕易完成分頁標籤(Tabs)手風琴選單(Accordion)的製作可移動與縮放對話盒(Dialog)的設計藉由刻度滑桿(Slider)的介面輸入數值便利的日期選擇器(Datepicker)
# Title of the webpage:
#
#     HTML與CSS網頁編輯製作
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 欲學習專業網站建置基礎與編輯應用者
# DocumentBOX Outline: 安裝與使用程式碼編輯器Visual Studio CodeHTML與網頁內容架構CSS基礎與網頁編排CSS與版面DIV編排CSS版面編排應用輕鬆搞懂HTML5與CSS3
# Title of the webpage:
#
#     WordPress快速上手網站實作
#
#
# Course duration: 18小時
# Course cost: NT$ 9,000
# Target audience: 需有HTML與CSS基礎
# DocumentBOX Outline: 在本機安裝 WordPress 網站1.1 使用 XAMPP 在本機安裝 WordPress 網站1.2  安裝Wordpress開始使用WordPress編輯頁面2.1 網站後臺管理介面2.2 新增文章2.3 新增頁面2.4 設定導覽列與首頁WordPress 佈景主題安裝與編輯3.1  安裝新的wordpress3.2  安裝佈景主題3.3  安裝 Elementor 免費版3.4  Elementor編輯頁面一頁式網站佈景主題實作4.1  安裝Wordpress與佈景主題4.2  更改與設定頁首4.3  編輯頁面4.4 設定EMAIL收發信形象網站佈景主題實作5.1  安裝Astra佈景主題5.2  調整網站設定5.3  修改頁面商品網站佈景主題實作6.1  安裝佈景主題Blocksy6.2  新增文章與頁面6.3  修改模板網站6.4  修改商品與文章6.5  修改頁尾6.6  設定購物相關功能6.7  設定會員帳號功能6.8  製作優惠劵附錄 / 網站上傳至 WEB 伺服器（網站空間）7.1  申請免費個人網站空間7.2  安裝網站空間端的wordpress7.3  匯出本機網站程式
# Title of the webpage:
#
#     區塊鏈與智慧合約實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想了解區塊鏈與智慧合約的工程師與專案經理2.想了解智慧合約的實作者
# DocumentBOX Outline: 1.BlockChain歷史與簡介●加解密演算法●Hash Tree/Merkle Tree雜湊樹●非對稱加解密2.BlockChain生態系簡介3.智慧合約與Solidity簡介●Solidity與Solidity相關檔案●Pragma、註解與Mport●合約本體●state變數、struct與修飾子●事件、列舉與函數●資料型態●參照型態●陣列與對應4.Solidity語法●函數與修飾子●View、常數與Pure Function●Address Function●Fallback Function●例外處理、事件和Summary5.Ethereum●EVM(Ethereum Virtual Machine)●Ethereum(Smart Contract)●Truffle框架的設定與使用6.合約的偵錯7.合約的升級
# Title of the webpage:
#
#     區塊鏈與DApp去中心化應用程式Full Stack全棧開發實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要開發區塊鏈應用程式的工程師想學習Ethereum區塊鏈實作的工程師想要了解區塊鏈的軟體架構師
# DocumentBOX Outline: 1.Ethereum網路架構●Blockchain的基本架構●Blockchain的演化●Ether、GAS和EVM2.使用wallet錢包和區塊鏈網路溝通●網頁錢包的安裝●連線與使用3.web3.js●帳戶列表和餘額API使用●交易與合約API呼叫●交易物件傳送●事件與日誌●過濾監控API4.Truffle Framework與Solidity智慧合約5.智慧合約設計樣式6.前端分散式應用程式的考量7.ERC20自訂代幣8.Truffle與React/Redux●建立前端應用程式專案●部署合約●使用React進行前端開發Truffle與VUETruffle與drizzleNFT (Non fungible token)
# Title of the webpage:
#
#     IIB Council區塊鏈專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 商業技術主管政府技術幕僚全端工程師(Full Stack Developer)
# DocumentBOX Outline: 掌握區塊鏈技術的理論和技術基礎了解去中心化(decentralization)的概念，其影響以及與區塊鏈技術的關係了解區塊鏈開發和實現的基本技術原則了解比特幣和其他加密貨幣背後的區塊鏈技術運作機制透過實際範例了解加密技術如何用於數據保護了解智能合約(smart contracts)的理論基礎，以及如何使用Solidity和相關開發框架，在以太坊(Ethereum)區塊鏈上開發去中心化的應用程式(DAapp)研究替代區塊鏈解決方案，包括超級帳本(Hyperledger)、Corda等了解各行各業中區塊鏈應用的使用案例探索區塊鏈實現和商業化策略了解當前業務架構中區塊鏈整合的最佳實務確定可能的區塊鏈實現對法律方面的影響預測應用策略採行可能帶來的風險和失敗，並學習採用有效的變更管理和專案管理方法加以避免探索區塊鏈技術的新研究課題和未來應用範圍
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_Cloud.xlsx

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到 "數據分析與商業智慧 Data Analysis & Business Intelligence" 的節點及其 children 節點
search_pattern = re.compile(r'{"id":"\{J\}23","typeName":"JobCategory","pkid":23,"text":"數據分析與商業智慧 Data Analysis & Business Intelligence","children":(\[.*?\])', re.DOTALL)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print("未找到 '數據分析與商業智慧 Data Analysis & Business Intelligence' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details4.xlsx', index=False)
    print("Data saved to courses_details4.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     ChatGPT與Excel整合實戰
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望學習如何使用Excel進行基本的數據處理的初學者對ChatGPT和Excel整合感興趣的個人與專業人士希望提高Excel數據處理技能，並將ChatGPT整合到他們的工作中希望了解如何使用ChatGPT和Excel提高工作效率
# DocumentBOX Outline: ChatGPT簡介和基本原理ChatGPT x Excel公式的應用ChatGPT x Excel函數的應用ChatGPT x Excel功能的應用ChatGPT x Excel巨集的應用
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Python中文自然語言NLP深度學習專家課程
#
#
# Course duration: 28小時
# Course cost: NT$ 24,000
# Target audience: 高階軟體開發工程師大數據相關研發人員或資料科學家統計/數值分析研究人員中文自然語言處理專家大型語言模型微調專家大型語言模型 RAG 架構專家
# DocumentBOX Outline: 1.AI下一世代：ChatGPT的崛起● 自然語言處理、自然語言理解和自然語言生成2.文字資料採集● 深入Python爬蟲Crawler框架和MongoDB非結構化資料庫建構● 收集巨量資料集，並進行文字資料清洗3.機器學習快速上手● 決策樹（Decision Tree）、隨機森林（Random Forest）和梯度下降（Gradient Descent）4.機率生成模型與分類模型● 貝氏分類（Bayesian Classification）在中文語意的應用場景5.關聯字詞模型訓練● 中文斷詞、斷句和詞彙Tokenization，實作Word2Vec、Doc2Vec、Ckip和Transformers6.文章分類模型訓練● 詞袋模型（Bag of Words）、TF-IDF詞頻分類法、Naive Bayes分類器和XGBoost分類器7.情感分析模型訓練● Fine-tuning HuggingFace上的模型於中文長短句的正負面機率● 使用Google Play Store留言，實作Keras/Tensorflow RNN情感程度模型訓練8.暱稱/姓名預測性別男女模型● 訓練中、英文姓名男女分類判別● 建立文字檔案以查找分群的標籤9.自然語言處理個案研究● 中文姓名預測API，以Python Flask為例● 自然語言文章分類在廣告標籤投放的應用● Facebook/Instagram留言探針時刻監測品牌危機● 留言情感分析在品牌策略操作上的處理● PTT新聞摘要與關聯10.如何微調ChatGPT模型，讓它認識你的產業知識?● 通用人工智慧 (Artificial General Intelligence)● 大型語言模型(LLM)需要準備的資料集指引，套用自己的資料集● 從ChatGPT 4前往Llama 2實作遷移式學習● 微調(Fine-tuning) OpenAI 模型，提供問答助手11.延伸大語言模型 (LLM) 擴增(RAG) 知識● 結合知識檢索的 OpenAI 生成技術● 提示詞工程(Prompt Engineering) 使用 LangChain 與 LlamaIndex● 事實查核避免 AI 幻想 (Fact-checking of ChatGPT and LLMs)● 部署地端大型語言模型 (GGUF)
# Title of the webpage:
#
#     Python與資料處理實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 具有簡單代數統計能力，並具有程式基礎的工程師，資料分析師，數據分析師
# DocumentBOX Outline: Python的環境安裝與IDE設定Python與物件導向Python與IPython NotebookPython與地圖的處理Python與地理位置的編碼Python與Excel的連結使用Scipy處理資料Python與Wiki的資料存取Python與背景狀態的更新Python與圖的處理Python與資料分析Python的ORM與SQL Server的連結Python與Apache Spark的結合
# Title of the webpage:
#
#     使用Spring Framework 5開發企業級應用程式
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要了解如何以Spring Framework開發企業Web應用程式的開發人員
# DocumentBOX Outline: 簡介Spring Framework 5Spring 元件與IoC容器Spring BootDependency InjectionSpring AOP(Aspect Oriented Programming)Spring整合資料庫交易控管Spring Data JPASpring整合MongoDBSpring與訊息(Message)整合Spring Web MVCSpring SecuritySpring Batch
# Title of the webpage:
#
#     Angular搭配Java EE開發現代化的Web應用程式
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 網頁前端工程師、後端工程師
# DocumentBOX Outline: Angular 7簡介Java EE 8簡介CDI(Context and Dependency Injection)EJB LiteJPA(Java Persistence API)Microservice與MicroProfileJSON-PJSON-BJAX-RS開發Restful Web ServiceMVC Pattern前端MVC框架與後台MVC框架比較TypeScript基礎Angular CLIAngular基礎Angular Data BindingAngular表單Angular呼叫Restful Web ServiceSecurity
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     爬蟲與社群聆聽視覺化分析實務課程-使用Python
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: 已經有Python或其他程式語言基礎或有獨立開發或管理過小型軟體專案者，對於爬蟲初次接觸，或無撰寫過爬蟲經驗者，課程將深入淺出引導關鍵程式，從無到有學習爬蟲腳本、非結構化(NoSQL)資料庫，成為大數據分析社群分析的領先者。
# DocumentBOX Outline: 社群網路- Social Network爬蟲技術，採集、清洗、儲存、運算Python, MongoDB, PHP, Apache環境準備與安裝Python Scrapy爬蟲實作PHP爬蟲實作社群發文、留言分析社群Dashboard-視覺化呈現爬蟲應用-輿情分析、即時、非即時品牌災難應變-以啤酒代言人專案為例
# Title of the webpage:
#
#     BigData入門-Hadoop與Spark介紹
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想要了解Big Data架構的系統管理人員2.想要了解Hadoop/Spark開發架構的程式開發人員3.想要了解Hadoop/Spark架構的資料分析人員
# DocumentBOX Outline: 1.BigData架構介紹●Hadoop生態系2.Hadoop架構介紹●HDFS●MapReduce(MR v2)開發框架●Spark開發框架3.Spark程式開發●Spark core語法介紹-RDD●DataFrame/DataSet●Spark SQL4.Hadoop資料分析●探索式分析●Hive(HQL)5.Hadoop機器學習●Spark MLlib
# Title of the webpage:
#
#     Python資料分析工具-使用Matplotlib、Numpy、Pandas
#
#
# Course duration: 21小時
# Course cost: NT$ 18,000
# Target audience: 想要了解資料分析的程式開發人員想要了解如何使用Python進行資料分析的資料分析人員
# DocumentBOX Outline: 探索式資料分析概論Numpy介紹Matplotlib基礎Matplotlib進階Pandas基礎-SeriesPandas基礎-DataFramePandas進階Pandas時間序列
# Title of the webpage:
#
#     ChatGPT與Excel整合實戰
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望學習如何使用Excel進行基本的數據處理的初學者對ChatGPT和Excel整合感興趣的個人與專業人士希望提高Excel數據處理技能，並將ChatGPT整合到他們的工作中希望了解如何使用ChatGPT和Excel提高工作效率
# DocumentBOX Outline: ChatGPT簡介和基本原理ChatGPT x Excel公式的應用ChatGPT x Excel函數的應用ChatGPT x Excel功能的應用ChatGPT x Excel巨集的應用
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# DocumentBOX Outline: 介紹什麼是Microsoft Power Platform(Introduction to Microsoft Power Platform)如何使用Microsoft Dataverse資料中心來進行資料庫的設計(Work with Microsoft Dataverse)如何使用Power Apps的model-driven apps來建立資料中心的後台資料中心處理的應用系統(Make model-driven apps with Power Apps)如何使用Power Apps的畫布應用工具來設計並開發客製化前端的使用者介面(Make canvas apps with Power Apps)如何使用Power Apps的入口網站開發工具來開發企業所需的應用系統入口網站(Make portals with Power Apps)介紹什麼是Microsoft Power automation (Introduction to automation)如何使用Power Automate的設計工具來設計開發雲端的自動化服務(Build cloud flows with Power Automate)如何使用Power Automate的桌面設計工具來設計整合地端桌面服務的自動化流程(Build desktop flows with Power Automate)如何設計在Model-Driven Apps的商務處理流程(Build business process flows)如何使用Power Virtual Agents來設計開發自訂的聊天機器人(Build chatbots with Power Virtual Agents)如何使用Power BI來設計開發資料的分析(Analyze data with Power BI)如何利用所有的工具來設計建立整體的應用系統(Putting it all together)
# Title of the webpage:
#
#     Python機器學習-使用Scikit-Learn
#
#
# Course duration: 21小時
# Course cost: NT$ 18,000
# Target audience: 想成為資料工程師/科學家的資訊相關人員
# DocumentBOX Outline: 1.機器學習介紹2.監督式學習2-1迴歸分析(Regression)2-2邏輯迴歸分類(Logistic Regression Classification)2-3貝氏分類(Bayesian Classification)2-4決策樹(Decision Tree)2-5支援向量機(Support Vector Machine)2-6最近鄰居分類(K-nearest Neighbors)
# 3.非監督式學習
# 3-1分群(Clustering)3-2異常偵測(Anomaly Detection)3-3主成分分析(Principal-Component Analysis)4.整體學習(Ensemble Learning)5.神經網路(Neural Network)6.特徵工程(Feature Engineering)
# Title of the webpage:
#
#     Microsoft Power BI資料分析
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要學習微軟大數據分析解決方案的整個架構規劃想要了解Power BI Desktop及Power BI服務如何結合運作熟悉SQL Server報表的建立者想要取得Microsoft Certified：Power BI Data Analyst Associate專業認證的人員
# DocumentBOX Outline: Microsoft 資料分析入門在Power BI中進行資料擷取、清理、轉換及載入作業在Power BI中設計資料模型在Power BI中使用DAX建立資料計算在Power BI建立視覺化報告在Power BI進行進階分析部署及維護Power BI的資產資料列層級安全性
# Title of the webpage:
#
#     PowerPoint 2022設計專業多媒體簡報
#
#
# Course duration: 14小時
# Course cost: NT$ 9,000
# Target audience: 有PowerPoint使用基礎
# DocumentBOX Outline: 1.設計簡報背景1.1 設定簡報單色或漸層背景1.2 圖片背景1.3 圖樣背景2.設計效果標題文字2.1 依版面配置直接輸入文字2.2 建立美工文字2.3 文字藝術師效果2.4 自訂文字效果2.5 漸層文字與圖片文字2.6 建立段落文字塊2.7 段落文字設定2.8 編號與項目符號3.圖案與圖片素材應用3.1 插入圖片與圖片效果3.2 Google搜尋透明背景圖3.3將螢幕擷取畫面新增至投影片3.4插入圖案3.5 圖案組合運算3.6 插入圖示3.7 圖示圖案加上效果3.8 圖示進階應用3.9繪製圖案與效果應用4.加強SmartArt圖形與圖表視覺效果4.1 建立SmartArt圖形物件4.2 美化SmartArt圖形物件4.3 調整SmartArt內容4.4 SmartArt圖案編輯應用4.5表格美化應用4.6圖表美化應用5.設計母片與佈景主題5.1新增投影片頁面5.2套用設計佈景主題5.3 修改佈景主題內容5.4 自訂佈景主題（母片）6.動畫效果與影片設定6.1 文字加動畫6.2 動畫順序與動畫啟動安排6.3 圖案加動畫與動畫類型6.4 圖片加動畫與複製動畫6.5 SmartArt加上動畫6.6圖表上套用動畫6.7 自訂動畫效果6.8複製動畫與安排順序6.9 安排動畫時間差6.10 善用旋轉強調動畫6.11 路徑動畫效果6.12加入3D模型與動畫進階影片、音效編輯7.1加入與編輯音訊7.2 插入視訊與編輯影片檔7.3 使用螢幕錄製8.轉場與頁面連結8.1 轉場設定8.2 投影片頁面連結8.3 轉化轉場應用8.4 投影片章節與縮放8.5 簡報輸出成自動播放影片
# Title of the webpage:
#
#     Python與機器學習深度學習-使用Keras與TensorFlow
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想做Data Scientist者需要學習Machine Learning /深度學習者
# DocumentBOX Outline: Anaconda與Python下tensorflow與sklearn的設定與組態開發環境整理與調校機器學習與深度學習概論機器學習與深度學習需要的資料處理與視覺化多變數線性迴歸監督式學習Logistic RegressionSupport Vector MachineDecision TreeRandom ForestKNNNaive Bayes非監督式學習KMeanPCA(Principal Component Analysis)Tensorflow與Keras離散分類問題的建模模型效能評估資料集合的處理Model Selection模型選取hyper parameter後設參數調校Keras與Neural Network數種MNIST預測IMDB與Reuter資料處理Keras與CNN(Convolutioal Neural Network)建模TensorBoard的使用彈性補充RNN深度學習與NVidia的Cuda的組態與設定
# Title of the webpage:
#
#     Microsoft Power Platform開發人員
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 想要成為Microsoft Power Platform的開發者想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展程式開發人員想要更詳細了解Power Platform各項工具的核心架構與設計內容，進而可以具備更深入的客製化設計能力的系統程式設計師想要取得Microsoft Certified：Power Platform Developer Associate專業認證的人員
# DocumentBOX Outline: 與Microsoft Dataverse雲端資料庫平台一起工作建立由Power Apps所提供的模型驅式動應用服務系統(Create a model-driven app in Power Apps)建立由Power Apps所提供的畫布應用程式(Create a canvas app in Power Apps)如何掌握畫布應用程式中的高級技巧和數據選項的使用(Master advance techniques and data options in canvas app)如何應用Power Automate中的自動化業務流程的處理(Automate a business process using Power Automate)Power Platform的開發簡介(Introduction to developing with Power Platform)如何擴展Power Platform通用數據服務(Extending the Power Platform Common Data Service)如何擴展Power Platform用戶體驗模型驅動式的應用程式與服務(Extending the Power Platform user experience Model Driven apps)如何使用Power Apps組件框架來建立所需要的組件(Create components with Power Apps Component Framework)如何擴充Power Apps的網站入口環境(Extend Power Apps Portals)如何將Power Platform與Common Data Service進行整合(Integrate with Power Platform and Common Data Service)
# Title of the webpage:
#
#     Python中文自然語言NLP深度學習專家課程
#
#
# Course duration: 28小時
# Course cost: NT$ 24,000
# Target audience: 高階軟體開發工程師大數據相關研發人員或資料科學家統計/數值分析研究人員中文自然語言處理專家大型語言模型微調專家大型語言模型 RAG 架構專家
# DocumentBOX Outline: 1.AI下一世代：ChatGPT的崛起● 自然語言處理、自然語言理解和自然語言生成2.文字資料採集● 深入Python爬蟲Crawler框架和MongoDB非結構化資料庫建構● 收集巨量資料集，並進行文字資料清洗3.機器學習快速上手● 決策樹（Decision Tree）、隨機森林（Random Forest）和梯度下降（Gradient Descent）4.機率生成模型與分類模型● 貝氏分類（Bayesian Classification）在中文語意的應用場景5.關聯字詞模型訓練● 中文斷詞、斷句和詞彙Tokenization，實作Word2Vec、Doc2Vec、Ckip和Transformers6.文章分類模型訓練● 詞袋模型（Bag of Words）、TF-IDF詞頻分類法、Naive Bayes分類器和XGBoost分類器7.情感分析模型訓練● Fine-tuning HuggingFace上的模型於中文長短句的正負面機率● 使用Google Play Store留言，實作Keras/Tensorflow RNN情感程度模型訓練8.暱稱/姓名預測性別男女模型● 訓練中、英文姓名男女分類判別● 建立文字檔案以查找分群的標籤9.自然語言處理個案研究● 中文姓名預測API，以Python Flask為例● 自然語言文章分類在廣告標籤投放的應用● Facebook/Instagram留言探針時刻監測品牌危機● 留言情感分析在品牌策略操作上的處理● PTT新聞摘要與關聯10.如何微調ChatGPT模型，讓它認識你的產業知識?● 通用人工智慧 (Artificial General Intelligence)● 大型語言模型(LLM)需要準備的資料集指引，套用自己的資料集● 從ChatGPT 4前往Llama 2實作遷移式學習● 微調(Fine-tuning) OpenAI 模型，提供問答助手11.延伸大語言模型 (LLM) 擴增(RAG) 知識● 結合知識檢索的 OpenAI 生成技術● 提示詞工程(Prompt Engineering) 使用 LangChain 與 LlamaIndex● 事實查核避免 AI 幻想 (Fact-checking of ChatGPT and LLMs)● 部署地端大型語言模型 (GGUF)
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     使用者介面視覺構成解析與優化
#
#
# Course duration: 14小時
# Course cost: NT$ 9,000
# Target audience: 程式設計師、App程式設計師、系統開發、網站企劃、行銷企劃本課程適合無任何設計軟體基礎者
# DocumentBOX Outline: 1.系統與介面設計畫面的版面設計1-1 關於介面設計1-2 畫面的合理版面1-3 畫面的版面分類2.配色優化一點通2-1 色彩在介面中的作用2-2 色彩基礎與屬性2-3 色彩基本概念2-4 配色工具輕鬆上手3.Photoshop必備影像快速處理撇步3-1 影像快速調整3-1-1 曲線調整亮度3-1-2 色相飽和度調色3-2 影像尺寸簡單處理3-2-1 最理想的影像格式3-2-2 直接更改尺寸與儲存最佳化影像3-2-3裁切影像3-3 裁切準確尺寸影像3-3-1 設定尺寸後裁切3-3-2 依目標尺寸多張裁切3-4 自動批次處理大量影像3-4-1 錄製動作與更改尺寸批次處理3-4-2 影像調整批次處理3-4-3 裁切批次處理4.Photoshop搭配畫面之影像精準切割法4-1 影像同尺寸等分切割4-2 不規則影像切割4-3 多種尺寸Icon切割4-4 搭配畫面之影像切割實作4-4-1 固定寬度介面影像圖框4-4-2 變動寬度介面影像圖框5.Photoshop輕鬆搞定畫面材質效果與按鈕素材5-1 形狀繪圖工具5-1-1 矩型工具5-1-2 圓角矩型工具5-1-3 橢圓工具5-1-4 多邊型工具5-1-5 直線工具5-1-6 自訂形狀工具5-2 輕鬆為圖案加上效果5-3 自製按鈕素材5-3-1 繪製按鈕與圖案5-3-2 加入按鈕文字5-4 快速打造畫面材質效果5-4-1繪製區塊圖框5-4-2 繪製介面區塊
# Title of the webpage:
#
#     Microsoft Power Automate RPA開發人員
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 想要成為Microsoft Power Automate RPA的開發者想要完整的了解Power Automate在桌面自動化處理的設計師想要取得Microsoft Certified：Power Automate RPA Developer專業認證的人員
# DocumentBOX Outline: 總覽Power Platform RPAPower Automate Cloud FlowsPower Automate Desktop Flows從Cloud Flows來使用Desktop Flows自訂連結器部署與管理自動化作業
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     Oracle 資料庫之適用於資料倉儲分析的SQL
#
#
# Course duration: 18小時
# Course cost: NT$ 49,000
# Target audience: 欲了解Oracle SQL資料分析函數與語法的資料庫管理者欲使用Oracle SQL資料分析函數與語法的程式設計人員欲了解Oracle SQL資料分析函數與語法的資料倉儲資料庫管理者
# DocumentBOX Outline: 課程簡介使用SQL指令對資料進行分群與彙總階層式查詢使用正規表示式使用SQL指令分析資料進行Pivot/Unpivot操作使用SQL指令進行樣式比對使用SQL指定對資料進行Model操作
# Data saved to courses_details4.xlsx

# %% [markdown]
# 結果說明:
#
# 1. 會把爬蟲取到的資料儲存成excel檔，並分別使用預設標題。

# %% [markdown]
# # 2. 更換search_pattern就可以爬取不同的系列課程資訊

# %% [markdown]
# ### 爬取資訊安全 Security 系列課程

# %% [markdown]
# search_pattern = re.compile(r'{"id":"\{J\}23","typeName":"JobCategory","pkid":23,"text":"數據分析與商業智慧 Data Analysis & Business Intelligence","children":(\[.*?\])', re.DOTALL)
# ________________________________________________________________________________________________________________
# search_pattern = re.compile(r'{"id":"\{J\}24","typeName":"JobCategory","pkid":24,"text":"資訊安全 Security","children":(\[.*?\])', re.DOTALL)

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到 "資訊安全 Security" 的節點及其 children 節點
search_pattern = re.compile(r'{"id":"\{J\}24","typeName":"JobCategory","pkid":24,"text":"資訊安全 Security","children":(\[.*?\])', re.DOTALL)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print("未找到 '資訊安全 Security' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details5.xlsx', index=False)
    print("Data saved to courses_details5.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CISA國際電腦稽核師認證研習班
#
#
# Course duration: 35小時
# Course cost: NT$ 40,000
# Target audience: 稽核人員、資訊人員及對資訊系統稽核或控制有興趣者
# DocumentBOX Outline: 資訊系統稽核流程 (Information System Auditing Process)資訊科技治理與管理 (Governance and Management of IT)資訊系統的取得、開發與建置 (Information Systems Acquisition, Development and Implementation)資訊系統的營運及企業靈活性 (Information Systems Operations and Business Resilience)資訊資產的保護 (Protection of Information Assets)
# Title of the webpage:
#
#     CISM國際資訊安全經理人認證專班
#
#
# Course duration: 35小時
# Course cost: NT$ 40,000
# Target audience: 資訊長/資安長、資訊人員、稽核人員及對資安管理或資訊系統稽核/控制有興趣者
# DocumentBOX Outline: 資訊安全治理 (Information Security Governance)資訊安全風險管理 (Information Security Risk Management)資訊安全計劃 (Information Security Program)事故管理 (Incident Management)
# Title of the webpage:
#
#     CompTIA Security＋國際網路資安認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者初階系統/網路工程師
# DocumentBOX Outline: Summarize Fundamental Security Concepts(總論基本安全概念)Compare Threat Types(比較威脅類型)Explain Cryptographic Solutions(解釋加密解決方案)Implement Identity and Access Management(實施身份和存取管理)Secure Enterprise Network Architecture(安全的企業網路架構)Secure Cloud Network Architecture(安全的雲端網路架構)Explain Resiliency and Site Security Concepts(解釋彈性與網站安全的概念)Explain Vulnerability Management(解釋漏洞管理)Evaluate Network Security Capabilities(評估網路安全能力)Assess Endpoint Security Capabilities(評估端點安全能力)Enhance Application Security Capabilities(增強應用程式的安全能力)Explain Incident Response and Monitoring Concepts(解釋事件回應與監控概念)Analyze Indicators of Malicious Activity(分析惡意活動指標)Summarize Security Governance Concepts(歸納安全治理概念)Explain Risk Management Processes(解釋風險管理流程)Summarize Data Protection and Compliance Concepts(總論資料保護與合規性概念)
# Title of the webpage:
#
#     EC-Council CCT 網路安全認證技師課程
#
#
# Course duration: 40小時
# Course cost: NT$ 39,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者初階系統/網路工程師
# DocumentBOX Outline: Information Security Threats and Vulnerabilities (資訊安全威脅與弱點)Information Security Attacks (資訊安全攻擊)Network Security Fundamentals (網路安全基礎)Identification, Authentication, and Authorization (識別、鑑別與授權)Network Security Controls–Administrative Controls (網路安全控制措施-管理控制措施)Network Security Controls–Physical Controls (網路安全控制措施-實體控制措施)Network Security Controls–Technical Controls (網路安全控制措施-技術控制措施)Network Security Assessment Techniques and Tools (網路安全評估技術與工具)Application Security (應用程式安全)Virtualization and Cloud Computing (虛擬化與雲端運算)Wireless Network Security (無線網路安全)Mobile Device Security (行動裝置安全)IoT and OT Security (物聯網與工控安全)Cryptography (密碼學)Data Security (資料安全)Network Troubleshooting (網路故障排除)Network Traffic Monitoring (網路流量監控)Network Logs Monitoring and Analysis (網路日誌監控與分析)Incident Response (事故應變)Computer Forensics (電腦鑑識)Business Continuity and Disaster Recovery (持續營運與災難復原)Risk Management (風險管理)
# Title of the webpage:
#
#     EC-Council CSCU安全電腦使用者認證課程
#
#
# Course duration: 16小時
# Course cost: NT$ 16,000
# Target audience: 個人用戶和家庭使用者商業和組織用戶學生和學術界人士任何對安全使用電腦、行動裝置、物聯網系統有興趣的人員
# DocumentBOX Outline: 資料安全介紹作業系統的安全性惡意軟體和防毒軟體網際網路安全社交網站的安全性保護電子郵件通訊行動裝置的安全性雲端安全性網路連接的安全性資料備份和災難復原保護物聯網設備和遊戲主機遠距工作的安全性
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     ISO/IEC 27001：2022資訊安全管理系統核心概念與條文要點解析訓練課程
#
#
# Course duration: 16小時
# Course cost: NT$ 21,000
# Target audience: 資訊安全人員欲從事ISO27001顧問人員公司內部導入ISMS系統的人員IT人員稽核部門人員
# DocumentBOX Outline: 資訊安全管理系統詮釋管理責任詮釋內部資訊安全稽核詮釋資訊安全管理審核詮釋資訊安全管理系統改善詮釋資訊安全控制措施詮釋
# Title of the webpage:
#
#     SSCP-資安專業人員認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 40,000
# Target audience: 對資訊安全工作有興趣者欲取得SSCP®認證資格者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 第一章 Introducing Security and Aligning Asset Management to Risk Management介紹安全及符合風險管理之資產管理第二章 Understanding Risk Management Options and the Use of Access Controls to Protect Assets認識管理風險之選項並使用存取控制保護資產第三章 Cryptography密碼學第四章 Securing Software, Data and Endpoints 保護軟體、資料與端點第五章 Network and Communications Security 網路與通訊安全第六章 Cloud and Wireless Security 雲端與無線安全第七章 Incident Detection and Response 事故偵測與應變第八章 Maturing Risk Management 強化風險管理
# Title of the webpage:
#
#     Veritas NetBackup資料保護專業人員認證課程
#
#
# Course duration: 35小時
# Course cost: NT$ 75,000
# Target audience: 適合負責設計、配置、操作、監控或支持NetBackup的技術專業人員
# DocumentBOX Outline: 介紹Veritas NetBackup以NetBackup Web UI介面執行工作進行 NetBackup憑證管理設定NetBackup基本及進階磁碟儲存設定NetBackup備份政策及工作排程設定檔案系統的備份及還原設定NetBackup媒體伺服器精簡刪除儲存池設定雲端儲存最佳化檔案系統備份管理及保護VMware虛擬環境復原VMware虛擬環境建立備份複本及異地抄寫保護NetBackup Catalog減輕勒索軟體的影響使用NetBackup報表升級及更新NetBackup版本收集事件記錄及診斷用資訊
# Title of the webpage:
#
#     掌握ChatGPT進行道德駭客攻擊和滲透測試
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 想要學習活用ChatGPT進行網路攻防演練的資安從業人員具備基本滲透測試技術能力的資安從業人員與網路工程師
# DocumentBOX Outline: 道德駭客基礎知識了解ChatGPT的優點和局限性在滲透測試平台中整合ChatGPT使用ChatGPT進行偵察和掃描使用ChatGPT執行密碼破解和暴力攻擊使用ChatGPT執行SQL注入和XSS使用ChatGPT進行進階漏洞利用開發相關實作演練
# Title of the webpage:
#
#     掌握ChatGPT進行道德駭客攻擊和滲透測試
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 想要學習活用ChatGPT進行網路攻防演練的資安從業人員具備基本滲透測試技術能力的資安從業人員與網路工程師
# DocumentBOX Outline: 道德駭客基礎知識了解ChatGPT的優點和局限性在滲透測試平台中整合ChatGPT使用ChatGPT進行偵察和掃描使用ChatGPT執行密碼破解和暴力攻擊使用ChatGPT執行SQL注入和XSS使用ChatGPT進行進階漏洞利用開發相關實作演練
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     資訊安全分析實務-方法、流程與工具
#
#
# Course duration: 35小時
# Course cost: NT$ 28,000
# Target audience: 想要學習資安實用操作技巧的IT人員對系統的資安有興趣管理，希望能加強實作技巧的IT人員
# DocumentBOX Outline: 評估系統的資訊安全評估流程與相關工具列舉與入侵系統的參考步驟駭客的矛盾對決探索與測試常見服務檢測：電子郵件伺服器常見服務檢測：網站伺服器常見服務檢測：搭配伺服器加密需求TLS跡證保存與警報系統備份與復原標準化建立系統與弱掃零檢出相關實作演練
# Title of the webpage:
#
#     網路鑑識及惡意程式分析
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 對資安事件調查領域工作有興趣者欲充實本身資安鑑識技術能力的人員
# DocumentBOX Outline: 惡意程式事件之現場蒐證處理方式網路封包蒐證及分析Windows 惡意程式主機端分析的主要重點資料資料搜尋、TimeLine及 Log分析惡意程式記憶體分析暨案例處理惡意程式反組譯分析
# Title of the webpage:
#
#     CSSLP-資安軟體開發專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 50,000
# Target audience: 參與系統或軟體開發之相關人員軟體專案經理、系統架構師、系統分析師程式設計師、軟體測試人員稽核人員
# DocumentBOX Outline: 本課程涵蓋CSSLP® CBK® SDLC八大領域。課程內容不涉及特定開發技術，而是著重在如何進行安全程式開發的流程與方法。Domain 1 安全軟體概念L1.1 定義軟體開發的核心安全目標L1.2 描述資訊安全三要素並解釋資訊機密性、完整性和可用性的主要機制L1.3 描述資訊安全與資料隱私之間的關係L1.4 辨識影響軟體安全的監管考量L1.5 解釋安全方法如何透過存取控制減輕弱點L1.6 描述軟體安全中多層保護的目的和功能L1.7 描述安全文化和實踐如何影響資料隱私和安全Domain 2 安全軟體生命週期管理L2.1 探討軟體開發的預測性和適應性方法中的安全性L2.2 描述將軟體安全實踐納入軟體開發生命週期過程中L2.3 辨識DevOps和DevSecOpsL2.4 認識安全性組態標準和基準L2.5 描述以安全為重點的組態管理過程L2.6 確定軟體弱點和漏洞的安全標準L2.7 解釋OWASP的軟體保證成熟模型和建立安全性成熟模型L2.8 在DevSecOps管道中定義軟體安全里程碑和檢查點L2.9 解釋系統安全計畫L2.10 辨識與安全相關的文件L2.11 辨識軟體開發中的指標L2.12 詳細說明軟體停用政策和流程L2.13 解釋DevSecOps中的安全性報告機制L2.14 描述風險評估和風險管理L2.15 審查安全運作流程的實施L2.16 辨識容器生命週期中的安全考慮Domain 3 安全軟體需求L3.1 描述需求管理以及軟體安全需求的來源L3.2 辨識功能性和非功能性需求L3.3 解釋SCRUM/SCRUM相似方法中以安全為重的故事的影響L3.4 描述軟體安全需求的來源L3.5 分析安全政策及其支援元素作為內部安全需求的來源L3.6 解釋遵循要求，並辨識法律、法規和行業標準作為外部安全需求的來源L3.7 討論安全標準和架構L3.8 描述資料治理和所有權L3.9 描述資料分類以及安全標籤和標記L3.10 辨識結構化和非結構化的資料類型L3.11 描述資料生命週期L3.12 辨識旨在減輕隱私風險的隱私法律和法規L3.13 討論資料匿名化並列舉各種匿名化方法L3.14 在隱私情境中解釋使用者同意、資料保留和資料處理L3.15 辨識跨境資料轉移的影響以及個人資料轉移的限制L3.16 描述使用者和軟體資料存取規定L3.17 描述誤用和濫用案例以及它們與已知攻擊模式的相關性L3.18 描述安全需求追蹤矩陣L3.19 辨識第三方供應商的安全性需求Domain 4 安全軟體架構和設計L4.1 描述架構和相關的安全設計模式L4.2 辨識介面設計的安全性標準L4.3 比較並區分各種身分驗證和授權機制L4.4 描述憑證管理L4.5 辨識網路安全中使用的原則和工具L4.6 描述維護資料庫安全性的方法L4.7 辨識威脅建模的過程、工具和方法L4.8 指出可攻擊面積評估和管理的過程L4.9 討論威脅情報和網絡威脅資訊的來源L4.10 描述架構風險評估的過程L4.11 辨識非功能性安全性特性和限制L4.12 辨識安全操作架構的考量Domain 5 安全軟體建置L5.1辨識安全編碼標準的特點L5.2 描述在受控應用程式中建置安全性的不同方法L5.3 辨識軟體中的常見缺陷以及相應的緩解策略L5.4 解釋常見的安全開發實踐L5.5 辨識在傳輸中和儲存中的資料保護方法L5.6 辨識列在最常見弱點清單和資料庫中的軟體弱點L5.7 描述軟體保證工具的功能和方法L5.8 描述按類型和功能對控制的分類L5.9 辨識防止常見網路應用程式弱點的控制措施L5.10 描述制定包括軟體風險考量的安全策略的過程L5.11 辨識使用第三方和開源組件和庫時相關的風險L5.12 描述各種整合類別及其對軟體安全性的相關性L5.13 描述建構自動化過程L5.14 解釋軟體保證中使用的技術Domain 6 安全軟體測試L6.1 辨識常見的安全測試技術L6.2 描述測試環境L6.3 辨識組織的軟體安全標準和指南L6.4 解釋群眾外包安全性和獎金計劃的好處L6.5 辨識安全測試的指南L6.6 辨識各種安全性測試案例L6.7 認識建立誤用和濫用案例的重要性L6.8 描述文件驗證和驗證L6.9 解釋OWASP的應用程式安全驗證標準的結構和目標L6.10 描述未記錄的功能和原始碼L6.11 解釋測試結果的安全性影響L6.12 區分測試結果的類型L6.13 描述追蹤安全性缺陷的過程L6.14 解釋風險評分系統和常見弱點評分系統L6.15 解釋測試數據的生成以及使用生產數據的後果L6.16 描述驗證和驗證測試的過程Domain 7 安全軟體部署、運營、維護L7.1在ISO 31000系列的背景下描述操作風險分析L7.2 描述安全配置管理(SecCM)L7.3 辨識安全持續整合和持續交付管道的元素L7.4 解釋應用程式安全工具鏈L7.5 辨識識別應用程式弱點的步驟L7.6 比較和區分常見的存儲和管理安全資料的方法L7.7 描述安全的安裝過程和方法L7.8 釋安全的軟體啟動機制L7.9 辨識運營授權(ATO)過程中的步驟和方法L7.10 解釋如何執行資訊安全持續監控L7.11 描述涉及事件應對計劃的階段L7.12 將修補管理過程與整體軟體安全實踐相關聯L7.13 描述用於弱點管理的方法和工具L7.14 描述控制如何在執行階段以控制措施保護應用程式L7.15 比較和區分業務持續性和災害復原計劃如何支援作業的連續性L7.16 解釋並區分服務水準協議（SLA）、服務水準目標（SLO）和服務水準指標（SLI），以實現供應商的持續性Domain 8 安全軟體供應鏈L8.1 描述軟體供應鏈L8.2 審查軟體供應鏈風險管理的過程L8.3 解釋與第三方軟體相關的安全風險L8.4 將風險與點對點應用程式和文件共享相關聯L8.5 解釋程式碼儲存庫和環境安全L8.6 表達具有密碼學雜湊和數位簽章的元件L8.7 辨識軟體取得中的安全需求和原則L8.8 詳細說明軟體取得的關鍵考慮因素L8.9 解釋軟體取得的合約要求
# Title of the webpage:
#
#     駭客殺手–CEH認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 65,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對駭客攻防技術有興趣者
# DocumentBOX Outline: Introduction to Ethical Hacking (介紹何謂道德入侵)Footprinting and Reconnaissance (蒐集蛛絲馬跡與網路勘查)Scanning Networks (網路服務與弱點掃描)Enumeration (列舉系統資訊)Vulnerability Analysis (弱點分析)System Hacking (入侵電腦系統)Malware Threats (惡意程式威脅)Sniffers (網路監聽與攻擊)Social Engineering (社交工程)Denial-of-Service (阻斷服務攻擊與傀儡網路)Session Hijacking (連線劫持)Evading IDS, Firewalls and Honeypots (規避入侵偵測/防火牆與誘捕系統)Hacking Webservers (入侵網站)Hacking Web Application (入侵網站程式)SQL Injection (資料隱碼攻擊)Hacking Wireless Network (入侵無線網路)Hacking Mobile Platforms (入侵行動平台)IoT and OT Hacking(入侵物聯網與工控)Cloud Computing (雲端運算)Cryptography (密碼學)
# Title of the webpage:
#
#     EC-Council CHFI資安鑑識調查專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: CHFI 課程專為所有參與資訊系統安全、計算機取證和危機事件處理的IT專業人員而設計。包含：警察和相關執法人員國防安全相關人員電子商務安全專業人士法律專業人士銀行、保險和其他專業人士政府機構 IT 資訊經理數位取證服務提供商
# DocumentBOX Outline: Computer Forensics in Today’s World (電腦鑑識總論)Computer Forensics Investigation Process (電腦鑑識程序)Understanding Hard Disks and File Systems (硬碟與檔案系統)Data Acquisition and Duplication (資料獲取與複製)Defeating Anti-Forensics Techniques (破解反鑑識技巧)Windows Forensics (Windows作業系統鑑識)Linux and Mac Forensics (Linux, Mac作業系統鑑識)Network Forensics (網路鑑識)Malware Forensics (惡意程式鑑識)Investigating Web Attacks (網站及網路服務攻擊鑑識)Dark Web Forensics (暗網調查)Cloud Forensics (雲端鑑識)Email and Social Media Forensics (電子郵件與社群媒體鑑識)Mobile Forensics (行動裝置鑑識)IoT Forensics (IoT鑑識)
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     ISO 27001資訊安全管理系統風險評鑑課程
#
#
# Course duration: 16小時
# Course cost: NT$ 21,000
# Target audience: 資訊安全人員欲從事ISO27001顧問人員公司內部導入ISMS系統的人員IT人員稽核部門人員
# DocumentBOX Outline: 何謂風險風險管理之目的流程導向之ISO 27001風險評估控制影響資訊安全管理系統風險之要素風險分析方法風險評估與執行在流程導向之資安系統中導入風險管理實務演練
# Title of the webpage:
#
#     資安事件損害控制暨資料復原實務
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 對資安領域工作有興趣者網商或電商經營者（有個資及交易紀錄）政府單位或八大關鍵基礎設施之資訊人員
# DocumentBOX Outline: 資安法對於資安緊急事件之要求個資法暨 165 網商詐騙通報對於個資外洩之要求資安事件應建立事前偵測才能把損害有效控制災損控制暨系統回復重點事前的防禦措施決定復原及災損的控制能力資料外洩之災損控制及回復實體故障/人員因素之災損控制及回復DDOS攻擊/主機遭駭之災損控制及回復實務綜合演練
# Title of the webpage:
#
#     資通安全法令遵循實務
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 法務人員、IT人員、資安人員、稽核人員
# DocumentBOX Outline: 資通安全現況資通安全事故案例研析資通安全法律規範 – 刑法妨害電腦使用罪章資通安全法律規範 – 個人資料保護法資通安全法律規範 – 資通安全管理法資通安全技術面應用資通安全管理面設計資通安全法令遵循執行策略與方法
# Title of the webpage:
#
#     藍隊資安事故處理-EC-Council ECIH認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 資安危機處理員、單位風險評估管理員、滲透測試人員、系統弱點評估人員、資安鑑識人員、系統管理員、系統工程師、防火牆管理員、IT主管或其他IT相關人員
# DocumentBOX Outline: Introduction to Incident Handling and Response (資安事件危機處理與回應簡介)Incident Handling and Response Process (資安事件危機處理的程序)Forensic Readiness and First Response (數位鑑識與第一時間反應準則)Handling and Responding to Malware Incidents (惡意程式所造成的危機事件應對與處理原則)Handling and Responding to Email Security Incidents (電子郵件所造成的危機事件應對與處理原則)Handling and Responding to Network Security Incidents (網路攻擊所造成的危機事件應對與處理原則)Handling and Responding to Web Application Security Incidents (網站及網路應用程式所造成的危機事件應對與處理原則)Handling and Responding to Cloud Security Incidents (雲端應用所造成的危機事件應對與處理原則)Handling and Responding to Insider Threats (內部威脅所造成的危機事件應對與處理原則)Handling and Responding to Endpoint Security Incidents(端點安全所造成的危機事件應對與處理原則)
# Title of the webpage:
#
#     CEH大師雙認證實戰考試總複習班
#
#
# Course duration: 14小時
# Course cost: NT$ 40,000
# Target audience: 已經取得CEH認證或者已經完成CEH課程且對取得CEH Practical認證有興趣者
# DocumentBOX Outline: 網路暨弱點掃描網路服務標誌擷取與列舉網路流量分析系統攻擊手法分析網站攻擊手法分析
# Title of the webpage:
#
#     CISSP-資安系統專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 安全開發人員、網路系統工程師、資安分析人員、資安系統工程師、資訊部門主管、資訊長、資安顧問、欲取得CISSP®資格者、欲從事資訊安全管理/顧問工作者
# DocumentBOX Outline: Domain 1: Security and Risk Management 安全與風險管理1.1 理解、遵守並促進專業倫理1.2 理解並應用安全概念1.3 評估、應用並維持安全治理
# 原則1.4 全面理解與資訊安全相關的法律、法規和合規問題1.5 理解調查類型的要求1.6 制定、文件化並實施安全政策、標準、程序和指南1.7 識別、分析、評估、優先排序並實施營運連續性 (BC) 要求1.8 貢獻並執行人員安全政策和程序1.9 理解並應用風險管理概念1.10 理解並應用威脅建模概念和方法1.11 應用供應鏈風險管理 (SCRM) 概念1.12 建立和維護安全意識、教育和培訓計畫Domain 2: Asset Security 資產安全2.1 確定並分類資訊和資產2.2 建立資訊和資產處理需求2.3 安全提供資源2.4 管理資料生命週期2.5 確保適當的資產保留2.6 確定資料安全控制和合規需求Domain 3: Security Architecture and Engineering 安全架構與工程3.1 研究、實施和管理使用安全設計原則的工程流程3.2 理解安全模型的基本概念3.3 根據系統安全要求選擇控制3.4 了解資訊系統的安全功能3.5 評估和減輕安全架構、設計和解決方案元素的漏洞3.6 選擇和確定加密解決方案3.7 了解加密攻擊的方法3.8 將安全原則應用於場地和設施設計3.9 設計場地和設施安全控制3.10 管理資訊系統的生命週期Domain 4: Communication and Network Security 通訊與網路安全4.1 在網路架構中應用安全設計原則4.2 保護網路元件安全4.3 根據設計實施安全通訊
# 通道Domain 5: Identity and Access Management (IAM) 識別與存取管理5.1 控制對資產的實體和邏輯存取5.2 設計身份識別和驗證策略5.3 使用第三方服務實現聯邦式身份5.4 實施和管理授權機制5.5 管理身份和存取提供生命週期5.6 實施身份驗證系統Domain 6: Security Assessmentand Testing 安全評估測試6.1 設計並驗證評估、測試和稽核策略6.2 進行安全控制測試6.3 收集安全流程資料6.4 分析測試輸出並產生報告6.5 進行或促進安全稽核Domain 7: Security Operations 安全作業7.1 理解並遵守調查程序7.2 執行日誌記錄和監控活動7.3 進行組態管理7.4 應用基礎安全作業概念7.5 應用資源保護7.6 進行事故管理7.7 操作和維護偵測和預防措施7.8 實施和支援修補和漏洞管理7.9 了解並參與變更管理流程7.10 實施復原策略7.11 實施災害復原流程7.12 測試災害復原計畫7.13 參與營運持續性規劃和演練7.14 實施和管理實體安全7.15 解決人員安全和安全擔憂Domain 8: Software Development Security 軟體開發安全8.1 了解並在軟體開發生命週期中整合安全性8.2 識別並應用軟體開發生態系統中的安全控制8.3 評估軟體安全性的有效性8.4 評估所獲得軟體的安全影響8.5 定義並應用安全程式撰寫準則和標準
# Title of the webpage:
#
#     CompTIA CySA＋網路資安分析師國際認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 48,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者想要成為安全營運中心的威脅情報分析師、應用程式安全分析師、合規分析師、安全事件回應處理專員的相關管理人員
# DocumentBOX Outline: Explaining the Importance of Security Controls(解釋安全控制的重要性)Utilizing Threat Data and Intelligence(如何利用威脅數據與情報)Analyzing Security Monitoring Data(如何分析安全監控的數據)Collecting and Querying Security Monitoring Data(如何收集與查看安全監控的數據)Utilizing Digital Forensics and Indicator Analysis Techniques(如何利用數位取證與指標分析的技術)Applying Incident Response Procedures(如何進行事件回應程序)Applying Risk Mitigation and Security Frameworks(如何進行風險緩解與安全框架)Performing Vulnerability Management(如何執行漏洞管理)Applying Security Solutions for Infrastructure Management(如何進行有關網路基礎架構的安全解決方案)Understanding Data Privacy and Protection(了解數據的隱私性與安全保護)Applying Security Solutions for Software Assurance(如何進行軟體保證的安全解決方案)Applying Security Solutions for Cloud and Automation(如何進行雲端自動化的安全解決方案)
# Title of the webpage:
#
#     EC-Council EDRP資安災害復原專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 網路設備管理員、防火牆管理員、系統管理員、應用程式開發人員、資訊安全人員
# DocumentBOX Outline: Introduction to Disaster Recovery and Business Continuity(災難復原計畫與營運持續計畫介紹)Business Continuity Management(營運持續計畫)Risk Assessment(風險評估)Business Impact Analysis (BIA)(商業衝擊分析)Business Continuity Planning (BCP) (商業持續營運計劃書)Data Backup(資料備份)Data Recovery(資料復原)Virtualization-Based Disaster Recovery(虛擬環境災害復原)System Recovery(系統復原)Centralized and Decentralized System Recovery(集中式與分散式之系統復原的選擇)Disaster Recovery Planning Process(災難復原計畫程序)BCP Testing, Maintenance, and Training(商業持續營運計劃書之測試，維運及訓練)
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     ISO 27001：2022資訊安全管理系統主導稽核員訓練課程
#
#
# Course duration: 40小時
# Course cost: NT$ 53,000
# Target audience: 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人2.風險管理相關經理人3.公司治理、政策制定經理人4.欲從事ISO 27001諮詢、顧問之人員5.內部稽核員、電腦稽核員
# DocumentBOX Outline: 1.資訊安全管理系統要求 (ISO/IEC 27001)2.資訊安全管理系統要求 (ISO/IEC 27001)、管理系統稽核指引(ISO 19011)、驗證稽核要求 (ISO 17021)3.管理系統稽核指引 (ISO 19011)-稽核過程演練-稽核準備與計畫4.管理系統稽核指引 (ISO 19011)-稽核過程演練-稽核起始會議、執行現場稽核活動、稽核員角色與稽核技巧演練5.管理系統稽核指引(ISO 19011)-稽核過程演練-稽核結束會議、稽核發現追蹤與認證
# Title of the webpage:
#
#     智慧型手機APP資安分析
#
#
# Course duration: 14小時
# Course cost: NT$ 24,000
# Target audience: 想學習App iOS、Android鑑識知識、手機APP開發人員、資安分析人員、欲充實本身資安鑑識技術能力的人員
# DocumentBOX Outline: 智慧型手機APP的安全問題及目前國際間的分析作法iOS平台 APP分析基本環境架設iOS平台 APP程式反組譯及相關靜態分析Android 平台APP分析基本環境架設Android 平台APP程式反組譯及相關靜態分析Android平台 APP 虛擬平台及Sandbox分析智慧型手機APP網路封包Man-in-the-middle解密分析
# Title of the webpage:
#
#     藍隊資安SOC監控-EC-Council CSA認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: SOC分析師(第一級和第二級)網路和安全管理員網路和安全工程師網路防禦分析師，網路防禦技術人員網路安全運營商以及處理網路安全操作的相關安全專業人員網路安全分析師任何想成為SOC分析師的人
# DocumentBOX Outline: 安全運營和管理(Security Operations and Management)了解網路威脅，IoC和攻擊方法(Understanding Cyber Threats,IoCs, and Attack Methodology)事件、事件和日誌記錄(Incidents, Events, and Logging)危機事件偵測與安全訊息及事件管理的(SIEM) (Incident Detection with Security Information and Event Management(SIEM))利用威脅情資增強事件檢測能力(Enhanced Incident Detection with Threat Intelligence)危機處理程序及應對方法(Incident Response)
# Title of the webpage:
#
#     CISSP資安系統專家認證課程-假日進修班
#
#
# Course duration: 40小時
# Course cost: NT$ 32,000
# Target audience: 安全開發人員、網路系統工程師、資安分析人員、資安系統工程師、資訊部門主管、資訊長、資安顧問、欲取得CISSP®資格者、欲從事資訊安全管理/顧問工作者
# DocumentBOX Outline: Domain 1: Security and Risk Management 安全與風險管理1.1 理解、遵守並促進專業倫理1.2 理解並應用安全概念1.3 評估、應用並維持安全治理
# 原則1.4 全面理解與資訊安全相關的法律、法規和合規問題1.5 理解調查類型的要求1.6 制定、文件化並實施安全政策、標準、程序和指南1.7 識別、分析、評估、優先排序並實施營運連續性 (BC) 要求1.8 貢獻並執行人員安全政策和程序1.9 理解並應用風險管理概念1.10 理解並應用威脅建模概念和方法1.11 應用供應鏈風險管理 (SCRM) 概念1.12 建立和維護安全意識、教育和培訓計畫Domain 2: Asset Security 資產安全2.1 確定並分類資訊和資產2.2 建立資訊和資產處理需求2.3 安全提供資源2.4 管理資料生命週期2.5 確保適當的資產保留2.6 確定資料安全控制和合規需求Domain 3: Security Architecture and Engineering 安全架構與工程3.1 研究、實施和管理使用安全設計原則的工程流程3.2 理解安全模型的基本概念3.3 根據系統安全要求選擇控制3.4 了解資訊系統的安全功能3.5 評估和減輕安全架構、設計和解決方案元素的漏洞3.6 選擇和確定加密解決方案3.7 了解加密攻擊的方法3.8 將安全原則應用於場地和設施設計3.9 設計場地和設施安全控制3.10 管理資訊系統的生命週期Domain 4: Communication and Network Security 通訊與網路安全4.1 在網路架構中應用安全設計原則4.2 保護網路元件安全4.3 根據設計實施安全通訊
# 通道Domain 5: Identity and Access Management (IAM) 識別與存取管理5.1 控制對資產的實體和邏輯存取5.2 設計身份識別和驗證策略5.3 使用第三方服務實現聯邦式身份5.4 實施和管理授權機制5.5 管理身份和存取提供生命週期5.6 實施身份驗證系統Domain 6: Security Assessmentand Testing 安全評估測試6.1 設計並驗證評估、測試和稽核策略6.2 進行安全控制測試6.3 收集安全流程資料6.4 分析測試輸出並產生報告6.5 進行或促進安全稽核Domain 7: Security Operations 安全作業7.1 理解並遵守調查程序7.2 執行日誌記錄和監控活動7.3 進行組態管理7.4 應用基礎安全作業概念7.5 應用資源保護7.6 進行事故管理7.7 操作和維護偵測和預防措施7.8 實施和支援修補和漏洞管理7.9 了解並參與變更管理流程7.10 實施復原策略7.11 實施災害復原流程7.12 測試災害復原計畫7.13 參與營運持續性規劃和演練7.14 實施和管理實體安全7.15 解決人員安全和安全擔憂Domain 8: Software Development Security 軟體開發安全8.1 了解並在軟體開發生命週期中整合安全性8.2 識別並應用軟體開發生態系統中的安全控制8.3 評估軟體安全性的有效性8.4 評估所獲得軟體的安全影響8.5 定義並應用安全程式撰寫準則和標準
# Title of the webpage:
#
#     EC-Council Web 應用程式安全課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 對網路安全有興趣者對應用程式安全性有興趣，希望能加強資安實作技巧的IT人員有志成為安全分析師、滲透測試人員、道德駭客或安全顧問等專業人員
# DocumentBOX Outline: Web應用程式：駭客與安全介紹初學級挑戰：SQL資料隱碼攻擊(SQL Injection)初學級挑戰：安全性錯誤配置(Security Misconfiguration)初學級挑戰：跨網站腳本攻擊(Cross Site Scripting)初學級挑戰：網路應用程式漏洞掃描和枚舉 (Scanning and Enumeration)中級挑戰：SQL資料隱碼攻擊(SQL Injection)中級挑戰：安全性錯誤配置(Security Misconfiguration)中級挑戰：無效的存取控管(Broken Access Control)精通級挑戰：無效的存取控管(Broken Access Control)精通級挑戰：安全性錯誤配置(Security Misconfiguration)精通級挑戰：伺服器層級認證與授權存取(Server Level Access)專家級挑戰：伺服器層級認證與授權存取(Server Level Access)專家級挑戰：安全性錯誤配置(Security Misconfiguration)
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     藍隊資安威脅分析-EC-Council CTIA認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對威脅情資分析有興趣者
# DocumentBOX Outline: Introduction to Threat Intelligence(何謂威脅情資)Cyber Threats and Attack Frameworks(網路威脅與攻擊框架)Requirements, Planning, Direction, and Review(要求、規劃、指導與檢討)Data Collection and Processing(資料收集與處理)Data Analysis(資料分析)Intelligence Reporting and Dissemination(情資通報與傳遞)Threat Hunting and Detection(威脅獵殺與偵測)Threat Intelligence in SOC Operations, Incident Response, and Risk Management(SOC作業、事故應變與風險管理中的威脅情資)
# Title of the webpage:
#
#     CISSP資安系統專家認證課程總複習班
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 已經取得CISSP課程40小時訓練證明，報考CISSP資格者
# DocumentBOX Outline: 第一天CISSP CBK 重點複習1.1 Domain 1: Security and Risk Management1.2 Domain 2: Asset Security1.3 Domain 3: Security Architecture and Engineering1.4 Domain 4: Communication and Network Security1.5 Domain 5: Identity and Access Management (IAM)第二天CISSP CBK 重點複習2.1 Domain 6: Security Assessment and Testing2.2 Domain 7: Security Operations2.3 Domain 8: Software Development Security2.4 考題重點講解2.5 經驗分享●　準備考試注意事項●　臨場考試注意事項●　考上後申請流程●　證照維持規定
# Title of the webpage:
#
#     EC-Council CPENT滲透測試專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 網路設備管理員、防火牆管理員、資訊安全測試人員、系統安全分析師
# DocumentBOX Outline: Introduction to Penetration Testing (滲透測試介紹)Penetration Testing Scoping and Engagement (滲透測試範疇與締約)Open-Source Intelligence(OSINT) (開放情報蒐集)Social Engineering Penetration Testing (社交工程滲透測試)Network Penetration Testing -External(外網滲透測試)Network Penetration Testing -Internal(內網滲透測試)Network Penetration Testing -Perimeter Devices(網路周邊裝置滲透測試)Web Application Penetration Testing (網站程式滲透測試方法)Wireless Network Penetration Testing (無線網路滲透測試方法)IoT Penetration Testing (物聯網滲透測試)OT/SCADA Penetration Testing (工控滲透測試)Cloud Penetration Testing (雲端滲透測試方法)Binary Analysis and Exploitation (二進制程式分析與攻擊)Reports Writing and Post Test Action(撰寫報告與測試後續動作)
# Title of the webpage:
#
#     FCP-NS認證 - FortiClient EMS Administrator認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 相關參與FortiClient EMS管理、配置和操作的 IT 和安全專業人員，以用於保護其組織的端點設備欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: FortiClient 和 FortiClient EMS 的簡介安裝和授權許可FortiClient EMS 的配置和管理FortiClient 的部署使用 FortiClient EMS 進行 FortiClient 的配置FortiClient Endpoint ProfilesZTNAZTNA 配置FortiClient Cloud診斷和故障排除
# Title of the webpage:
#
#     資訊安全基礎課程
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 人人皆需要資訊安全的知識，本課程特別適合企業內所有工作人員，每人皆應具備資訊安全的基礎觀念
# DocumentBOX Outline: 回顧近年重大個人資安時事檢視不良的上網習慣有線／無線連網的安全性個人／公用電腦安全健身操行動裝置黑魔法防禦術選擇使用安全的應用程式社群軟體安全注意事項有備無患-如何正確進行資料備份
# Title of the webpage:
#
#     網路安全封包分析認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: 具備TCP/IP網路技術概念者企業網路之管理人員欲從事網路安全之相關人員對網路安全有興趣者
# DocumentBOX Outline: 網路封包分析的基本知識與常用技巧常見網路服務FTP、Telnet、SSH、SMTP、POP3、IMAP封包行為分析常見HTTP、HTTPS之正常與異常封包行為分析網路芳鄰(CIFS/SMB/NAS)之正常與異常封包行為分析ODBC、MS-SQL、MySQL、PostgreSQL、Oracle資料庫之封包行為分析惡意程式(Malware)、跳板主機與駭客攻擊封包行為分析網路異常與駭客攻擊的案例分析
# Title of the webpage:
#
#     藍隊資安威脅分析-EC-Council CTIA認證課程-假日進修班
#
#
# Course duration: 24小時
# Course cost: NT$ 25,000
# Target audience: 具實務經驗之網路/系統資安人員、資安從業人員、對威脅情資分析有興趣者
# DocumentBOX Outline: Introduction to Threat Intelligence(何謂威脅情資)Cyber Threats and Attack Frameworks(網路威脅與攻擊框架)Requirements, Planning, Direction, and Review(要求、規劃、指導與檢討)Data Collection and Processing(資料收集與處理)Data Analysis(資料分析)Intelligence Reporting and Dissemination(情資通報與傳遞)Threat Hunting and Detection(威脅獵殺與偵測)Threat Intelligence in SOC Operations, Incident Response, and Risk Management(SOC作業、事故應變與風險管理中的威脅情資)
# Title of the webpage:
#
#     EC-Council CCSE雲端資安工程師認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 68,000
# Target audience: 雲端技術工程師、或對雲端安全技術有興趣者
# DocumentBOX Outline: Introduction to Cloud Security (介紹雲端運算安全)Platform and Infrastructure Security in Cloud (雲端運算中的平台與基礎設施安全)Application Security in Cloud (雲端運算中的應用程式安全)Data Security in Cloud (雲端運算中的資料安全)Security Operations in Cloud (雲端運算中的安全作業)Penetration Testing in Cloud (雲端運算中的滲透測試)Incident Response in Cloud (雲端運算中的事故應變)Forensic Investigation in Cloud (雲端運算中的鑑識調查)Business Continuity and Disaster Recovery in Cloud (雲端運算中的持續營運與災難回復)Governance, Risk Management, and Compliance in Cloud (雲端運算中的治理、風險管理與遵循)Standards, Policies, and Legal Issues in Cloud (雲端運算中的標準、政策與法律議題)
# Title of the webpage:
#
#     EC-Council CSCU安全電腦使用者認證課程
#
#
# Course duration: 16小時
# Course cost: NT$ 16,000
# Target audience: 個人用戶和家庭使用者商業和組織用戶學生和學術界人士任何對安全使用電腦、行動裝置、物聯網系統有興趣的人員
# DocumentBOX Outline: 資料安全介紹作業系統的安全性惡意軟體和防毒軟體網際網路安全社交網站的安全性保護電子郵件通訊行動裝置的安全性雲端安全性網路連接的安全性資料備份和災難復原保護物聯網設備和遊戲主機遠距工作的安全性
# Title of the webpage:
#
#     FCP-NS認證 - 資安鐵三角FortiSwitch認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或參與Fortinet資安鐵三角–FortiSwitch管理、配置和監控，以為終端設備提供安全網路存取的網路安全專業人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 交換器託管模式(Managed Switch)交換器基礎功能第2層設計第2層安全性進階功能監控交換器獨立模式(Standalone Switch)故障排除
# Title of the webpage:
#
#     ISO/IEC 27701：2019隱私資訊管理系統主導稽核員轉證訓練課程
#
#
# Course duration: 14小時
# Course cost: NT$ 21,000
# Target audience: 稽核人員法務/法令遵循人員個人資訊管理專責人員資訊安全管理專責人員有志從事ISO 27701輔導顧問之人員
# DocumentBOX Outline: 認識個人資訊管理系統國際個人資訊法規要求趨勢ISO 27000 資安管理系列架構概論ISO 27701:2019 條款與附錄個人資料盤點與風險管理ISO 27701:2019與BS10012:2017差異說明驗證申請與條件實作演練稽核證據稽核角色扮演稽核報告 / 陳述稽核發現
# Title of the webpage:
#
#     網路安全封包分析進階實作
#
#
# Course duration: 21小時
# Course cost: NT$ 24,000
# Target audience: NSPA Class C 認證人員企業網路之管理人員欲從事網路安全之相關人員對網路安全有興趣者
# DocumentBOX Outline: 1、網路安全封包分析-常見木馬程式實例包括有：網路資安基本檢測方式、判斷網路異常通訊方式、正常網路封包的分析(實作)、惡意程式攻擊實作與封包分析(AgentTesla, HawkEye, QuasarRAT, NjRAT, NanoCore, AveMaria, Lucifer等等)、封包分析技巧的學習評量與討論(實作題5題、木馬程式部分)2、網路安全封包分析-常見加密勒索實例包括有:加密勒索的運作與偵測、加密勒索的案例研析、加密勒索攻擊實作與封包分析(Loocipher, WannaCry, Sodinokibi, Dharma, Nemty, GlobleImposter)的分析、封包分析技巧的學習評量與討論(實作題5題, 加密勒索部分)3、網路安全封包分析-常見IDS/IPS與手機封包實例包括有: APT組織的探討與案例、駭客攻擊的策略與戰術、多重複合式攻擊的案例、IDS/IPS偵測規則與Wireshark的規則轉換、封包分析技巧的學習評量與討論(實作題18題)
# Title of the webpage:
#
#     FCP-NS認證 - 資安鐵三角Secure Wireless LAN認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或參與Fortinet資安鐵三角–FortiAP (整合與雲端無線解決方案)的管理、配置和監控的網路和安全專業人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: Managed FortiAP無線網路安全無線網路存取FortiAP配置檔 (FortiAP Profiles)Rogue Aps (非法APs) 和FortiPresence進階選項和監控故障排除
# Title of the webpage:
#
#     CompTIA PenTest＋滲透測試和漏洞管理國際認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 48,000
# Target audience: 系統管理人員網路安全管理人員對網路安全技術有興趣者想要成為安全營運中心的威脅情報分析師、應用程式安全分析師、合規分析師、安全事件回應處理專員的相關管理人員
# DocumentBOX Outline: Planning and Scoping Penetration Tests(如何規劃滲透測試的範圍)Conducting Passive Reconnaissance(如何進行被動式偵查)Performing Non-Technical Tests(如何執行非技術性的測試)Conducting Active Reconnaissance(如何進行主動式偵查)Analyzing Vulnerabilities(如何進行漏洞分析)Penetrating Networks(什麼是網路滲透)Exploiting Host-Based Vulnerabilities(如何利用主機式的漏洞)Testing Applications(應用程式的測試)Completing Post-Exploit Tasks(完成漏洞利用後的任務)Analyzing and Reporting Pen Test Results(如何分析並報告滲透測試的結果)
# Title of the webpage:
#
#     EC-Council CCISO資安長課程
#
#
# Course duration: 40小時
# Course cost: NT$ 99,000
# Target audience: 有志於成為專業資安經理人或資安長資訊安全之規劃、設計與管理者對資訊安全管理與知識有興趣者
# DocumentBOX Outline: Domain 1：Governance治理Drivers that Influence Governance 治理驅動力Corporate Governance Activities 公司治理活動Information Security Governance Activities 資安治理活動Governance and Ethical Decision Making 治理與道德決策Domain 2：Security Management Controls and Auditing Management資安管理控制措施與稽核管理Risk Management 風險管理Risk Treatment 風險處置Risk Management Frameworks 風險管理框架Audit Management 稽核管理Risk Communication and Organizational Reporting 溝通風險與通報Domain 3：Security Program Management and Operations 安全計畫管理與作業Information Security Portfolio Management 資安組合管理Information Security Program Management 資安計畫管理Information Security Project Management 資安專案管理Security Operations 安全作業Domain 4：Information Security Core Competencies資安核心職能Access Control 存取控制Physical Security 實體安全Network and Communications Security 網通安全Threat and Vulnerability Management 威脅與弱點管理System and Application Security 系統安全Encryption Concepts and Technology 加密與相關技術Domain 5：Strategic Planning, Financial Management, and Vendor Management 策略性規劃及財務與供應商管理Strategic Planning 策略性規劃Financial Management 財務管理Vendor Risk Management 供應商風險管理
# Title of the webpage:
#
#     FCP-NS認證 - FortiAuthenticator Administrator認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 負責FortiAuthenticator日常管理的任何人欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置使用者管理和高可用性管理和驗證使用者使用者身份驗證故障排除雙因子身份驗證(2FA)Fortinet單一登入(FSSO) 流程和方法Fortinet單一登入(FSSO) 部署和故障排除入口網站服務(Portal Services)PKI和設定FortiAuthenticator為CA憑證管理802.1X驗證OAuth和SAMLFIDO2身份驗證
# Title of the webpage:
#
#     FCP-NS認證 - FortiAnalyzer Administrator認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 簡介和初始配置系統管理容錯式磁碟陣列(RAID) 和 高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     EC-Council CASE Java應用程式安全工程師認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 2年以上Java實務開發經驗有志成為Java應用程式安全工程師/安全分析師/安全測試專業人員工作範圍涉及開發、測試、管理或保護應用程式安全之專業人員
# DocumentBOX Outline: 應用程式的安全、威脅與攻擊應用程式安全需求收集安全應用程式設計與架構輸入驗證安全編碼實務鑑別與授權加密技術安全編碼實務Session管理錯誤處理安全編碼實務靜態與動態應用程式安全測試(SAST & DAST)安全部署與維護
# Title of the webpage:
#
#     FCP-PCS認證 - FortiWeb Administrator認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 參與FortiWeb管理和支援的網路&安全專業人員欲取得FCP-PCS專業認證資格者欲重認證FCF, FCA, FCP-PCS者
# DocumentBOX Outline: 介紹基本設定合規性身份驗證和存取控制網路應用程式安全服務阻斷(DoS)和竄改(Defacement)攻擊機器學習和機器人檢測(Bot Detection)SSL/TLS應用程式交付API保護和機器人緩解措施(Bot Mitigation)其他配置故障排除
# Title of the webpage:
#
#     FCP-PCS認證 -AWS Cloud Security Administrator認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 任何負責在AWS上部署或管理 Fortinet 解決方案的人都應該參加本課程欲取得FCP-PCS專業認證資格者欲重認證FCF, FCA, FCP-PCS者
# DocumentBOX Outline: 公有雲簡介AWS元件用於AWS的Fortinet產品和部署用於AWS 的高可用性用於AWS 的負載平衡器
# Title of the webpage:
#
#     Security Engineering on AWS
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 安全工程師安全架構師安全分析人員安全稽核人員
# DocumentBOX Outline: AWS上的入口點Web應用程式環境的安全注意事項保護Amazon VPC內的網路通訊安全應用程式安全性與事件回應資料安全性與事件回應混合環境的安全注意事項AWS監控和日誌收集在AWS上處理日誌保護Amazon VPC以外的威脅AWS上的帳戶管理無伺服器環境的安全注意事項在AWS上自動執行安全性和事件回應威脅檢測和敏感資料監控
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate Enterprise Firewall認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 欲學習FortiGate高階專業知識者本課程假定您具備高階網路知識，以及FortiGate、FortiManager 和 FortiAnalyzer 的豐富使用經驗欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 網路安全架構簡介硬體加速安全織網 (Security Fabric)高可用性(HA)集中管理OSPFBGPFortiGuard 和 Security Profiles入侵防禦系統(IPS)IPsec VPNAuto-Discovery VPN (ADVPN)
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate SD-WAN認證課程
#
#
# Course duration: 28小時
# Course cost: NT$ 63,000
# Target audience: 想了解或負責Fortinet SD-WAN部署和網路日常維運的任何人欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 介紹集中管理成員、Zones和Performance SLA路由、連線會話SD-WAN 優先等級規則 (SD-WAN Rules)進階IPsec流量塑型
# Title of the webpage:
#
#     FCSS-SO認證 - FortiSIEM Advanced Analytics認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 參與企業或服務提供商(MSSP)部署中的FortiSIEM和FortiSOAR設備的管理、配置和監控的安全專業人員欲取得FCSS-SO高階專業認證資格者欲重認證FCF, FCA, FCP-SO, FCSS-SO者
# DocumentBOX Outline: 多租戶FortiSIEM Collectors和FortiSOAR 連接器Collectors的運作Windows和Linux Agents規則單子模式規則多子模式規則基線(Baseline)基線規則FortiSIEM UEBA巢狀式查詢和查找表告警事故自動清除條件緩解告警事故(Remediation)
# Title of the webpage:
#
#     FCSS-NS認證 - FortiGate Network Security Support Engineer認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 使用FortiGate設備對企業安全基礎設施進行診斷、故障排除和支援之網路安全專業人員本課程假定您具備高階網路知識以及FortiGate的豐富使用經驗欲取得FCSS-NS高階專業認證資格者欲重認證FCF, FCA, FCP-NS, FCSS-NS者
# DocumentBOX Outline: 故障排除概念系統資源連線會話、流量和網路安全織網防火牆身份驗證FSSOSecurity Profiles高可用性IPsecIPsec—IKEv2BGPOSPF
# Title of the webpage:
#
#     FCSS-OS認證 - OT Security認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 使用 Fortinet 設備設計、實施和管理 OT 基礎設施之網路安全專業人員欲取得FCSS-OS高階專業認證資格者欲重認證FCF, FCA, FCSS-OS者
# DocumentBOX Outline: 介紹資產管理存取控制分段防護日誌記錄和監控風險評估
# Title of the webpage:
#
#     Fortinet FortiSIEM Parser課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 負責FortiSIEM日常管理的人想了解如何建立客製化解譯器的人
# DocumentBOX Outline: 介紹正規表示式事件格式識別器解析Switch Case結構客製化CMDB 事件類型Choose-When結構鍵/值對(Key Value Pair)日誌的處理值列表(Value List)日誌的處理進階功能
# Title of the webpage:
#
#     EC-Council CASE .NET應用程式安全工程師認證課程
#
#
# Course duration: 24小時
# Course cost: NT$ 39,000
# Target audience: 2年以上.NET實務開發經驗有志成為.NET應用程式資安工程師/資安分析師/資安測試專業人員工作範圍涉及開發、測試、管理或保護應用程式安全之專業人員
# DocumentBOX Outline: 應用程式的安全、威脅與攻擊應用程式安全需求收集安全應用程式設計與架構輸入驗證安全編碼實務鑑別與授權加密技術安全編碼實務Session管理錯誤處理安全編碼實務靜態與動態應用程式安全測試(SAST & DAST)安全部署與維護
# Title of the webpage:
#
#     Mobile App Security資訊安全程式實作演練-通訊與資料儲存的安全
#
#
# Course duration: 14小時
# Course cost: NT$ 20,000
# Target audience: 1.已完成Android或iOS行動裝置應用系統課程者，或具備基本App觀念與關聯式資料庫、網路存取的學員。2.Android方面需對Activity生命週期與Java語法有基礎認識3.iOS方面需了解基本的Objective-C/swift，對MVC架構有基本理解
# DocumentBOX Outline: iOS的keychain swift實作iOS的sqlite加密sqlcipher說明iOS的sqlite加密sqlcipher應用Android的keyguard實作Android的sqlcipher實作與說明Android的sqlcipher建置OWASP mobile重點說明與其餘補充網路傳輸與加解密基礎導論
# Data saved to courses_details5.xlsx

# %% [markdown]
# # 3.再改成一開始只要打好課程代碼和系列課程名稱就可以指定爬取

# %% [markdown]
# ### 設定目標系列課程的ID和名稱
# 1. course_id = 29
# 2. course_name = "雲端技術 Cloud - Google Cloud"

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 設定目標系列課程的ID和名稱
course_id = 29
course_name = "雲端技術 Cloud - Google Cloud"

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

# 使用正則表達式找到目標系列課程的節點及其 children 節點
search_pattern = re.compile(
    rf'{{"id":"\{{J\}}{course_id}","typeName":"JobCategory","pkid":{course_id},"text":"{course_name}","children":(\[.*?\])',
    re.DOTALL
)
match = search_pattern.search(file_content)

if match:
    # 提取匹配的 children 節點
    start_index = match.start(1)
    bracket_count = 1
    end_index = start_index + 1

    # 查找匹配的結束括號以提取完整的 children 節點
    while bracket_count > 0 and end_index < len(file_content):
        if file_content[end_index] == '[':
            bracket_count += 1
        elif file_content[end_index] == ']':
            bracket_count -= 1
        end_index += 1
    
    children_json = file_content[start_index:end_index]
    
    try:
        # 解析為 JSON 格式
        children_courses = json.loads(children_json)
        
        # 生成課程網址
        base_url = "https://www.uuu.com.tw/Course/Show/"
        urls = []
        for course in children_courses:
            course_id = course['id'].replace("{C}", "")
            friendly_url = course['attributes']['FriendlyUrl']
            full_url = f"{base_url}{course_id}/{friendly_url}"
            urls.append(full_url)
    except json.JSONDecodeError as e:
        print(f"JSON 解碼錯誤: {e}")
else:
    print(f"未找到 '{course_name}' 的相關內容。")
    urls = []

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details_7.xlsx', index=False)
    print("Data saved to courses_details_7.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(urls)
# Out:
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_7.xlsx

# %% [markdown]
# # 4.爬取所有課程

# %%
import re
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 設定目標系列課程的ID和名稱
courses = [
    (1, "網路系統工程 System Engineer"),
    (15, "網路通訊 System Communication"),
    (16, "雲端技術 Cloud - Microsoft Azure"),
    (17, "雲端技術 Cloud - Amazon Web Services (AWS)"),
    (18, "虛擬化技術"),
    (19, "程式設計 Programer"),
    (20, "前端工程師系列 Front-End Engineer"),
    (21, "智慧型手機應用程式 Mobile App"),
    (22, "資料庫管理 Database"),
    (23, "數據分析與商業智慧 Data Analysis & Business Intelligence"),
    (24, "資訊安全 Security"),
    (25, "管理類別 Management"),
    (26, "主導稽核員 Leading auditors"),
    (27, "多媒體設計 Multimedia Design"),
    (28, "區塊鏈"),
    (29, "雲端技術 Cloud - Google Cloud")
]

# 讀取上傳的文件內容並解析
file_path = "C:/Users/WCHuang8/Desktop/CourseTrees_Js"

with open(file_path, 'r', encoding='utf-8') as file:
    file_content = file.read()

all_course_urls = []

for course_id, course_name in courses:
    # 使用正則表達式找到目標系列課程的節點及其 children 節點
    search_pattern = re.compile(
        rf'{{"id":"\{{J\}}{course_id}","typeName":"JobCategory","pkid":{course_id},"text":"{course_name}","children":(\[.*?\])',
        re.DOTALL
    )
    match = search_pattern.search(file_content)

    if match:
        # 提取匹配的 children 節點
        start_index = match.start(1)
        bracket_count = 1
        end_index = start_index + 1

        # 查找匹配的結束括號以提取完整的 children 節點
        while bracket_count > 0 and end_index < len(file_content):
            if file_content[end_index] == '[':
                bracket_count += 1
            elif file_content[end_index] == ']':
                bracket_count -= 1
            end_index += 1
        
        children_json = file_content[start_index:end_index]
        
        try:
            # 解析為 JSON 格式
            children_courses = json.loads(children_json)
            
            # 生成課程網址
            base_url = "https://www.uuu.com.tw/Course/Show/"
            urls = []
            for course in children_courses:
                course_id = course['id'].replace("{C}", "")
                friendly_url = course['attributes']['FriendlyUrl']
                full_url = f"{base_url}{course_id}/{friendly_url}"
                urls.append(full_url)
            
            all_course_urls.extend(urls)
        except json.JSONDecodeError as e:
            print(f"JSON 解碼錯誤: {e}")
    else:
        print(f"未找到 '{course_name}' 的相關內容。")

# 定義爬蟲函數
def scrape_course_details(url):
    """
    爬取給定URL的課程詳細信息。
    """
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').get_text()
        print('Title of the webpage:', title)
        
        duration_element = soup.find('li', string=lambda x: x and '時數：' in x)
        if duration_element:
            duration = duration_element.get_text(strip=True).split('：')[1]
            print('Course duration:', duration)
        else:
            print('Course duration not found')
        
        cost_element = soup.find('li', string=lambda x: x and '費用：' in x)
        if cost_element:
            cost = cost_element.get_text(strip=True).split('：')[1]
            print('Course cost:', cost)
        else:
            print('Course cost not found')
        
        target_audience = None
        target_audience_div = soup.find('div', class_='Target')
        if target_audience_div:
            target_audience_element = target_audience_div.find('div', class_='Content')
            if target_audience_element:
                target_audience = target_audience_element.get_text(strip=True)
                print('Target audience:', target_audience)
            else:
                print('Target audience content not found')
        else:
            print('Target audience section not found')
        
        documentbox_outline = None
        documentbox_outline_div = soup.find('div', class_='Outline')
        if documentbox_outline_div:
            documentbox_outline_element = documentbox_outline_div.find('div', class_='Content')
            if documentbox_outline_element:
                documentbox_outline = documentbox_outline_element.get_text(strip=True)
                print('DocumentBOX Outline:', documentbox_outline)
            else:
                print('DocumentBOX Outline content not found')
        else:
            print('DocumentBOX Outline section not found')

        return {
            'Title': title,
            'Course Duration': duration,
            'Course Cost': cost,
            'Target Audience': target_audience,
            'DocumentBOX Outline': documentbox_outline
        }
    else:
        print(f'Failed to retrieve the webpage: {url}')
        return None

def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並保存到Excel文件中。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    
    df = pd.DataFrame(courses_data)
    df.to_excel('courses_details_all.xlsx', index=False)
    print("Data saved to courses_details_all.xlsx")

# 使用生成的課程網址爬取課程詳細信息
scrape_courses(all_course_urls)
# Out:
# 未找到 '雲端技術 Cloud - Amazon Web Services (AWS)' 的相關內容。
# Title of the webpage:
#
#     CCNA認證-建置與管理Cisco解決方案
#
#
# Course duration: 70小時
# Course cost: NT$ 66,000
# Target audience: 1.對通訊產業有高度興趣，欲從事相關工作者2.從事網路維運相關工作者3.想要取得CCNA認證者
# DocumentBOX Outline: 1.建立網路與區域網路的基礎概念2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協定介紹）3.認識封包的基本構造4.網路設備的設定與IOS的管理5.建置企業交換器虛擬區域網路(VLAN)環境6.交換器擴展樹協定（STP與RSTP）運作原理與最佳化7.乙太通道網路EtherChannel的運作概念與設定8.路由運作基礎與設定9.廣域網路WAN與虛擬私人網路VPN相關運作技術與設定介紹10.網路設備安全性強化措施，ACL相關技術的實作與設定11.Layer 3 Redundancy的相關技術介紹與HSRP的實作12.淺談智能網路（SDN、SD-Access、SD-WAN、Cisco DNA Center）的發展與變革13.常用網管協定的設定與自動化，例如：SNMP、Syslog、NTP、CDP/LLDP14.網路服務效能（QoS）簡介15.無線區域網路（WLAN）運作原理與基本設定16.認識網路安全威脅與相關的防範因應措施
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路建置專家
#
#
# Course duration: 98小時
# Course cost: NT$ 129,000
# Target audience: 企業網路架構管理與規劃人員企業網路解決方案規劃與支援人員對大型企業網路運作技術有興趣深入瞭解者
# DocumentBOX Outline: ENCOR—思科企業網路核心技術建置與維運ENARSI—建置思科高級企業等級路由與服務
# Title of the webpage:
#
#     CCNP Security認證-思科網路安全核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 負責企業網路安全維護管理者需要企業網路安全相關知識與技術者對於企業網路安全機制有興趣瞭解者
# DocumentBOX Outline: 了解資訊安全概念了常見的TCP/IP攻擊、網路應用攻擊、端點攻擊與網路安全技術部署思科ASA防火牆與思科Firepower下一代防火牆部署電子郵件與網站內容安全性部署Cisco Umbrella了解VPN技術和密碼學推出思科站點之間VPN安全解決方案與點對點的Cisco IOS VTI在Cisco ASA和Cisco Firepower NGFW上部署點對點IPsec VPN與遠端存取的SSL VPN了解思科安全網路訪問解決方案了解與配置802.1X驗證了解端點安全技術並部署Cisco端點AMP介紹並部署網路基礎架構保護措施
# Title of the webpage:
#
#     CompTIA Network＋國際網路認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 想要跨至資訊網路工程領域的學習工作者想要取得網路基礎技術認證的工程師想要完成網路安全技術認證的工程師相要進一步學習不同的網路系統技術（包括Microsoft、Linux、CISCO）需要具備的網路基礎知識的網路工程師。
# DocumentBOX Outline: Comparing OSI Model Network Functions（比較 OSI 模型的網路功能）Deploying Ethernet Cabling（部署乙太網路的線路）Deploying Ethernet Switching（部署乙太網路的交換器）Troubleshooting Ethernet Networks（乙太網路的疑難排除）Explaining IPv4 Addressing（了解IPv4的定址模式）Supporting IPv4 and IPv6 Networks（如何同時支援IPv4與IPv6的網路）Configuring and Troubleshooting Routers（網路路由器的設定與疑難排除）Explaining Network Topologies and Types（了解網路的拓樸架構與類型）Explaining Transport Layer Protocols（了解傳輸層的協定）Explaining Network Services（了解什麼是網路服務）Explaining Network Applications（了解什麼是網路應用程式）Ensuring Network Availability（確保網路的可用性）Explaining Common Security Concepts（了解通用安全的概念）Supporting and Troubleshooting Secure Networks（安全網路的支援與疑難排除）Deploying and Troubleshooting Wireless Networks（無線網路的部署與疑難排除）Comparing WAN Links and Remote Access Methods（比較廣域網路連線與網路遠端存取連線的方法）Explaining Organizational and Physical Security Concepts（了解組織與實體安全的概念）Explaining Disaster Recovery and High Availability Concepts（了解災難重建與高可用性的概念）Applying Network Hardening Techniques（應用網路的強化技術）Summarizing Cloud and Datacenter Architecture（總論雲端與資料中心的架構）
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     Red Hat JBoss應用伺服器的系統管理
#
#
# Course duration: 35小時
# Course cost: NT$ 56,000
# Target audience: 想要在公司導入JBoss系統的系統管理人員欲學習JBoss EAP 7伺服器的安裝與管理的系統管理人員欲了解JBoss EAP 7伺服器在部署與維運時搭配的管理重點者
# DocumentBOX Outline: 安裝與設定JBoss EAP 7伺服器在Standalone與Domain模式上配置一個Domain部署Java應用程式在JBoss EAP 7伺服器上組態與JBoss EAP 7伺服器的DataSource連結工作組態Java Message Service與HornetQ組態與JBoss EAP 7伺服器的日誌相關設定部署應用程式的安全性與批次處理在JBoss EAP 7伺服器上認識JBoss EAP 7伺服器的Cluster環境
# Title of the webpage:
#
#     Red Hat OpenShift I：Containers和Kubernetes
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 想深入了解Container與Kubernetes如何組成微服務運作的軟體架構人員工作需求需要設計微服務的應用程式開發人員協助企業評估Container應用需求的架構工程人員
# DocumentBOX Outline: 了解Container、Docker和Red Hat OpenShift的Container架構建立Container化服務管理Container和Container的映像檔案管理客製Container映像檔在Red Hat OpenShift上部署搭配Container的應用程序部署多Container的應用程序
# Title of the webpage:
#
#     Red Hat Linux認證工程師培訓班
#
#
# Course duration: 98小時
# Course cost: NT$ 72,000
# Target audience: 1.Linux入門者、具備網路基本架構概念者2.想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124： Red Hat紅帽系統管理 I (35小時)RH134： Red Hat紅帽系統管理 II (35小時)RH294： Red Hat紅帽系統管理 III-Linux自動化(28小時)
# Title of the webpage:
#
#     Red Hat紅帽RHCSA 認證課程
#
#
# Course duration: 70小時
# Course cost: NT$ 50,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124：Red Hat紅帽系統管理 I (35小時)RH134：Red Hat紅帽系統管理 II (35小時)
# Title of the webpage:
#
#     Red Hat紅帽系統管理 I
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RHEL介紹Linux指令模式的使用在指令模式下進行檔案的管理如何取系統說明文件Linux的帳號管理檔案存取權限的管理Linux系統下的行程管理Linux系統下的服務管理OpenSSH的使用Linux系統的Log管理Linux系統下的網路管理Linux系統下的壓縮工具及檔案傳輸工具RHEL 9下的套件管理( DNF )Linux系統下的檔案系統管理
# Title of the webpage:
#
#     配置Aruba行動網路第一級
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 1.對無線通訊產業有高度興趣，欲從事相關工作者2.部署中小企業等級無線網路解決方案的網路IT專業人員
# DocumentBOX Outline: 介紹無線區域網路802.11與射頻(RF)基礎知識介紹以行動為優先的Aruba OS 8.X網路架構，包含行動控制台種類與運作模式設置Aruba行動主控台(Mobility Master)與行動控制台(Mobility Controller)，了解群組與子群組的分層設定，並介紹使用不同的配置方法將行動控制台加入到行動主控台使用行動主控台的GUI配置安全的無線區域網路，並解釋AP群組架構(AP Group)與其配置檔(AP Group Profile)介紹AP的配置佈建(AP Provisioning)，包含AP與行動控制台間的通訊、AP開機過程、與Control Plane保護機制(CPSec)介紹無線區域網路的資安概念，包含各種不同的WPA/WPA2 802.1X認證與MAC認證方法、對稱與不對稱加密金鑰、與使用WIPS來發現惡意的無線基地台(Rogue AP)介紹Aruba整合式防火牆策略與角色，包含以身份為基礎的Aruba防火牆、使用別名(alias)來設定防火牆策略與規則、與如何指派角色給用戶(Role Derivation)介紹Aruba自動管理射頻(RF)功能，包含Airmatch/ARM功能是如何校準網路來選擇最佳的頻道與設定功率、與Client Match功能是如何引導用戶連接更好的AP使用Captive portal搭配Clearpass認證伺服器來建置Aruba訪客造訪(Guest Access)的資安解決方案，與創建guest provisioning account介紹無線區域網路的監控與故障排除，包含使用Airwave與行動主控台儀表板功能來監控與診斷client/WLAN/AP相關疑難問題、與使用APPrf過濾功能來分析流量
# Title of the webpage:
#
#     網路基礎架構與網路服務
#
#
# Course duration: 42小時
# Course cost: NT$ 16,000
# Target audience: 想進入資訊領域，卻完全沒有資訊背景或經驗者想成為網路工程師、系統工程師，基礎不穩固或無基礎者跨領域學習工作者
# DocumentBOX Outline: 了解主/從(Client/Server)、雲端(Cloud Computing)架構微軟Hypervisor虛擬機器使用及操作ISO/OSI 7 Layer獨家精闢詳解細說乙太網路設備運作原理(訊號增益器、橋接器、交換器、路由器與閘道器)IPv4/IPv6位址、子網段切割、CIDR、Supernetting獨家教材詳解與教學廣域網路(WAN)介紹深入淺出TCP/IP網路重要概念路由(Routing)及網路位址轉譯(NAT)原理詳解及實作IT人員必備的基本網路服務的運作原理(DHCP、DNS、Web、FTP)資訊安全與防毒系統的整體概念
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 1.負責中大型企業網路運作與管理者2.需要中大型企業網路優化調校相關知識與技術者3.對於中大型企業網路運作機制有興趣瞭解者
# DocumentBOX Outline: 檢查思科企業網路架構與思科交換路徑建置園區域網路高可用性網路連接探索、建置及優化企業路由通訊協定（包含OSPF、EIGRP、BGP）介紹網路虛擬化協定與虛擬私人網路和介面探索無線原理、無線漫遊和定位服務與無線AP操作無線部署與無線客戶端身份驗證選項檢查與建置無線客戶端連接故障排除群播（Multicast）路由協定介紹介紹、建置QoS與其他網路服務使用網路分析工具了解企業網路安全架構建置基礎架構安全與安全訪問控制使用思科DNA中心探索自動化和保證，並且在Cisco DNA Center和vManage中導入API檢查思科SD-Access解決方案了解思科SD-WAN解決方案的工作原理介紹網路可開發性協議與Python程式設計基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CDCP資訊機房專業人員國際認證班
#
#
# Course duration: 14小時
# Course cost: NT$ 60,000
# Target audience: 資訊機房(Data Center)相關IT/設施人員資訊機房負責營運人員/管理層學習如何建置符合企業需求資訊機房(Data Center)的人員想取得CDCP國際認證者
# DocumentBOX Outline: 1.資料中心，重要性和停機的原因2.資料中心標準和最佳實踐3.資料中心的地點，建設和建設•   選擇合適的場所和建築物以及如何避免陷阱•   有效資料中心的各種組件和支持設施的設置4.高架地板/輕鋼架•   統一、集中和滾動載荷定義•   適用標準•   高架地板準則•   信號參考網格、機架接地•   殘疾法和法規•   輕鋼架的使用和要求5.照明•   標準•   照明類型和位置•   應急照明，應急電源(EPS)6.電力基礎設施•   從發電到機架的電力基礎設施佈局•   ATS和STS系統•   冗餘級別和技術•   三相和單相使用•   房中的配電選項•   電源線和母線槽•   連接和接地•   共模噪聲和隔離變壓器•   配電板，尺寸和IP保護等級•   電能質量準則•   有功功率和視在功率•   如何確定和計算資料中心的負載•   發電機•   靜態和動態UPS系統，選擇標準，操作模式和能效選項•   電池類型，正確的選擇和測試•   熱成像•   可再生能源係數 (REF，Renewable Energy Factor)7.電磁場•   電場和磁場的定義和測量單位•   電磁場的來源•   電磁場對人體健康和設備的影響•   (H)EMP•   標準•   EMF遮蔽解決方案8.機架•   機架標準、特性和選擇標準•   安全注意事項•   配電盤/槽選項9.冷卻基礎設施•   溫度和濕度建議•   冷卻測量單位和轉換率•   顯熱和潛熱定義•   舒適型與精密冷卻之間的差異•   不同的空調技術概述•   高架地板與非高架地板散熱•   空調單元的放置和限制•   補充冷卻選項•   冷通道/熱通道密閉•   液浸冷卻•   冷卻概念：季節性熱能儲存 (STER, Seasonal Thermal Energy Storage)10.供水•   供水和應用領域的重要性•   備用供水技術11.設計可擴展的網路基礎架構•   結構化佈線系統的重要性•   規劃注意事項•   銅和光纜技術和標準•   ANSI/ TIA-942佈線層次結構和建議•   測試與驗證•   網路冗餘•   建築物之間的連接•   網路監控系統要求12.防火•   滅火標準•   檢測系統•   各種全浸式滅火技術和系統、其優缺點•   手提式滅火器•   標牌與安全•   法規要求和最佳做法13.物理保全和人身安全•   物理保全考慮•   人身安全注意事項14.輔助系統•   資料中心監控要求•   EMS、BMS和DCIM•   漏水檢測系統•   警報通知
# Title of the webpage:
#
#     Designing and Implementing Storage on AWS
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端儲存工程師解決方案架構師雲端維運工程師DevOps工程師
# DocumentBOX Outline: 第一天：Module 1：雲端儲存介紹Module 2：設計物件儲存解決方案Module 3：使用Amazon S3建置物件儲存解決方案Module 4：設計區塊儲存解決方案第二天：Module 5：使用Amazon EBS建置區塊儲存解決方案Module 6：檔案儲存與Amazon EFSModule 7：使用Amazon FSx建置雲端檔案儲存第三天：Module 8：混合與邊緣的雲端儲存Module 9：搬移資料至AWSModule 10：AWS的備份與災難復原Module 11：對AWS儲存進行監控、自動化與最佳化
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Microsoft 365 Fundamentals認證班
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 由於本課程是許多將要銷售Microsoft 365服務的銷售員或專員的基本認證課程，所以只要是從事相關工作的人員都是要學習本課程的對象從事Microsoft 365相關服務銷售、代理、整合應用服務的銷售員、服務解說員想要認識、評估或使用Microsoft 365的操作人員、資訊工作者欲進一步熟悉Microsoft 365所提供軟體即應用服務的架構，與需要進行管理與維護的Microsoft 365管理員有志取得完整Microsoft 365 Certified：Fundamentals認證者
# DocumentBOX Outline: 展示Microsoft 365生產力和團隊合作的基本知識(Demonstrate fundamental knowledge of Microsoft 365 productivity and teamwork)展示Microsoft 365商務管理功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 business management capabilities)展示Microsoft 365授權、服務和支援的基礎知識(Demonstrate fundamental knowledge of Microsoft 365 licensing, service and support)展示Microsoft 365安全性與合規性功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 security and compliance capabilities)
# Title of the webpage:
#
#     Microsoft Azure基礎知識
#
#
# Course duration: 14小時
# Course cost: NT$ 12,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified Azure Fundamentals認證者
# DocumentBOX Outline: 描述雲端概念•      說明雲端運算•      說明使用雲端服務的優點•      描述雲端服務類型描述Azure架構與服務•      描述Azure的核心架構元件•      說明Azure計算和網路服務•      描述Azure儲存體服務•      說明Azure身分識別、存取和安全性描述Azure管理與治理•      說明在Azure中成本管理•      說明Azure中與治理及合規性相關的功能與工具•      說明管理和部署Azure資源的功能和工具•      說明Azure中的監視工具微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft安全性、合規性和身份基礎知識
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified：Security, Compliance, and Identity Fundamentals認證者
# DocumentBOX Outline: 安全性、合規性和身份的基本概念Microsoft身份和存取管理解決方案的觀念及功能Microsoft安全解決方案Microsoft合規性管理的功能微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Red Hat紅帽系統管理II
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習Linux系統管理的IT人員
# DocumentBOX Outline: Linux系統下文字模式的進階使用及shell scriptLinux系統下的排程管理Linux系統下的效能調校SELinux系統的管理Linux系統下的硬碟管理及儲存空間的使用Linux Volume Manage的管理及使用NFS Client的使用Linux系統的開機流程RHEL 9的網路存取控制安裝RHEL 9虛擬化技術 / 容器技術
# Title of the webpage:
#
#     VMware Aria Automation安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: System administrators and system integrators responsible for designing, implementing, and managing VMware Aria Automation
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.VMware Aria Automation Overview and Architecture• Describe the purpose and functionality of VMware Aria Automation• Identify the key services offered by VMware Aria Automation• Describe the VMware Aria Automation architecture• Describe the use of VMware Workspace ONE Access™• Describe the relationship between Kubernetes clusters, container, and VMware Aria Automation services3.Installing VMware Aria Automation• List the different VMware Aria Automation deployment types• Describe the purpose of Easy Installer• Describe the VMware Aria Automation installation process4.Authentication and Authorization• Identify the steps to integrating Workspace ONE® Access with Active Directory• Describe the features of Workspace ONE Access• Describe the user roles available in VMware Aria Automation• Identify the key tasks performed by each user role• Define custom roles• Configure branding and multitenancy5.Basic Initial Configuration• Create a basic configuration with a cloud account, cloud zone, project, flavor mapping, and image mapping6.VMware Aria Automation Templates• Configure and deploy a basic VMware Aria Automation template• Create a VMware Aria Automation template that can run on any cloud• Use cloudConfig and cloudbase-init to run commands, create users, and install software• Use YAML for inputs, variables, and conditional deployments7.Tags• Configure tags• Describe functions of tags• Manage tags
# 8.Storage Configuration• Configure storage profiles• Use tags and storage profiles9.Integrating NSX With VMware Aria Automation• List the capabilities and use cases of VMware NSX®• Describe the NSX architecture and components• Integrate NSX with VMware Aria Automation• List the supported network profiles in VMware Aria Automation• Use the NSX components to design a multitier application with VMware Aria Automation Templates• Identify the network and security options available in design canvas• Create and manage on-demand networks and security groups• Configure NSX Day 2 actions10.Integrating with Public Clouds• Configure and use VMware Cloud Foundation™ accounts• Integrate VMware Cloud Director™ account• Configure and use an AWS cloud account• Configure and use an Azure cloud account• Configure and use a Google Cloud Platform cloud account• Integrate VMware Cloud on AWS cloud account11.Using VMware Aria Automation Consumption• Release a VMware Aria Automation template• Define content source and content sharing• Define VMware Aria Automation policy enforcement• Use custom forms for catalog items12.VMware Aria Automation Extensibility• Describe VMware Aria Automation extensibility• Use event topics• Create a subscription• Call a VMware Aria Automation Orchestrator workflow• Create ABX actions13.Using Kubernetes Clusters• Introduction to Kubernetes• Connect to an existing Kubernetes Cluster• Create a VMware Aria Automation template with Kubernetes components14.Using VMware Aria Automation Config for Configuration Management• Describe VMware Aria Automation Config• Use VMware Aria Automation Config for software deployment• Use VMware Aria Automation Config for configuration management• Use VMware Aria Automation Config with event-driven orchestration15.VMware Aria Automation Troubleshooting and Integration• Demonstrate how to monitor deployment history• Demonstrate basic troubleshooting• Execute CLI commands• Explain how to collect logs• Describe integration with VMware Aria Operations for Logs• Describe integration with VMware Aria Operations
# Title of the webpage:
#
#     VMware Kubernetes Fundamentals and Cluster Operations
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Anyone who is preparing to build and run Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction•  Introductions and objectives2.Containers•  What and Why containers•  Building images•  Running containers•  Registry and image management3.Kubernetes Overview•  Kubernetes project•  Plugin interfaces•  Building Kubernetes•  Kubectl CLI4.Beyond Kubernetes Basics•  Kubernetes objects•  YAML•  Pods, replicas, and deployments•  Services•  Deployment management•  Rolling updates•  Controlling deployments•  Pod and container configurations5.Kubernetes Networking•  Networking within a pod•  Pod-to-Pod Networking•  Services to Pods•  ClusterIP, NodePort, and LoadBalancer•  Ingress controllers•  Service Discovery via DNS6.Stateful Applications in Kubernetes•  Stateless versus Stateful•  Volumes•  Persistent volumes claims•  StorageClasses•  StatefulSets7.Additional Kubernetes Considerations•  Dynamic configuration•  ConfigMaps•  Secrets•  Jobs, CronJobs8.Security•  Network policy•  Applying a NetworkPolicy•  SecurityContext•  runAsUser/Group•  Service accounts•  Role-based access control9.Logging and Monitoring•  Logging for various objects•  Sidecar logging•  Node logging•  Audit logging•  Monitoring architecture•  Monitoring solutions•  Octant•  VMware vRealize®Operations Manager™10.Cluster Operations•  Onboarding new applications•  Backups•  Upgrading•  Drain and cordon commands•  Impact of an upgrade to running applications•  Troubleshooting commands•  VMware Tanzu™ portfolio overview
# Title of the webpage:
#
#     VMware NSX安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: Experienced security administrators or network administrators
# DocumentBOX Outline: 1.Course Introduction2.VMware Virtual Cloud Network and VMware NSX3.Preparing the NSX Infrastructure4.NSX Logical Switching5.NSX Logical Routing6.NSX Bridging7.NSX Firewalls8.NSX Advanced Threat Prevention9.NSX Services10.NSX User and Role Management11.NSX Federation
# Title of the webpage:
#
#     VMware Tanzu Kubernetes Grid安裝及設定管理課程
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Platform operators who are responsible for deploying and managing Tanzu Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction2.Introducing VMware Tanzu Kubernetes Grid3.VMware Tanzu Kubernetes Grid CLI and API4.Authentication5.Load Balancers6.VMware Tanzu Kubernetes Grid on vSphere7.VMware Tanzu Kubernetes Grid on Public Clouds8.Tanzu Kubernetes Workload Clusters9.Tanzu Kubernetes Grid Packages10.Configuring and Managing Tanzu Kubernetes Grid Operation and Analytics Packages11.Configuring and Managing Tanzu Kubernetes Grid Networking Packages12.Tanzu Kubernetes Grid Day 2 Operations13.Troubleshooting Tanzu Kubernetes Grid
# Title of the webpage:
#
#     VMware vSphere安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 69,900
# Target audience: 系統管理員系統工程師
# DocumentBOX Outline: 1.Course Introduction2.vSphere and Virtualization Overview3.Installing and Configuring ESXi4.Deploying and Configuring vCenter5.Configuring and Managing Virtual Networks6.Configuring vSphere Storage7.Deploying Virtual Machines8.Managing Virtual Machines9.Deploying and Configuring vSphere Clusters10.Managing the vSphere Lifecycle
# Title of the webpage:
#
#     Windows Server 2016的安裝、儲存及運算
#
#
# Course duration: 42小時
# Course cost: NT$ 28,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望提升企業資訊服務高可用性與負載平衡的管理者與規劃人員
# DocumentBOX Outline: Nano、Server Core伺服器準備、安裝、升級與遷移的策略設定本地儲存裝置企業儲存解決方案儲存空間與重複資料刪除安裝設定Hyper-V與虛擬機器部署管理Windows與Hyper-V容器(Container)高可用性與災難恢復的概論施作與管理容錯移轉叢集建置Hyper-V虛擬機器的容錯移轉叢集配置網路負載平衡(NLB)建立、管理與部署映像檔案(Image)管理、監控和維護虛擬機器的安裝
# Title of the webpage:
#
#     配置Aruba行動網路第二級
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 1.負責中大型企業無線網路維運、管理與部署相關工作者2.對中大型企業無線網路技術有高度興趣者
# DocumentBOX Outline: 回顧配置Aruba行動網路第一級的課程主題，包含各種AP專業用語、圖形界面的分層架構、與WLAN轉發模式介紹行動主控台的備援機制(Mobility Master Redundancy)，包含VRRP的安裝設定、與MM資料庫的同步介紹行動主控台(MM)與行動控制台(MC)的操作，包含行動控制台的各種部署方式、與安裝設定許可證(license)的進階功能介紹Multizone功能，包含Multizone AP功能流程、Primary與Data zone、與Multizone故障排除介紹MC叢集(Cluster)功能，包含cluster leader選舉過程、MC叢集角色、無中斷式叢集的故障切換(hitless cluster failover)、與叢集內部AP和用戶的負載平衡介紹Aruba行動漫遊(Roaming)功能，包含標準的802.11漫遊、單台與多台行動控制台間的漫遊、與叢集式的行動漫遊(Cluster Mobility)介紹角色的指派(Role Derivation)功能，包含使用VSA來解釋角色的指派、描述用戶規則(user rule)與認證預設角色(authentication default role)、解釋如何做故障排除、與以角色為基礎的ACL介紹Aruba遠端存取(Remote Access)的各種解決方案(RAP/VIA/IAP-VPN/branch controller)，包含RAP的認證、安裝、設定、備援選項及故障排除、與VIA的設定、下載、安裝及故障排除介紹Aruba語音最佳化功能，包含檢視語音QoS、解釋WMM、描述UCC Heuristic與SDN API運行模式、語音連線的監控與故障排除介紹Aruba網狀無線網路(Mesh)功能，包含mesh技術、與mesh cluster設定介紹Aruba裝置的管理，包含管理帳戶與其密碼的重置、設定Guest Provisioning account、使用RADIUS或TACACS認證、與如何取消console access介紹行動控制台的操作，包含如何升級新的影像檔、AP image preload、cluster in service的升級、設定檔的自動回滾(Auto roll back)功能、與可載入的服務模組(LSM)介紹Aruba AirGroup功能，包含AirGroup解決方案的設定及其限制、與ClearPass的整合、AirGroup伺服器與用戶的監控介紹自動分段(Dynamic Segmentation)功能，包含以端口為基礎的通道功能(PBT)與以用戶為基礎的通道功能(UBT)、描述交換機與行動控制台的互動、與如何排除tunnel連線的故障介紹Aruba AirWave管理平台，包含描述AirWave功能、使用群組與檔案夾、設定裝置憑證(device credential)、與如何添加新裝置介紹使用AirWave平台來識別與監控網路健康問題，包含解釋診斷頁面的指示、使用網路健康圖形來識別網路問題、使用效能圖形來幫助網路規劃、與使用Clarity功能引導管理員尋找問題的根源介紹使用AirWave平台來排除用戶與AP裝置的疑難問題，包含解釋如何搜尋用戶與排除相關問題、調查用戶SNR、與如何在AirWave內監控MC叢集介紹使用AirWave平台的VisualRF、報告與警示功能，包含解釋不同的VisualRF顯示選項、描述VisualRF應用程式的監控、設定triggers以創建alerts、與生成22種各式各樣的報告
# Title of the webpage:
#
#     區域網路規劃與架設導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對通訊網路產業有高度興趣，想從事相關工作者有志從事網路規劃的IT人員欲自我提升能力的網路系統工程師
# DocumentBOX Outline: 網路規劃的基本觀念網路規劃的方法論規劃企業區域網路應有的考量VLAN的規劃概要IP位址的規劃概要線路備援的規劃概要網路管理的規劃案例研討
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     管理Exchange Server 2016及2019
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 對微軟郵件訊息平台有興趣者對Exchange Server 2016/2019管理有濃厚興趣，欲成為Exchange Server管理者本身為Exchange Server 2003/2007/2010管理者，欲晉升為Exchange Server 2016/2019管理者
# DocumentBOX Outline: 部署Exchange Server 2019，和在Server Core上安裝Exchange Server 2019管理Exchange Server信箱伺服器建立和管理各種收件者物件，和配置地址清單的策略使用EMS管理收件者物件和Exchange伺服器規劃用戶端連線、部署和配置用戶端存取服務管理Exchange Server伺服器的高可用性實作Exchange Server伺服器角色的災難復原設定及管理訊息傳輸架構設定防毒、垃圾郵件以及防惡意程式保護Exchange Server的監視和疑難排解保護和維護Exchange Server的管理稽核規劃及管理Exchange Online的部署
# Title of the webpage:
#
#     ACA-Campus Access認證－Aruba園區存取網路基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 網路現場技術人員、部署技術人員、第1級NOC人員、或具有Aruba產品實作經驗的初級網路工程師具有1年以上的網路經驗為佳，並且瞭解各家廠商通用的基本網路協定想要取得(Aruba Certified Associate - Campus Access)國際認證者
# DocumentBOX Outline: Networking Fundamentals－解釋OSI模型與封包封裝、TCPIP堆疊、討論不同種類的實體介質、與比較單播、群播與廣播AOS-CX Switching Fundamentals－介紹交換機的初始設定、如何配置VLAN與tagging、如何使用LLDP與ICMP做為網路發現與診斷、如何配置Link aggregation以增進效能Basic IP Setup－討論inter-VLAN routing、解釋DHCP relay、討論Static IP routing、解釋如何配置單一區域的OSPFNetwork Redundancy－討論Spanning Tree、解釋VRRP與VSXVSF－介紹VSF、解釋如何配置VSF、描述Auto-VSF、解釋VSF MADIntroduction to Aruba Solutions－介紹Aruba交換機與WLAN的產品組合、介紹Aruba Central與ClearPassCentral for Device Mangement－介紹Device Onboarding、描述如何創建Central Groups、描述UI設定模式、描述template設定解釋如何實施模式、描述Aruba Central licensingDevice Profiles and AP Onboarding－描述Device Profiling的使用、描述LLDP與MAC profiling、解釋如何連接AP到Aruba Central、解釋如何實施AP的初始設定WLAN Fundamentals－描述802.11與射頻(RF)基礎知識、解釋SNR、描述漫遊標準與QoS需求、描述射頻的規劃、解釋如何配置WLANImplementing Secure WLANs－介紹AAA、描述802.1X認證、解釋如何配置安全的WLAN、討論角色(roles)與訪問規則Implementing Guest Access－解釋如何配置captive portal認證、描述如何設定guest WLANWLAN Security－介紹無線網路的資安、解釋憑證(certificates)、描述雲端認證Monitoring and Maintenance－解釋如何使用Aruba Central的監控能力、描述如何識別LED狀態、解釋如何實施firmware的升級、描述如何啟動設備的SNMP、描述AI Insights、描述警報與報告、解釋UXITroubleshooting－描述如何實施密碼復原與重置出廠設定步驟、解釋Central connectivity的故障排除、描述如何啟動頻譜的分析(spectrum analysis)、探索Central排除故障的工具
# Title of the webpage:
#
#     AWS Cloud Practitioner Essentials
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 銷售法律行銷商業分析師專案經理高層主管AWS Academy學員其他 IT 相關專業人員
# DocumentBOX Outline: 雲端概念AWS服務安全性架構定價與支援
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科高級企業等級路由與服務
#
#
# Course duration: 42小時
# Course cost: NT$ 68,000
# Target audience: 1.企業路由基礎架構管理與規劃人員2.企業路由解決方案規劃與支援人員3.對大型企業網路運作技術有興趣者
# DocumentBOX Outline: EIGRP建置、優化與疑難排解OSPF建置、優化與疑難排解BGP建置、優化與疑難排解路由重新發佈（Redistribution）設定與疑難排解建置路徑控制探討及探討L3 MPLS VPN架構與路由設定簡化的虛擬路由與轉送（VRF-Lite）建置動態多點虛擬私人網路（DMVPN）建置與疑難排解DHCP介紹IPv6的第一站安全性保全思科路由器疑難排解安全架構與服務針對DNA Center Assurance 進行疑難排解
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     Microsoft 365管理者認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 本課程適用於有志成為Microsoft 365系統管理員角色的IT人員
# DocumentBOX Outline: 部署與設定您的Microsoft 365租用戶環境管理您的Microsoft 365租用戶環境部署與地端AD目錄服務的識別驗證同步服務作業探索Microsoft 365的安全指標管理您在Microsoft 365 Defender中的安全服務如何使用Microsoft 365 Defender來部署威脅保護探索在Microsoft 365的資料治理部署在Microsoft 365中的合規性管理在Microsoft 365中的合規性
# Title of the webpage:
#
#     Microsoft Azure管理員認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure的使用經驗欲進一步熟悉Azure基礎結構建置、管理與維護的Azure管理員有志取得Microsoft Certified：Azure Administrator Associate認證者
# DocumentBOX Outline: 身份識別•     Azure Active Directory(Microsoft Entra ID)、Users and Groups治理與合規•     Subscriptions and Accounts、Azure Policy、Role-based Access ControlAzure管理•     Azure Resource Manager、Azure Portal and Cloud Shell、Azure PowerShell and CLI、ARM Templates虛擬網路•     Virtual Networks、IP Addressing、Network Security Groups、Azure Firewall、Azure DNS網路間連接•     Vnet Peering、VPN Gateway Connections、ExpressRoute and Virtual WAN網路流量管理•     Network Routing and Endpoints、Azure Load Balancer、Azure Application GatewayAzure儲存體帳戶•     Storage Accounts、Blob Storage、Storage Security、Azure Files and File Sync、Managing StorageAzure虛擬機器•     Virtual Machine Planning、Creating Virtual Machines、Virtual Machine Availability、Virtual Machine Extensions管理PaaS運算選項•     Azure App Service Plans、Azure App Service、Container Services、Azure Kubernetes Service、Azure Container Instance資料保護•     File and Folder Backups、Virtual Machine Backups監視•     Azure Monitor、Azure Alerts、Log Analytics、Network Watcher
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     Microsoft安全營運分析師
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，且已具備Azure與Microsoft 365使用經驗欲進一步熟悉Azure安全營運與Microsoft 365安全營運的分析師有志取得Microsoft Certified：Security Operations Analyst Associate認證者
# DocumentBOX Outline: 使用Microsoft 365 Defender緩解威脅使用Microsoft Defender for Endpoint緩解威脅使用Microsoft Defender for Cloud緩解威脅使用Kusto Query Language(KQL)為Microsoft Sentinel建立查詢設定您的Microsoft Sentinel環境將logs連接到Microsoft Sentinel使用Microsoft Sentinel建立檢測並執行調查在Microsoft Sentinel中執行威脅搜尋微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     RHCA認證-Red Hat OpenShift開發II：容器化應用
#
#
# Course duration: 28小時
# Course cost: NT$ 56,000
# Target audience: 企業應用開發人員站點可靠性工程師
# DocumentBOX Outline: 管理和觸發應用建置版本自定義現有Source-to-image基礎鏡像建立OpenShift模板建立健康檢查，監控和提高應用可靠性建立和部署Jenkins流水線，以實現持續集成和持續部署為OpenShift建立和部署雲原生應用
# Title of the webpage:
#
#     VMware NSX疑難排除與操作課程
#
#
# Course duration: 35小時
# Course cost: NT$ 84,400
# Target audience: • Experienced system administrators and network administrators• Network and security professionals who work with enterprise networks
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.NSX Operations and Tools• Explain and validate the native troubleshooting tools for NSX• Configure syslog, IPFIX, and log collections for the NSX environment• Integrate NSX with VMware Aria Operations for Logs and VMware Aria Operations for Networks• Validate and review the API methods available to configure the NSX environment3.Troubleshooting the NSX Management Cluster• Describe the NSX Management cluster architecture, components, and communication channels• Identify the workflows involved in configuring the NSX Management cluster• Validate and troubleshoot the NSX Management cluster formation4.Troubleshooting Infrastructure Preparation• Describe the data plane architecture, components, and communication channels• Explain and troubleshoot VMware ESXi transport node preparation issues• Explain and troubleshoot NSX Edge deployment issues5.Troubleshooting Logical Switching• Describe the architecture of logical switching• List the modules and processes involved in configuring logical switching• Explain the importance of VDS in transport nodes• Review the architecture and workflows involved in attaching workloads to segments• Identify and troubleshoot common logical switching issues6.Troubleshooting Logical Routing• Review the architecture of logical routing• Explain the workflows involved in the configuration of Tier-0 and Tier-1 gateways• Explain the high availability modes and validate logical router placements• Identify and troubleshoot common logical routing issues using both BGP and OSPF7.Troubleshooting Security• Review the architecture of the Distributed Firewall• Explain the workflows involved in configuring the Distributed Firewall• Review the architecture of the Gateway Firewall• Explain the workflows involved in configuring the Gateway Firewall• Identify and troubleshoot common Distributed firewall and Gateway Firewall issues• Review the architecture and workflows involved in configuring Distributed IDS/IPS• Identify and troubleshoot common Distributed IDS/IPS problems8.Troubleshooting Services• Review the NSX Advanced Load Balancer architecture and components• Identify and troubleshoot common NSX Advanced Load Balancer issues• Review the IPsec and L2 VPN architecture and components• Identify and troubleshoot common IPsec and L2 VPN issues9.Datapath Walkthrough• Verify and validate the path of the packet on the NSX datapath• Identify and perform packet captures at various points in the datapath• Use NSX CLI and native hypervisor commands to retrieve configurations involved in the NSX datapath
# Title of the webpage:
#
#     VMware vSphere新增功能
#
#
# Course duration: 14小時
# Course cost: NT$ 30,600
# Target audience: System architects, system administrators, IT managers, VMware partners, and individuals responsible for implementing and managing vSphere architectures who want to deploy vSphere 8.0 into their existing vSphere environment.
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.Artificial Intelligence and Machine Learning• Describe how device groups support AI and ML in vSphere 8.0• Describe how device virtualization extensions support AI and ML in vSphere 8.03.vSphere Distributed Services Engine• Describe the benefits of Distributed Services Engine• Explain how Distributed Services Engine works• Recognize use cases for Distributed Services Engine• Install ESXi on a host equipped with a DPU• View DPU information in the vSphere Client• Add an ESXi host equipped with a DPU to a cluster• Use vSphere Lifecycle Manager to update an ESXi host that contains a DPU• Create a vSphere distributed switch for network offloads• Add a host with a DPU to the vSphere distributed switch• Configure a VM to use uniform passthrough mode4.vSphere and vCenter Management• Describe improvements to the communication between vCenter and ESXi hosts• Describe enhancements to the vCenter recovery process5.ESXi Enhancements• Describe the function of the central configuration store in ESXi• Explain how ConfigStore affects interaction with ESXi configuration files• Recognize the supported system storage partition configuration on ESXi 8.0• Identify devices supported for system storage on ESXi 8.0• Configure an RDMA host local device on ESXi 8.06.vSphere Storage• Describe the VMware vSAN¬ Express Storage Architecture• Recognize the benefits of using vSAN Express Storage Architecture• Describe the benefits of using NVMe• Recognize the support for NVMe devices in vSphere 8.07.Guest OS and Workloads• Review the enhancements of the latest virtual hardware versions• Describe the features introduced with virtual hardware version 20• Identify the snapshot modes of NVDIMM devices8.Resource Management• View energy and carbon emission metrics in VMware vRealize® Operations Manager™• Describe the vSphere Memory Monitoring and Remediation (vMMR) functionality• Describe how vMMR enhances the performance of DRS9.Security and Compliance• Describe how to manage vTPM secrets when cloning a VM• Manage OVF templates for VMs configured with vTPM• Deploy an OVF template with vTPM• Describe the enhancements to trusted binary enforcement in ESXi• Describe ESXi 8.0 enhanced security features10.vSphere Lifecycle Manager• Describe the enhancements to life cycle management of standalone ESXi hosts• Manage the configuration profiles of ESXi hosts in a cluster• Use Auto Deploy to boot a host with the desired image and configuration specifications• Upgrade multiple ESXi hosts in a cluster in parallel• Stage an ESXi host image before remediation11.Auto Deploy• Manage custom host certificates using Auto Deploy12.vSphere with Tanzu• Describe the features of Vmware Tanzu® Kubernetes Grid™ 2.013.Announcing vSphere+• Describe the functionality and benefits of vSphere+
# Title of the webpage:
#
#     企業IT服務伺服器架設與選擇方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對IT產業有興趣、想從事伺服器管理相關工作者想學習認識企業建構伺服器有哪些不同的異質平台(如：Windows、Linux、Mac等)可供選擇者
# DocumentBOX Outline: 企業常見IT伺服器平台介紹企業常見IT伺服器應用介紹File伺服器介紹Proxy/NAT/Firewall介紹DNS伺服器介紹Web伺服器介紹Mail伺服器介紹集中驗證伺服器介紹授權伺服器軟體vs.免費伺服器軟體Hands on Lab
# Title of the webpage:
#
#     ACP-Campus Access認證－建置Aruba園區存取網路
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 第2/3級NOC人員、網路分析師、或具有2-5年Aruba產品組合經驗的網路工程師為佳想要取得(Aruba Certified Professional - Campus Access)國際認證者
# DocumentBOX Outline: Introduction to Aruba Solutions－介紹Aruba ESP架構、Aruba產品組合、自動化與REST APIBuilding Wired Infrastructure－介紹VSX、OSPF、虛擬化路由與轉發、以策略為基礎的路由、Aruba Central Template GroupsWireless Infrastructure with Aruba Gateways－介紹AOS 10與Central Groups、Aruba Gateways的部署、Gateway的初始設定、Gateway ClusterTunneled WLAN Architecture－介紹Tunneled Mode WLAN、Client MonitoringSecure Enterprise WLAN－介紹802.1X認證、防火牆Roles與Role Derivation、CoA支持Guest and Captive Portal－介紹訪客的訪問、訪客認證過程、訪客WLAN配置、MAC快取Wireless Authentication for IoT－介紹MPSK、MPSK認證過程、本地MPSK設定Mixed Mode Architecture－介紹Aruba混合模式WLAN、與其設定Gateway Cluster Deployments－介紹Cluster部署選項、Cluster設定、Cluster監控、Secondary GatewayWired Port Access－介紹Wired認證、802.1X設定、MAC認證、RADIUS Attributes與Roles、動態分段、Wired Captive PortalVXLAN and GBP－介紹分散式Overlay與VXLAN、VXLAN GBPSecurity and Availability Features－介紹IDS/IPS、Authentication Survivability、Central Survivability、管理用戶認證Traffic Optimization and QOS－介紹WLAN優化、AirGroup、服務品質、UCC、LLDP MEDMonitoring－介紹Central警告、Device Insights、用戶體驗Insights
# Title of the webpage:
#
#     AWS Cloud Financial Management for Builders
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 解決方案架構師開發者成本優化管理者系統管理者
# DocumentBOX Outline: 雲端服務財務管理導論：管理簡介、四個支柱、資源標記定價與成本：定價基礎、AWS免費方案、批量折扣、儲蓄計劃、預留實例AWS的帳單、報告、監控、發票、預算運算資源的成本構建：Amazon EC2規格調整、購買選項、Amazon CloudWatch監控和自動化、Amazon EC2競價型實例、自動化基礎架構、無伺服器解決方案網路資源的成本構建：資料傳輸費用、不同服務的資料成本、如何分攤網路成本儲存資源的成本構建：Amazon EBS、Amazon S3、Amazon EFS的成本、定價和最佳實踐資料庫資源的成本構建：Amazon RDS、Amazon Aurora、Amazon DynamoDB、Amazon ElastiCache、Amazon Redshift的成本、定價和最佳實踐成本治理：設置AWS組織、AWS Systems Manager
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科SD-WAN解決方案
#
#
# Course duration: 35小時
# Course cost: NT$ 79,000
# Target audience: 企業路由基礎架構管理與規劃人員企業路由解決方案規劃與支援人員對大型企業網路運作技術有興趣者
# DocumentBOX Outline: 檢查 Cisco SD WAN 架構檢查 Cisco SD-WAN 部署選項部署廣域網路邊緣設備設備設定管理探索冗餘、高可用性和可擴展性啟用服務端和傳輸端路由了解Cisco SD-WAN策略配置基礎知識定義高階控制策略定義高階資料策略建置應用程式體驗品質（Application Quality of Experience）建置應用程式感知路由（Application-Aware Routing）檢查直接Internet訪問和雲部署選項探索思科SD-WAN安全性設計和遷移到Cisco SD-WAN執行Cisco SD-WAN網路管理和故障排除檢查Cisco SD-WAN群播支持
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     Microsoft Azure安全性技術
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事Azure系統與網路管理之管理人員或系統工程師欲進一步了解Azure安全性技術者有志取得Microsoft Certified：Azure Security Engineer Associate認證者
# DocumentBOX Outline: 管理身分識別和存取•     Azure Active Directory(Microsoft Entra ID)•     Azure身分保護•     企業治理•     設定Azure AD特權身份管理•     混合身分識別實行平台防護•     周邊網路的安全性•     網路安全性•     主機安全性•     容器安全性保全資料與應用程式•     Azure金鑰保存庫•     應用程式安全性•     儲存體安全性•     SQL資料庫安全性管理安全操作•     Azure監視•     Microsoft Defender for Cloud•     Microsoft Sentine微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft身份和存取管理員
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，並已具備Azure的管理技能欲進一步了解在安全架構中規劃與解決方案的專業人員有志取得Microsoft Certified：Identity and Access Administrator Associate認證者
# DocumentBOX Outline: 實施身份管理解決方案實施身份驗證和存取解決方案實施應用程式的存取管理規劃和實施身份治理的策略微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Red Hat OpenShift管理III：在企業中擴展Kubernetes部署
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 專為想要在其數據中心部署和管理大型Red Hat OpenShift Container Platform環境的系統管理人員而設計
# DocumentBOX Outline: 身份驗證和身份管理備份、還原和遷移OADP(OpenShift API for Data Protection) 的應用程式叢集分區Pod 調度OpenShift GitOpsOpenShift 監控OpenShift 日誌記錄
# Title of the webpage:
#
#     VMware vSphere設計規劃課程
#
#
# Course duration: 21小時
# Course cost: NT$ 50,700
# Target audience: Experienced system integrators and consultants responsible for designing and deploying vSphere environments
# DocumentBOX Outline: Course Introduction•          Introductions and course logistics•      Course objectivesInfrastructure Assessment•      Follow a proven process to design a virtualization solution•          Define customer business objectives•          Gather and analyze business and application requirements•      Document design requirements, constraints, assumptions, and risks•      Use a systematic method to evaluate and document design decisions•      Create a conceptual designCore Management Infrastructure•          Determine the number of VMware vCenter® Server ApplianceTM instances to include in a design•      Choose the appropriate single sign-on identity source•      Choose the time synchronization method•          Choose methods to collect log files and ESXi core dumps•          Design a vCenter Server deployment topology that is appropriate for the size and requirements of the data centerVirtual Data Center Infrastructure•      Calculate total compute capacity requirements for a virtual data center•          Create a virtual data center cluster design that meets business and workload requirements•      Evaluate in the virtual data center the use of several management services, such as VMware vSphere® High Availability and VMware vSphere® Distributed Resource Scheduler™•      Evaluate the use of resource pools in the virtual data center designCompute Infrastructure•      Create a compute infrastructure design that includes the appropriate ESXi boot, installation, and configuration options•      Choose the ESXi host hardware for the compute infrastructureStorage Infrastructure•      Calculate storage capacity and performance requirements for a design•          Evaluate the use of different storage platforms and storage management solutions•      Design a storage platform infrastructure and storage management architecture that meets the needs of the vSphere environmentNetwork Infrastructure•      Evaluate the use of different network component and network management solutions•      Design a network component architecture that includes information about network segmentation and virtual switch types•      Design a network management architecture that meets the needs of the vSphere environmentVirtual Machine Design•      Make virtual machine design decisions, including decisions about resources•      Design virtual machines that meet the needs of the applications in the vSphere environment and follow VMware best practicesInfrastructure Security•      Make security design decisions for various layers in the vSphere environment•      Design a security strategy that meets the needs of the vSphere environment and follows VMware best practicesInfrastructure Manageability•          Make lifecycle management, scalability, and capacity planning design decisions that adhere to business requirements•      Design lifecycle management, scalability, and capacity planning strategies that meet the needs of the vSphere environment and follow VMware best practicesInfrastructure Recoverability•      Make infrastructure recoverability design decisions that adhere to business requirements•          Design an infrastructure recoverability strategy that meets the needs of the vSphere environment and follows VMware best practices
# Title of the webpage:
#
#     Windows Server 2016的身分識別
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望經由AD目錄服務整合憑證、版權管理及防護機敏資料的管理人員已具備Windows Server 2008/2012 AD網路管理經驗者
# DocumentBOX Outline: 安裝與設定網域控制器(DC)管理AD DS系統與物件進階AD DS基礎結構管理施作與管理AD DS站台與複寫群組原則部署與除錯運用群組原則管理用戶設定強化AD DS的安全性部署與設定AD憑證服務(AD CS)配置與管理憑證實施與管理AD同盟服務(AD FS)實施與管理AD版權管理服務(AD RMS)部署AD DS與Microsoft Azure AD的同步監視、管理、與復原AD DS
# Title of the webpage:
#
#     企業資料的備份與救援簡易解決方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: IT人員，管理伺服器與資料安全領域相關工作者想了解企業與個人資料保全相關技術者
# DocumentBOX Outline: 設計企業資料保全政策資料安全風險評估選擇備份媒體、方法與技術排程備份與檢視備份資料救援與系統快照磁碟陣列儲存網路異地備援備份反運作：數位資源的抹除大量的實務練習
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     製作適用於Microsoft 365的Microsoft Copilot的有效提示
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 學習者應熟悉Microsoft 365應用程式，例如Word、Excel和PowerPoint。本課程適用於使用Microsoft 365的Microsoft Copilot的所有類型使用者
# DocumentBOX Outline: 適用於Microsoft 365的Copilot簡介探索使用適用於Microsoft 365的Copilot的可能性優化和擴充適用於Microsoft 365的Copilot使用Microsoft Copilot for Microsoft 365進行總結使用Microsoft Copilot for Microsoft 365建立和起草文案使用Microsoft Copilot for Microsoft 365編輯和轉換內容使用Microsoft Copilot for Microsoft 365提出問題並分析內容
# Title of the webpage:
#
#     Azure管理員及解決方案架構專家雙認證班
#
#
# Course duration: 63小時
# Course cost: NT$ 55,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure使用經驗欲進一步熟悉Azure基礎結構建置、管理、維護及解決方案架構設計的IT管理員
# DocumentBOX Outline: AZ104：Microsoft Azure管理員認證班(35小時)•　 身份識別•　 治理與合規•　 Azure管理•　 虛擬網路•　 網路間連接•　 網路流量管理•　 Azure儲存體帳戶•　 Azure虛擬機器•　 管理PaaS運算(Web App、ACI及AKS)•　 資料保護•　 監視AZ305：設計Microsoft Azure基礎結構解決方案(28小時)•　 設計治理與計算解決方案•　 設計儲存體和資料整合解決方案•　 設計應用程式架構•　 存取和監視解決方案•　 設計網路、持續性和移轉解決方案微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# ...
# Title of the webpage:
#
#     前端必學的網頁開發基礎技能
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 對網頁開發有興趣的所有人員
# DocumentBOX Outline: HTML 文件結構HTML 常用與語意標籤圖片、表格與超連結標籤表單的建立影音多媒體標籤CSS 基本語法CSS 選取方式介紹色彩與文字設定寬度與高度屬性CSS 外框模型背景與漸層屬性定位方式與版面設定媒體查詢Flex 彈性排版效果響應式網頁設計變形與動畫效果JavaScript語法簡介以JavaScript設定簡易互動效果
# Title of the webpage:
#
#     前端網頁與UI設計師轉職就業養成班
#
#
# Course duration: 306小時
# Course cost: NT$ 72,000
# Target audience: 不需要相關科系背景或經歷，只要是對從事平面設計、網頁設計、App設計、網路數位行銷、網頁互動、數位內容產業有興趣者都可以參加
# DocumentBOX Outline: - Photoshop視覺影像與前端設計應用 30小時課程將帶您進入Photoshop的神奇世界，學習如何製作令人驚豔的視覺效果，包括圖片編輯、多媒體應用設計，讓您學會用電腦製作出您腦中的無限創意設計。- Illustrator專業向量繪圖與動畫素材設計 24小時您將掌握Illustrator並專注於網頁素材和動畫設計，這是一個非常重要的關鍵技能，對於網站和應用程序的成功至關重要。- Photoshop與Illustrator專業App UI介面視覺設計 24小時課程涵蓋App UI介面的視覺設計，教您如何設計流暢的用戶界面，並將您的視覺設計技能應用於使用者體驗設計當中。- Figma專業UI設計實作 18小時透過對Figma的深入研究，您將學會如何使用這個領先的UI設計工具，並在實際專案中應用您的技術。- Adobe Animate CC 製作HTML5動畫與互動效果 24小時課程將幫助您掌握Adobe Animate CC，以製作出生動的HTML5動畫和互動效果，使您的網頁更具吸引力。- HTML與CSS網頁編輯製作 30小時HTML決定網頁的架構而CSS決定網頁的視覺設計，可以說CSS就是網頁的化妝師，此課程引導不黯程式撰寫的您精耕HTML與CSS相關語法，加強專業的網頁設計實力，也方便後續與JavaScript/jQuery之間的設計應用。- WordPress快速上手網站實作 18小時WordPress是一個快速建立功能強大網站的重要工具。我們將教您如何使用WordPress，製作出專屬於您的網站，以展現您的設計創意。- 響應式網頁設計 24小時隨著行動裝置多樣化，響應式網頁設計是當今的網頁主要趨勢之一，您將學到如何設計可以在不同裝置上完美呈現網頁。- 前端互動式網頁程式設計-UI與元件設計 30小時由最基礎的語法開始，逐步的引導學員瞭解JavaScript的基礎，能讓完全沒有程式基礎的設計人員快速瞭解JavaScript的運作原理，課程將引導您深入瞭解前端互動式網頁程式設計，包括UI和元件設計，為您的網頁增添互動性。- JavaScript與jQuery網頁互動實作 36小時jQuery提供了許多強大功能函式庫，能夠一次解決網頁設計上常見的重大困難。透過範例中的步驟，您將掌握JavaScript和jQuery，提供網頁的互動能力，優化使用者經驗。- 個人作品集設計實務整合與數位影音履歷 48小時整合上述所學，打造完整個人作品集和數位影音履歷，讓後續轉職找工作有重要的作品呈現。這門課程涵蓋了以下內容：1. 個人作品集設計實務整合：精心設計和整合個人作品集，以展示您的設計技能和創意，包括您的平面設計、網頁設計、動畫和其他相關領域的作品。2. 數位影音履歷設計：這個部分涵蓋了如何設計和製作一個引人入勝的數位影音履歷，透過影片、動畫和其他元素來強調個人技能和經驗。製作令人印象深刻的履歷。進階課程需求，提供更優惠的價格，讓您在網頁設計師的職涯上更得心應手！【前端課程系列】- Sass與SCSS快速上手(原價12,000元)- 網頁統計圖表Chart.js快速上手(原價12,000元)養成班顧客於結業後一年內報名上述前端課程系列，可以原價5折優惠上課。
# Title of the webpage:
#
#     Photoshop視覺影像與前端設計應用
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: Photoshop初學者、欲學習Photoshop多媒體設計應用者
# DocumentBOX Outline: 基本操作環境與數位影像概念1-1  工作區域概覽1-2  檢視工具1-3  尺標、參考線1-4  影像檔案管理1-5  影像尺寸與版面尺寸1-6  裁切影像1-7  儲存檔案與影像檔案格式圖層與Photoshop影像編輯入門2-1 認識圖層2-2 圖層浮動視窗基本操作2-3 圖層管理2-4 選取與移動圖層2-5 變形指令2-6 各式變形2-7 數值變形2-8 翻轉變形由選取範圍開始玩耍影像合成3-1 固定形狀選取畫面工具3-2 特定形狀選取畫面工具3-3 選取範圍與影像編輯3-4 選取與填色3-5 漸層填色3-6 漸層顏色編輯3-7 油漆桶填色快速影像修正撇步4-1 影像調整工具組4-2 影像處理工具組4-3 影像亮度快速調整4-4 快速影像顏色加強術4-5 修復工具組4-6 內容感知填色4-7 仿製印章修圖向量形狀工具與路徑編輯應用5-1 向量形狀工具繪圖5-2 向量形狀工具繪製路徑應用5-3 路徑編輯工具5-4 使用筆型工具5-5 筆型工具描圖去背5-6 繪製形狀格式向量繪圖進階圖層編輯與濾鏡6-1 圖層對齊與均分6-2 使用圖層樣式6-3 圖層樣式設定6-4 建立圖層遮色片6-5 圖層混色模式6-6 濾鏡效果與設定文字編輯與設計應用7-1 建立文字7-2 段落文字7-3 圖層樣式文字應用7-4 效果文字應用影像處理與設計應用8-1 影像去背處理8-2 影像白邊框風格8-3 繪製剪影表現風格8-4 立可拍風格8-5 影像產品去背與陰影8-6 產品側面陰影前端網頁設計實作9-1 網頁按鈕與圖文框設計9-2 形象網站主視覺設計9-3 活動網站主視覺設計9-4 商品網站主視覺設計9-5 網頁內容設計
# Title of the webpage:
#
#     輕鬆玩出網頁影音新威力
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 1.有興趣學習影音處理製作者2.有需要製作網頁影音作品者
# DocumentBOX Outline: 開始數位影音創作1.1操作環境1.2匯入影片素材與儲存1.3素材取得幻燈片秀、自動模式輕鬆完成影片2.1 幻燈片秀編輯器2.2 自動模式2.3 Magic Movie精靈應用數位影音創作功能3.1 置換天空與動態人物特效3.2 關鍵畫格與動畫3.3 進階編輯模式製作動畫效果3.4 遮罩設計師製作動畫效果3.5 炫粒製作效果3.6 文字效果快速編排影片與效果神奇魔術工具快速編排影片5.1 素材分類管理與裁切圖片5.2 Magic Movie快速編排影片5.3 平移與縮放效果5.4 Magic Cut 快速剪輯影片遮罩與創意主題設計應用6.1 製作連續多張圖片放大影片片段6.2 組合成完整多張圖片放大影片6.3 完成遮色片文字動畫6.4 加入創意主題內容開場動畫與影片剪輯應用7.1製作遮色片開場動畫7.2剪輯主要影片內容與說明文字教學步驟影片進階編輯8.1善用轉場製作開場動畫8.2材料清單文字動畫8.3 主要影片編輯8.4加入圖框與影片效果運用影片調整與特效9.1 製作片頭文字專案9.2 製作主影片與調整影片9.3 應用疊加>炫粒9.4 加入文字動畫堆疊效果影片編輯應用10.1片頭影片與動畫10.2編輯主要影片10.3安排堆疊效果多角度拍攝影片編輯11.1開場動畫11.2編輯主要影片11.3加入影片文字與字幕動作類影片進階編輯12.1整合3D動畫素材12.2圖片平移縮放製作開場動畫12.3運動動作類影片整合編輯進階編輯個人數位影音介紹13.1加入素材13.2介紹影片去背合成13.3加入旁白與字幕13.4背景音樂與片尾
# Title of the webpage:
#
#     響應式網頁設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 需有HTML與CSS基礎，欲學習響應式網頁設計的設計師
# DocumentBOX Outline: 從動手瀏覽觀察網頁開始1-1    甚麼是響應式網頁1-2    建置響應式網頁1.3     安裝VS code 延伸模組開始使用Bootstrap2.1     新增Bootstrap空白頁面2.2     Bootstrap柵格系統2.3     Bootstrap 一般內容與通用類別+2.3.1     文字顏色與背景色2.3.2     文字屬性2.3.3     標題與顯示標題2.3.4     文字行高2.3.5     邊界與內距屬性設定2.3.6     對齊圖片2.3.7     響應式表格(Table)2.3.8     圓角(rounded)與邊框(Borders)2.3.9     響應式圖片與圖片區(Figures)2.3.10     BootStrtap ICON圖標2.4         其他更多的版面區塊編排2.4.1     自動佈局的欄 / 等寬2.4.2     巢狀排列2.4.3     使用邊界水平對齊區塊2.4.4     多個區塊水平對齊2.4.5     欄的推移2.4.6     間隙Gutters2.4.7     Flex對齊Bootstrap元件素材3.1     一般物件3.1.1     按鈕 (Buttons)3.1.2     麵包屑 (Breadcrumb)3.1.3     廣告大屏幕 (Jumbotron)3.2     區塊內容物件3.2.1     多項圖文編排(Media Object)3.2.2     標籤切換內容(Tab)3.2.3     折疊切換內容 (Accordion)3.3     Bootstrap響應式導覽列3.3.1     基本型收合導覽列3.3.2     收合導覽列元件3.4     Card卡片3.4.1     預設卡片類型3.4.2    卡片組合3.4.3     水平卡片3.4.4     網格卡片3.4.5     card圖文框排列版面3.5     Carousel輪播3.5.1     carousel-caption3.5.2     更改carousel CSS3.5.3     控制高度與自訂切換按鈕Bootstrap頁面編排應用4.1     先讓頁面捲動起來4.2    側邊導覽列捲動頁面4.3     頁面編排與效果4.4     頁面動態效果
# Title of the webpage:
#
#     Illustrator專業向量繪圖與動畫素材設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 對於向量插圖、網頁與動畫素材設計有興趣者
# DocumentBOX Outline: 操作環境介紹與檔案管理1-1 操作環境1-2 工具箱1-3 檔案管理與輔助操作基礎繪圖與物件選取變形2-1 基礎繪圖工具2-2 線條繪圖工具2-3 橡皮擦、美工刀與剪刀工具2-4 物件選取與管理2-5 變形工具與變形指令2-6 封套變形指令物件造型與進階變形3-1 形狀模式3-2 路徑管理運算3-3 路徑管理運算繪製圖案應用3-4 即時上色3-5 使用影像描圖與即時上色繪圖3-6 點陣圖剪裁遮色片3-7 漸層填色3-8 形狀運算與漸層填色3-9 網格漸層填色不規則繪圖與描圖4-1 鉛筆工具組徒手繪圖4-2 繪製路徑工具組4-3 路徑編輯工具4-4 鋼筆繪製曲線路徑文字處理5-1 文字字元屬性5-2 建立外框字5-3 路徑文字5-4 文字造型設計應用5-5 段落文字特殊繪圖效果6-1 物件漸變6-2 筆畫效果6-3 Illustrator 效果6-4 3D 效果6-5 Photoshop 濾鏡7 繪圖應用7-1 對齊排列構圖7-2 路徑管理員設計動畫元件7-3 可愛動物動畫元件繪製8 漸層填色與特殊效果功能繪製素材8-1 漸層文字8-2 漸層星光8-3 漸層繪圖造型文字8-4 3D 效果繪圖應用
# Title of the webpage:
#
#     前端互動式網頁程式設計-UI與元件設計
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 網站開發人員、網頁設計人員
# DocumentBOX Outline: 網頁設計:HTML, CSS, JavaScript簡介JavaScript基礎語法深入瞭解JavaScript資料與變數宣告基礎運算子操作數值資料處理進階文字處理邏輯與判斷式迴圈處理與應用DOM文件物件模型操作利用JSON處理複雜資料深入瞭解Function函式架構日期物件與時間處理事件處理常式彈出式互動視窗 Modal window廣告定時呈現與關閉效果Timeout popup window放大鏡檢視圖片Zoom in image頁籤切換介面Tabs手風琴收合效果Accordion圖片輪撥效果Carousel
# Title of the webpage:
#
#     JavaScript與jQuery網頁互動實作
#
#
# Course duration: 36小時
# Course cost: NT$ 18,000
# Target audience: 希望提升網頁互動能力，或縮短開發時程者適合網頁設計師或網站程式開發人員
# DocumentBOX Outline: CSS樣式基礎知識與設定JavaScript基礎知識與語法jQuery基礎知識jQuery動態效果，與動畫設定jQuery選取器，包含階層、內容、屬性、表單等各式選取方式jQuery樣式套用，可取得物件樣式屬性與動態設定樣式jQuery綁定事件，如滑鼠、鍵盤、系統等jQuery控制DOM物件jQuery操控AJAXjQuery UI的介紹與安裝設定輕易完成分頁標籤(Tabs)手風琴選單(Accordion)的製作可移動與縮放對話盒(Dialog)的設計藉由刻度滑桿(Slider)的介面輸入數值便利的日期選擇器(Datepicker)
# Title of the webpage:
#
#     HTML與CSS網頁編輯製作
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 欲學習專業網站建置基礎與編輯應用者
# DocumentBOX Outline: 安裝與使用程式碼編輯器Visual Studio CodeHTML與網頁內容架構CSS基礎與網頁編排CSS與版面DIV編排CSS版面編排應用輕鬆搞懂HTML5與CSS3
# Title of the webpage:
#
#     WordPress快速上手網站實作
#
#
# Course duration: 18小時
# Course cost: NT$ 9,000
# Target audience: 需有HTML與CSS基礎
# DocumentBOX Outline: 在本機安裝 WordPress 網站1.1 使用 XAMPP 在本機安裝 WordPress 網站1.2  安裝Wordpress開始使用WordPress編輯頁面2.1 網站後臺管理介面2.2 新增文章2.3 新增頁面2.4 設定導覽列與首頁WordPress 佈景主題安裝與編輯3.1  安裝新的wordpress3.2  安裝佈景主題3.3  安裝 Elementor 免費版3.4  Elementor編輯頁面一頁式網站佈景主題實作4.1  安裝Wordpress與佈景主題4.2  更改與設定頁首4.3  編輯頁面4.4 設定EMAIL收發信形象網站佈景主題實作5.1  安裝Astra佈景主題5.2  調整網站設定5.3  修改頁面商品網站佈景主題實作6.1  安裝佈景主題Blocksy6.2  新增文章與頁面6.3  修改模板網站6.4  修改商品與文章6.5  修改頁尾6.6  設定購物相關功能6.7  設定會員帳號功能6.8  製作優惠劵附錄 / 網站上傳至 WEB 伺服器（網站空間）7.1  申請免費個人網站空間7.2  安裝網站空間端的wordpress7.3  匯出本機網站程式
# Title of the webpage:
#
#     區塊鏈與智慧合約實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想了解區塊鏈與智慧合約的工程師與專案經理2.想了解智慧合約的實作者
# DocumentBOX Outline: 1.BlockChain歷史與簡介●加解密演算法●Hash Tree/Merkle Tree雜湊樹●非對稱加解密2.BlockChain生態系簡介3.智慧合約與Solidity簡介●Solidity與Solidity相關檔案●Pragma、註解與Mport●合約本體●state變數、struct與修飾子●事件、列舉與函數●資料型態●參照型態●陣列與對應4.Solidity語法●函數與修飾子●View、常數與Pure Function●Address Function●Fallback Function●例外處理、事件和Summary5.Ethereum●EVM(Ethereum Virtual Machine)●Ethereum(Smart Contract)●Truffle框架的設定與使用6.合約的偵錯7.合約的升級
# Title of the webpage:
#
#     區塊鏈與DApp去中心化應用程式Full Stack全棧開發實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要開發區塊鏈應用程式的工程師想學習Ethereum區塊鏈實作的工程師想要了解區塊鏈的軟體架構師
# DocumentBOX Outline: 1.Ethereum網路架構●Blockchain的基本架構●Blockchain的演化●Ether、GAS和EVM2.使用wallet錢包和區塊鏈網路溝通●網頁錢包的安裝●連線與使用3.web3.js●帳戶列表和餘額API使用●交易與合約API呼叫●交易物件傳送●事件與日誌●過濾監控API4.Truffle Framework與Solidity智慧合約5.智慧合約設計樣式6.前端分散式應用程式的考量7.ERC20自訂代幣8.Truffle與React/Redux●建立前端應用程式專案●部署合約●使用React進行前端開發Truffle與VUETruffle與drizzleNFT (Non fungible token)
# Title of the webpage:
#
#     IIB Council區塊鏈專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 商業技術主管政府技術幕僚全端工程師(Full Stack Developer)
# DocumentBOX Outline: 掌握區塊鏈技術的理論和技術基礎了解去中心化(decentralization)的概念，其影響以及與區塊鏈技術的關係了解區塊鏈開發和實現的基本技術原則了解比特幣和其他加密貨幣背後的區塊鏈技術運作機制透過實際範例了解加密技術如何用於數據保護了解智能合約(smart contracts)的理論基礎，以及如何使用Solidity和相關開發框架，在以太坊(Ethereum)區塊鏈上開發去中心化的應用程式(DAapp)研究替代區塊鏈解決方案，包括超級帳本(Hyperledger)、Corda等了解各行各業中區塊鏈應用的使用案例探索區塊鏈實現和商業化策略了解當前業務架構中區塊鏈整合的最佳實務確定可能的區塊鏈實現對法律方面的影響預測應用策略採行可能帶來的風險和失敗，並學習採用有效的變更管理和專案管理方法加以避免探索區塊鏈技術的新研究課題和未來應用範圍
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_all.xlsx

# %% [markdown]
# ## 5. 透過關鍵字查找相關課程

# %% [markdown]
# ### 使用方式:
# ### 更換 keyword = "Cloud"，最後會存成 "courses_details_Cloud.xlsx"

# %%
# 爬取所有課程並保存到一個列表中
def scrape_courses(urls):
    """
    爬取給定URL列表中的所有課程，並返回包含課程詳細信息的列表。
    """
    courses_data = []
    for url in urls:
        course_details = scrape_course_details(url)
        if course_details:
            courses_data.append(course_details)
    return courses_data

# 使用生成的課程網址爬取課程詳細信息
all_courses_data = scrape_courses(all_course_urls)

# 根據關鍵字過濾課程並保存到Excel文件
def save_courses_to_excel(courses_data, keyword):
    """
    根據關鍵字過濾課程並保存到Excel文件中。
    """
    filtered_courses = [course for course in courses_data if keyword.lower() in course['Title'].lower()]
    df = pd.DataFrame(filtered_courses)
    df.to_excel(f'courses_details_{keyword}.xlsx', index=False)
    print(f"Data saved to courses_details_{keyword}.xlsx")

# 示例關鍵字查找
keyword = "Cloud"
save_courses_to_excel(all_courses_data, keyword)
# Out:
# Title of the webpage:
#
#     CCNA認證-建置與管理Cisco解決方案
#
#
# Course duration: 70小時
# Course cost: NT$ 66,000
# Target audience: 1.對通訊產業有高度興趣，欲從事相關工作者2.從事網路維運相關工作者3.想要取得CCNA認證者
# DocumentBOX Outline: 1.建立網路與區域網路的基礎概念2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協定介紹）3.認識封包的基本構造4.網路設備的設定與IOS的管理5.建置企業交換器虛擬區域網路(VLAN)環境6.交換器擴展樹協定（STP與RSTP）運作原理與最佳化7.乙太通道網路EtherChannel的運作概念與設定8.路由運作基礎與設定9.廣域網路WAN與虛擬私人網路VPN相關運作技術與設定介紹10.網路設備安全性強化措施，ACL相關技術的實作與設定11.Layer 3 Redundancy的相關技術介紹與HSRP的實作12.淺談智能網路（SDN、SD-Access、SD-WAN、Cisco DNA Center）的發展與變革13.常用網管協定的設定與自動化，例如：SNMP、Syslog、NTP、CDP/LLDP14.網路服務效能（QoS）簡介15.無線區域網路（WLAN）運作原理與基本設定16.認識網路安全威脅與相關的防範因應措施
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路建置專家
#
#
# Course duration: 98小時
# Course cost: NT$ 129,000
# Target audience: 企業網路架構管理與規劃人員企業網路解決方案規劃與支援人員對大型企業網路運作技術有興趣深入瞭解者
# DocumentBOX Outline: ENCOR—思科企業網路核心技術建置與維運ENARSI—建置思科高級企業等級路由與服務
# Title of the webpage:
#
#     CCNP Security認證-思科網路安全核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 負責企業網路安全維護管理者需要企業網路安全相關知識與技術者對於企業網路安全機制有興趣瞭解者
# DocumentBOX Outline: 了解資訊安全概念了常見的TCP/IP攻擊、網路應用攻擊、端點攻擊與網路安全技術部署思科ASA防火牆與思科Firepower下一代防火牆部署電子郵件與網站內容安全性部署Cisco Umbrella了解VPN技術和密碼學推出思科站點之間VPN安全解決方案與點對點的Cisco IOS VTI在Cisco ASA和Cisco Firepower NGFW上部署點對點IPsec VPN與遠端存取的SSL VPN了解思科安全網路訪問解決方案了解與配置802.1X驗證了解端點安全技術並部署Cisco端點AMP介紹並部署網路基礎架構保護措施
# Title of the webpage:
#
#     CompTIA Network＋國際網路認證班
#
#
# Course duration: 40小時
# Course cost: NT$ 42,000
# Target audience: 想要跨至資訊網路工程領域的學習工作者想要取得網路基礎技術認證的工程師想要完成網路安全技術認證的工程師相要進一步學習不同的網路系統技術（包括Microsoft、Linux、CISCO）需要具備的網路基礎知識的網路工程師。
# DocumentBOX Outline: Comparing OSI Model Network Functions（比較 OSI 模型的網路功能）Deploying Ethernet Cabling（部署乙太網路的線路）Deploying Ethernet Switching（部署乙太網路的交換器）Troubleshooting Ethernet Networks（乙太網路的疑難排除）Explaining IPv4 Addressing（了解IPv4的定址模式）Supporting IPv4 and IPv6 Networks（如何同時支援IPv4與IPv6的網路）Configuring and Troubleshooting Routers（網路路由器的設定與疑難排除）Explaining Network Topologies and Types（了解網路的拓樸架構與類型）Explaining Transport Layer Protocols（了解傳輸層的協定）Explaining Network Services（了解什麼是網路服務）Explaining Network Applications（了解什麼是網路應用程式）Ensuring Network Availability（確保網路的可用性）Explaining Common Security Concepts（了解通用安全的概念）Supporting and Troubleshooting Secure Networks（安全網路的支援與疑難排除）Deploying and Troubleshooting Wireless Networks（無線網路的部署與疑難排除）Comparing WAN Links and Remote Access Methods（比較廣域網路連線與網路遠端存取連線的方法）Explaining Organizational and Physical Security Concepts（了解組織與實體安全的概念）Explaining Disaster Recovery and High Availability Concepts（了解災難重建與高可用性的概念）Applying Network Hardening Techniques（應用網路的強化技術）Summarizing Cloud and Datacenter Architecture（總論雲端與資料中心的架構）
# Title of the webpage:
#
#     CyberOps Associate認證-思科網路安全運營基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 50,000
# Target audience: 對網路安全維運監控有高度興趣，欲從事相關工作者從事安全維運中心維運相關工作者想要取得Cisco Certificated CyberOps Associate認證者
# DocumentBOX Outline: 定義安全維運中心了解網路基礎結構和網路安全監視工具探索數據類型類別了解基本密碼學概念了解常見的TCP / IP攻擊了解端點安全技術了解以威脅為中心的SOC中的事件分析識別用於應對網路威脅的資源了解事件相關性和規範化識別常見的攻擊媒介識別惡意活動識別可疑行為的模式進行安全事件調查使用Playbook模型組織安全監控了解SOC指標了解SOC工作流程和自動化描述事件回應了解VERIS的用法了解Windows作業系統基礎知識了解Linux作業系統基礎
# Title of the webpage:
#
#     Red Hat JBoss應用伺服器的系統管理
#
#
# Course duration: 35小時
# Course cost: NT$ 56,000
# Target audience: 想要在公司導入JBoss系統的系統管理人員欲學習JBoss EAP 7伺服器的安裝與管理的系統管理人員欲了解JBoss EAP 7伺服器在部署與維運時搭配的管理重點者
# DocumentBOX Outline: 安裝與設定JBoss EAP 7伺服器在Standalone與Domain模式上配置一個Domain部署Java應用程式在JBoss EAP 7伺服器上組態與JBoss EAP 7伺服器的DataSource連結工作組態Java Message Service與HornetQ組態與JBoss EAP 7伺服器的日誌相關設定部署應用程式的安全性與批次處理在JBoss EAP 7伺服器上認識JBoss EAP 7伺服器的Cluster環境
# Title of the webpage:
#
#     Red Hat OpenShift I：Containers和Kubernetes
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 想深入了解Container與Kubernetes如何組成微服務運作的軟體架構人員工作需求需要設計微服務的應用程式開發人員協助企業評估Container應用需求的架構工程人員
# DocumentBOX Outline: 了解Container、Docker和Red Hat OpenShift的Container架構建立Container化服務管理Container和Container的映像檔案管理客製Container映像檔在Red Hat OpenShift上部署搭配Container的應用程序部署多Container的應用程序
# Title of the webpage:
#
#     Red Hat Linux認證工程師培訓班
#
#
# Course duration: 98小時
# Course cost: NT$ 72,000
# Target audience: 1.Linux入門者、具備網路基本架構概念者2.想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124： Red Hat紅帽系統管理 I (35小時)RH134： Red Hat紅帽系統管理 II (35小時)RH294： Red Hat紅帽系統管理 III-Linux自動化(28小時)
# Title of the webpage:
#
#     Red Hat紅帽RHCSA 認證課程
#
#
# Course duration: 70小時
# Course cost: NT$ 50,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RH124：Red Hat紅帽系統管理 I (35小時)RH134：Red Hat紅帽系統管理 II (35小時)
# Title of the webpage:
#
#     Red Hat紅帽系統管理 I
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習一般Linux使用操作技巧的IT人員
# DocumentBOX Outline: RHEL介紹Linux指令模式的使用在指令模式下進行檔案的管理如何取系統說明文件Linux的帳號管理檔案存取權限的管理Linux系統下的行程管理Linux系統下的服務管理OpenSSH的使用Linux系統的Log管理Linux系統下的網路管理Linux系統下的壓縮工具及檔案傳輸工具RHEL 9下的套件管理( DNF )Linux系統下的檔案系統管理
# Title of the webpage:
#
#     配置Aruba行動網路第一級
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 1.對無線通訊產業有高度興趣，欲從事相關工作者2.部署中小企業等級無線網路解決方案的網路IT專業人員
# DocumentBOX Outline: 介紹無線區域網路802.11與射頻(RF)基礎知識介紹以行動為優先的Aruba OS 8.X網路架構，包含行動控制台種類與運作模式設置Aruba行動主控台(Mobility Master)與行動控制台(Mobility Controller)，了解群組與子群組的分層設定，並介紹使用不同的配置方法將行動控制台加入到行動主控台使用行動主控台的GUI配置安全的無線區域網路，並解釋AP群組架構(AP Group)與其配置檔(AP Group Profile)介紹AP的配置佈建(AP Provisioning)，包含AP與行動控制台間的通訊、AP開機過程、與Control Plane保護機制(CPSec)介紹無線區域網路的資安概念，包含各種不同的WPA/WPA2 802.1X認證與MAC認證方法、對稱與不對稱加密金鑰、與使用WIPS來發現惡意的無線基地台(Rogue AP)介紹Aruba整合式防火牆策略與角色，包含以身份為基礎的Aruba防火牆、使用別名(alias)來設定防火牆策略與規則、與如何指派角色給用戶(Role Derivation)介紹Aruba自動管理射頻(RF)功能，包含Airmatch/ARM功能是如何校準網路來選擇最佳的頻道與設定功率、與Client Match功能是如何引導用戶連接更好的AP使用Captive portal搭配Clearpass認證伺服器來建置Aruba訪客造訪(Guest Access)的資安解決方案，與創建guest provisioning account介紹無線區域網路的監控與故障排除，包含使用Airwave與行動主控台儀表板功能來監控與診斷client/WLAN/AP相關疑難問題、與使用APPrf過濾功能來分析流量
# Title of the webpage:
#
#     網路基礎架構與網路服務
#
#
# Course duration: 42小時
# Course cost: NT$ 16,000
# Target audience: 想進入資訊領域，卻完全沒有資訊背景或經驗者想成為網路工程師、系統工程師，基礎不穩固或無基礎者跨領域學習工作者
# DocumentBOX Outline: 了解主/從(Client/Server)、雲端(Cloud Computing)架構微軟Hypervisor虛擬機器使用及操作ISO/OSI 7 Layer獨家精闢詳解細說乙太網路設備運作原理(訊號增益器、橋接器、交換器、路由器與閘道器)IPv4/IPv6位址、子網段切割、CIDR、Supernetting獨家教材詳解與教學廣域網路(WAN)介紹深入淺出TCP/IP網路重要概念路由(Routing)及網路位址轉譯(NAT)原理詳解及實作IT人員必備的基本網路服務的運作原理(DHCP、DNS、Web、FTP)資訊安全與防毒系統的整體概念
# Title of the webpage:
#
#     CCNP Enterprise認證-思科企業網路核心技術建置與維運
#
#
# Course duration: 56小時
# Course cost: NT$ 79,000
# Target audience: 1.負責中大型企業網路運作與管理者2.需要中大型企業網路優化調校相關知識與技術者3.對於中大型企業網路運作機制有興趣瞭解者
# DocumentBOX Outline: 檢查思科企業網路架構與思科交換路徑建置園區域網路高可用性網路連接探索、建置及優化企業路由通訊協定（包含OSPF、EIGRP、BGP）介紹網路虛擬化協定與虛擬私人網路和介面探索無線原理、無線漫遊和定位服務與無線AP操作無線部署與無線客戶端身份驗證選項檢查與建置無線客戶端連接故障排除群播（Multicast）路由協定介紹介紹、建置QoS與其他網路服務使用網路分析工具了解企業網路安全架構建置基礎架構安全與安全訪問控制使用思科DNA中心探索自動化和保證，並且在Cisco DNA Center和vManage中導入API檢查思科SD-Access解決方案了解思科SD-WAN解決方案的工作原理介紹網路可開發性協議與Python程式設計基礎
# Title of the webpage:
#
#     CCNP Security認證-建置與設定思科身份識別服務引擎
#
#
# Course duration: 42小時
# Course cost: NT$ 59,000
# Target audience: 網路安全工程師Cisco ISE管理人員無線網路安全工程師思科系統整合商和合作夥伴
# DocumentBOX Outline: 思科ISE體系結構和部署簡介思科ISE策略實施Web身份驗證和訪客服務思科ISE Profiler思科ISE BYOD思科ISE端點合規性服務使用網路訪問設備
# Title of the webpage:
#
#     CDCP資訊機房專業人員國際認證班
#
#
# Course duration: 14小時
# Course cost: NT$ 60,000
# Target audience: 資訊機房(Data Center)相關IT/設施人員資訊機房負責營運人員/管理層學習如何建置符合企業需求資訊機房(Data Center)的人員想取得CDCP國際認證者
# DocumentBOX Outline: 1.資料中心，重要性和停機的原因2.資料中心標準和最佳實踐3.資料中心的地點，建設和建設•   選擇合適的場所和建築物以及如何避免陷阱•   有效資料中心的各種組件和支持設施的設置4.高架地板/輕鋼架•   統一、集中和滾動載荷定義•   適用標準•   高架地板準則•   信號參考網格、機架接地•   殘疾法和法規•   輕鋼架的使用和要求5.照明•   標準•   照明類型和位置•   應急照明，應急電源(EPS)6.電力基礎設施•   從發電到機架的電力基礎設施佈局•   ATS和STS系統•   冗餘級別和技術•   三相和單相使用•   房中的配電選項•   電源線和母線槽•   連接和接地•   共模噪聲和隔離變壓器•   配電板，尺寸和IP保護等級•   電能質量準則•   有功功率和視在功率•   如何確定和計算資料中心的負載•   發電機•   靜態和動態UPS系統，選擇標準，操作模式和能效選項•   電池類型，正確的選擇和測試•   熱成像•   可再生能源係數 (REF，Renewable Energy Factor)7.電磁場•   電場和磁場的定義和測量單位•   電磁場的來源•   電磁場對人體健康和設備的影響•   (H)EMP•   標準•   EMF遮蔽解決方案8.機架•   機架標準、特性和選擇標準•   安全注意事項•   配電盤/槽選項9.冷卻基礎設施•   溫度和濕度建議•   冷卻測量單位和轉換率•   顯熱和潛熱定義•   舒適型與精密冷卻之間的差異•   不同的空調技術概述•   高架地板與非高架地板散熱•   空調單元的放置和限制•   補充冷卻選項•   冷通道/熱通道密閉•   液浸冷卻•   冷卻概念：季節性熱能儲存 (STER, Seasonal Thermal Energy Storage)10.供水•   供水和應用領域的重要性•   備用供水技術11.設計可擴展的網路基礎架構•   結構化佈線系統的重要性•   規劃注意事項•   銅和光纜技術和標準•   ANSI/ TIA-942佈線層次結構和建議•   測試與驗證•   網路冗餘•   建築物之間的連接•   網路監控系統要求12.防火•   滅火標準•   檢測系統•   各種全浸式滅火技術和系統、其優缺點•   手提式滅火器•   標牌與安全•   法規要求和最佳做法13.物理保全和人身安全•   物理保全考慮•   人身安全注意事項14.輔助系統•   資料中心監控要求•   EMS、BMS和DCIM•   漏水檢測系統•   警報通知
# Title of the webpage:
#
#     Designing and Implementing Storage on AWS
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端儲存工程師解決方案架構師雲端維運工程師DevOps工程師
# DocumentBOX Outline: 第一天：Module 1：雲端儲存介紹Module 2：設計物件儲存解決方案Module 3：使用Amazon S3建置物件儲存解決方案Module 4：設計區塊儲存解決方案第二天：Module 5：使用Amazon EBS建置區塊儲存解決方案Module 6：檔案儲存與Amazon EFSModule 7：使用Amazon FSx建置雲端檔案儲存第三天：Module 8：混合與邊緣的雲端儲存Module 9：搬移資料至AWSModule 10：AWS的備份與災難復原Module 11：對AWS儲存進行監控、自動化與最佳化
# Title of the webpage:
#
#     FCP-NS認證 - Fortinet網路安全專家全修班
#
#
# Course duration: 35小時
# Course cost: NT$ 78,750
# Target audience: 任何負責管理、配置和監控FortiGate設備，以用於保護公司組織的網路資安專業人員任何負責 FortiAnalyzer 設備日常管理的人都應該參加本課程對網路資訊安全工作有興趣者欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者欲充實本身資安技術能力的IT人員
# DocumentBOX Outline: 《FortiGate Administrator》- 4天系統和網路設定防火牆政策和轉址路由使用者身份驗證Fortinet 單一登入 (FSSO)憑證的操作管理防毒網頁過濾入侵防禦和應用程式控制SSL VPNIPsec VPNSD-WAN 配置和監控安全織網高可用性診斷和故障排除《FortiAnalyzer Administrator》- 1天簡介和初始配置系統管理容錯式磁碟陣列(RAID)和高可用性(HA)設備註冊和管理日誌和報告管理
# Title of the webpage:
#
#     FCP-SO認證 - FortiAnalyzer Analyst認證課程
#
#
# Course duration: 7小時
# Course cost: NT$ 15,750
# Target audience: 任何負責 Fortinet 安全織網分析和自動化任務，以及使用FortiAnalyzer來檢測與響應網路攻擊事件的人都應該參加本課程負責 FortiAnalyzer (虛擬機或硬體設備) 日常管理的任何人欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介與初始配置日誌記錄通報事故和事件報表劇本
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Microsoft 365 Fundamentals認證班
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 由於本課程是許多將要銷售Microsoft 365服務的銷售員或專員的基本認證課程，所以只要是從事相關工作的人員都是要學習本課程的對象從事Microsoft 365相關服務銷售、代理、整合應用服務的銷售員、服務解說員想要認識、評估或使用Microsoft 365的操作人員、資訊工作者欲進一步熟悉Microsoft 365所提供軟體即應用服務的架構，與需要進行管理與維護的Microsoft 365管理員有志取得完整Microsoft 365 Certified：Fundamentals認證者
# DocumentBOX Outline: 展示Microsoft 365生產力和團隊合作的基本知識(Demonstrate fundamental knowledge of Microsoft 365 productivity and teamwork)展示Microsoft 365商務管理功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 business management capabilities)展示Microsoft 365授權、服務和支援的基礎知識(Demonstrate fundamental knowledge of Microsoft 365 licensing, service and support)展示Microsoft 365安全性與合規性功能的基本知識(Demonstrate fundamental knowledge of Microsoft 365 security and compliance capabilities)
# Title of the webpage:
#
#     Microsoft Azure基礎知識
#
#
# Course duration: 14小時
# Course cost: NT$ 12,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified Azure Fundamentals認證者
# DocumentBOX Outline: 描述雲端概念•      說明雲端運算•      說明使用雲端服務的優點•      描述雲端服務類型描述Azure架構與服務•      描述Azure的核心架構元件•      說明Azure計算和網路服務•      描述Azure儲存體服務•      說明Azure身分識別、存取和安全性描述Azure管理與治理•      說明在Azure中成本管理•      說明Azure中與治理及合規性相關的功能與工具•      說明管理和部署Azure資源的功能和工具•      說明Azure中的監視工具微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft安全性、合規性和身份基礎知識
#
#
# Course duration: 7小時
# Course cost: NT$ 8,000
# Target audience: 希望快速獲得Microsoft Azure基礎知識的IT人員有志取得Microsoft Certified：Security, Compliance, and Identity Fundamentals認證者
# DocumentBOX Outline: 安全性、合規性和身份的基本概念Microsoft身份和存取管理解決方案的觀念及功能Microsoft安全解決方案Microsoft合規性管理的功能微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Power BI Desktop數據分析實戰
#
#
# Course duration: 21小時
# Course cost: NT$ 20,000
# Target audience: 想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者數據及報表分析人員需要跨部溝通及討論商業運作者想要學習數據分析及商業思考的使用者熟悉SQL Server報表的建立者已完成以下課程所具備技術能力BITBG：商業數據分析-Excel 2021 Power BI大數據資料清理、拆解分析與視覺化溝通
# DocumentBOX Outline: Power BI產品組合介紹Power BI Desktop的下載與安裝Power BI Desktop資料的匯入不同資料格式的匯入及合併彙整資料夾中多個相同格式的資料檔資料的清理、淨化、重塑及轉換資料表間的合併及附加處理查詢步驟的組態與調整查詢的複製、重複及參照資料錯誤的解決與處理Power BI Desktop資料建模與管理組態及優化資料表間的關聯性強化資料模型中的計算邏輯與格式DAX語法說明及各類函數的使用利用DAX公式建立資料表、量值及資料行，以豐富資料模型的處理Power BI Desktop範本檔的建立Power BI Desktop互動式視覺化報表的建立建立豐富的互動式視覺化儀表板多種視覺化效果(卡片、表格、量測計、矩陣、長條圖、組合圖 ......)的運用搭配介紹各項視覺化效果的細部組態視覺化效果的進階分析設定使用書籤串連數據解析及建立故事自訂視覺化效果的匯入及運用發佈Power BI Desktop報表至Power BI服務使用手機進行報表的互動式資料探索將製作的報表匯出至PDF
# Title of the webpage:
#
#     Red Hat紅帽系統管理II
#
#
# Course duration: 35小時
# Course cost: NT$ 32,000
# Target audience: Linux入門者、具備網路基本架構概念者想要學習Linux系統管理的IT人員
# DocumentBOX Outline: Linux系統下文字模式的進階使用及shell scriptLinux系統下的排程管理Linux系統下的效能調校SELinux系統的管理Linux系統下的硬碟管理及儲存空間的使用Linux Volume Manage的管理及使用NFS Client的使用Linux系統的開機流程RHEL 9的網路存取控制安裝RHEL 9虛擬化技術 / 容器技術
# Title of the webpage:
#
#     VMware Aria Automation安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: System administrators and system integrators responsible for designing, implementing, and managing VMware Aria Automation
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.VMware Aria Automation Overview and Architecture• Describe the purpose and functionality of VMware Aria Automation• Identify the key services offered by VMware Aria Automation• Describe the VMware Aria Automation architecture• Describe the use of VMware Workspace ONE Access™• Describe the relationship between Kubernetes clusters, container, and VMware Aria Automation services3.Installing VMware Aria Automation• List the different VMware Aria Automation deployment types• Describe the purpose of Easy Installer• Describe the VMware Aria Automation installation process4.Authentication and Authorization• Identify the steps to integrating Workspace ONE® Access with Active Directory• Describe the features of Workspace ONE Access• Describe the user roles available in VMware Aria Automation• Identify the key tasks performed by each user role• Define custom roles• Configure branding and multitenancy5.Basic Initial Configuration• Create a basic configuration with a cloud account, cloud zone, project, flavor mapping, and image mapping6.VMware Aria Automation Templates• Configure and deploy a basic VMware Aria Automation template• Create a VMware Aria Automation template that can run on any cloud• Use cloudConfig and cloudbase-init to run commands, create users, and install software• Use YAML for inputs, variables, and conditional deployments7.Tags• Configure tags• Describe functions of tags• Manage tags
# 8.Storage Configuration• Configure storage profiles• Use tags and storage profiles9.Integrating NSX With VMware Aria Automation• List the capabilities and use cases of VMware NSX®• Describe the NSX architecture and components• Integrate NSX with VMware Aria Automation• List the supported network profiles in VMware Aria Automation• Use the NSX components to design a multitier application with VMware Aria Automation Templates• Identify the network and security options available in design canvas• Create and manage on-demand networks and security groups• Configure NSX Day 2 actions10.Integrating with Public Clouds• Configure and use VMware Cloud Foundation™ accounts• Integrate VMware Cloud Director™ account• Configure and use an AWS cloud account• Configure and use an Azure cloud account• Configure and use a Google Cloud Platform cloud account• Integrate VMware Cloud on AWS cloud account11.Using VMware Aria Automation Consumption• Release a VMware Aria Automation template• Define content source and content sharing• Define VMware Aria Automation policy enforcement• Use custom forms for catalog items12.VMware Aria Automation Extensibility• Describe VMware Aria Automation extensibility• Use event topics• Create a subscription• Call a VMware Aria Automation Orchestrator workflow• Create ABX actions13.Using Kubernetes Clusters• Introduction to Kubernetes• Connect to an existing Kubernetes Cluster• Create a VMware Aria Automation template with Kubernetes components14.Using VMware Aria Automation Config for Configuration Management• Describe VMware Aria Automation Config• Use VMware Aria Automation Config for software deployment• Use VMware Aria Automation Config for configuration management• Use VMware Aria Automation Config with event-driven orchestration15.VMware Aria Automation Troubleshooting and Integration• Demonstrate how to monitor deployment history• Demonstrate basic troubleshooting• Execute CLI commands• Explain how to collect logs• Describe integration with VMware Aria Operations for Logs• Describe integration with VMware Aria Operations
# Title of the webpage:
#
#     VMware Kubernetes Fundamentals and Cluster Operations
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Anyone who is preparing to build and run Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction•  Introductions and objectives2.Containers•  What and Why containers•  Building images•  Running containers•  Registry and image management3.Kubernetes Overview•  Kubernetes project•  Plugin interfaces•  Building Kubernetes•  Kubectl CLI4.Beyond Kubernetes Basics•  Kubernetes objects•  YAML•  Pods, replicas, and deployments•  Services•  Deployment management•  Rolling updates•  Controlling deployments•  Pod and container configurations5.Kubernetes Networking•  Networking within a pod•  Pod-to-Pod Networking•  Services to Pods•  ClusterIP, NodePort, and LoadBalancer•  Ingress controllers•  Service Discovery via DNS6.Stateful Applications in Kubernetes•  Stateless versus Stateful•  Volumes•  Persistent volumes claims•  StorageClasses•  StatefulSets7.Additional Kubernetes Considerations•  Dynamic configuration•  ConfigMaps•  Secrets•  Jobs, CronJobs8.Security•  Network policy•  Applying a NetworkPolicy•  SecurityContext•  runAsUser/Group•  Service accounts•  Role-based access control9.Logging and Monitoring•  Logging for various objects•  Sidecar logging•  Node logging•  Audit logging•  Monitoring architecture•  Monitoring solutions•  Octant•  VMware vRealize®Operations Manager™10.Cluster Operations•  Onboarding new applications•  Backups•  Upgrading•  Drain and cordon commands•  Impact of an upgrade to running applications•  Troubleshooting commands•  VMware Tanzu™ portfolio overview
# Title of the webpage:
#
#     VMware NSX安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 76,600
# Target audience: Experienced security administrators or network administrators
# DocumentBOX Outline: 1.Course Introduction2.VMware Virtual Cloud Network and VMware NSX3.Preparing the NSX Infrastructure4.NSX Logical Switching5.NSX Logical Routing6.NSX Bridging7.NSX Firewalls8.NSX Advanced Threat Prevention9.NSX Services10.NSX User and Role Management11.NSX Federation
# Title of the webpage:
#
#     VMware Tanzu Kubernetes Grid安裝及設定管理課程
#
#
# Course duration: 28小時
# Course cost: NT$ 59,500
# Target audience: Platform operators who are responsible for deploying and managing Tanzu Kubernetes clusters
# DocumentBOX Outline: 1.Course Introduction2.Introducing VMware Tanzu Kubernetes Grid3.VMware Tanzu Kubernetes Grid CLI and API4.Authentication5.Load Balancers6.VMware Tanzu Kubernetes Grid on vSphere7.VMware Tanzu Kubernetes Grid on Public Clouds8.Tanzu Kubernetes Workload Clusters9.Tanzu Kubernetes Grid Packages10.Configuring and Managing Tanzu Kubernetes Grid Operation and Analytics Packages11.Configuring and Managing Tanzu Kubernetes Grid Networking Packages12.Tanzu Kubernetes Grid Day 2 Operations13.Troubleshooting Tanzu Kubernetes Grid
# Title of the webpage:
#
#     VMware vSphere安裝及設定管理課程
#
#
# Course duration: 35小時
# Course cost: NT$ 69,900
# Target audience: 系統管理員系統工程師
# DocumentBOX Outline: 1.Course Introduction2.vSphere and Virtualization Overview3.Installing and Configuring ESXi4.Deploying and Configuring vCenter5.Configuring and Managing Virtual Networks6.Configuring vSphere Storage7.Deploying Virtual Machines8.Managing Virtual Machines9.Deploying and Configuring vSphere Clusters10.Managing the vSphere Lifecycle
# Title of the webpage:
#
#     Windows Server 2016的安裝、儲存及運算
#
#
# Course duration: 42小時
# Course cost: NT$ 28,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望提升企業資訊服務高可用性與負載平衡的管理者與規劃人員
# DocumentBOX Outline: Nano、Server Core伺服器準備、安裝、升級與遷移的策略設定本地儲存裝置企業儲存解決方案儲存空間與重複資料刪除安裝設定Hyper-V與虛擬機器部署管理Windows與Hyper-V容器(Container)高可用性與災難恢復的概論施作與管理容錯移轉叢集建置Hyper-V虛擬機器的容錯移轉叢集配置網路負載平衡(NLB)建立、管理與部署映像檔案(Image)管理、監控和維護虛擬機器的安裝
# Title of the webpage:
#
#     配置Aruba行動網路第二級
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 1.負責中大型企業無線網路維運、管理與部署相關工作者2.對中大型企業無線網路技術有高度興趣者
# DocumentBOX Outline: 回顧配置Aruba行動網路第一級的課程主題，包含各種AP專業用語、圖形界面的分層架構、與WLAN轉發模式介紹行動主控台的備援機制(Mobility Master Redundancy)，包含VRRP的安裝設定、與MM資料庫的同步介紹行動主控台(MM)與行動控制台(MC)的操作，包含行動控制台的各種部署方式、與安裝設定許可證(license)的進階功能介紹Multizone功能，包含Multizone AP功能流程、Primary與Data zone、與Multizone故障排除介紹MC叢集(Cluster)功能，包含cluster leader選舉過程、MC叢集角色、無中斷式叢集的故障切換(hitless cluster failover)、與叢集內部AP和用戶的負載平衡介紹Aruba行動漫遊(Roaming)功能，包含標準的802.11漫遊、單台與多台行動控制台間的漫遊、與叢集式的行動漫遊(Cluster Mobility)介紹角色的指派(Role Derivation)功能，包含使用VSA來解釋角色的指派、描述用戶規則(user rule)與認證預設角色(authentication default role)、解釋如何做故障排除、與以角色為基礎的ACL介紹Aruba遠端存取(Remote Access)的各種解決方案(RAP/VIA/IAP-VPN/branch controller)，包含RAP的認證、安裝、設定、備援選項及故障排除、與VIA的設定、下載、安裝及故障排除介紹Aruba語音最佳化功能，包含檢視語音QoS、解釋WMM、描述UCC Heuristic與SDN API運行模式、語音連線的監控與故障排除介紹Aruba網狀無線網路(Mesh)功能，包含mesh技術、與mesh cluster設定介紹Aruba裝置的管理，包含管理帳戶與其密碼的重置、設定Guest Provisioning account、使用RADIUS或TACACS認證、與如何取消console access介紹行動控制台的操作，包含如何升級新的影像檔、AP image preload、cluster in service的升級、設定檔的自動回滾(Auto roll back)功能、與可載入的服務模組(LSM)介紹Aruba AirGroup功能，包含AirGroup解決方案的設定及其限制、與ClearPass的整合、AirGroup伺服器與用戶的監控介紹自動分段(Dynamic Segmentation)功能，包含以端口為基礎的通道功能(PBT)與以用戶為基礎的通道功能(UBT)、描述交換機與行動控制台的互動、與如何排除tunnel連線的故障介紹Aruba AirWave管理平台，包含描述AirWave功能、使用群組與檔案夾、設定裝置憑證(device credential)、與如何添加新裝置介紹使用AirWave平台來識別與監控網路健康問題，包含解釋診斷頁面的指示、使用網路健康圖形來識別網路問題、使用效能圖形來幫助網路規劃、與使用Clarity功能引導管理員尋找問題的根源介紹使用AirWave平台來排除用戶與AP裝置的疑難問題，包含解釋如何搜尋用戶與排除相關問題、調查用戶SNR、與如何在AirWave內監控MC叢集介紹使用AirWave平台的VisualRF、報告與警示功能，包含解釋不同的VisualRF顯示選項、描述VisualRF應用程式的監控、設定triggers以創建alerts、與生成22種各式各樣的報告
# Title of the webpage:
#
#     區域網路規劃與架設導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對通訊網路產業有高度興趣，想從事相關工作者有志從事網路規劃的IT人員欲自我提升能力的網路系統工程師
# DocumentBOX Outline: 網路規劃的基本觀念網路規劃的方法論規劃企業區域網路應有的考量VLAN的規劃概要IP位址的規劃概要線路備援的規劃概要網路管理的規劃案例研討
# Title of the webpage:
#
#     資安國際認證與網路系統工程師就業養成班
#
#
# Course duration: 414小時
# Course cost: NT$ 93,000
# Target audience: 電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證者沒有任何資訊技術背景或想轉職進入熱門資訊產業者從基礎觀念開始導入，適合想打好進入資訊產業的強健體魄者資訊產業新手，想厚植專業技能，加強自身就業競爭力及提升就業薪資
# DocumentBOX Outline: 【網路基礎】網路基礎架構與網路服務【Windows系統管理建置】Windows Server 2016的網路功能Windows Server 2016驗證服務【Linux系統管理建置】Red Hat Linux系統管理實務訓練課程ⅠRed Hat Linux系統管理實務訓練課程ⅡRHCSA(Red Hat Certified System Administrator)認證考試輔導【CompTIA Security＋國際網路資安認證】CompTIA Security＋國際網路資安認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)【藍隊資安防禦通識-EC-Council CND認證】藍隊資安防禦通識-EC-Council CND認證課程(此課程為「數位發展部資通安全署」認可之資通安全專業證照)藍隊資安防禦通識-EC-Council CND認證考試輔導【就業前置作業輔導】產業現況分析履歷撰寫及面試技巧就業輔導與企業媒合
# Title of the webpage:
#
#     管理Exchange Server 2016及2019
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 對微軟郵件訊息平台有興趣者對Exchange Server 2016/2019管理有濃厚興趣，欲成為Exchange Server管理者本身為Exchange Server 2003/2007/2010管理者，欲晉升為Exchange Server 2016/2019管理者
# DocumentBOX Outline: 部署Exchange Server 2019，和在Server Core上安裝Exchange Server 2019管理Exchange Server信箱伺服器建立和管理各種收件者物件，和配置地址清單的策略使用EMS管理收件者物件和Exchange伺服器規劃用戶端連線、部署和配置用戶端存取服務管理Exchange Server伺服器的高可用性實作Exchange Server伺服器角色的災難復原設定及管理訊息傳輸架構設定防毒、垃圾郵件以及防惡意程式保護Exchange Server的監視和疑難排解保護和維護Exchange Server的管理稽核規劃及管理Exchange Online的部署
# Title of the webpage:
#
#     ACA-Campus Access認證－Aruba園區存取網路基礎
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 網路現場技術人員、部署技術人員、第1級NOC人員、或具有Aruba產品實作經驗的初級網路工程師具有1年以上的網路經驗為佳，並且瞭解各家廠商通用的基本網路協定想要取得(Aruba Certified Associate - Campus Access)國際認證者
# DocumentBOX Outline: Networking Fundamentals－解釋OSI模型與封包封裝、TCPIP堆疊、討論不同種類的實體介質、與比較單播、群播與廣播AOS-CX Switching Fundamentals－介紹交換機的初始設定、如何配置VLAN與tagging、如何使用LLDP與ICMP做為網路發現與診斷、如何配置Link aggregation以增進效能Basic IP Setup－討論inter-VLAN routing、解釋DHCP relay、討論Static IP routing、解釋如何配置單一區域的OSPFNetwork Redundancy－討論Spanning Tree、解釋VRRP與VSXVSF－介紹VSF、解釋如何配置VSF、描述Auto-VSF、解釋VSF MADIntroduction to Aruba Solutions－介紹Aruba交換機與WLAN的產品組合、介紹Aruba Central與ClearPassCentral for Device Mangement－介紹Device Onboarding、描述如何創建Central Groups、描述UI設定模式、描述template設定解釋如何實施模式、描述Aruba Central licensingDevice Profiles and AP Onboarding－描述Device Profiling的使用、描述LLDP與MAC profiling、解釋如何連接AP到Aruba Central、解釋如何實施AP的初始設定WLAN Fundamentals－描述802.11與射頻(RF)基礎知識、解釋SNR、描述漫遊標準與QoS需求、描述射頻的規劃、解釋如何配置WLANImplementing Secure WLANs－介紹AAA、描述802.1X認證、解釋如何配置安全的WLAN、討論角色(roles)與訪問規則Implementing Guest Access－解釋如何配置captive portal認證、描述如何設定guest WLANWLAN Security－介紹無線網路的資安、解釋憑證(certificates)、描述雲端認證Monitoring and Maintenance－解釋如何使用Aruba Central的監控能力、描述如何識別LED狀態、解釋如何實施firmware的升級、描述如何啟動設備的SNMP、描述AI Insights、描述警報與報告、解釋UXITroubleshooting－描述如何實施密碼復原與重置出廠設定步驟、解釋Central connectivity的故障排除、描述如何啟動頻譜的分析(spectrum analysis)、探索Central排除故障的工具
# Title of the webpage:
#
#     AWS Cloud Practitioner Essentials
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 銷售法律行銷商業分析師專案經理高層主管AWS Academy學員其他 IT 相關專業人員
# DocumentBOX Outline: 雲端概念AWS服務安全性架構定價與支援
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科高級企業等級路由與服務
#
#
# Course duration: 42小時
# Course cost: NT$ 68,000
# Target audience: 1.企業路由基礎架構管理與規劃人員2.企業路由解決方案規劃與支援人員3.對大型企業網路運作技術有興趣者
# DocumentBOX Outline: EIGRP建置、優化與疑難排解OSPF建置、優化與疑難排解BGP建置、優化與疑難排解路由重新發佈（Redistribution）設定與疑難排解建置路徑控制探討及探討L3 MPLS VPN架構與路由設定簡化的虛擬路由與轉送（VRF-Lite）建置動態多點虛擬私人網路（DMVPN）建置與疑難排解DHCP介紹IPv6的第一站安全性保全思科路由器疑難排解安全架構與服務針對DNA Center Assurance 進行疑難排解
# Title of the webpage:
#
#     FCP-NS認證 - FortiManager認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或工作上負責使用FortiManager，對FortiGate安全政策執行日常管理的相關人員欲取得FCP-NS專業認證資格者欲重認證FCF, FCA, FCP-NS者
# DocumentBOX Outline: 簡介和初始配置系統管理設備註冊設備層級的配置和安裝政策和物件全局管理域和中央管理診斷和故障排除額外配置介紹
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     Microsoft 365管理者認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 本課程適用於有志成為Microsoft 365系統管理員角色的IT人員
# DocumentBOX Outline: 部署與設定您的Microsoft 365租用戶環境管理您的Microsoft 365租用戶環境部署與地端AD目錄服務的識別驗證同步服務作業探索Microsoft 365的安全指標管理您在Microsoft 365 Defender中的安全服務如何使用Microsoft 365 Defender來部署威脅保護探索在Microsoft 365的資料治理部署在Microsoft 365中的合規性管理在Microsoft 365中的合規性
# Title of the webpage:
#
#     Microsoft Azure管理員認證班
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure的使用經驗欲進一步熟悉Azure基礎結構建置、管理與維護的Azure管理員有志取得Microsoft Certified：Azure Administrator Associate認證者
# DocumentBOX Outline: 身份識別•     Azure Active Directory(Microsoft Entra ID)、Users and Groups治理與合規•     Subscriptions and Accounts、Azure Policy、Role-based Access ControlAzure管理•     Azure Resource Manager、Azure Portal and Cloud Shell、Azure PowerShell and CLI、ARM Templates虛擬網路•     Virtual Networks、IP Addressing、Network Security Groups、Azure Firewall、Azure DNS網路間連接•     Vnet Peering、VPN Gateway Connections、ExpressRoute and Virtual WAN網路流量管理•     Network Routing and Endpoints、Azure Load Balancer、Azure Application GatewayAzure儲存體帳戶•     Storage Accounts、Blob Storage、Storage Security、Azure Files and File Sync、Managing StorageAzure虛擬機器•     Virtual Machine Planning、Creating Virtual Machines、Virtual Machine Availability、Virtual Machine Extensions管理PaaS運算選項•     Azure App Service Plans、Azure App Service、Container Services、Azure Kubernetes Service、Azure Container Instance資料保護•     File and Folder Backups、Virtual Machine Backups監視•     Azure Monitor、Azure Alerts、Log Analytics、Network Watcher
# Title of the webpage:
#
#     Microsoft Power Platform基本原理
#
#
# Course duration: 14小時
# Course cost: NT$ 16,000
# Target audience: 需要銷售Power Platform相關內容的銷售人員想要了解如何利用Power Platform來整合Microsoft 365應用環境的管理者想要將Dynamic 365與Power Platform進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Fundamentals專業認證的人員
# DocumentBOX Outline: 介紹Microsoft Power Platform的商業價值認識Power Platform所提供的基礎組件如何開始使用Power Apps來設計自訂的應用程式如何開始使用Power Automate來設計所需的自動化流程介紹Power BI的能力介紹Power Platform附加的解決方案Microsoft 365整合應用透過Excel 365產出QR Code圖片
# Title of the webpage:
#
#     Microsoft安全營運分析師
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，且已具備Azure與Microsoft 365使用經驗欲進一步熟悉Azure安全營運與Microsoft 365安全營運的分析師有志取得Microsoft Certified：Security Operations Analyst Associate認證者
# DocumentBOX Outline: 使用Microsoft 365 Defender緩解威脅使用Microsoft Defender for Endpoint緩解威脅使用Microsoft Defender for Cloud緩解威脅使用Kusto Query Language(KQL)為Microsoft Sentinel建立查詢設定您的Microsoft Sentinel環境將logs連接到Microsoft Sentinel使用Microsoft Sentinel建立檢測並執行調查在Microsoft Sentinel中執行威脅搜尋微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     RHCA認證-Red Hat OpenShift開發II：容器化應用
#
#
# Course duration: 28小時
# Course cost: NT$ 56,000
# Target audience: 企業應用開發人員站點可靠性工程師
# DocumentBOX Outline: 管理和觸發應用建置版本自定義現有Source-to-image基礎鏡像建立OpenShift模板建立健康檢查，監控和提高應用可靠性建立和部署Jenkins流水線，以實現持續集成和持續部署為OpenShift建立和部署雲原生應用
# Title of the webpage:
#
#     VMware NSX疑難排除與操作課程
#
#
# Course duration: 35小時
# Course cost: NT$ 84,400
# Target audience: • Experienced system administrators and network administrators• Network and security professionals who work with enterprise networks
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.NSX Operations and Tools• Explain and validate the native troubleshooting tools for NSX• Configure syslog, IPFIX, and log collections for the NSX environment• Integrate NSX with VMware Aria Operations for Logs and VMware Aria Operations for Networks• Validate and review the API methods available to configure the NSX environment3.Troubleshooting the NSX Management Cluster• Describe the NSX Management cluster architecture, components, and communication channels• Identify the workflows involved in configuring the NSX Management cluster• Validate and troubleshoot the NSX Management cluster formation4.Troubleshooting Infrastructure Preparation• Describe the data plane architecture, components, and communication channels• Explain and troubleshoot VMware ESXi transport node preparation issues• Explain and troubleshoot NSX Edge deployment issues5.Troubleshooting Logical Switching• Describe the architecture of logical switching• List the modules and processes involved in configuring logical switching• Explain the importance of VDS in transport nodes• Review the architecture and workflows involved in attaching workloads to segments• Identify and troubleshoot common logical switching issues6.Troubleshooting Logical Routing• Review the architecture of logical routing• Explain the workflows involved in the configuration of Tier-0 and Tier-1 gateways• Explain the high availability modes and validate logical router placements• Identify and troubleshoot common logical routing issues using both BGP and OSPF7.Troubleshooting Security• Review the architecture of the Distributed Firewall• Explain the workflows involved in configuring the Distributed Firewall• Review the architecture of the Gateway Firewall• Explain the workflows involved in configuring the Gateway Firewall• Identify and troubleshoot common Distributed firewall and Gateway Firewall issues• Review the architecture and workflows involved in configuring Distributed IDS/IPS• Identify and troubleshoot common Distributed IDS/IPS problems8.Troubleshooting Services• Review the NSX Advanced Load Balancer architecture and components• Identify and troubleshoot common NSX Advanced Load Balancer issues• Review the IPsec and L2 VPN architecture and components• Identify and troubleshoot common IPsec and L2 VPN issues9.Datapath Walkthrough• Verify and validate the path of the packet on the NSX datapath• Identify and perform packet captures at various points in the datapath• Use NSX CLI and native hypervisor commands to retrieve configurations involved in the NSX datapath
# Title of the webpage:
#
#     VMware vSphere新增功能
#
#
# Course duration: 14小時
# Course cost: NT$ 30,600
# Target audience: System architects, system administrators, IT managers, VMware partners, and individuals responsible for implementing and managing vSphere architectures who want to deploy vSphere 8.0 into their existing vSphere environment.
# DocumentBOX Outline: 1.Course Introduction• Introductions and course logistics• Course objectives2.Artificial Intelligence and Machine Learning• Describe how device groups support AI and ML in vSphere 8.0• Describe how device virtualization extensions support AI and ML in vSphere 8.03.vSphere Distributed Services Engine• Describe the benefits of Distributed Services Engine• Explain how Distributed Services Engine works• Recognize use cases for Distributed Services Engine• Install ESXi on a host equipped with a DPU• View DPU information in the vSphere Client• Add an ESXi host equipped with a DPU to a cluster• Use vSphere Lifecycle Manager to update an ESXi host that contains a DPU• Create a vSphere distributed switch for network offloads• Add a host with a DPU to the vSphere distributed switch• Configure a VM to use uniform passthrough mode4.vSphere and vCenter Management• Describe improvements to the communication between vCenter and ESXi hosts• Describe enhancements to the vCenter recovery process5.ESXi Enhancements• Describe the function of the central configuration store in ESXi• Explain how ConfigStore affects interaction with ESXi configuration files• Recognize the supported system storage partition configuration on ESXi 8.0• Identify devices supported for system storage on ESXi 8.0• Configure an RDMA host local device on ESXi 8.06.vSphere Storage• Describe the VMware vSAN¬ Express Storage Architecture• Recognize the benefits of using vSAN Express Storage Architecture• Describe the benefits of using NVMe• Recognize the support for NVMe devices in vSphere 8.07.Guest OS and Workloads• Review the enhancements of the latest virtual hardware versions• Describe the features introduced with virtual hardware version 20• Identify the snapshot modes of NVDIMM devices8.Resource Management• View energy and carbon emission metrics in VMware vRealize® Operations Manager™• Describe the vSphere Memory Monitoring and Remediation (vMMR) functionality• Describe how vMMR enhances the performance of DRS9.Security and Compliance• Describe how to manage vTPM secrets when cloning a VM• Manage OVF templates for VMs configured with vTPM• Deploy an OVF template with vTPM• Describe the enhancements to trusted binary enforcement in ESXi• Describe ESXi 8.0 enhanced security features10.vSphere Lifecycle Manager• Describe the enhancements to life cycle management of standalone ESXi hosts• Manage the configuration profiles of ESXi hosts in a cluster• Use Auto Deploy to boot a host with the desired image and configuration specifications• Upgrade multiple ESXi hosts in a cluster in parallel• Stage an ESXi host image before remediation11.Auto Deploy• Manage custom host certificates using Auto Deploy12.vSphere with Tanzu• Describe the features of Vmware Tanzu® Kubernetes Grid™ 2.013.Announcing vSphere+• Describe the functionality and benefits of vSphere+
# Title of the webpage:
#
#     企業IT服務伺服器架設與選擇方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: 對IT產業有興趣、想從事伺服器管理相關工作者想學習認識企業建構伺服器有哪些不同的異質平台(如：Windows、Linux、Mac等)可供選擇者
# DocumentBOX Outline: 企業常見IT伺服器平台介紹企業常見IT伺服器應用介紹File伺服器介紹Proxy/NAT/Firewall介紹DNS伺服器介紹Web伺服器介紹Mail伺服器介紹集中驗證伺服器介紹授權伺服器軟體vs.免費伺服器軟體Hands on Lab
# Title of the webpage:
#
#     ACP-Campus Access認證－建置Aruba園區存取網路
#
#
# Course duration: 35小時
# Course cost: NT$ 63,000
# Target audience: 第2/3級NOC人員、網路分析師、或具有2-5年Aruba產品組合經驗的網路工程師為佳想要取得(Aruba Certified Professional - Campus Access)國際認證者
# DocumentBOX Outline: Introduction to Aruba Solutions－介紹Aruba ESP架構、Aruba產品組合、自動化與REST APIBuilding Wired Infrastructure－介紹VSX、OSPF、虛擬化路由與轉發、以策略為基礎的路由、Aruba Central Template GroupsWireless Infrastructure with Aruba Gateways－介紹AOS 10與Central Groups、Aruba Gateways的部署、Gateway的初始設定、Gateway ClusterTunneled WLAN Architecture－介紹Tunneled Mode WLAN、Client MonitoringSecure Enterprise WLAN－介紹802.1X認證、防火牆Roles與Role Derivation、CoA支持Guest and Captive Portal－介紹訪客的訪問、訪客認證過程、訪客WLAN配置、MAC快取Wireless Authentication for IoT－介紹MPSK、MPSK認證過程、本地MPSK設定Mixed Mode Architecture－介紹Aruba混合模式WLAN、與其設定Gateway Cluster Deployments－介紹Cluster部署選項、Cluster設定、Cluster監控、Secondary GatewayWired Port Access－介紹Wired認證、802.1X設定、MAC認證、RADIUS Attributes與Roles、動態分段、Wired Captive PortalVXLAN and GBP－介紹分散式Overlay與VXLAN、VXLAN GBPSecurity and Availability Features－介紹IDS/IPS、Authentication Survivability、Central Survivability、管理用戶認證Traffic Optimization and QOS－介紹WLAN優化、AirGroup、服務品質、UCC、LLDP MEDMonitoring－介紹Central警告、Device Insights、用戶體驗Insights
# Title of the webpage:
#
#     AWS Cloud Financial Management for Builders
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 解決方案架構師開發者成本優化管理者系統管理者
# DocumentBOX Outline: 雲端服務財務管理導論：管理簡介、四個支柱、資源標記定價與成本：定價基礎、AWS免費方案、批量折扣、儲蓄計劃、預留實例AWS的帳單、報告、監控、發票、預算運算資源的成本構建：Amazon EC2規格調整、購買選項、Amazon CloudWatch監控和自動化、Amazon EC2競價型實例、自動化基礎架構、無伺服器解決方案網路資源的成本構建：資料傳輸費用、不同服務的資料成本、如何分攤網路成本儲存資源的成本構建：Amazon EBS、Amazon S3、Amazon EFS的成本、定價和最佳實踐資料庫資源的成本構建：Amazon RDS、Amazon Aurora、Amazon DynamoDB、Amazon ElastiCache、Amazon Redshift的成本、定價和最佳實踐成本治理：設置AWS組織、AWS Systems Manager
# Title of the webpage:
#
#     CCNP Enterprise認證-建置思科SD-WAN解決方案
#
#
# Course duration: 35小時
# Course cost: NT$ 79,000
# Target audience: 企業路由基礎架構管理與規劃人員企業路由解決方案規劃與支援人員對大型企業網路運作技術有興趣者
# DocumentBOX Outline: 檢查 Cisco SD WAN 架構檢查 Cisco SD-WAN 部署選項部署廣域網路邊緣設備設備設定管理探索冗餘、高可用性和可擴展性啟用服務端和傳輸端路由了解Cisco SD-WAN策略配置基礎知識定義高階控制策略定義高階資料策略建置應用程式體驗品質（Application Quality of Experience）建置應用程式感知路由（Application-Aware Routing）檢查直接Internet訪問和雲部署選項探索思科SD-WAN安全性設計和遷移到Cisco SD-WAN執行Cisco SD-WAN網路管理和故障排除檢查Cisco SD-WAN群播支持
# Title of the webpage:
#
#     FCP-SO認證 - FortiSIEM認證課程
#
#
# Course duration: 21小時
# Course cost: NT$ 47,250
# Target audience: 想了解或任何負責FortiSIEM日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 簡介SIEM和PAM概念探索設備和FortiSIEM代理程式FortiSIEM關聯分析CMDB查找和過濾條件群組分類和資料彙總規則和MITREATT&CK告警事故和通報政策報表和儀表板維護和調整故障排除
# Title of the webpage:
#
#     Microsoft Azure安全性技術
#
#
# Course duration: 35小時
# Course cost: NT$ 30,000
# Target audience: 已從事Azure系統與網路管理之管理人員或系統工程師欲進一步了解Azure安全性技術者有志取得Microsoft Certified：Azure Security Engineer Associate認證者
# DocumentBOX Outline: 管理身分識別和存取•     Azure Active Directory(Microsoft Entra ID)•     Azure身分保護•     企業治理•     設定Azure AD特權身份管理•     混合身分識別實行平台防護•     周邊網路的安全性•     網路安全性•     主機安全性•     容器安全性保全資料與應用程式•     Azure金鑰保存庫•     應用程式安全性•     儲存體安全性•     SQL資料庫安全性管理安全操作•     Azure監視•     Microsoft Defender for Cloud•     Microsoft Sentine微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Microsoft身份和存取管理員
#
#
# Course duration: 28小時
# Course cost: NT$ 40,000
# Target audience: 已從事系統管理員或系統工程師之職務，並已具備Azure的管理技能欲進一步了解在安全架構中規劃與解決方案的專業人員有志取得Microsoft Certified：Identity and Access Administrator Associate認證者
# DocumentBOX Outline: 實施身份管理解決方案實施身份驗證和存取解決方案實施應用程式的存取管理規劃和實施身份治理的策略微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     Red Hat OpenShift管理III：在企業中擴展Kubernetes部署
#
#
# Course duration: 28小時
# Course cost: NT$ 45,000
# Target audience: 專為想要在其數據中心部署和管理大型Red Hat OpenShift Container Platform環境的系統管理人員而設計
# DocumentBOX Outline: 身份驗證和身份管理備份、還原和遷移OADP(OpenShift API for Data Protection) 的應用程式叢集分區Pod 調度OpenShift GitOpsOpenShift 監控OpenShift 日誌記錄
# Title of the webpage:
#
#     VMware vSphere設計規劃課程
#
#
# Course duration: 21小時
# Course cost: NT$ 50,700
# Target audience: Experienced system integrators and consultants responsible for designing and deploying vSphere environments
# DocumentBOX Outline: Course Introduction•          Introductions and course logistics•      Course objectivesInfrastructure Assessment•      Follow a proven process to design a virtualization solution•          Define customer business objectives•          Gather and analyze business and application requirements•      Document design requirements, constraints, assumptions, and risks•      Use a systematic method to evaluate and document design decisions•      Create a conceptual designCore Management Infrastructure•          Determine the number of VMware vCenter® Server ApplianceTM instances to include in a design•      Choose the appropriate single sign-on identity source•      Choose the time synchronization method•          Choose methods to collect log files and ESXi core dumps•          Design a vCenter Server deployment topology that is appropriate for the size and requirements of the data centerVirtual Data Center Infrastructure•      Calculate total compute capacity requirements for a virtual data center•          Create a virtual data center cluster design that meets business and workload requirements•      Evaluate in the virtual data center the use of several management services, such as VMware vSphere® High Availability and VMware vSphere® Distributed Resource Scheduler™•      Evaluate the use of resource pools in the virtual data center designCompute Infrastructure•      Create a compute infrastructure design that includes the appropriate ESXi boot, installation, and configuration options•      Choose the ESXi host hardware for the compute infrastructureStorage Infrastructure•      Calculate storage capacity and performance requirements for a design•          Evaluate the use of different storage platforms and storage management solutions•      Design a storage platform infrastructure and storage management architecture that meets the needs of the vSphere environmentNetwork Infrastructure•      Evaluate the use of different network component and network management solutions•      Design a network component architecture that includes information about network segmentation and virtual switch types•      Design a network management architecture that meets the needs of the vSphere environmentVirtual Machine Design•      Make virtual machine design decisions, including decisions about resources•      Design virtual machines that meet the needs of the applications in the vSphere environment and follow VMware best practicesInfrastructure Security•      Make security design decisions for various layers in the vSphere environment•      Design a security strategy that meets the needs of the vSphere environment and follows VMware best practicesInfrastructure Manageability•          Make lifecycle management, scalability, and capacity planning design decisions that adhere to business requirements•      Design lifecycle management, scalability, and capacity planning strategies that meet the needs of the vSphere environment and follow VMware best practicesInfrastructure Recoverability•      Make infrastructure recoverability design decisions that adhere to business requirements•          Design an infrastructure recoverability strategy that meets the needs of the vSphere environment and follows VMware best practices
# Title of the webpage:
#
#     Windows Server 2016的身分識別
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 已從事系統管理員或系統工程師之職務欲熟悉Windows Server 2016安裝設定與基礎架構者希望經由AD目錄服務整合憑證、版權管理及防護機敏資料的管理人員已具備Windows Server 2008/2012 AD網路管理經驗者
# DocumentBOX Outline: 安裝與設定網域控制器(DC)管理AD DS系統與物件進階AD DS基礎結構管理施作與管理AD DS站台與複寫群組原則部署與除錯運用群組原則管理用戶設定強化AD DS的安全性部署與設定AD憑證服務(AD CS)配置與管理憑證實施與管理AD同盟服務(AD FS)實施與管理AD版權管理服務(AD RMS)部署AD DS與Microsoft Azure AD的同步監視、管理、與復原AD DS
# Title of the webpage:
#
#     企業資料的備份與救援簡易解決方案導覽
#
#
# Course duration: 7小時
# Course cost: NT$ 6,000
# Target audience: IT人員，管理伺服器與資料安全領域相關工作者想了解企業與個人資料保全相關技術者
# DocumentBOX Outline: 設計企業資料保全政策資料安全風險評估選擇備份媒體、方法與技術排程備份與檢視備份資料救援與系統快照磁碟陣列儲存網路異地備援備份反運作：數位資源的抹除大量的實務練習
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     製作適用於Microsoft 365的Microsoft Copilot的有效提示
#
#
# Course duration: 7小時
# Course cost: NT$ 9,000
# Target audience: 學習者應熟悉Microsoft 365應用程式，例如Word、Excel和PowerPoint。本課程適用於使用Microsoft 365的Microsoft Copilot的所有類型使用者
# DocumentBOX Outline: 適用於Microsoft 365的Copilot簡介探索使用適用於Microsoft 365的Copilot的可能性優化和擴充適用於Microsoft 365的Copilot使用Microsoft Copilot for Microsoft 365進行總結使用Microsoft Copilot for Microsoft 365建立和起草文案使用Microsoft Copilot for Microsoft 365編輯和轉換內容使用Microsoft Copilot for Microsoft 365提出問題並分析內容
# Title of the webpage:
#
#     Azure管理員及解決方案架構專家雙認證班
#
#
# Course duration: 63小時
# Course cost: NT$ 55,000
# Target audience: 已從事系統管理員或系統工程師之職務並已有Azure使用經驗欲進一步熟悉Azure基礎結構建置、管理、維護及解決方案架構設計的IT管理員
# DocumentBOX Outline: AZ104：Microsoft Azure管理員認證班(35小時)•　 身份識別•　 治理與合規•　 Azure管理•　 虛擬網路•　 網路間連接•　 網路流量管理•　 Azure儲存體帳戶•　 Azure虛擬機器•　 管理PaaS運算(Web App、ACI及AKS)•　 資料保護•　 監視AZ305：設計Microsoft Azure基礎結構解決方案(28小時)•　 設計治理與計算解決方案•　 設計儲存體和資料整合解決方案•　 設計應用程式架構•　 存取和監視解決方案•　 設計網路、持續性和移轉解決方案微軟最新財報出爐，Azure營收成長50%！想要跨入雲端領域，取得最夯的Azure認證該如何準備?
# Title of the webpage:
#
#     FCP-SO認證 - FortiEDR認證課程
#
#
# Course duration: 14小時
# Course cost: NT$ 31,500
# Target audience: 想了解或任何負責FortiEDR日常管理的人都應該參加這個課程欲取得FCP-SO專業認證資格者欲重認證FCF, FCA, FCP-SO者
# DocumentBOX Outline: 產品概述及安裝管理安全政策Fortinet雲服務(FCS)和劇本通訊控制事件和警報威脅獵捕和鑑識Fortinet安全織網和FortiXDR的整合RESTful API故障排除
# Title of the webpage:
#
#     Microsoft Power Platform功能顧問
#
#
# Course duration: 28小時
# Course cost: NT$ 28,000
# Target audience: 想要成為Microsoft Power Platform的功能顧問師想要使用Mirosoft Power Platform與將Dynamic 365的商務應用進行整合的發展設計人員希望透過自動化業務流程提升生產力，透過分析資料生成業務見解，以及透過建立簡單的App體驗提高執行效率的使用者想要取得Microsoft Certified：Power Platform Functional Consultant Associate專業認證的人員已完成以下課程所具備技術能力MS900：Microsoft 365 Fundamentals認證班PL900：Microsoft Power Platform基本原理PL100：Microsoft Power Platform應用程式製作者
# ...
# Title of the webpage:
#
#     前端必學的網頁開發基礎技能
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 對網頁開發有興趣的所有人員
# DocumentBOX Outline: HTML 文件結構HTML 常用與語意標籤圖片、表格與超連結標籤表單的建立影音多媒體標籤CSS 基本語法CSS 選取方式介紹色彩與文字設定寬度與高度屬性CSS 外框模型背景與漸層屬性定位方式與版面設定媒體查詢Flex 彈性排版效果響應式網頁設計變形與動畫效果JavaScript語法簡介以JavaScript設定簡易互動效果
# Title of the webpage:
#
#     前端網頁與UI設計師轉職就業養成班
#
#
# Course duration: 306小時
# Course cost: NT$ 72,000
# Target audience: 不需要相關科系背景或經歷，只要是對從事平面設計、網頁設計、App設計、網路數位行銷、網頁互動、數位內容產業有興趣者都可以參加
# DocumentBOX Outline: - Photoshop視覺影像與前端設計應用 30小時課程將帶您進入Photoshop的神奇世界，學習如何製作令人驚豔的視覺效果，包括圖片編輯、多媒體應用設計，讓您學會用電腦製作出您腦中的無限創意設計。- Illustrator專業向量繪圖與動畫素材設計 24小時您將掌握Illustrator並專注於網頁素材和動畫設計，這是一個非常重要的關鍵技能，對於網站和應用程序的成功至關重要。- Photoshop與Illustrator專業App UI介面視覺設計 24小時課程涵蓋App UI介面的視覺設計，教您如何設計流暢的用戶界面，並將您的視覺設計技能應用於使用者體驗設計當中。- Figma專業UI設計實作 18小時透過對Figma的深入研究，您將學會如何使用這個領先的UI設計工具，並在實際專案中應用您的技術。- Adobe Animate CC 製作HTML5動畫與互動效果 24小時課程將幫助您掌握Adobe Animate CC，以製作出生動的HTML5動畫和互動效果，使您的網頁更具吸引力。- HTML與CSS網頁編輯製作 30小時HTML決定網頁的架構而CSS決定網頁的視覺設計，可以說CSS就是網頁的化妝師，此課程引導不黯程式撰寫的您精耕HTML與CSS相關語法，加強專業的網頁設計實力，也方便後續與JavaScript/jQuery之間的設計應用。- WordPress快速上手網站實作 18小時WordPress是一個快速建立功能強大網站的重要工具。我們將教您如何使用WordPress，製作出專屬於您的網站，以展現您的設計創意。- 響應式網頁設計 24小時隨著行動裝置多樣化，響應式網頁設計是當今的網頁主要趨勢之一，您將學到如何設計可以在不同裝置上完美呈現網頁。- 前端互動式網頁程式設計-UI與元件設計 30小時由最基礎的語法開始，逐步的引導學員瞭解JavaScript的基礎，能讓完全沒有程式基礎的設計人員快速瞭解JavaScript的運作原理，課程將引導您深入瞭解前端互動式網頁程式設計，包括UI和元件設計，為您的網頁增添互動性。- JavaScript與jQuery網頁互動實作 36小時jQuery提供了許多強大功能函式庫，能夠一次解決網頁設計上常見的重大困難。透過範例中的步驟，您將掌握JavaScript和jQuery，提供網頁的互動能力，優化使用者經驗。- 個人作品集設計實務整合與數位影音履歷 48小時整合上述所學，打造完整個人作品集和數位影音履歷，讓後續轉職找工作有重要的作品呈現。這門課程涵蓋了以下內容：1. 個人作品集設計實務整合：精心設計和整合個人作品集，以展示您的設計技能和創意，包括您的平面設計、網頁設計、動畫和其他相關領域的作品。2. 數位影音履歷設計：這個部分涵蓋了如何設計和製作一個引人入勝的數位影音履歷，透過影片、動畫和其他元素來強調個人技能和經驗。製作令人印象深刻的履歷。進階課程需求，提供更優惠的價格，讓您在網頁設計師的職涯上更得心應手！【前端課程系列】- Sass與SCSS快速上手(原價12,000元)- 網頁統計圖表Chart.js快速上手(原價12,000元)養成班顧客於結業後一年內報名上述前端課程系列，可以原價5折優惠上課。
# Title of the webpage:
#
#     Photoshop視覺影像與前端設計應用
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: Photoshop初學者、欲學習Photoshop多媒體設計應用者
# DocumentBOX Outline: 基本操作環境與數位影像概念1-1  工作區域概覽1-2  檢視工具1-3  尺標、參考線1-4  影像檔案管理1-5  影像尺寸與版面尺寸1-6  裁切影像1-7  儲存檔案與影像檔案格式圖層與Photoshop影像編輯入門2-1 認識圖層2-2 圖層浮動視窗基本操作2-3 圖層管理2-4 選取與移動圖層2-5 變形指令2-6 各式變形2-7 數值變形2-8 翻轉變形由選取範圍開始玩耍影像合成3-1 固定形狀選取畫面工具3-2 特定形狀選取畫面工具3-3 選取範圍與影像編輯3-4 選取與填色3-5 漸層填色3-6 漸層顏色編輯3-7 油漆桶填色快速影像修正撇步4-1 影像調整工具組4-2 影像處理工具組4-3 影像亮度快速調整4-4 快速影像顏色加強術4-5 修復工具組4-6 內容感知填色4-7 仿製印章修圖向量形狀工具與路徑編輯應用5-1 向量形狀工具繪圖5-2 向量形狀工具繪製路徑應用5-3 路徑編輯工具5-4 使用筆型工具5-5 筆型工具描圖去背5-6 繪製形狀格式向量繪圖進階圖層編輯與濾鏡6-1 圖層對齊與均分6-2 使用圖層樣式6-3 圖層樣式設定6-4 建立圖層遮色片6-5 圖層混色模式6-6 濾鏡效果與設定文字編輯與設計應用7-1 建立文字7-2 段落文字7-3 圖層樣式文字應用7-4 效果文字應用影像處理與設計應用8-1 影像去背處理8-2 影像白邊框風格8-3 繪製剪影表現風格8-4 立可拍風格8-5 影像產品去背與陰影8-6 產品側面陰影前端網頁設計實作9-1 網頁按鈕與圖文框設計9-2 形象網站主視覺設計9-3 活動網站主視覺設計9-4 商品網站主視覺設計9-5 網頁內容設計
# Title of the webpage:
#
#     輕鬆玩出網頁影音新威力
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 1.有興趣學習影音處理製作者2.有需要製作網頁影音作品者
# DocumentBOX Outline: 開始數位影音創作1.1操作環境1.2匯入影片素材與儲存1.3素材取得幻燈片秀、自動模式輕鬆完成影片2.1 幻燈片秀編輯器2.2 自動模式2.3 Magic Movie精靈應用數位影音創作功能3.1 置換天空與動態人物特效3.2 關鍵畫格與動畫3.3 進階編輯模式製作動畫效果3.4 遮罩設計師製作動畫效果3.5 炫粒製作效果3.6 文字效果快速編排影片與效果神奇魔術工具快速編排影片5.1 素材分類管理與裁切圖片5.2 Magic Movie快速編排影片5.3 平移與縮放效果5.4 Magic Cut 快速剪輯影片遮罩與創意主題設計應用6.1 製作連續多張圖片放大影片片段6.2 組合成完整多張圖片放大影片6.3 完成遮色片文字動畫6.4 加入創意主題內容開場動畫與影片剪輯應用7.1製作遮色片開場動畫7.2剪輯主要影片內容與說明文字教學步驟影片進階編輯8.1善用轉場製作開場動畫8.2材料清單文字動畫8.3 主要影片編輯8.4加入圖框與影片效果運用影片調整與特效9.1 製作片頭文字專案9.2 製作主影片與調整影片9.3 應用疊加>炫粒9.4 加入文字動畫堆疊效果影片編輯應用10.1片頭影片與動畫10.2編輯主要影片10.3安排堆疊效果多角度拍攝影片編輯11.1開場動畫11.2編輯主要影片11.3加入影片文字與字幕動作類影片進階編輯12.1整合3D動畫素材12.2圖片平移縮放製作開場動畫12.3運動動作類影片整合編輯進階編輯個人數位影音介紹13.1加入素材13.2介紹影片去背合成13.3加入旁白與字幕13.4背景音樂與片尾
# Title of the webpage:
#
#     響應式網頁設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 需有HTML與CSS基礎，欲學習響應式網頁設計的設計師
# DocumentBOX Outline: 從動手瀏覽觀察網頁開始1-1    甚麼是響應式網頁1-2    建置響應式網頁1.3     安裝VS code 延伸模組開始使用Bootstrap2.1     新增Bootstrap空白頁面2.2     Bootstrap柵格系統2.3     Bootstrap 一般內容與通用類別+2.3.1     文字顏色與背景色2.3.2     文字屬性2.3.3     標題與顯示標題2.3.4     文字行高2.3.5     邊界與內距屬性設定2.3.6     對齊圖片2.3.7     響應式表格(Table)2.3.8     圓角(rounded)與邊框(Borders)2.3.9     響應式圖片與圖片區(Figures)2.3.10     BootStrtap ICON圖標2.4         其他更多的版面區塊編排2.4.1     自動佈局的欄 / 等寬2.4.2     巢狀排列2.4.3     使用邊界水平對齊區塊2.4.4     多個區塊水平對齊2.4.5     欄的推移2.4.6     間隙Gutters2.4.7     Flex對齊Bootstrap元件素材3.1     一般物件3.1.1     按鈕 (Buttons)3.1.2     麵包屑 (Breadcrumb)3.1.3     廣告大屏幕 (Jumbotron)3.2     區塊內容物件3.2.1     多項圖文編排(Media Object)3.2.2     標籤切換內容(Tab)3.2.3     折疊切換內容 (Accordion)3.3     Bootstrap響應式導覽列3.3.1     基本型收合導覽列3.3.2     收合導覽列元件3.4     Card卡片3.4.1     預設卡片類型3.4.2    卡片組合3.4.3     水平卡片3.4.4     網格卡片3.4.5     card圖文框排列版面3.5     Carousel輪播3.5.1     carousel-caption3.5.2     更改carousel CSS3.5.3     控制高度與自訂切換按鈕Bootstrap頁面編排應用4.1     先讓頁面捲動起來4.2    側邊導覽列捲動頁面4.3     頁面編排與效果4.4     頁面動態效果
# Title of the webpage:
#
#     Illustrator專業向量繪圖與動畫素材設計
#
#
# Course duration: 24小時
# Course cost: NT$ 12,000
# Target audience: 對於向量插圖、網頁與動畫素材設計有興趣者
# DocumentBOX Outline: 操作環境介紹與檔案管理1-1 操作環境1-2 工具箱1-3 檔案管理與輔助操作基礎繪圖與物件選取變形2-1 基礎繪圖工具2-2 線條繪圖工具2-3 橡皮擦、美工刀與剪刀工具2-4 物件選取與管理2-5 變形工具與變形指令2-6 封套變形指令物件造型與進階變形3-1 形狀模式3-2 路徑管理運算3-3 路徑管理運算繪製圖案應用3-4 即時上色3-5 使用影像描圖與即時上色繪圖3-6 點陣圖剪裁遮色片3-7 漸層填色3-8 形狀運算與漸層填色3-9 網格漸層填色不規則繪圖與描圖4-1 鉛筆工具組徒手繪圖4-2 繪製路徑工具組4-3 路徑編輯工具4-4 鋼筆繪製曲線路徑文字處理5-1 文字字元屬性5-2 建立外框字5-3 路徑文字5-4 文字造型設計應用5-5 段落文字特殊繪圖效果6-1 物件漸變6-2 筆畫效果6-3 Illustrator 效果6-4 3D 效果6-5 Photoshop 濾鏡7 繪圖應用7-1 對齊排列構圖7-2 路徑管理員設計動畫元件7-3 可愛動物動畫元件繪製8 漸層填色與特殊效果功能繪製素材8-1 漸層文字8-2 漸層星光8-3 漸層繪圖造型文字8-4 3D 效果繪圖應用
# Title of the webpage:
#
#     前端互動式網頁程式設計-UI與元件設計
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 網站開發人員、網頁設計人員
# DocumentBOX Outline: 網頁設計:HTML, CSS, JavaScript簡介JavaScript基礎語法深入瞭解JavaScript資料與變數宣告基礎運算子操作數值資料處理進階文字處理邏輯與判斷式迴圈處理與應用DOM文件物件模型操作利用JSON處理複雜資料深入瞭解Function函式架構日期物件與時間處理事件處理常式彈出式互動視窗 Modal window廣告定時呈現與關閉效果Timeout popup window放大鏡檢視圖片Zoom in image頁籤切換介面Tabs手風琴收合效果Accordion圖片輪撥效果Carousel
# Title of the webpage:
#
#     JavaScript與jQuery網頁互動實作
#
#
# Course duration: 36小時
# Course cost: NT$ 18,000
# Target audience: 希望提升網頁互動能力，或縮短開發時程者適合網頁設計師或網站程式開發人員
# DocumentBOX Outline: CSS樣式基礎知識與設定JavaScript基礎知識與語法jQuery基礎知識jQuery動態效果，與動畫設定jQuery選取器，包含階層、內容、屬性、表單等各式選取方式jQuery樣式套用，可取得物件樣式屬性與動態設定樣式jQuery綁定事件，如滑鼠、鍵盤、系統等jQuery控制DOM物件jQuery操控AJAXjQuery UI的介紹與安裝設定輕易完成分頁標籤(Tabs)手風琴選單(Accordion)的製作可移動與縮放對話盒(Dialog)的設計藉由刻度滑桿(Slider)的介面輸入數值便利的日期選擇器(Datepicker)
# Title of the webpage:
#
#     HTML與CSS網頁編輯製作
#
#
# Course duration: 30小時
# Course cost: NT$ 15,000
# Target audience: 欲學習專業網站建置基礎與編輯應用者
# DocumentBOX Outline: 安裝與使用程式碼編輯器Visual Studio CodeHTML與網頁內容架構CSS基礎與網頁編排CSS與版面DIV編排CSS版面編排應用輕鬆搞懂HTML5與CSS3
# Title of the webpage:
#
#     WordPress快速上手網站實作
#
#
# Course duration: 18小時
# Course cost: NT$ 9,000
# Target audience: 需有HTML與CSS基礎
# DocumentBOX Outline: 在本機安裝 WordPress 網站1.1 使用 XAMPP 在本機安裝 WordPress 網站1.2  安裝Wordpress開始使用WordPress編輯頁面2.1 網站後臺管理介面2.2 新增文章2.3 新增頁面2.4 設定導覽列與首頁WordPress 佈景主題安裝與編輯3.1  安裝新的wordpress3.2  安裝佈景主題3.3  安裝 Elementor 免費版3.4  Elementor編輯頁面一頁式網站佈景主題實作4.1  安裝Wordpress與佈景主題4.2  更改與設定頁首4.3  編輯頁面4.4 設定EMAIL收發信形象網站佈景主題實作5.1  安裝Astra佈景主題5.2  調整網站設定5.3  修改頁面商品網站佈景主題實作6.1  安裝佈景主題Blocksy6.2  新增文章與頁面6.3  修改模板網站6.4  修改商品與文章6.5  修改頁尾6.6  設定購物相關功能6.7  設定會員帳號功能6.8  製作優惠劵附錄 / 網站上傳至 WEB 伺服器（網站空間）7.1  申請免費個人網站空間7.2  安裝網站空間端的wordpress7.3  匯出本機網站程式
# Title of the webpage:
#
#     區塊鏈與智慧合約實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 1.想了解區塊鏈與智慧合約的工程師與專案經理2.想了解智慧合約的實作者
# DocumentBOX Outline: 1.BlockChain歷史與簡介●加解密演算法●Hash Tree/Merkle Tree雜湊樹●非對稱加解密2.BlockChain生態系簡介3.智慧合約與Solidity簡介●Solidity與Solidity相關檔案●Pragma、註解與Mport●合約本體●state變數、struct與修飾子●事件、列舉與函數●資料型態●參照型態●陣列與對應4.Solidity語法●函數與修飾子●View、常數與Pure Function●Address Function●Fallback Function●例外處理、事件和Summary5.Ethereum●EVM(Ethereum Virtual Machine)●Ethereum(Smart Contract)●Truffle框架的設定與使用6.合約的偵錯7.合約的升級
# Title of the webpage:
#
#     區塊鏈與DApp去中心化應用程式Full Stack全棧開發實戰演練
#
#
# Course duration: 35小時
# Course cost: NT$ 24,000
# Target audience: 想要開發區塊鏈應用程式的工程師想學習Ethereum區塊鏈實作的工程師想要了解區塊鏈的軟體架構師
# DocumentBOX Outline: 1.Ethereum網路架構●Blockchain的基本架構●Blockchain的演化●Ether、GAS和EVM2.使用wallet錢包和區塊鏈網路溝通●網頁錢包的安裝●連線與使用3.web3.js●帳戶列表和餘額API使用●交易與合約API呼叫●交易物件傳送●事件與日誌●過濾監控API4.Truffle Framework與Solidity智慧合約5.智慧合約設計樣式6.前端分散式應用程式的考量7.ERC20自訂代幣8.Truffle與React/Redux●建立前端應用程式專案●部署合約●使用React進行前端開發Truffle與VUETruffle與drizzleNFT (Non fungible token)
# Title of the webpage:
#
#     IIB Council區塊鏈專家認證課程
#
#
# Course duration: 40小時
# Course cost: NT$ 56,000
# Target audience: 商業技術主管政府技術幕僚全端工程師(Full Stack Developer)
# DocumentBOX Outline: 掌握區塊鏈技術的理論和技術基礎了解去中心化(decentralization)的概念，其影響以及與區塊鏈技術的關係了解區塊鏈開發和實現的基本技術原則了解比特幣和其他加密貨幣背後的區塊鏈技術運作機制透過實際範例了解加密技術如何用於數據保護了解智能合約(smart contracts)的理論基礎，以及如何使用Solidity和相關開發框架，在以太坊(Ethereum)區塊鏈上開發去中心化的應用程式(DAapp)研究替代區塊鏈解決方案，包括超級帳本(Hyperledger)、Corda等了解各行各業中區塊鏈應用的使用案例探索區塊鏈實現和商業化策略了解當前業務架構中區塊鏈整合的最佳實務確定可能的區塊鏈實現對法律方面的影響預測應用策略採行可能帶來的風險和失敗，並學習採用有效的變更管理和專案管理方法加以避免探索區塊鏈技術的新研究課題和未來應用範圍
# Title of the webpage:
#
#     Google Cloud基礎知識之核心基礎架構
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 計劃在Google Cloud Platform上部署應用程式和建立應用程式環境的使用者初接觸Google Cloud Platform的開發人員、系統維運專家和解決方案架構師管理或企業決策者等，想評估Google Cloud Platform滿足其各項商業需求的潛力
# DocumentBOX Outline: 介紹Google Cloud Platform●  Google Cloud Platform的優勢●  定義Google網路基礎架構的組成，包括：服務據點、資料中心、地區和區域●  了解基礎架構即服務(IaaS)和平台即服務(PaaS)之間的區別GCP的資源與操作●  定義GCP專案的目的●  了解身分識別和存取權管理的目的和使用案例●  列舉操作GCP的方法雲端的VM虛擬機器和網路●  Google Compute Engine的用途和使用案例●  定義基本的GCP網路雲端的儲存服務●  介紹Google Cloud Storage、Google Cloud SQL、Google Cloud Bigtable和Google Cloud Datastore用途和使用案例●  於GCP上挑選合適的儲存產品雲端的容器服務(Containers)●  定義容器的概念並了解容器的用途●  Google Kubernetes Engine和Kubernetes的用途和使用案例雲端的App應用程式●  了解Google App Engine的用途和使用案例●  對比App Engine標準與彈性環境●  了解Google Cloud Endpoints的用途和使用案例：後端架構上開發、部署及管理雲端的開發、部署●  雲端原始碼託管儲存體與Cloud Function●  利用範本建立和管理資源雲端的日誌與監控●  定義SLIs、SLOs、SLAs●  各項整合管理工具：監控、警示與除錯
# Title of the webpage:
#
#     Google Cloud的安全性設定
#
#
# Course duration: 24小時
# Course cost: NT$ 42,000
# Target audience: 雲端資訊安全分析師雲端資訊安全架構師雲端資訊安全工程師資訊安全專家雲端基礎架構工程師
# DocumentBOX Outline: 課程介紹Google Cloud安全的基礎介紹安全地存取Google Cloud身份辨識與存取管理設定虛擬私有雲以做到隔離與安全強化Compute Engine安全強化Cloud Data安全應用程式的安全性強化Google Kubernetes Engine安全保護對抗分散式阻斷服務攻擊(DDos)內容相關的漏洞記錄、監控、稽核與掃描
# Title of the webpage:
#
#     使用Google Compute Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端解決方案架構師、DevOps工程師使用Google Cloud Platform建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud Platform整合的工程人員
# DocumentBOX Outline: 操作Google Cloud●  Google Cloud Platform基礎架構●  使用Google Cloud●  Demo：專案Projects虛擬網路(Virtual Networks)●  雲端上的VPC、專案、網路、子網路、IP地址、路由、防火牆規則●  以子網路概念管理資源取代實體網路拓撲虛擬機器●  Compute Engine介紹●  CPU/ Memory等多種運算選擇●  Images系統映像檔●  常用的Compute Engine操作程序身分驗證與存取權管理服務●  Cloud IAM最佳實踐於管理組織、角色、成員與Service accounts儲存與資料庫服務●  Cloud Storage●  Cloud SQL●  Cloud Spanner、Cloud Datastore●  Cloud Bigtable資源管理●  資源管理工具：資源配額、標籤、名稱與計費管理●  Demo：Billing Administration資源監控●  Google Cloud Operation Suite與監控●  日誌分析、錯誤報告、追蹤效能瓶頸與除錯互聯網路●  Cloud Virtual Private Network(VPN)●  雲端路由器、企業專線連線、外部對等連線、雲端網域名稱系統(DNS)服務負載平衡與自動彈性擴展●  各項負載平衡代管服務：HTTPS load balancing、Cross-region and contentbased load balancing、SSL proxy/TCP proxy load balancing、Network load balancing●  自動縮放、規則與配置基礎架構自動化●  Terraform、Images, Metadata、Scripts、Google Cloud API●  Google Cloud Marketplace託管服務●  Cloud Dataproc、Cloud Dataflow、BigQuery、Cloud Datalab
# Title of the webpage:
#
#     使用Google Kubernetes Engine進行架構設計
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 雲端架構師雲端管理師SysOps與DevOps人員想要使用Google Cloud建立雲原生應用程式程式開發人員想要將本地部署的現存應用程式與Google Cloud整合的程式開發人員
# DocumentBOX Outline: Google Cloud介紹Container與Kubernetes介紹Kubernetes的架構Kubernetes的操作部署、排程與擴縮Google Kubernetes Engine(GKE)的網路架構資料持久化與儲存Kubernetes與GKE的存取控制與安全機制Google Kubernetes Engine(GKE)日誌與監控GKE使用Google Cloud管理的儲存服務使用CI/CD部署Kubernetes工作負擔
# Title of the webpage:
#
#     使用Google Cloud進行架構設計：設計與過程
#
#
# Course duration: 14小時
# Course cost: NT$ 28,000
# Target audience: 雲端解決方案架構師、站點可靠性工程師、系統操作專業人員、DevOps工程師、IT經理使用Google Cloud建立新解決方案或將現有系統、應用程式環境和基礎架構與Google Cloud整合的個人
# DocumentBOX Outline: 定義服務●  根據角色和角色描述用戶●  使用用戶故事編寫定性需求●  使用關鍵績效指標編寫量化需求(KPI)●  使用SLO和SLI評估KPI●  使用SMART標準確定應用程式品質的需求微服務設計與架構●  將單體應用程式分解為微服務●  識別適當的微服務邊界●  構建有狀態和無狀態服務以最佳化可擴展性和可靠性●  使用12要素最佳實務建置服務●  通過建置精心設計的服務來構建鬆散耦合的服務REST架構●  設計一致、標準的RESTful服務APIDevOps自動化●  使用CI/CD pipeline自動化服務部署●  利用Cloud Source Repositories獲取源碼和版本控制●  使用Cloud Build和構建觸發器自動構建程式碼●  使用Google Container Registry管理容器映像●  使用Deployment Manager和Terraform建立以程式碼建構基礎架構選擇儲存與資料的解決方案●  依據案例、耐用性、可用性、可擴展性和成本選擇合適的Google Cloud資料儲存服務●  使用Cloud Storage儲存二進制資料●  使用Cloud SQL和Spanner儲存關聯式資料●  使用Firestore和Cloud Bigtable儲存NoSQL資料●  使用Memorystore快取資料以加速存取●  使用BigQuery構建資料倉儲Google Cloud和混合環境的網路架構●  設計VPC網路以最佳化成本、安全性和效能●  設置全域和區域負載平衡器以提供存取服務●  利用Cloud CDN提供更低的延遲並減少網路連出●  使用Cloud Network Intelligence Center評估網路架構●  使用對等互連(peering)和VPN連接網路●  使用Cloud Interconnect在Google Cloud和本地資料中心之間建立混合網路將應用程式部署到Google Cloud●  為應用程式選擇適合的Google Cloud部署服務●  使用Instance Template and Group設置可擴展、有彈性的基礎架構●  使用Kubernetes和GKE編排微服務部署●  利用App Engine做為一個完全自動化的平台即服務(PaaS)●  使用Cloud Functions建立無伺服器的應用程式設計可靠的系統●  設計服務以滿足可用性、耐用性和可擴展性●  通過避免單點故障來實現系統故障、相關故障和級聯故障的容錯●  使用斷路器和指數輪詢設計模式避免過載故障●  使用懶惰刪除來設計具有彈性的資料儲存●  使用成本/風險分析，分析災難場景並制定災難回復計劃安全性●  使用最佳實務設計安全系統，例如分離關注點、最小特權原則和定期稽核●  利用Cloud Security Command Center幫助識別漏洞●  使用組織策略和資料夾以簡化雲端治理●  使用IAM角色、Identity-Aware Proxy和Identity Platform●  管理機器和處理程序使用服務帳戶對資源的存取和授權●  使用私有IP、防火牆和私有Google Access加強網路安全●  利用Cloud DNS和Cloud Armor減少DDoS攻擊維護和監控●  使用滾動更新管理新服務版本，藍/綠部署和金絲雀版本●  使用Google Cloud定價計算器、計費報告分析和計費資料預測、監控和最佳化服務成本●  使用Cloud Monitoring and Dashboard觀察您的服務是否滿足其SLO●  使用Uptime Check來確定服務可用性●  使用Cloud Monitoring Alert回應服務中斷
# Title of the webpage:
#
#     使用Google Cloud進行AI與機器學習的基礎介紹
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 雲端基礎架構工程師雲端程式設計師資料科學家機器學習工程師人工智慧程式設計師機器學習、AI產品經理
# DocumentBOX Outline: Module 0：課程介紹Module 1：介紹AI基礎知識Module 2：開發AI的選項Module 3：開發AI的工作流程Module 4：生成式AI
# Title of the webpage:
#
#     實際應用Vertex於預測與時間序列
#
#
# Course duration: 7小時
# Course cost: NT$ 14,000
# Target audience: 資料分析師資料科學家機器學習工程師
# DocumentBOX Outline: 課程介紹時間序列與預測的基礎知識Google Cloud的預測選項資料準備模型訓練模型評估模型監控使用Vertex AI以零售資料集建立預測模型課程總結
# Title of the webpage:
#
#     使用Google Cloud進行機器學習
#
#
# Course duration: 35小時
# Course cost: NT$ 70,000
# Target audience: 資料工程師資料科學家大資料工程師AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹如何使用Google Cloud進行AI與機器學習●  AI基礎●  AI開發選項●  AI開發流程●  生成式AI開始機器學習●  了解資料
# ●  實作機器學習
# ●  使用Vertex AI訓練AutoML模型在Google Cloud使用TensorFlow●  介紹TensorFlow生態系●  設計與建立輸入資料管線●  使用TensorFlow與Keras API建立神經網路●  使用Vertex AI訓練大規模資料特徵工程●  特徵工程介紹●  如何將原始資料轉化為特徵●  進行特徵工程●  Vertex AI Feature Store介紹在企業內實施機器學習●  了解企業裡的機器學習流程●  企業裡的資料●  機器學習的科學與客製化訓練●  使用Vertex Vizier進行超參數優化●  使用Vertex AI進行預測與監控模型●  Vertex AI管線●  使用Vertex AI開發機器學習的最佳實踐課程總結
# Title of the webpage:
#
#     使用Google Cloud建置現代化的資料湖與資料倉儲
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師資料倉儲工程師
# DocumentBOX Outline: 介紹資料工程建立資料湖建立資料倉儲
# Title of the webpage:
#
#     使用Google Cloud建置批次資料管道
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹批次操作的資料管線使用Dataproc執行Spark使用Dataflow進行無伺服器的資料處理使用Cloud Data Fusion與Cloud Composer管理資料管道
# Title of the webpage:
#
#     使用Google Cloud建置具彈性的串流分析系統
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料工程師大資料工程師
# DocumentBOX Outline: 課程介紹介紹串流資料的處理使用Pub/Sub進行無伺服器的訊息傳遞Dataflow Streaming的功能高通量的BigQuery與BigTable Streaming的功能進階的BigQuery功能與效能優化
# Title of the webpage:
#
#     使用Google Cloud進行精巧分析、機器學習、AI
#
#
# Course duration: 8小時
# Course cost: NT$ 14,000
# Target audience: 資料科學家AI工程師機器學習工程師
# DocumentBOX Outline: 課程介紹介紹何謂資料分析與AI對非結構化資料使用預訓練的機器學習模型API使用Notebook進行大資料分析正式環境下的機器學習管線使用SQL在BigQuery ML建立客製模型使用Vertex AI AutoML建立客製模型
# Title of the webpage:
#
#     使用Google Cloud開發應用程式
#
#
# Course duration: 21小時
# Course cost: NT$ 42,000
# Target audience: 想要了解如何使用Google Cloud開發應用程式的人員
# DocumentBOX Outline: 應用程式開發的最佳實踐開始使用Google Cloud進行開發資料儲存選項的簡介使用Cloud Datastore的最佳實踐操作Cloud Storage使用Cloud Storage的最佳實踐處理身份驗證與授權使用Pub/Sub整合您的應用程式組件為您的應用程式增加智能功能使用Cloud Function進行事件驅動處理使用Cloud Endpoints管理APIs部署應用程式應用程式的運算選項除錯、監控與效能調優結論與反饋
# Data saved to courses_details_Cloud.xlsx
